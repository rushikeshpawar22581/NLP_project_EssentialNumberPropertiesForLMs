# %% [markdown]
# # get min max of list from gemini

# %% [markdown]
# Install necessary packages

# %%
# !pip install -q -U google-generativeai
# !pip install python-dotenv

# %%
import os
from dotenv import load_dotenv
import random
import time
import json
import google.generativeai as genai

# %% [markdown]
# ### load model

# %%
load_dotenv()
GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
gemini = genai.GenerativeModel('gemini-pro')

# %% [markdown]
# ## For finding min

# %% [markdown]
# ### load data and create initial prompt

# %%
with open('../../data/lists.json','r') as file:
    data = json.load(file)

# create batches, batch sizes are heuristics and I tried out several
# batch sizes, although input token limit is 30,720 tokens, output token limit is 2048
# which restricts the batch size
size_dict = {'lists_size_3_pos':50,
             'lists_size_3_neg':50,
             'lists_size_5_pos':40,
             'lists_size_5_neg':40,
             'lists_size_10_pos':25,
             'lists_size_10_neg':25}

batch_prompts = []

for list in data:
    list_ = data[list]

    # get batch size for the list
    BATCH_SIZE = size_dict[list]

    index = 0
    while index < len(list_):
        batch = []
        while index < len(list_):
            batch_prompt = [f"Find the minimum number in the list {list_[i]}." for i in range(index, min(index+BATCH_SIZE, len(list_)))]
            batch_prompts.append(batch_prompt)
            index += BATCH_SIZE


print("Number of batches:", len(batch_prompts))
print("Number of prompts in each batch:", [len(batch) for batch in batch_prompts])
# Out:
# Number of batches: 86
# Number of prompts in each batch: [50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 20, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 20, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25]

# %%
# give a prompt once and then generate the response,
# and then use this prompt+response directly instead of doing everytime

promt_saying_you_are_a_math_assistant = '''You are a math assistant. I will ask you to find the minimum number in a list. Please answer in the correct format. For example, if I ask 'Find the minimum number in the list [1, 2, 3]', you should answer 'Min([1, 2, 3]) = 1'. Each question is in a separate line. Please return each answer in a separate line. Do you understand ?'''
Initial_messages = [{'role':'user', 'parts': [promt_saying_you_are_a_math_assistant] }]

# get response from the model and then append it to the prompt
Initial_response = gemini.generate_content(Initial_messages)                                   
Initial_messages.append(Initial_response.candidates[0].content)

# %%
print(Initial_messages)
# Out:
# [{'role': 'user', 'parts': ["You are a math assistant. I will ask you to find the minimum number in a list. Please answer in the correct format. For example, if I ask 'Find the minimum number in the list [1, 2, 3]', you should answer 'Min([1, 2, 3]) = 1'. Each question is in a separate line. Please return each answer in a separate line. Do you understand ?"]}, parts {
#   text: "Yes, I understand. I will find the minimum number in the given list and return the answer in the format \'Min([list]) = [minimum number]\'."
# }
# role: "model"
# ]

# %%
import pickle

# save the initial messages to a file, in case we need to restart the conversation, initial message should be consistent
# across all batches

with open('initial_messages_min.pkl', 'wb') as file:
    pickle.dump(Initial_messages, file)

# %% [markdown]
# ### conduct experiment for min

# %%
# path to save responses
response_file = 'gemini_response/list_min_responses.txt'

# request per minute limit for free api
rpm = 60

# %%
for i, batch_prompt in enumerate(batch_prompts):

    # to start from a specific batch number, give printed_batch_num -1 here
    batch_no_to_start_from = 0 
    if i < batch_no_to_start_from:
        continue

    # print status
    print(f"Sending batch {i+1} of {len(batch_prompts)}")

    num_prompts = len(batch_prompt)

    # create prompt for the batch
    curr_prompt = "".join([f"{prompt} \n " for prompt in batch_prompt])

    
    # create a complete prompt to send to the model
    complete_promt = Initial_messages.copy()
    complete_promt.append({'role':'user', 'parts': [curr_prompt]})

    # get response from the model, candidate_count is 1 because we only need one response,
    # temperature is 0 because we need deterministic responses
    response = gemini.generate_content( complete_promt,
                                        generation_config= genai.GenerationConfig(
                                        candidate_count = 1,
                                        temperature = 0.0,
                                        )
                                )
    
    try:
        # extract text from the response
        model_responses = response.candidates[0].content.parts.__getitem__(0).text.split('\n')
    except IndexError:
        # if model gives no response, fill with 0
        print("Error in response")
        model_responses = ["0"]*num_prompts

    # save responses to file
    with open(response_file, 'a') as file:
        for model_response in model_responses:
            file.write(model_response + '\n')

    
    #print the prompt and response separated by space
    print('# of prompts: ',len(batch_prompt),'# of responses: ', len(model_responses))


    for prompt, response in zip(batch_prompt, model_responses):
        print(prompt, response, sep=" ->")
    
    
    print("Received responses for batch", i+1, "of", len(batch_prompts))
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")

    time.sleep(60//rpm) #to avoid rate limit errors

print("Responses saved to", response_file)
# Out:
# Sending batch 1 of 86
# # of prompts:  50 # of responses:  50
# Find the minimum number in the list [1, 0, 4]. ->Min([1, 0, 4]) = 0
# Find the minimum number in the list [6, 0, 0]. ->Min([6, 0, 0]) = 0
# Find the minimum number in the list [3, 8, 6]. ->Min([3, 8, 6]) = 3
# Find the minimum number in the list [5, 4, 2]. ->Min([5, 4, 2]) = 2
# Find the minimum number in the list [5, 9, 4]. ->Min([5, 9, 4]) = 4
# Find the minimum number in the list [4, 9, 5]. ->Min([4, 9, 5]) = 4
# Find the minimum number in the list [3, 1, 6]. ->Min([3, 1, 6]) = 1
# Find the minimum number in the list [4, 1, 9]. ->Min([4, 1, 9]) = 1
# Find the minimum number in the list [8, 3, 5]. ->Min([8, 3, 5]) = 3
# Find the minimum number in the list [3, 9, 5]. ->Min([3, 9, 5]) = 3
# Find the minimum number in the list [3, 8, 8]. ->Min([3, 8, 8]) = 3
# Find the minimum number in the list [2, 8, 7]. ->Min([2, 8, 7]) = 2
# Find the minimum number in the list [1, 6, 6]. ->Min([1, 6, 6]) = 1
# Find the minimum number in the list [8, 4, 5]. ->Min([8, 4, 5]) = 4
# Find the minimum number in the list [8, 2, 8]. ->Min([8, 2, 8]) = 2
# Find the minimum number in the list [2, 8, 8]. ->Min([2, 8, 8]) = 2
# Find the minimum number in the list [4, 3, 0]. ->Min([4, 3, 0]) = 0
# Find the minimum number in the list [2, 2, 7]. ->Min([2, 2, 7]) = 2
# Find the minimum number in the list [8, 3, 4]. ->Min([8, 3, 4]) = 3
# Find the minimum number in the list [3, 1, 5]. ->Min([3, 1, 5]) = 1
# Find the minimum number in the list [1, 0, 3]. ->Min([1, 0, 3]) = 0
# Find the minimum number in the list [7, 3, 8]. ->Min([7, 3, 8]) = 3
# Find the minimum number in the list [3, 1, 1]. ->Min([3, 1, 1]) = 1
# Find the minimum number in the list [0, 6, 5]. ->Min([0, 6, 5]) = 0
# Find the minimum number in the list [6, 2, 4]. ->Min([6, 2, 4]) = 2
# Find the minimum number in the list [8, 0, 1]. ->Min([8, 0, 1]) = 0
# Find the minimum number in the list [0, 2, 6]. ->Min([0, 2, 6]) = 0
# Find the minimum number in the list [7, 2, 3]. ->Min([7, 2, 3]) = 2
# Find the minimum number in the list [0, 0, 9]. ->Min([0, 0, 9]) = 0
# Find the minimum number in the list [2, 1, 9]. ->Min([2, 1, 9]) = 1
# Find the minimum number in the list [9, 0, 9]. ->Min([9, 0, 9]) = 0
# Find the minimum number in the list [3, 5, 3]. ->Min([3, 5, 3]) = 3
# Find the minimum number in the list [0, 7, 9]. ->Min([0, 7, 9]) = 0
# Find the minimum number in the list [2, 5, 1]. ->Min([2, 5, 1]) = 1
# Find the minimum number in the list [9, 8, 0]. ->Min([9, 8, 0]) = 0
# Find the minimum number in the list [8, 2, 4]. ->Min([8, 2, 4]) = 2
# Find the minimum number in the list [7, 4, 0]. ->Min([7, 4, 0]) = 0
# Find the minimum number in the list [4, 2, 7]. ->Min([4, 2, 7]) = 2
# Find the minimum number in the list [8, 0, 5]. ->Min([8, 0, 5]) = 0
# Find the minimum number in the list [5, 0, 5]. ->Min([5, 0, 5]) = 0
# Find the minimum number in the list [2, 3, 2]. ->Min([2, 3, 2]) = 2
# Find the minimum number in the list [4, 2, 1]. ->Min([4, 2, 1]) = 1
# Find the minimum number in the list [4, 3, 3]. ->Min([4, 3, 3]) = 3
# Find the minimum number in the list [5, 8, 6]. ->Min([5, 8, 6]) = 5
# Find the minimum number in the list [4, 0, 1]. ->Min([4, 0, 1]) = 0
# Find the minimum number in the list [1, 6, 9]. ->Min([1, 6, 9]) = 1
# Find the minimum number in the list [3, 5, 6]. ->Min([3, 5, 6]) = 3
# Find the minimum number in the list [4, 6, 5]. ->Min([4, 6, 5]) = 4
# Find the minimum number in the list [2, 9, 9]. ->Min([2, 9, 9]) = 2
# Find the minimum number in the list [6, 9, 9]. ->Min([6, 9, 9]) = 6
# Received responses for batch 1 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 2 of 86
# # of prompts:  50 # of responses:  50
# Find the minimum number in the list [2, 1, 4]. ->Min([2, 1, 4]) = 1
# Find the minimum number in the list [3, 2, 0]. ->Min([3, 2, 0]) = 0
# Find the minimum number in the list [9, 3, 6]. ->Min([9, 3, 6]) = 3
# Find the minimum number in the list [3, 2, 8]. ->Min([3, 2, 8]) = 2
# Find the minimum number in the list [7, 8, 8]. ->Min([7, 8, 8]) = 7
# Find the minimum number in the list [7, 2, 7]. ->Min([7, 2, 7]) = 2
# Find the minimum number in the list [4, 7, 1]. ->Min([4, 7, 1]) = 1
# Find the minimum number in the list [2, 2, 3]. ->Min([2, 2, 3]) = 2
# Find the minimum number in the list [8, 7, 6]. ->Min([8, 7, 6]) = 6
# Find the minimum number in the list [6, 7, 0]. ->Min([6, 7, 0]) = 0
# Find the minimum number in the list [3, 7, 3]. ->Min([3, 7, 3]) = 3
# Find the minimum number in the list [2, 7, 2]. ->Min([2, 7, 2]) = 2
# Find the minimum number in the list [1, 6, 2]. ->Min([1, 6, 2]) = 1
# Find the minimum number in the list [7, 5, 5]. ->Min([7, 5, 5]) = 5
# Find the minimum number in the list [8, 0, 5]. ->Min([8, 0, 5]) = 0
# Find the minimum number in the list [9, 2, 3]. ->Min([9, 2, 3]) = 2
# Find the minimum number in the list [5, 2, 9]. ->Min([5, 2, 9]) = 2
# Find the minimum number in the list [4, 9, 6]. ->Min([4, 9, 6]) = 4
# Find the minimum number in the list [9, 1, 9]. ->Min([9, 1, 9]) = 1
# Find the minimum number in the list [5, 0, 6]. ->Min([5, 0, 6]) = 0
# Find the minimum number in the list [2, 8, 4]. ->Min([2, 8, 4]) = 2
# Find the minimum number in the list [5, 3, 1]. ->Min([5, 3, 1]) = 1
# Find the minimum number in the list [5, 0, 7]. ->Min([5, 0, 7]) = 0
# Find the minimum number in the list [4, 9, 4]. ->Min([4, 9, 4]) = 4
# Find the minimum number in the list [7, 8, 3]. ->Min([7, 8, 3]) = 3
# Find the minimum number in the list [6, 3, 4]. ->Min([6, 3, 4]) = 3
# Find the minimum number in the list [8, 5, 5]. ->Min([8, 5, 5]) = 5
# Find the minimum number in the list [5, 1, 8]. ->Min([5, 1, 8]) = 1
# Find the minimum number in the list [9, 4, 1]. ->Min([9, 4, 1]) = 1
# Find the minimum number in the list [8, 2, 4]. ->Min([8, 2, 4]) = 2
# Find the minimum number in the list [0, 9, 4]. ->Min([0, 9, 4]) = 0
# Find the minimum number in the list [7, 1, 1]. ->Min([7, 1, 1]) = 1
# Find the minimum number in the list [9, 4, 1]. ->Min([9, 4, 1]) = 1
# Find the minimum number in the list [3, 8, 6]. ->Min([3, 8, 6]) = 3
# Find the minimum number in the list [9, 0, 9]. ->Min([9, 0, 9]) = 0
# Find the minimum number in the list [2, 8, 1]. ->Min([2, 8, 1]) = 1
# Find the minimum number in the list [0, 3, 4]. ->Min([0, 3, 4]) = 0
# Find the minimum number in the list [6, 1, 8]. ->Min([6, 1, 8]) = 1
# Find the minimum number in the list [4, 9, 9]. ->Min([4, 9, 9]) = 4
# Find the minimum number in the list [8, 8, 7]. ->Min([8, 8, 7]) = 7
# Find the minimum number in the list [4, 0, 1]. ->Min([4, 0, 1]) = 0
# Find the minimum number in the list [2, 7, 8]. ->Min([2, 7, 8]) = 2
# Find the minimum number in the list [7, 5, 6]. ->Min([7, 5, 6]) = 5
# Find the minimum number in the list [4, 6, 8]. ->Min([4, 6, 8]) = 4
# Find the minimum number in the list [6, 8, 0]. ->Min([6, 8, 0]) = 0
# Find the minimum number in the list [9, 7, 7]. ->Min([9, 7, 7]) = 7
# Find the minimum number in the list [7, 1, 0]. ->Min([7, 1, 0]) = 0
# Find the minimum number in the list [6, 1, 3]. ->Min([6, 1, 3]) = 1
# Find the minimum number in the list [4, 6, 7]. ->Min([4, 6, 7]) = 4
# Find the minimum number in the list [9, 8, 2]. ->Min([9, 8, 2]) = 2
# Received responses for batch 2 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 3 of 86
# # of prompts:  50 # of responses:  50
# Find the minimum number in the list [36, 92, 38]. ->Min([36, 92, 38]) = 36
# Find the minimum number in the list [61, 44, 42]. ->Min([61, 44, 42]) = 42
# Find the minimum number in the list [89, 30, 73]. ->Min([89, 30, 73]) = 30
# Find the minimum number in the list [60, 90, 48]. ->Min([60, 90, 48]) = 48
# Find the minimum number in the list [64, 75, 42]. ->Min([64, 75, 42]) = 42
# Find the minimum number in the list [18, 52, 83]. ->Min([18, 52, 83]) = 18
# Find the minimum number in the list [50, 83, 10]. ->Min([50, 83, 10]) = 10
# Find the minimum number in the list [97, 62, 69]. ->Min([97, 62, 69]) = 62
# Find the minimum number in the list [29, 95, 11]. ->Min([29, 95, 11]) = 11
# Find the minimum number in the list [21, 88, 38]. ->Min([21, 88, 38]) = 21
# Find the minimum number in the list [55, 18, 31]. ->Min([55, 18, 31]) = 18
# Find the minimum number in the list [10, 78, 48]. ->Min([10, 78, 48]) = 10
# Find the minimum number in the list [59, 81, 32]. ->Min([59, 81, 32]) = 32
# Find the minimum number in the list [69, 20, 9]. ->Min([69, 20, 9]) = 9
# Find the minimum number in the list [32, 58, 38]. ->Min([32, 58, 38]) = 32
# Find the minimum number in the list [45, 73, 37]. ->Min([45, 73, 37]) = 37
# Find the minimum number in the list [72, 87, 99]. ->Min([72, 87, 99]) = 72
# Find the minimum number in the list [29, 77, 45]. ->Min([29, 77, 45]) = 29
# Find the minimum number in the list [92, 98, 84]. ->Min([92, 98, 84]) = 84
# Find the minimum number in the list [39, 56, 4]. ->Min([39, 56, 4]) = 4
# Find the minimum number in the list [95, 53, 22]. ->Min([95, 53, 22]) = 22
# Find the minimum number in the list [21, 32, 61]. ->Min([21, 32, 61]) = 21
# Find the minimum number in the list [96, 28, 86]. ->Min([96, 28, 86]) = 28
# Find the minimum number in the list [1, 33, 68]. ->Min([1, 33, 68]) = 1
# Find the minimum number in the list [74, 48, 81]. ->Min([74, 48, 81]) = 48
# Find the minimum number in the list [71, 41, 78]. ->Min([71, 41, 78]) = 41
# Find the minimum number in the list [83, 52, 14]. ->Min([83, 52, 14]) = 14
# Find the minimum number in the list [30, 68, 17]. ->Min([30, 68, 17]) = 17
# Find the minimum number in the list [53, 75, 95]. ->Min([53, 75, 95]) = 53
# Find the minimum number in the list [52, 35, 4]. ->Min([52, 35, 4]) = 4
# Find the minimum number in the list [12, 87, 47]. ->Min([12, 87, 47]) = 12
# Find the minimum number in the list [15, 58, 11]. ->Min([15, 58, 11]) = 11
# Find the minimum number in the list [42, 31, 16]. ->Min([42, 31, 16]) = 16
# Find the minimum number in the list [27, 29, 42]. ->Min([27, 29, 42]) = 27
# Find the minimum number in the list [69, 32, 22]. ->Min([69, 32, 22]) = 22
# Find the minimum number in the list [75, 41, 2]. ->Min([75, 41, 2]) = 2
# Find the minimum number in the list [14, 95, 8]. ->Min([14, 95, 8]) = 8
# Find the minimum number in the list [57, 64, 28]. ->Min([57, 64, 28]) = 28
# Find the minimum number in the list [82, 3, 7]. ->Min([82, 3, 7]) = 3
# Find the minimum number in the list [56, 9, 10]. ->Min([56, 9, 10]) = 9
# Find the minimum number in the list [81, 74, 70]. ->Min([81, 74, 70]) = 70
# Find the minimum number in the list [64, 77, 55]. ->Min([64, 77, 55]) = 55
# Find the minimum number in the list [92, 27, 55]. ->Min([92, 27, 55]) = 27
# Find the minimum number in the list [93, 12, 40]. ->Min([93, 12, 40]) = 12
# Find the minimum number in the list [60, 8, 11]. ->Min([60, 8, 11]) = 8
# Find the minimum number in the list [16, 71, 7]. ->Min([16, 71, 7]) = 7
# Find the minimum number in the list [45, 85, 96]. ->Min([45, 85, 96]) = 45
# Find the minimum number in the list [13, 73, 64]. ->Min([13, 73, 64]) = 13
# Find the minimum number in the list [71, 47, 14]. ->Min([71, 47, 14]) = 14
# Find the minimum number in the list [79, 78, 86]. ->Min([79, 78, 86]) = 78
# Received responses for batch 3 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 4 of 86
# # of prompts:  50 # of responses:  50
# Find the minimum number in the list [3, 23, 34]. ->Min([3, 23, 34]) = 3
# Find the minimum number in the list [18, 72, 84]. ->Min([18, 72, 84]) = 18
# Find the minimum number in the list [95, 67, 27]. ->Min([95, 67, 27]) = 27
# Find the minimum number in the list [92, 41, 99]. ->Min([92, 41, 99]) = 41
# Find the minimum number in the list [79, 6, 86]. ->Min([79, 6, 86]) = 6
# Find the minimum number in the list [56, 53, 34]. ->Min([56, 53, 34]) = 34
# Find the minimum number in the list [36, 86, 86]. ->Min([36, 86, 86]) = 36
# Find the minimum number in the list [50, 76, 7]. ->Min([50, 76, 7]) = 7
# Find the minimum number in the list [32, 37, 41]. ->Min([32, 37, 41]) = 32
# Find the minimum number in the list [48, 68, 90]. ->Min([48, 68, 90]) = 48
# Find the minimum number in the list [94, 5, 55]. ->Min([94, 5, 55]) = 5
# Find the minimum number in the list [51, 90, 81]. ->Min([51, 90, 81]) = 51
# Find the minimum number in the list [79, 58, 88]. ->Min([79, 58, 88]) = 58
# Find the minimum number in the list [51, 67, 10]. ->Min([51, 67, 10]) = 10
# Find the minimum number in the list [21, 9, 65]. ->Min([21, 9, 65]) = 9
# Find the minimum number in the list [44, 93, 82]. ->Min([44, 93, 82]) = 44
# Find the minimum number in the list [77, 19, 97]. ->Min([77, 19, 97]) = 19
# Find the minimum number in the list [59, 96, 72]. ->Min([59, 96, 72]) = 59
# Find the minimum number in the list [79, 41, 80]. ->Min([79, 41, 80]) = 41
# Find the minimum number in the list [38, 35, 75]. ->Min([38, 35, 75]) = 35
# Find the minimum number in the list [4, 7, 47]. ->Min([4, 7, 47]) = 4
# Find the minimum number in the list [49, 59, 74]. ->Min([49, 59, 74]) = 49
# Find the minimum number in the list [41, 77, 60]. ->Min([41, 77, 60]) = 41
# Find the minimum number in the list [10, 64, 82]. ->Min([10, 64, 82]) = 10
# Find the minimum number in the list [66, 78, 20]. ->Min([66, 78, 20]) = 20
# Find the minimum number in the list [86, 76, 6]. ->Min([86, 76, 6]) = 6
# Find the minimum number in the list [86, 49, 36]. ->Min([86, 49, 36]) = 36
# Find the minimum number in the list [74, 84, 18]. ->Min([74, 84, 18]) = 18
# Find the minimum number in the list [76, 90, 10]. ->Min([76, 90, 10]) = 10
# Find the minimum number in the list [89, 94, 87]. ->Min([89, 94, 87]) = 87
# Find the minimum number in the list [2, 46, 39]. ->Min([2, 46, 39]) = 2
# Find the minimum number in the list [17, 19, 9]. ->Min([17, 19, 9]) = 9
# Find the minimum number in the list [4, 84, 43]. ->Min([4, 84, 43]) = 4
# Find the minimum number in the list [23, 88, 98]. ->Min([23, 88, 98]) = 23
# Find the minimum number in the list [86, 92, 30]. ->Min([86, 92, 30]) = 30
# Find the minimum number in the list [68, 30, 39]. ->Min([68, 30, 39]) = 30
# Find the minimum number in the list [98, 36, 99]. ->Min([98, 36, 99]) = 36
# Find the minimum number in the list [17, 32, 6]. ->Min([17, 32, 6]) = 6
# Find the minimum number in the list [15, 36, 10]. ->Min([15, 36, 10]) = 10
# Find the minimum number in the list [11, 28, 57]. ->Min([11, 28, 57]) = 11
# Find the minimum number in the list [30, 49, 10]. ->Min([30, 49, 10]) = 10
# Find the minimum number in the list [42, 18, 17]. ->Min([42, 18, 17]) = 17
# Find the minimum number in the list [60, 57, 78]. ->Min([60, 57, 78]) = 57
# Find the minimum number in the list [93, 77, 67]. ->Min([93, 77, 67]) = 67
# Find the minimum number in the list [6, 30, 53]. ->Min([6, 30, 53]) = 6
# Find the minimum number in the list [68, 2, 80]. ->Min([68, 2, 80]) = 2
# Find the minimum number in the list [0, 78, 45]. ->Min([0, 78, 45]) = 0
# Find the minimum number in the list [67, 46, 8]. ->Min([67, 46, 8]) = 8
# Find the minimum number in the list [60, 5, 81]. ->Min([60, 5, 81]) = 5
# Find the minimum number in the list [44, 30, 93]. ->Min([44, 30, 93]) = 30
# Received responses for batch 4 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 5 of 86
# # of prompts:  50 # of responses:  50
# Find the minimum number in the list [340, 136, 45]. ->Min([340, 136, 45]) = 45
# Find the minimum number in the list [797, 701, 475]. ->Min([797, 701, 475]) = 475
# Find the minimum number in the list [733, 794, 966]. ->Min([733, 794, 966]) = 733
# Find the minimum number in the list [907, 42, 323]. ->Min([907, 42, 323]) = 42
# Find the minimum number in the list [259, 37, 771]. ->Min([259, 37, 771]) = 37
# Find the minimum number in the list [886, 671, 339]. ->Min([886, 671, 339]) = 339
# Find the minimum number in the list [761, 450, 916]. ->Min([761, 450, 916]) = 450
# Find the minimum number in the list [509, 376, 946]. ->Min([509, 376, 946]) = 376
# Find the minimum number in the list [80, 440, 616]. ->Min([80, 440, 616]) = 80
# Find the minimum number in the list [335, 676, 302]. ->Min([335, 676, 302]) = 302
# Find the minimum number in the list [454, 359, 457]. ->Min([454, 359, 457]) = 359
# Find the minimum number in the list [281, 654, 810]. ->Min([281, 654, 810]) = 281
# Find the minimum number in the list [525, 820, 767]. ->Min([525, 820, 767]) = 525
# Find the minimum number in the list [694, 800, 448]. ->Min([694, 800, 448]) = 448
# Find the minimum number in the list [370, 392, 972]. ->Min([370, 392, 972]) = 370
# Find the minimum number in the list [379, 380, 454]. ->Min([379, 380, 454]) = 379
# Find the minimum number in the list [321, 665, 285]. ->Min([321, 665, 285]) = 285
# Find the minimum number in the list [530, 396, 935]. ->Min([530, 396, 935]) = 396
# Find the minimum number in the list [219, 626, 292]. ->Min([219, 626, 292]) = 219
# Find the minimum number in the list [75, 462, 176]. ->Min([75, 462, 176]) = 75
# Find the minimum number in the list [865, 327, 683]. ->Min([865, 327, 683]) = 327
# Find the minimum number in the list [307, 871, 161]. ->Min([307, 871, 161]) = 161
# Find the minimum number in the list [370, 520, 229]. ->Min([370, 520, 229]) = 229
# Find the minimum number in the list [26, 369, 567]. ->Min([26, 369, 567]) = 26
# Find the minimum number in the list [905, 88, 67]. ->Min([905, 88, 67]) = 67
# Find the minimum number in the list [787, 419, 843]. ->Min([787, 419, 843]) = 419
# Find the minimum number in the list [460, 477, 696]. ->Min([460, 477, 696]) = 460
# Find the minimum number in the list [655, 601, 186]. ->Min([655, 601, 186]) = 186
# Find the minimum number in the list [56, 851, 127]. ->Min([56, 851, 127]) = 56
# Find the minimum number in the list [726, 230, 354]. ->Min([726, 230, 354]) = 230
# Find the minimum number in the list [256, 201, 650]. ->Min([256, 201, 650]) = 201
# Find the minimum number in the list [546, 95, 514]. ->Min([546, 95, 514]) = 95
# Find the minimum number in the list [674, 639, 737]. ->Min([674, 639, 737]) = 639
# Find the minimum number in the list [845, 884, 29]. ->Min([845, 884, 29]) = 29
# Find the minimum number in the list [666, 215, 785]. ->Min([666, 215, 785]) = 215
# Find the minimum number in the list [642, 558, 296]. ->Min([642, 558, 296]) = 296
# Find the minimum number in the list [701, 415, 304]. ->Min([701, 415, 304]) = 304
# Find the minimum number in the list [495, 475, 208]. ->Min([495, 475, 208]) = 208
# Find the minimum number in the list [751, 881, 353]. ->Min([751, 881, 353]) = 353
# Find the minimum number in the list [108, 326, 247]. ->Min([108, 326, 247]) = 108
# Find the minimum number in the list [51, 297, 968]. ->Min([51, 297, 968]) = 51
# Find the minimum number in the list [923, 163, 833]. ->Min([923, 163, 833]) = 163
# Find the minimum number in the list [163, 510, 527]. ->Min([163, 510, 527]) = 163
# Find the minimum number in the list [967, 402, 517]. ->Min([967, 402, 517]) = 402
# Find the minimum number in the list [51, 288, 506]. ->Min([51, 288, 506]) = 51
# Find the minimum number in the list [549, 8, 867]. ->Min([549, 8, 867]) = 8
# Find the minimum number in the list [782, 412, 374]. ->Min([782, 412, 374]) = 374
# Find the minimum number in the list [566, 295, 75]. ->Min([566, 295, 75]) = 75
# Find the minimum number in the list [638, 696, 625]. ->Min([638, 696, 625]) = 625
# Find the minimum number in the list [347, 571, 961]. ->Min([347, 571, 961]) = 347
# Received responses for batch 5 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 6 of 86
# # of prompts:  50 # of responses:  50
# Find the minimum number in the list [512, 41, 46]. ->Min([512, 41, 46]) = 41
# Find the minimum number in the list [467, 152, 620]. ->Min([467, 152, 620]) = 152
# Find the minimum number in the list [166, 402, 631]. ->Min([166, 402, 631]) = 166
# Find the minimum number in the list [521, 545, 501]. ->Min([521, 545, 501]) = 501
# Find the minimum number in the list [339, 689, 112]. ->Min([339, 689, 112]) = 112
# Find the minimum number in the list [704, 644, 27]. ->Min([704, 644, 27]) = 27
# Find the minimum number in the list [794, 592, 591]. ->Min([794, 592, 591]) = 591
# Find the minimum number in the list [644, 738, 634]. ->Min([644, 738, 634]) = 634
# Find the minimum number in the list [32, 586, 970]. ->Min([32, 586, 970]) = 32
# Find the minimum number in the list [155, 422, 707]. ->Min([155, 422, 707]) = 155
# Find the minimum number in the list [893, 868, 753]. ->Min([893, 868, 753]) = 753
# Find the minimum number in the list [332, 678, 489]. ->Min([332, 678, 489]) = 332
# Find the minimum number in the list [545, 350, 559]. ->Min([545, 350, 559]) = 350
# Find the minimum number in the list [822, 709, 270]. ->Min([822, 709, 270]) = 270
# Find the minimum number in the list [305, 230, 964]. ->Min([305, 230, 964]) = 230
# Find the minimum number in the list [721, 500, 324]. ->Min([721, 500, 324]) = 324
# Find the minimum number in the list [280, 294, 124]. ->Min([280, 294, 124]) = 124
# Find the minimum number in the list [353, 977, 791]. ->Min([353, 977, 791]) = 353
# Find the minimum number in the list [80, 354, 946]. ->Min([80, 354, 946]) = 80
# Find the minimum number in the list [847, 551, 277]. ->Min([847, 551, 277]) = 277
# Find the minimum number in the list [758, 600, 245]. ->Min([758, 600, 245]) = 245
# Find the minimum number in the list [238, 53, 102]. ->Min([238, 53, 102]) = 53
# Find the minimum number in the list [140, 5, 987]. ->Min([140, 5, 987]) = 5
# Find the minimum number in the list [899, 487, 488]. ->Min([899, 487, 488]) = 487
# Find the minimum number in the list [661, 60, 929]. ->Min([661, 60, 929]) = 60
# Find the minimum number in the list [740, 870, 959]. ->Min([740, 870, 959]) = 740
# Find the minimum number in the list [180, 956, 941]. ->Min([180, 956, 941]) = 180
# Find the minimum number in the list [766, 985, 893]. ->Min([766, 985, 893]) = 766
# Find the minimum number in the list [617, 109, 950]. ->Min([617, 109, 950]) = 109
# Find the minimum number in the list [910, 961, 137]. ->Min([910, 961, 137]) = 137
# Find the minimum number in the list [338, 166, 748]. ->Min([338, 166, 748]) = 166
# Find the minimum number in the list [345, 809, 302]. ->Min([345, 809, 302]) = 302
# Find the minimum number in the list [654, 918, 415]. ->Min([654, 918, 415]) = 415
# Find the minimum number in the list [97, 189, 143]. ->Min([97, 189, 143]) = 97
# Find the minimum number in the list [241, 457, 771]. ->Min([241, 457, 771]) = 241
# Find the minimum number in the list [11, 267, 669]. ->Min([11, 267, 669]) = 11
# Find the minimum number in the list [314, 163, 415]. ->Min([314, 163, 415]) = 163
# Find the minimum number in the list [318, 706, 120]. ->Min([318, 706, 120]) = 120
# Find the minimum number in the list [224, 980, 136]. ->Min([224, 980, 136]) = 136
# Find the minimum number in the list [718, 562, 934]. ->Min([718, 562, 934]) = 562
# Find the minimum number in the list [780, 253, 696]. ->Min([780, 253, 696]) = 253
# Find the minimum number in the list [540, 720, 370]. ->Min([540, 720, 370]) = 370
# Find the minimum number in the list [924, 517, 207]. ->Min([924, 517, 207]) = 207
# Find the minimum number in the list [452, 119, 696]. ->Min([452, 119, 696]) = 119
# Find the minimum number in the list [456, 828, 56]. ->Min([456, 828, 56]) = 56
# Find the minimum number in the list [572, 473, 688]. ->Min([572, 473, 688]) = 473
# Find the minimum number in the list [3, 763, 223]. ->Min([3, 763, 223]) = 3
# Find the minimum number in the list [554, 61, 957]. ->Min([554, 61, 957]) = 61
# Find the minimum number in the list [184, 787, 138]. ->Min([184, 787, 138]) = 138
# Find the minimum number in the list [912, 391, 459]. ->Min([912, 391, 459]) = 391
# Received responses for batch 6 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 7 of 86
# # of prompts:  50 # of responses:  50
# Find the minimum number in the list [8835, 2178, 5697]. ->Min([8835, 2178, 5697]) = 2178
# Find the minimum number in the list [56, 372, 4888]. ->Min([56, 372, 4888]) = 56
# Find the minimum number in the list [7546, 5671, 2541]. ->Min([7546, 5671, 2541]) = 2541
# Find the minimum number in the list [3376, 1102, 1653]. ->Min([3376, 1102, 1653]) = 1102
# Find the minimum number in the list [6590, 7191, 3839]. ->Min([6590, 7191, 3839]) = 3839
# Find the minimum number in the list [9438, 5224, 9461]. ->Min([9438, 5224, 9461]) = 5224
# Find the minimum number in the list [6775, 4923, 4508]. ->Min([6775, 4923, 4508]) = 4508
# Find the minimum number in the list [768, 5642, 6244]. ->Min([768, 5642, 6244]) = 768
# Find the minimum number in the list [3012, 8813, 7758]. ->Min([3012, 8813, 7758]) = 3012
# Find the minimum number in the list [6761, 6824, 9130]. ->Min([6761, 6824, 9130]) = 6761
# Find the minimum number in the list [1295, 7369, 6079]. ->Min([1295, 7369, 6079]) = 1295
# Find the minimum number in the list [9878, 647, 1192]. ->Min([9878, 647, 1192]) = 647
# Find the minimum number in the list [4967, 251, 3470]. ->Min([4967, 251, 3470]) = 251
# Find the minimum number in the list [3921, 9045, 5269]. ->Min([3921, 9045, 5269]) = 3921
# Find the minimum number in the list [5892, 8401, 8147]. ->Min([5892, 8401, 8147]) = 5892
# Find the minimum number in the list [6781, 749, 9216]. ->Min([6781, 749, 9216]) = 749
# Find the minimum number in the list [6841, 4836, 2497]. ->Min([6841, 4836, 2497]) = 2497
# Find the minimum number in the list [9021, 5530, 4216]. ->Min([9021, 5530, 4216]) = 4216
# Find the minimum number in the list [8954, 8000, 3015]. ->Min([8954, 8000, 3015]) = 3015
# Find the minimum number in the list [6756, 2252, 3791]. ->Min([6756, 2252, 3791]) = 2252
# Find the minimum number in the list [990, 7916, 7993]. ->Min([990, 7916, 7993]) = 990
# Find the minimum number in the list [8673, 4501, 8777]. ->Min([8673, 4501, 8777]) = 4501
# Find the minimum number in the list [8591, 2439, 3948]. ->Min([8591, 2439, 3948]) = 2439
# Find the minimum number in the list [6112, 6652, 7520]. ->Min([6112, 6652, 7520]) = 6112
# Find the minimum number in the list [6640, 6213, 6179]. ->Min([6640, 6213, 6179]) = 6179
# Find the minimum number in the list [7109, 5427, 9270]. ->Min([7109, 5427, 9270]) = 5427
# Find the minimum number in the list [4441, 762, 1218]. ->Min([4441, 762, 1218]) = 762
# Find the minimum number in the list [3394, 9617, 2362]. ->Min([3394, 9617, 2362]) = 2362
# Find the minimum number in the list [6375, 8856, 5435]. ->Min([6375, 8856, 5435]) = 5435
# Find the minimum number in the list [7161, 3803, 1245]. ->Min([7161, 3803, 1245]) = 1245
# Find the minimum number in the list [7381, 8038, 3737]. ->Min([7381, 8038, 3737]) = 3737
# Find the minimum number in the list [1404, 4839, 4037]. ->Min([1404, 4839, 4037]) = 1404
# Find the minimum number in the list [5188, 5909, 1745]. ->Min([5188, 5909, 1745]) = 1745
# Find the minimum number in the list [2170, 1430, 3070]. ->Min([2170, 1430, 3070]) = 1430
# Find the minimum number in the list [430, 1468, 5798]. ->Min([430, 1468, 5798]) = 430
# Find the minimum number in the list [4781, 6779, 6353]. ->Min([4781, 6779, 6353]) = 4781
# Find the minimum number in the list [2777, 2274, 4405]. ->Min([2777, 2274, 4405]) = 2274
# Find the minimum number in the list [4521, 6899, 4911]. ->Min([4521, 6899, 4911]) = 4521
# Find the minimum number in the list [3203, 7501, 1752]. ->Min([3203, 7501, 1752]) = 1752
# Find the minimum number in the list [7212, 5484, 7055]. ->Min([7212, 5484, 7055]) = 5484
# Find the minimum number in the list [5147, 2910, 6524]. ->Min([5147, 2910, 6524]) = 2910
# Find the minimum number in the list [4592, 6437, 5980]. ->Min([4592, 6437, 5980]) = 4592
# Find the minimum number in the list [440, 7563, 3434]. ->Min([440, 7563, 3434]) = 440
# Find the minimum number in the list [3965, 4139, 2525]. ->Min([3965, 4139, 2525]) = 2525
# Find the minimum number in the list [6566, 8755, 8300]. ->Min([6566, 8755, 8300]) = 6566
# Find the minimum number in the list [1791, 4067, 5816]. ->Min([1791, 4067, 5816]) = 1791
# Find the minimum number in the list [172, 1615, 4239]. ->Min([172, 1615, 4239]) = 172
# Find the minimum number in the list [7303, 6129, 6408]. ->Min([7303, 6129, 6408]) = 6129
# Find the minimum number in the list [1712, 4840, 6815]. ->Min([1712, 4840, 6815]) = 1712
# Find the minimum number in the list [3389, 8537, 7912]. ->Min([3389, 8537, 7912]) = 3389
# Received responses for batch 7 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 8 of 86
# # of prompts:  50 # of responses:  50
# Find the minimum number in the list [4919, 732, 1885]. ->Min([4919, 732, 1885]) = 732
# Find the minimum number in the list [9042, 2623, 5422]. ->Min([9042, 2623, 5422]) = 2623
# Find the minimum number in the list [7080, 6481, 478]. ->Min([7080, 6481, 478]) = 478
# Find the minimum number in the list [3371, 4560, 1025]. ->Min([3371, 4560, 1025]) = 1025
# Find the minimum number in the list [7496, 1867, 4298]. ->Min([7496, 1867, 4298]) = 1867
# Find the minimum number in the list [1871, 5700, 5766]. ->Min([1871, 5700, 5766]) = 1871
# Find the minimum number in the list [1931, 3908, 5003]. ->Min([1931, 3908, 5003]) = 1931
# Find the minimum number in the list [9771, 2258, 9417]. ->Min([9771, 2258, 9417]) = 2258
# Find the minimum number in the list [2733, 8022, 4732]. ->Min([2733, 8022, 4732]) = 2733
# Find the minimum number in the list [7939, 2236, 3196]. ->Min([7939, 2236, 3196]) = 2236
# Find the minimum number in the list [7272, 8006, 2740]. ->Min([7272, 8006, 2740]) = 2740
# Find the minimum number in the list [3683, 8808, 4729]. ->Min([3683, 8808, 4729]) = 3683
# Find the minimum number in the list [9383, 1871, 4389]. ->Min([9383, 1871, 4389]) = 1871
# Find the minimum number in the list [6965, 1677, 4055]. ->Min([6965, 1677, 4055]) = 1677
# Find the minimum number in the list [1923, 3882, 3438]. ->Min([1923, 3882, 3438]) = 1923
# Find the minimum number in the list [3390, 972, 9340]. ->Min([3390, 972, 9340]) = 972
# Find the minimum number in the list [4794, 4740, 9383]. ->Min([4794, 4740, 9383]) = 4740
# Find the minimum number in the list [2078, 2174, 4090]. ->Min([2078, 2174, 4090]) = 2078
# Find the minimum number in the list [4402, 6786, 6146]. ->Min([4402, 6786, 6146]) = 4402
# Find the minimum number in the list [7449, 7996, 5362]. ->Min([7449, 7996, 5362]) = 5362
# Find the minimum number in the list [6516, 3568, 7039]. ->Min([6516, 3568, 7039]) = 3568
# Find the minimum number in the list [9468, 2139, 9275]. ->Min([9468, 2139, 9275]) = 2139
# Find the minimum number in the list [2035, 2588, 7230]. ->Min([2035, 2588, 7230]) = 2035
# Find the minimum number in the list [4489, 1529, 5905]. ->Min([4489, 1529, 5905]) = 1529
# Find the minimum number in the list [3836, 7032, 1494]. ->Min([3836, 7032, 1494]) = 1494
# Find the minimum number in the list [3705, 8510, 7291]. ->Min([3705, 8510, 7291]) = 3705
# Find the minimum number in the list [1160, 3751, 6276]. ->Min([1160, 3751, 6276]) = 1160
# Find the minimum number in the list [6270, 2181, 2340]. ->Min([6270, 2181, 2340]) = 2181
# Find the minimum number in the list [5753, 3490, 2480]. ->Min([5753, 3490, 2480]) = 2480
# Find the minimum number in the list [9659, 6291, 5759]. ->Min([9659, 6291, 5759]) = 5759
# Find the minimum number in the list [9066, 9846, 9830]. ->Min([9066, 9846, 9830]) = 9066
# Find the minimum number in the list [8348, 3090, 6418]. ->Min([8348, 3090, 6418]) = 3090
# Find the minimum number in the list [8185, 9730, 1163]. ->Min([8185, 9730, 1163]) = 1163
# Find the minimum number in the list [6895, 5986, 8951]. ->Min([6895, 5986, 8951]) = 5986
# Find the minimum number in the list [4295, 3534, 652]. ->Min([4295, 3534, 652]) = 652
# Find the minimum number in the list [6590, 1350, 8791]. ->Min([6590, 1350, 8791]) = 1350
# Find the minimum number in the list [3329, 2545, 8788]. ->Min([3329, 2545, 8788]) = 2545
# Find the minimum number in the list [948, 4005, 1412]. ->Min([948, 4005, 1412]) = 948
# Find the minimum number in the list [1956, 207, 2248]. ->Min([1956, 207, 2248]) = 207
# Find the minimum number in the list [2735, 6092, 2079]. ->Min([2735, 6092, 2079]) = 2079
# Find the minimum number in the list [1046, 4308, 9447]. ->Min([1046, 4308, 9447]) = 1046
# Find the minimum number in the list [9287, 2734, 6024]. ->Min([9287, 2734, 6024]) = 2734
# Find the minimum number in the list [42, 721, 201]. ->Min([42, 721, 201]) = 42
# Find the minimum number in the list [579, 9058, 6870]. ->Min([579, 9058, 6870]) = 579
# Find the minimum number in the list [9364, 6108, 1956]. ->Min([9364, 6108, 1956]) = 1956
# Find the minimum number in the list [1129, 7620, 4625]. ->Min([1129, 7620, 4625]) = 1129
# Find the minimum number in the list [3287, 4777, 9237]. ->Min([3287, 4777, 9237]) = 3287
# Find the minimum number in the list [8954, 4016, 2466]. ->Min([8954, 4016, 2466]) = 2466
# Find the minimum number in the list [5488, 23, 6164]. ->Min([5488, 23, 6164]) = 23
# Find the minimum number in the list [981, 2332, 4584]. ->Min([981, 2332, 4584]) = 981
# Received responses for batch 8 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 9 of 86
# # of prompts:  50 # of responses:  50
# Find the minimum number in the list [98028, 11128, 76122]. ->Min([98028, 11128, 76122]) = 11128
# Find the minimum number in the list [74425, 8163, 57014]. ->Min([74425, 8163, 57014]) = 8163
# Find the minimum number in the list [91845, 96384, 42762]. ->Min([91845, 96384, 42762]) = 42762
# Find the minimum number in the list [76638, 14283, 20369]. ->Min([76638, 14283, 20369]) = 14283
# Find the minimum number in the list [70244, 46961, 27215]. ->Min([70244, 46961, 27215]) = 27215
# Find the minimum number in the list [89922, 39874, 92367]. ->Min([89922, 39874, 92367]) = 39874
# Find the minimum number in the list [93212, 32534, 46627]. ->Min([93212, 32534, 46627]) = 32534
# Find the minimum number in the list [4073, 53004, 59270]. ->Min([4073, 53004, 59270]) = 4073
# Find the minimum number in the list [18322, 15919, 1567]. ->Min([18322, 15919, 1567]) = 1567
# Find the minimum number in the list [82614, 84500, 11015]. ->Min([82614, 84500, 11015]) = 11015
# Find the minimum number in the list [84670, 58121, 16880]. ->Min([84670, 58121, 16880]) = 16880
# Find the minimum number in the list [75220, 56774, 94952]. ->Min([75220, 56774, 94952]) = 56774
# Find the minimum number in the list [46392, 28143, 24530]. ->Min([46392, 28143, 24530]) = 24530
# Find the minimum number in the list [80868, 32215, 84840]. ->Min([80868, 32215, 84840]) = 32215
# Find the minimum number in the list [36670, 50202, 17987]. ->Min([36670, 50202, 17987]) = 17987
# Find the minimum number in the list [2559, 50134, 93502]. ->Min([2559, 50134, 93502]) = 2559
# Find the minimum number in the list [42153, 50905, 35446]. ->Min([42153, 50905, 35446]) = 35446
# Find the minimum number in the list [7679, 61824, 69393]. ->Min([7679, 61824, 69393]) = 7679
# Find the minimum number in the list [31608, 34934, 69951]. ->Min([31608, 34934, 69951]) = 31608
# Find the minimum number in the list [23081, 31005, 77662]. ->Min([23081, 31005, 77662]) = 23081
# Find the minimum number in the list [91823, 46095, 74403]. ->Min([91823, 46095, 74403]) = 46095
# Find the minimum number in the list [23010, 64282, 4975]. ->Min([23010, 64282, 4975]) = 4975
# Find the minimum number in the list [62650, 89, 43481]. ->Min([62650, 89, 43481]) = 89
# Find the minimum number in the list [7806, 2872, 19360]. ->Min([7806, 2872, 19360]) = 2872
# Find the minimum number in the list [48967, 92345, 86787]. ->Min([48967, 92345, 86787]) = 48967
# Find the minimum number in the list [20644, 95990, 57261]. ->Min([20644, 95990, 57261]) = 20644
# Find the minimum number in the list [90906, 80440, 46769]. ->Min([90906, 80440, 46769]) = 46769
# Find the minimum number in the list [90242, 38602, 16691]. ->Min([90242, 38602, 16691]) = 16691
# Find the minimum number in the list [4244, 23865, 78956]. ->Min([4244, 23865, 78956]) = 4244
# Find the minimum number in the list [18434, 43406, 97693]. ->Min([18434, 43406, 97693]) = 18434
# Find the minimum number in the list [92925, 87821, 83768]. ->Min([92925, 87821, 83768]) = 83768
# Find the minimum number in the list [90855, 8885, 45938]. ->Min([90855, 8885, 45938]) = 8885
# Find the minimum number in the list [96021, 55004, 21802]. ->Min([96021, 55004, 21802]) = 21802
# Find the minimum number in the list [62847, 75766, 85323]. ->Min([62847, 75766, 85323]) = 62847
# Find the minimum number in the list [38654, 2631, 41774]. ->Min([38654, 2631, 41774]) = 2631
# Find the minimum number in the list [95942, 9830, 71702]. ->Min([95942, 9830, 71702]) = 9830
# Find the minimum number in the list [56534, 85673, 21626]. ->Min([56534, 85673, 21626]) = 21626
# Find the minimum number in the list [24901, 53645, 91382]. ->Min([24901, 53645, 91382]) = 24901
# Find the minimum number in the list [38980, 31135, 12571]. ->Min([38980, 31135, 12571]) = 12571
# Find the minimum number in the list [47294, 500, 56047]. ->Min([47294, 500, 56047]) = 500
# Find the minimum number in the list [12712, 3373, 27125]. ->Min([12712, 3373, 27125]) = 3373
# Find the minimum number in the list [52096, 61727, 64106]. ->Min([52096, 61727, 64106]) = 52096
# Find the minimum number in the list [48630, 49996, 48418]. ->Min([48630, 49996, 48418]) = 48418
# Find the minimum number in the list [29654, 35200, 73956]. ->Min([29654, 35200, 73956]) = 29654
# Find the minimum number in the list [87574, 45061, 70968]. ->Min([87574, 45061, 70968]) = 45061
# Find the minimum number in the list [68495, 54870, 70190]. ->Min([68495, 54870, 70190]) = 54870
# Find the minimum number in the list [51747, 93625, 4551]. ->Min([51747, 93625, 4551]) = 4551
# Find the minimum number in the list [15765, 99246, 58856]. ->Min([15765, 99246, 58856]) = 15765
# Find the minimum number in the list [10271, 89538, 57067]. ->Min([10271, 89538, 57067]) = 10271
# Find the minimum number in the list [8783, 11406, 50868]. ->Min([8783, 11406, 50868]) = 8783
# Received responses for batch 9 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 10 of 86
# # of prompts:  50 # of responses:  50
# Find the minimum number in the list [1620, 91804, 81665]. ->Min([1620, 91804, 81665]) = 1620
# Find the minimum number in the list [74264, 77061, 76372]. ->Min([74264, 77061, 76372]) = 74264
# Find the minimum number in the list [45071, 53856, 34620]. ->Min([45071, 53856, 34620]) = 34620
# Find the minimum number in the list [22570, 36099, 52818]. ->Min([22570, 36099, 52818]) = 22570
# Find the minimum number in the list [51877, 43449, 90507]. ->Min([51877, 43449, 90507]) = 43449
# Find the minimum number in the list [44284, 39722, 40756]. ->Min([44284, 39722, 40756]) = 39722
# Find the minimum number in the list [39384, 97481, 58079]. ->Min([39384, 97481, 58079]) = 39384
# Find the minimum number in the list [24633, 57896, 27707]. ->Min([24633, 57896, 27707]) = 24633
# Find the minimum number in the list [67537, 20836, 8600]. ->Min([67537, 20836, 8600]) = 8600
# Find the minimum number in the list [3794, 22772, 25265]. ->Min([3794, 22772, 25265]) = 3794
# Find the minimum number in the list [92357, 26097, 35910]. ->Min([92357, 26097, 35910]) = 26097
# Find the minimum number in the list [4005, 31711, 48819]. ->Min([4005, 31711, 48819]) = 4005
# Find the minimum number in the list [45843, 45121, 21432]. ->Min([45843, 45121, 21432]) = 21432
# Find the minimum number in the list [6507, 21352, 75007]. ->Min([6507, 21352, 75007]) = 6507
# Find the minimum number in the list [85404, 53674, 67276]. ->Min([85404, 53674, 67276]) = 53674
# Find the minimum number in the list [78792, 1109, 29329]. ->Min([78792, 1109, 29329]) = 1109
# Find the minimum number in the list [55549, 49345, 45706]. ->Min([55549, 49345, 45706]) = 45706
# Find the minimum number in the list [81737, 52055, 76609]. ->Min([81737, 52055, 76609]) = 52055
# Find the minimum number in the list [77826, 79829, 37051]. ->Min([77826, 79829, 37051]) = 37051
# Find the minimum number in the list [83964, 42616, 36291]. ->Min([83964, 42616, 36291]) = 36291
# Find the minimum number in the list [67802, 31496, 7441]. ->Min([67802, 31496, 7441]) = 7441
# Find the minimum number in the list [3336, 85904, 65191]. ->Min([3336, 85904, 65191]) = 3336
# Find the minimum number in the list [76418, 92808, 74978]. ->Min([76418, 92808, 74978]) = 74978
# Find the minimum number in the list [83665, 62355, 88063]. ->Min([83665, 62355, 88063]) = 62355
# Find the minimum number in the list [38506, 12793, 61706]. ->Min([38506, 12793, 61706]) = 12793
# Find the minimum number in the list [89091, 43992, 85778]. ->Min([89091, 43992, 85778]) = 43992
# Find the minimum number in the list [43426, 48717, 34152]. ->Min([43426, 48717, 34152]) = 34152
# Find the minimum number in the list [76490, 76062, 81350]. ->Min([76490, 76062, 81350]) = 76062
# Find the minimum number in the list [69446, 39106, 54146]. ->Min([69446, 39106, 54146]) = 39106
# Find the minimum number in the list [59974, 18772, 41469]. ->Min([59974, 18772, 41469]) = 18772
# Find the minimum number in the list [41079, 83165, 7603]. ->Min([41079, 83165, 7603]) = 7603
# Find the minimum number in the list [20766, 64169, 11539]. ->Min([20766, 64169, 11539]) = 11539
# Find the minimum number in the list [62573, 50242, 611]. ->Min([62573, 50242, 611]) = 611
# Find the minimum number in the list [99201, 69603, 24979]. ->Min([99201, 69603, 24979]) = 24979
# Find the minimum number in the list [90901, 45134, 40906]. ->Min([90901, 45134, 40906]) = 40906
# Find the minimum number in the list [8557, 5992, 39085]. ->Min([8557, 5992, 39085]) = 5992
# Find the minimum number in the list [56841, 90017, 17536]. ->Min([56841, 90017, 17536]) = 17536
# Find the minimum number in the list [2506, 29939, 29402]. ->Min([2506, 29939, 29402]) = 2506
# Find the minimum number in the list [22149, 16143, 48049]. ->Min([22149, 16143, 48049]) = 16143
# Find the minimum number in the list [81675, 6368, 77846]. ->Min([81675, 6368, 77846]) = 6368
# Find the minimum number in the list [15176, 54627, 58237]. ->Min([15176, 54627, 58237]) = 15176
# Find the minimum number in the list [26934, 91120, 89881]. ->Min([26934, 91120, 89881]) = 26934
# Find the minimum number in the list [68197, 35386, 81631]. ->Min([68197, 35386, 81631]) = 35386
# Find the minimum number in the list [80962, 15431, 37054]. ->Min([80962, 15431, 37054]) = 15431
# Find the minimum number in the list [68569, 26433, 46913]. ->Min([68569, 26433, 46913]) = 26433
# Find the minimum number in the list [27222, 90204, 63001]. ->Min([27222, 90204, 63001]) = 27222
# Find the minimum number in the list [75255, 87690, 64763]. ->Min([75255, 87690, 64763]) = 64763
# Find the minimum number in the list [33540, 84454, 30298]. ->Min([33540, 84454, 30298]) = 30298
# Find the minimum number in the list [5170, 38085, 47214]. ->Min([5170, 38085, 47214]) = 5170
# Find the minimum number in the list [6014, 1267, 18139]. ->Min([6014, 1267, 18139]) = 1267
# Received responses for batch 10 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 11 of 86
# # of prompts:  40 # of responses:  40
# Find the minimum number in the list [1, 0, 4, 3, 3]. ->Min([1, 0, 4, 3, 3]) = 0
# Find the minimum number in the list [6, 0, 0, 1, 3]. ->Min([6, 0, 0, 1, 3]) = 0
# Find the minimum number in the list [3, 8, 6, 3, 7]. ->Min([3, 8, 6, 3, 7]) = 3
# Find the minimum number in the list [5, 4, 2, 3, 5]. ->Min([5, 4, 2, 3, 5]) = 2
# Find the minimum number in the list [5, 9, 4, 0, 7]. ->Min([5, 9, 4, 0, 7]) = 0
# Find the minimum number in the list [4, 9, 5, 9, 3]. ->Min([4, 9, 5, 9, 3]) = 3
# Find the minimum number in the list [3, 1, 6, 4, 7]. ->Min([3, 1, 6, 4, 7]) = 1
# Find the minimum number in the list [4, 1, 9, 2, 8]. ->Min([4, 1, 9, 2, 8]) = 1
# Find the minimum number in the list [8, 3, 5, 0, 3]. ->Min([8, 3, 5, 0, 3]) = 0
# Find the minimum number in the list [3, 9, 5, 3, 7]. ->Min([3, 9, 5, 3, 7]) = 3
# Find the minimum number in the list [3, 8, 8, 4, 9]. ->Min([3, 8, 8, 4, 9]) = 3
# Find the minimum number in the list [2, 8, 7, 1, 0]. ->Min([2, 8, 7, 1, 0]) = 0
# Find the minimum number in the list [1, 6, 6, 9, 7]. ->Min([1, 6, 6, 9, 7]) = 1
# Find the minimum number in the list [8, 4, 5, 1, 4]. ->Min([8, 4, 5, 1, 4]) = 1
# Find the minimum number in the list [8, 2, 8, 1, 4]. ->Min([8, 2, 8, 1, 4]) = 1
# Find the minimum number in the list [2, 8, 8, 0, 9]. ->Min([2, 8, 8, 0, 9]) = 0
# Find the minimum number in the list [4, 3, 0, 3, 9]. ->Min([4, 3, 0, 3, 9]) = 0
# Find the minimum number in the list [2, 2, 7, 8, 2]. ->Min([2, 2, 7, 8, 2]) = 2
# Find the minimum number in the list [8, 3, 4, 6, 5]. ->Min([8, 3, 4, 6, 5]) = 3
# Find the minimum number in the list [3, 1, 5, 0, 9]. ->Min([3, 1, 5, 0, 9]) = 0
# Find the minimum number in the list [1, 0, 3, 1, 0]. ->Min([1, 0, 3, 1, 0]) = 0
# Find the minimum number in the list [7, 3, 8, 2, 9]. ->Min([7, 3, 8, 2, 9]) = 2
# Find the minimum number in the list [3, 1, 1, 6, 5]. ->Min([3, 1, 1, 6, 5]) = 1
# Find the minimum number in the list [0, 6, 5, 1, 3]. ->Min([0, 6, 5, 1, 3]) = 0
# Find the minimum number in the list [6, 2, 4, 7, 3]. ->Min([6, 2, 4, 7, 3]) = 2
# Find the minimum number in the list [8, 0, 1, 3, 2]. ->Min([8, 0, 1, 3, 2]) = 0
# Find the minimum number in the list [0, 2, 6, 0, 6]. ->Min([0, 2, 6, 0, 6]) = 0
# Find the minimum number in the list [7, 2, 3, 4, 3]. ->Min([7, 2, 3, 4, 3]) = 2
# Find the minimum number in the list [0, 0, 9, 7, 8]. ->Min([0, 0, 9, 7, 8]) = 0
# Find the minimum number in the list [2, 1, 9, 1, 3]. ->Min([2, 1, 9, 1, 3]) = 1
# Find the minimum number in the list [9, 0, 9, 1, 6]. ->Min([9, 0, 9, 1, 6]) = 0
# Find the minimum number in the list [3, 5, 3, 4, 6]. ->Min([3, 5, 3, 4, 6]) = 3
# Find the minimum number in the list [0, 7, 9, 9, 1]. ->Min([0, 7, 9, 9, 1]) = 0
# Find the minimum number in the list [2, 5, 1, 3, 5]. ->Min([2, 5, 1, 3, 5]) = 1
# Find the minimum number in the list [9, 8, 0, 8, 4]. ->Min([9, 8, 0, 8, 4]) = 0
# Find the minimum number in the list [8, 2, 4, 4, 9]. ->Min([8, 2, 4, 4, 9]) = 2
# Find the minimum number in the list [7, 4, 0, 1, 6]. ->Min([7, 4, 0, 1, 6]) = 0
# Find the minimum number in the list [4, 2, 7, 8, 6]. ->Min([4, 2, 7, 8, 6]) = 2
# Find the minimum number in the list [8, 0, 5, 9, 8]. ->Min([8, 0, 5, 9, 8]) = 0
# Find the minimum number in the list [5, 0, 5, 3, 3]. ->Min([5, 0, 5, 3, 3]) = 0
# Received responses for batch 11 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 12 of 86
# # of prompts:  40 # of responses:  40
# Find the minimum number in the list [2, 3, 2, 2, 6]. ->Min([2, 3, 2, 2, 6]) = 2
# Find the minimum number in the list [4, 2, 1, 6, 0]. ->Min([4, 2, 1, 6, 0]) = 0
# Find the minimum number in the list [4, 3, 3, 0, 3]. ->Min([4, 3, 3, 0, 3]) = 0
# Find the minimum number in the list [5, 8, 6, 8, 5]. ->Min([5, 8, 6, 8, 5]) = 5
# Find the minimum number in the list [4, 0, 1, 9, 6]. ->Min([4, 0, 1, 9, 6]) = 0
# Find the minimum number in the list [1, 6, 9, 3, 4]. ->Min([1, 6, 9, 3, 4]) = 1
# Find the minimum number in the list [3, 5, 6, 1, 5]. ->Min([3, 5, 6, 1, 5]) = 1
# Find the minimum number in the list [4, 6, 5, 6, 4]. ->Min([4, 6, 5, 6, 4]) = 4
# Find the minimum number in the list [2, 9, 9, 4, 6]. ->Min([2, 9, 9, 4, 6]) = 2
# Find the minimum number in the list [6, 9, 9, 5, 7]. ->Min([6, 9, 9, 5, 7]) = 5
# Find the minimum number in the list [2, 1, 4, 8, 9]. ->Min([2, 1, 4, 8, 9]) = 1
# Find the minimum number in the list [3, 2, 0, 0, 3]. ->Min([3, 2, 0, 0, 3]) = 0
# Find the minimum number in the list [9, 3, 6, 7, 6]. ->Min([9, 3, 6, 7, 6]) = 3
# Find the minimum number in the list [3, 2, 8, 7, 0]. ->Min([3, 2, 8, 7, 0]) = 0
# Find the minimum number in the list [7, 8, 8, 9, 5]. ->Min([7, 8, 8, 9, 5]) = 5
# Find the minimum number in the list [7, 2, 7, 7, 4]. ->Min([7, 2, 7, 7, 4]) = 2
# Find the minimum number in the list [4, 7, 1, 4, 3]. ->Min([4, 7, 1, 4, 3]) = 1
# Find the minimum number in the list [2, 2, 3, 6, 2]. ->Min([2, 2, 3, 6, 2]) = 2
# Find the minimum number in the list [8, 7, 6, 0, 3]. ->Min([8, 7, 6, 0, 3]) = 0
# Find the minimum number in the list [6, 7, 0, 5, 4]. ->Min([6, 7, 0, 5, 4]) = 0
# Find the minimum number in the list [3, 7, 3, 4, 6]. ->Min([3, 7, 3, 4, 6]) = 3
# Find the minimum number in the list [2, 7, 2, 9, 8]. ->Min([2, 7, 2, 9, 8]) = 2
# Find the minimum number in the list [1, 6, 2, 7, 2]. ->Min([1, 6, 2, 7, 2]) = 1
# Find the minimum number in the list [7, 5, 5, 6, 4]. ->Min([7, 5, 5, 6, 4]) = 4
# Find the minimum number in the list [8, 0, 5, 3, 1]. ->Min([8, 0, 5, 3, 1]) = 0
# Find the minimum number in the list [9, 2, 3, 2, 7]. ->Min([9, 2, 3, 2, 7]) = 2
# Find the minimum number in the list [5, 2, 9, 9, 1]. ->Min([5, 2, 9, 9, 1]) = 1
# Find the minimum number in the list [4, 9, 6, 6, 3]. ->Min([4, 9, 6, 6, 3]) = 3
# ...
# Received responses for batch 83 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 84 of 86
# # of prompts:  25 # of responses:  25
# Find the minimum number in the list [-20644, 95990, 57261, -83789, 63858, -85089, -41586, -22833, 92691, -73659]. ->Min([-20644, 95990, 57261, -83789, 63858, -85089, -41586, -22833, 92691, -73659]) = -85089
# Find the minimum number in the list [90906, 80440, -46769, -29260, -87232, 77194, -22983, -49595, -40215, -96206]. ->Min([90906, 80440, -46769, -29260, -87232, 77194, -22983, -49595, -40215, -96206]) = -96206
# Find the minimum number in the list [90242, 38602, -16691, 23292, 95529, 235, 92013, -75082, 51327, 74381]. ->Min([90242, 38602, -16691, 23292, 95529, 235, 92013, -75082, 51327, 74381]) = -75082
# Find the minimum number in the list [4244, -23865, 78956, -41709, -80134, 28953, -83839, -74127, -13645, 65035]. ->Min([4244, -23865, 78956, -41709, -80134, 28953, -83839, -74127, -13645, 65035]) = -83839
# Find the minimum number in the list [-18434, 43406, -97693, 10198, 31194, -45457, -41879, 22005, -83386, 11629]. ->Min([-18434, 43406, -97693, 10198, 31194, -45457, -41879, 22005, -83386, 11629]) = -97693
# Find the minimum number in the list [92925, -87821, 83768, 95588, -44007, -58540, -1493, -34761, 27483, 32707]. ->Min([92925, -87821, 83768, 95588, -44007, -58540, -1493, -34761, 27483, 32707]) = -87821
# Find the minimum number in the list [-90855, -8885, -45938, -33640, 14160, -94426, -167, 6310, 50585, 57438]. ->Min([-90855, -8885, -45938, -33640, 14160, -94426, -167, 6310, 50585, 57438]) = -94426
# Find the minimum number in the list [-96021, -55004, -21802, -54266, -64629, -49638, 46036, -71568, -49197, 13294]. ->Min([-96021, -55004, -21802, -54266, -64629, -49638, 46036, -71568, -49197, 13294]) = -96021
# Find the minimum number in the list [-62847, 75766, 85323, -99384, -90067, 29567, -21319, -59151, 9661, 4379]. ->Min([-62847, 75766, 85323, -99384, -90067, 29567, -21319, -59151, 9661, 4379]) = -99384
# Find the minimum number in the list [38654, -2631, -41774, 34226, 13726, -9725, 44801, 22296, -49212, 21090]. ->Min([38654, -2631, -41774, 34226, 13726, -9725, 44801, 22296, -49212, 21090]) = -49212
# Find the minimum number in the list [95942, 9830, -71702, 12203, -44295, -77860, 80431, -63273, 92340, -4062]. ->Min([95942, 9830, -71702, 12203, -44295, -77860, 80431, -63273, 92340, -4062]) = -77860
# Find the minimum number in the list [56534, 85673, 21626, -79602, 56911, -20591, -7019, -13272, 43397, 26941]. ->Min([56534, 85673, 21626, -79602, 56911, -20591, -7019, -13272, 43397, 26941]) = -79602
# Find the minimum number in the list [24901, 53645, 91382, 72628, 94638, -95679, 70795, 34768, -86585, -36899]. ->Min([24901, 53645, 91382, 72628, 94638, -95679, 70795, 34768, -86585, -36899]) = -95679
# Find the minimum number in the list [-38980, -31135, 12571, -6505, 51498, 74943, -72045, 64349, -20131, -7144]. ->Min([-38980, -31135, 12571, -6505, 51498, 74943, -72045, 64349, -20131, -7144]) = -72045
# Find the minimum number in the list [-47294, 500, 56047, 11485, -38607, 86772, -81931, -78671, 62957, 26171]. ->Min([-47294, 500, 56047, 11485, -38607, 86772, -81931, -78671, 62957, 26171]) = -81931
# Find the minimum number in the list [-12712, -3373, 27125, 22391, -83648, 38248, -10739, -62071, 15139, -40416]. ->Min([-12712, -3373, 27125, 22391, -83648, 38248, -10739, -62071, 15139, -40416]) = -83648
# Find the minimum number in the list [52096, 61727, -64106, 86643, -34734, -11945, -84130, 71319, 50793, 24232]. ->Min([52096, 61727, -64106, 86643, -34734, -11945, -84130, 71319, 50793, 24232]) = -84130
# Find the minimum number in the list [48630, -49996, 48418, 24455, 58428, -5848, 34510, 57637, -60956, 34524]. ->Min([48630, -49996, 48418, 24455, 58428, -5848, 34510, 57637, -60956, 34524]) = -60956
# Find the minimum number in the list [29654, 35200, 73956, 8079, -19808, 98596, 91287, 87486, 12675, -11233]. ->Min([29654, 35200, 73956, 8079, -19808, 98596, 91287, 87486, 12675, -11233]) = -19808
# Find the minimum number in the list [-87574, 45061, 70968, 54262, -99150, 77296, 29820, 72561, 7993, -50738]. ->Min([-87574, 45061, 70968, 54262, -99150, 77296, 29820, 72561, 7993, -50738]) = -99150
# Find the minimum number in the list [-68495, -54870, 70190, -90055, -62236, 75066, -30886, -62424, -39171, 10348]. ->Min([-68495, -54870, 70190, -90055, -62236, 75066, -30886, -62424, -39171, 10348]) = -90055
# Find the minimum number in the list [-51747, -93625, 4551, 65811, -74870, 67740, 74905, -88805, 81300, -19326]. ->Min([-51747, -93625, 4551, 65811, -74870, 67740, 74905, -88805, 81300, -19326]) = -93625
# Find the minimum number in the list [-15765, -99246, 58856, 22659, 21910, -27772, -25260, -16539, 5593, -55492]. ->Min([-15765, -99246, 58856, 22659, 21910, -27772, -25260, -16539, 5593, -55492]) = -99246
# Find the minimum number in the list [-10271, -89538, 57067, -26465, -82211, 19382, 77994, 33801, -41910, -95302]. ->Min([-10271, -89538, 57067, -26465, -82211, 19382, 77994, 33801, -41910, -95302]) = -95302
# Find the minimum number in the list [-8783, -11406, 50868, 72923, 52082, 72358, 42746, -36202, -68116, 60051]. ->Min([-8783, -11406, 50868, 72923, 52082, 72358, 42746, -36202, -68116, 60051]) = -68116
# Received responses for batch 84 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 85 of 86
# # of prompts:  25 # of responses:  25
# Find the minimum number in the list [1620, 91804, -81665, 77014, 68493, 54997, 14748, 54321, -19613, 19424]. ->Min([1620, 91804, -81665, 77014, 68493, 54997, 14748, 54321, -19613, 19424]) = -81665
# Find the minimum number in the list [-74264, 77061, -76372, -99402, 13133, 13845, -73752, -13237, 37498, -70206]. ->Min([-74264, 77061, -76372, -99402, 13133, 13845, -73752, -13237, 37498, -70206]) = -99402
# Find the minimum number in the list [45071, 53856, 34620, -50206, 85824, -63646, 74976, -79817, -62003, -4910]. ->Min([45071, 53856, 34620, -50206, 85824, -63646, 74976, -79817, -62003, -4910]) = -79817
# Find the minimum number in the list [22570, 36099, 52818, 18855, 81034, -79777, 89235, -90919, -52654, -5083]. ->Min([22570, 36099, 52818, 18855, 81034, -79777, 89235, -90919, -52654, -5083]) = -90919
# Find the minimum number in the list [51877, -43449, 90507, -31139, -6460, -97746, 62287, 35203, -48816, 2651]. ->Min([51877, -43449, 90507, -31139, -6460, -97746, 62287, 35203, -48816, 2651]) = -97746
# Find the minimum number in the list [44284, 39722, 40756, 36745, -64437, -91250, 89764, 12873, -29878, -17614]. ->Min([44284, 39722, 40756, 36745, -64437, -91250, 89764, 12873, -29878, -17614]) = -91250
# Find the minimum number in the list [39384, -97481, 58079, 42056, 35313, 95525, 54627, -79295, 84614, -11703]. ->Min([39384, -97481, 58079, 42056, 35313, 95525, 54627, -79295, 84614, -11703]) = -97481
# Find the minimum number in the list [-24633, 57896, -27707, -53368, 97117, 63499, -99548, 67698, -49009, -7367]. ->Min([-24633, 57896, -27707, -53368, 97117, 63499, -99548, 67698, -49009, -7367]) = -99548
# Find the minimum number in the list [67537, -20836, -8600, -40779, -93004, -66426, 52872, -17779, 68719, -74537]. ->Min([67537, -20836, -8600, -40779, -93004, -66426, 52872, -17779, 68719, -74537]) = -93004
# Find the minimum number in the list [3794, -22772, 25265, -26309, 7553, 32701, 4334, -59827, 6626, 47235]. ->Min([3794, -22772, 25265, -26309, 7553, 32701, 4334, -59827, 6626, 47235]) = -59827
# Find the minimum number in the list [92357, 26097, 35910, 48280, -60846, -66207, -52028, -83284, 16236, 89282]. ->Min([92357, 26097, 35910, 48280, -60846, -66207, -52028, -83284, 16236, 89282]) = -83284
# Find the minimum number in the list [4005, -31711, -48819, 64066, -77862, -58471, 23276, 62204, 76923, -72264]. ->Min([4005, -31711, -48819, 64066, -77862, -58471, 23276, 62204, 76923, -72264]) = -77862
# Find the minimum number in the list [45843, -45121, -21432, -33903, -98167, -90289, -11847, -37364, -3597, -50667]. ->Min([45843, -45121, -21432, -33903, -98167, -90289, -11847, -37364, -3597, -50667]) = -98167
# Find the minimum number in the list [6507, 21352, -75007, 28091, -29012, 84853, -29505, -88826, 27096, 35269]. ->Min([6507, 21352, -75007, 28091, -29012, 84853, -29505, -88826, 27096, 35269]) = -88826
# Find the minimum number in the list [85404, 53674, -67276, -2628, -89417, -1166, -62140, 17342, 84852, 22701]. ->Min([85404, 53674, -67276, -2628, -89417, -1166, -62140, 17342, 84852, 22701]) = -89417
# Find the minimum number in the list [78792, 1109, 29329, -33081, -79736, 40037, -93420, -92978, 84245, -36094]. ->Min([78792, 1109, 29329, -33081, -79736, 40037, -93420, -92978, 84245, -36094]) = -93420
# Find the minimum number in the list [-55549, 49345, -45706, 60161, -33029, 28601, -61171, -39602, 88761, 68241]. ->Min([-55549, 49345, -45706, 60161, -33029, 28601, -61171, -39602, 88761, 68241]) = -61171
# Find the minimum number in the list [-81737, -52055, 76609, 13410, -963, -67045, 86816, -49051, 73591, 84848]. ->Min([-81737, -52055, 76609, 13410, -963, -67045, 86816, -49051, 73591, 84848]) = -81737
# Find the minimum number in the list [-77826, -79829, 37051, -39121, 89707, -14169, -63142, 8367, -44077, 36239]. ->Min([-77826, -79829, 37051, -39121, 89707, -14169, -63142, 8367, -44077, 36239]) = -79829
# Find the minimum number in the list [-83964, 42616, -36291, 34229, 85998, 93204, 85389, -39163, 24688, 19651]. ->Min([-83964, 42616, -36291, 34229, 85998, 93204, 85389, -39163, 24688, 19651]) = -83964
# Find the minimum number in the list [67802, 31496, -7441, 78647, -52965, -86577, 41888, 89228, 18340, -94540]. ->Min([67802, 31496, -7441, 78647, -52965, -86577, 41888, 89228, 18340, -94540]) = -94540
# Find the minimum number in the list [-3336, 85904, -65191, -38745, 34003, -54862, 53031, -50891, -96564, 4629]. ->Min([-3336, 85904, -65191, -38745, 34003, -54862, 53031, -50891, -96564, 4629]) = -96564
# Find the minimum number in the list [76418, -92808, 74978, -24892, -44979, 95230, -93502, -29145, 89957, -70075]. ->Min([76418, -92808, 74978, -24892, -44979, 95230, -93502, -29145, 89957, -70075]) = -93502
# Find the minimum number in the list [83665, -62355, 88063, -46988, -66494, 39347, -22280, 86194, -73170, -23741]. ->Min([83665, -62355, 88063, -46988, -66494, 39347, -22280, 86194, -73170, -23741]) = -73170
# Find the minimum number in the list [38506, 12793, -61706, 16769, 97113, 33902, 95051, 73273, -99997, 23995]. ->Min([38506, 12793, -61706, 16769, 97113, 33902, 95051, 73273, -99997, 23995]) = -99997
# Received responses for batch 85 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 86 of 86
# # of prompts:  25 # of responses:  25
# Find the minimum number in the list [89091, 43992, -85778, -11704, -29131, -46567, -29272, 97545, 40250, 55112]. ->Min([89091, 43992, -85778, -11704, -29131, -46567, -29272, 97545, 40250, 55112]) = -85778
# Find the minimum number in the list [43426, -48717, 34152, 76751, -38541, -60786, -15437, 61674, 7035, 83151]. ->Min([43426, -48717, 34152, 76751, -38541, -60786, -15437, 61674, 7035, 83151]) = -60786
# Find the minimum number in the list [-76490, -76062, 81350, -9334, -61894, -25499, -65598, -15704, -89220, -50026]. ->Min([-76490, -76062, 81350, -9334, -61894, -25499, -65598, -15704, -89220, -50026]) = -89220
# Find the minimum number in the list [-69446, -39106, 54146, -7086, -19762, -18004, -26253, 44914, -53633, 74632]. ->Min([-69446, -39106, 54146, -7086, -19762, -18004, -26253, 44914, -53633, 74632]) = -69446
# Find the minimum number in the list [59974, -18772, -41469, 93804, -23639, -10592, -63908, 43598, 82710, -23176]. ->Min([59974, -18772, -41469, 93804, -23639, -10592, -63908, 43598, 82710, -23176]) = -63908
# Find the minimum number in the list [-41079, -83165, 7603, -617, 59251, 35851, -27444, 99771, -22099, -75534]. ->Min([-41079, -83165, 7603, -617, 59251, 35851, -27444, 99771, -22099, -75534]) = -83165
# Find the minimum number in the list [-20766, -64169, 11539, 16961, 80541, 56847, -83032, 56283, 52873, 56233]. ->Min([-20766, -64169, 11539, 16961, 80541, 56847, -83032, 56283, 52873, 56233]) = -83032
# Find the minimum number in the list [62573, -50242, 611, 4944, -69963, 26137, 95768, -48903, -1845, -42233]. ->Min([62573, -50242, 611, 4944, -69963, 26137, 95768, -48903, -1845, -42233]) = -69963
# Find the minimum number in the list [-99201, 69603, -24979, -2348, 88702, 540, 82141, 96154, 32613, -29657]. ->Min([-99201, 69603, -24979, -2348, 88702, 540, 82141, 96154, 32613, -29657]) = -99201
# Find the minimum number in the list [-90901, -45134, 40906, -16899, 13462, -50272, -65973, 77158, -40123, 21891]. ->Min([-90901, -45134, 40906, -16899, 13462, -50272, -65973, 77158, -40123, 21891]) = -90901
# Find the minimum number in the list [8557, 5992, 39085, 38119, -59759, 95398, 68195, 78167, 68697, 44280]. ->Min([8557, 5992, 39085, 38119, -59759, 95398, 68195, 78167, 68697, 44280]) = -59759
# Find the minimum number in the list [56841, 90017, -17536, -44922, 64248, -47087, 98319, -24697, -21611, -52873]. ->Min([56841, 90017, -17536, -44922, 64248, -47087, 98319, -24697, -21611, -52873]) = -52873
# Find the minimum number in the list [-2506, -29939, -29402, -95311, -17197, 27681, -96216, 2872, -77292, 66143]. ->Min([-2506, -29939, -29402, -95311, -17197, 27681, -96216, 2872, -77292, 66143]) = -96216
# Find the minimum number in the list [-22149, -16143, 48049, 93206, 85267, -4897, -49177, -83928, -33526, 70088]. ->Min([-22149, -16143, 48049, 93206, 85267, -4897, -49177, -83928, -33526, 70088]) = -83928
# Find the minimum number in the list [-81675, -6368, 77846, 6286, 86765, -14170, 85664, 2587, 6322, 90406]. ->Min([-81675, -6368, 77846, 6286, 86765, -14170, 85664, 2587, 6322, 90406]) = -81675
# Find the minimum number in the list [-15176, -54627, -58237, -49840, -16199, -71733, 33126, -62180, 91995, 20070]. ->Min([-15176, -54627, -58237, -49840, -16199, -71733, 33126, -62180, 91995, 20070]) = -71733
# Find the minimum number in the list [-26934, -91120, 89881, -82616, -1219, 39467, 55164, 86725, -13235, -86832]. ->Min([-26934, -91120, 89881, -82616, -1219, 39467, 55164, 86725, -13235, -86832]) = -91120
# Find the minimum number in the list [-68197, -35386, 81631, -79381, -91845, 17978, 54896, -13751, 67054, 94210]. ->Min([-68197, -35386, 81631, -79381, -91845, 17978, 54896, -13751, 67054, 94210]) = -91845
# Find the minimum number in the list [80962, 15431, -37054, 14943, 13928, 65239, -26037, -79823, 26181, -34471]. ->Min([80962, 15431, -37054, 14943, 13928, 65239, -26037, -79823, 26181, -34471]) = -79823
# Find the minimum number in the list [68569, -26433, 46913, -92200, -53707, 38712, -21020, 5164, -71845, 65058]. ->Min([68569, -26433, 46913, -92200, -53707, 38712, -21020, 5164, -71845, 65058]) = -92200
# Find the minimum number in the list [-27222, -90204, -63001, 43332, -30737, 358, -1671, 88032, 11665, 14474]. ->Min([-27222, -90204, -63001, 43332, -30737, 358, -1671, 88032, 11665, 14474]) = -90204
# Find the minimum number in the list [75255, -87690, -64763, 19548, -11807, 67070, -9836, 94838, -94840, -13276]. ->Min([75255, -87690, -64763, 19548, -11807, 67070, -9836, 94838, -94840, -13276]) = -94840
# Find the minimum number in the list [33540, -84454, 30298, -59867, -38800, -34619, -60853, -6564, -13082, 22898]. ->Min([33540, -84454, 30298, -59867, -38800, -34619, -60853, -6564, -13082, 22898]) = -84454
# Find the minimum number in the list [-5170, -38085, -47214, 88705, -40987, 55836, 96801, 15191, 12451, 99379]. ->Min([-5170, -38085, -47214, 88705, -40987, 55836, 96801, 15191, 12451, 99379]) = -47214
# Find the minimum number in the list [6014, -1267, -18139, -86947, 84829, -22349, -43078, -46861, 57372, -81501]. ->Min([6014, -1267, -18139, -86947, 84829, -22349, -43078, -46861, 57372, -81501]) = -86947
# Received responses for batch 86 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Responses saved to gemini_response/list_min_responses.txt

# %% [markdown]
# ## For finding max

# %% [markdown]
# ### load data and create initial prompt

# %%
with open('../../data/lists.json','r') as file:
    data = json.load(file)

# create batches, batch sizes are heuristics and I tried out several
# batch sizes, although input token limit is 30,720 tokens, output token limit is 2048
# which restricts the batch size
size_dict = {'lists_size_3_pos':50,
             'lists_size_3_neg':50,
             'lists_size_5_pos':40,
             'lists_size_5_neg':40,
             'lists_size_10_pos':25,
             'lists_size_10_neg':25}

batch_prompts = []

for list in data:
    list_ = data[list]

    # get the batch size for the list
    BATCH_SIZE = size_dict[list]

    index = 0
    while index < len(list_):
        batch = []
        while index < len(list_):
            batch_prompt = [f"Find the maximum number in the list {list_[i]}." for i in range(index, min(index+BATCH_SIZE, len(list_)))]
            batch_prompts.append(batch_prompt)
            index += BATCH_SIZE


print("Number of batches:", len(batch_prompts))
print("Number of prompts in each batch:", [len(batch) for batch in batch_prompts])
# Out:
# Number of batches: 86
# Number of prompts in each batch: [50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 20, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 20, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25]

# %%
# give a prompt once and then generate the response,
# and then use this prompt+response directly instead of doing everytime

promt_saying_you_are_a_math_assistant = '''You are a math assistant. I will ask you to find the maximum number in a list. Please answer in the correct format. For example, if I ask 'Find the maximum number in the list [1, 2, 3]', you should answer 'Max([1, 2, 3]) = 3'. Each question is in a separate line. Please return each answer in a separate line. Do you understand ?'''
Initial_messages = [{'role':'user', 'parts': [promt_saying_you_are_a_math_assistant] }]

# get response from the model and then append it to the prompt
Initial_response = gemini.generate_content(Initial_messages)                                   
Initial_messages.append(Initial_response.candidates[0].content)

# %%
print(Initial_messages)
# Out:
# [{'role': 'user', 'parts': ["You are a math assistant. I will ask you to find the maximum number in a list. Please answer in the correct format. For example, if I ask 'Find the maximum number in the list [1, 2, 3]', you should answer 'Max([1, 2, 3]) = 3'. Each question is in a separate line. Please return each answer in a separate line. Do you understand ?"]}, parts {
#   text: "Yes, I understand. I will find the maximum number in a list and return the answer in the correct format.\n\nMax([1, 2, 3]) = 3\nMax([4, 5, 6]) = 6\nMax([7, 8, 9]) = 9"
# }
# role: "model"
# ]

# %%
import pickle

# save the initial messages to a file, in case we need to restart the conversation, initial message should be consistent
# across all batches
with open('initial_messages_max.pkl', 'wb') as file:
    pickle.dump(Initial_messages, file)

# %% [markdown]
# ### conduct experiment for max

# %%
# path to save responses
response_file = 'gemini_response/list_max_responses.txt'

# request per minute limit for free api
rpm = 60

# %%
for i, batch_prompt in enumerate(batch_prompts):
    
    # to start from a specific batch number, give (printed_batch_num -1) here
    batch_no_to_start_from = 0 
    if i < batch_no_to_start_from:
        continue

    # print status
    print(f"Sending batch {i+1} of {len(batch_prompts)}")

    num_prompts = len(batch_prompt)

    # create prompt for the batch
    curr_prompt = "".join([f"{prompt} \n " for prompt in batch_prompt])

    
    # create a complete prompt to send to the model
    complete_promt = Initial_messages.copy()
    complete_promt.append({'role':'user', 'parts': [curr_prompt]})

    # get response from the model, candidate_count is 1 because we only need one response,
    # temperature is 0 because we need deterministic responses
    response = gemini.generate_content( complete_promt,
                                        generation_config= genai.GenerationConfig(
                                        candidate_count = 1,
                                        temperature = 0.0,
                                        )
                                )
    
    try:
        # extract text from the response
        model_responses = response.candidates[0].content.parts.__getitem__(0).text.split('\n')
    except IndexError:
        # if model gives no response, fill with 0
        print("Error in response")
        model_responses = ["0"]*num_prompts

    # save responses to file
    with open(response_file, 'a') as file:
        for model_response in model_responses:
            file.write(model_response + '\n')

    
    #print the prompt and response separated by space
    print('# of prompts: ',len(batch_prompt),'# of responses: ', len(model_responses))


    for prompt, response in zip(batch_prompt, model_responses):
        print(prompt, response, sep=" ->")
    
    
    print("Received responses for batch", i+1, "of", len(batch_prompts))
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")

    time.sleep(60//rpm) #to avoid rate limit errors

print("Responses saved to", response_file)
# Out:
# Sending batch 1 of 86
# # of prompts:  50 # of responses:  50
# Find the maximum number in the list [1, 0, 4]. ->Max([1, 0, 4]) = 4
# Find the maximum number in the list [6, 0, 0]. ->Max([6, 0, 0]) = 6
# Find the maximum number in the list [3, 8, 6]. ->Max([3, 8, 6]) = 8
# Find the maximum number in the list [5, 4, 2]. ->Max([5, 4, 2]) = 5
# Find the maximum number in the list [5, 9, 4]. ->Max([5, 9, 4]) = 9
# Find the maximum number in the list [4, 9, 5]. ->Max([4, 9, 5]) = 9
# Find the maximum number in the list [3, 1, 6]. ->Max([3, 1, 6]) = 6
# Find the maximum number in the list [4, 1, 9]. ->Max([4, 1, 9]) = 9
# Find the maximum number in the list [8, 3, 5]. ->Max([8, 3, 5]) = 8
# Find the maximum number in the list [3, 9, 5]. ->Max([3, 9, 5]) = 9
# Find the maximum number in the list [3, 8, 8]. ->Max([3, 8, 8]) = 8
# Find the maximum number in the list [2, 8, 7]. ->Max([2, 8, 7]) = 8
# Find the maximum number in the list [1, 6, 6]. ->Max([1, 6, 6]) = 6
# Find the maximum number in the list [8, 4, 5]. ->Max([8, 4, 5]) = 8
# Find the maximum number in the list [8, 2, 8]. ->Max([8, 2, 8]) = 8
# Find the maximum number in the list [2, 8, 8]. ->Max([2, 8, 8]) = 8
# Find the maximum number in the list [4, 3, 0]. ->Max([4, 3, 0]) = 4
# Find the maximum number in the list [2, 2, 7]. ->Max([2, 2, 7]) = 7
# Find the maximum number in the list [8, 3, 4]. ->Max([8, 3, 4]) = 8
# Find the maximum number in the list [3, 1, 5]. ->Max([3, 1, 5]) = 5
# Find the maximum number in the list [1, 0, 3]. ->Max([1, 0, 3]) = 3
# Find the maximum number in the list [7, 3, 8]. ->Max([7, 3, 8]) = 8
# Find the maximum number in the list [3, 1, 1]. ->Max([3, 1, 1]) = 3
# Find the maximum number in the list [0, 6, 5]. ->Max([0, 6, 5]) = 6
# Find the maximum number in the list [6, 2, 4]. ->Max([6, 2, 4]) = 6
# Find the maximum number in the list [8, 0, 1]. ->Max([8, 0, 1]) = 8
# Find the maximum number in the list [0, 2, 6]. ->Max([0, 2, 6]) = 6
# Find the maximum number in the list [7, 2, 3]. ->Max([7, 2, 3]) = 7
# Find the maximum number in the list [0, 0, 9]. ->Max([0, 0, 9]) = 9
# Find the maximum number in the list [2, 1, 9]. ->Max([2, 1, 9]) = 9
# Find the maximum number in the list [9, 0, 9]. ->Max([9, 0, 9]) = 9
# Find the maximum number in the list [3, 5, 3]. ->Max([3, 5, 3]) = 5
# Find the maximum number in the list [0, 7, 9]. ->Max([0, 7, 9]) = 9
# Find the maximum number in the list [2, 5, 1]. ->Max([2, 5, 1]) = 5
# Find the maximum number in the list [9, 8, 0]. ->Max([9, 8, 0]) = 9
# Find the maximum number in the list [8, 2, 4]. ->Max([8, 2, 4]) = 8
# Find the maximum number in the list [7, 4, 0]. ->Max([7, 4, 0]) = 7
# Find the maximum number in the list [4, 2, 7]. ->Max([4, 2, 7]) = 7
# Find the maximum number in the list [8, 0, 5]. ->Max([8, 0, 5]) = 8
# Find the maximum number in the list [5, 0, 5]. ->Max([5, 0, 5]) = 5
# Find the maximum number in the list [2, 3, 2]. ->Max([2, 3, 2]) = 3
# Find the maximum number in the list [4, 2, 1]. ->Max([4, 2, 1]) = 4
# Find the maximum number in the list [4, 3, 3]. ->Max([4, 3, 3]) = 4
# Find the maximum number in the list [5, 8, 6]. ->Max([5, 8, 6]) = 8
# Find the maximum number in the list [4, 0, 1]. ->Max([4, 0, 1]) = 4
# Find the maximum number in the list [1, 6, 9]. ->Max([1, 6, 9]) = 9
# Find the maximum number in the list [3, 5, 6]. ->Max([3, 5, 6]) = 6
# Find the maximum number in the list [4, 6, 5]. ->Max([4, 6, 5]) = 6
# Find the maximum number in the list [2, 9, 9]. ->Max([2, 9, 9]) = 9
# Find the maximum number in the list [6, 9, 9]. ->Max([6, 9, 9]) = 9
# Received responses for batch 1 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 2 of 86
# # of prompts:  50 # of responses:  50
# Find the maximum number in the list [2, 1, 4]. ->Max([2, 1, 4]) = 4
# Find the maximum number in the list [3, 2, 0]. ->Max([3, 2, 0]) = 3
# Find the maximum number in the list [9, 3, 6]. ->Max([9, 3, 6]) = 9
# Find the maximum number in the list [3, 2, 8]. ->Max([3, 2, 8]) = 8
# Find the maximum number in the list [7, 8, 8]. ->Max([7, 8, 8]) = 8
# Find the maximum number in the list [7, 2, 7]. ->Max([7, 2, 7]) = 7
# Find the maximum number in the list [4, 7, 1]. ->Max([4, 7, 1]) = 7
# Find the maximum number in the list [2, 2, 3]. ->Max([2, 2, 3]) = 3
# Find the maximum number in the list [8, 7, 6]. ->Max([8, 7, 6]) = 8
# Find the maximum number in the list [6, 7, 0]. ->Max([6, 7, 0]) = 7
# Find the maximum number in the list [3, 7, 3]. ->Max([3, 7, 3]) = 7
# Find the maximum number in the list [2, 7, 2]. ->Max([2, 7, 2]) = 7
# Find the maximum number in the list [1, 6, 2]. ->Max([1, 6, 2]) = 6
# Find the maximum number in the list [7, 5, 5]. ->Max([7, 5, 5]) = 7
# Find the maximum number in the list [8, 0, 5]. ->Max([8, 0, 5]) = 8
# Find the maximum number in the list [9, 2, 3]. ->Max([9, 2, 3]) = 9
# Find the maximum number in the list [5, 2, 9]. ->Max([5, 2, 9]) = 9
# Find the maximum number in the list [4, 9, 6]. ->Max([4, 9, 6]) = 9
# Find the maximum number in the list [9, 1, 9]. ->Max([9, 1, 9]) = 9
# Find the maximum number in the list [5, 0, 6]. ->Max([5, 0, 6]) = 6
# Find the maximum number in the list [2, 8, 4]. ->Max([2, 8, 4]) = 8
# Find the maximum number in the list [5, 3, 1]. ->Max([5, 3, 1]) = 5
# Find the maximum number in the list [5, 0, 7]. ->Max([5, 0, 7]) = 7
# Find the maximum number in the list [4, 9, 4]. ->Max([4, 9, 4]) = 9
# Find the maximum number in the list [7, 8, 3]. ->Max([7, 8, 3]) = 8
# Find the maximum number in the list [6, 3, 4]. ->Max([6, 3, 4]) = 6
# Find the maximum number in the list [8, 5, 5]. ->Max([8, 5, 5]) = 8
# Find the maximum number in the list [5, 1, 8]. ->Max([5, 1, 8]) = 8
# Find the maximum number in the list [9, 4, 1]. ->Max([9, 4, 1]) = 9
# Find the maximum number in the list [8, 2, 4]. ->Max([8, 2, 4]) = 8
# Find the maximum number in the list [0, 9, 4]. ->Max([0, 9, 4]) = 9
# Find the maximum number in the list [7, 1, 1]. ->Max([7, 1, 1]) = 7
# Find the maximum number in the list [9, 4, 1]. ->Max([9, 4, 1]) = 9
# Find the maximum number in the list [3, 8, 6]. ->Max([3, 8, 6]) = 8
# Find the maximum number in the list [9, 0, 9]. ->Max([9, 0, 9]) = 9
# Find the maximum number in the list [2, 8, 1]. ->Max([2, 8, 1]) = 8
# Find the maximum number in the list [0, 3, 4]. ->Max([0, 3, 4]) = 4
# Find the maximum number in the list [6, 1, 8]. ->Max([6, 1, 8]) = 8
# Find the maximum number in the list [4, 9, 9]. ->Max([4, 9, 9]) = 9
# Find the maximum number in the list [8, 8, 7]. ->Max([8, 8, 7]) = 8
# Find the maximum number in the list [4, 0, 1]. ->Max([4, 0, 1]) = 4
# Find the maximum number in the list [2, 7, 8]. ->Max([2, 7, 8]) = 8
# Find the maximum number in the list [7, 5, 6]. ->Max([7, 5, 6]) = 7
# Find the maximum number in the list [4, 6, 8]. ->Max([4, 6, 8]) = 8
# Find the maximum number in the list [6, 8, 0]. ->Max([6, 8, 0]) = 8
# Find the maximum number in the list [9, 7, 7]. ->Max([9, 7, 7]) = 9
# Find the maximum number in the list [7, 1, 0]. ->Max([7, 1, 0]) = 7
# Find the maximum number in the list [6, 1, 3]. ->Max([6, 1, 3]) = 6
# Find the maximum number in the list [4, 6, 7]. ->Max([4, 6, 7]) = 7
# Find the maximum number in the list [9, 8, 2]. ->Max([9, 8, 2]) = 9
# Received responses for batch 2 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 3 of 86
# # of prompts:  50 # of responses:  50
# Find the maximum number in the list [36, 92, 38]. ->Max([36, 92, 38]) = 92
# Find the maximum number in the list [61, 44, 42]. ->Max([61, 44, 42]) = 61
# Find the maximum number in the list [89, 30, 73]. ->Max([89, 30, 73]) = 89
# Find the maximum number in the list [60, 90, 48]. ->Max([60, 90, 48]) = 90
# Find the maximum number in the list [64, 75, 42]. ->Max([64, 75, 42]) = 75
# Find the maximum number in the list [18, 52, 83]. ->Max([18, 52, 83]) = 83
# Find the maximum number in the list [50, 83, 10]. ->Max([50, 83, 10]) = 83
# Find the maximum number in the list [97, 62, 69]. ->Max([97, 62, 69]) = 97
# Find the maximum number in the list [29, 95, 11]. ->Max([29, 95, 11]) = 95
# Find the maximum number in the list [21, 88, 38]. ->Max([21, 88, 38]) = 88
# Find the maximum number in the list [55, 18, 31]. ->Max([55, 18, 31]) = 55
# Find the maximum number in the list [10, 78, 48]. ->Max([10, 78, 48]) = 78
# Find the maximum number in the list [59, 81, 32]. ->Max([59, 81, 32]) = 81
# Find the maximum number in the list [69, 20, 9]. ->Max([69, 20, 9]) = 69
# Find the maximum number in the list [32, 58, 38]. ->Max([32, 58, 38]) = 58
# Find the maximum number in the list [45, 73, 37]. ->Max([45, 73, 37]) = 73
# Find the maximum number in the list [72, 87, 99]. ->Max([72, 87, 99]) = 99
# Find the maximum number in the list [29, 77, 45]. ->Max([29, 77, 45]) = 77
# Find the maximum number in the list [92, 98, 84]. ->Max([92, 98, 84]) = 98
# Find the maximum number in the list [39, 56, 4]. ->Max([39, 56, 4]) = 56
# Find the maximum number in the list [95, 53, 22]. ->Max([95, 53, 22]) = 95
# Find the maximum number in the list [21, 32, 61]. ->Max([21, 32, 61]) = 61
# Find the maximum number in the list [96, 28, 86]. ->Max([96, 28, 86]) = 96
# Find the maximum number in the list [1, 33, 68]. ->Max([1, 33, 68]) = 68
# Find the maximum number in the list [74, 48, 81]. ->Max([74, 48, 81]) = 81
# Find the maximum number in the list [71, 41, 78]. ->Max([71, 41, 78]) = 78
# Find the maximum number in the list [83, 52, 14]. ->Max([83, 52, 14]) = 83
# Find the maximum number in the list [30, 68, 17]. ->Max([30, 68, 17]) = 68
# Find the maximum number in the list [53, 75, 95]. ->Max([53, 75, 95]) = 95
# Find the maximum number in the list [52, 35, 4]. ->Max([52, 35, 4]) = 52
# Find the maximum number in the list [12, 87, 47]. ->Max([12, 87, 47]) = 87
# Find the maximum number in the list [15, 58, 11]. ->Max([15, 58, 11]) = 58
# Find the maximum number in the list [42, 31, 16]. ->Max([42, 31, 16]) = 42
# Find the maximum number in the list [27, 29, 42]. ->Max([27, 29, 42]) = 42
# Find the maximum number in the list [69, 32, 22]. ->Max([69, 32, 22]) = 69
# Find the maximum number in the list [75, 41, 2]. ->Max([75, 41, 2]) = 75
# Find the maximum number in the list [14, 95, 8]. ->Max([14, 95, 8]) = 95
# Find the maximum number in the list [57, 64, 28]. ->Max([57, 64, 28]) = 64
# Find the maximum number in the list [82, 3, 7]. ->Max([82, 3, 7]) = 82
# Find the maximum number in the list [56, 9, 10]. ->Max([56, 9, 10]) = 56
# Find the maximum number in the list [81, 74, 70]. ->Max([81, 74, 70]) = 81
# Find the maximum number in the list [64, 77, 55]. ->Max([64, 77, 55]) = 77
# Find the maximum number in the list [92, 27, 55]. ->Max([92, 27, 55]) = 92
# Find the maximum number in the list [93, 12, 40]. ->Max([93, 12, 40]) = 93
# Find the maximum number in the list [60, 8, 11]. ->Max([60, 8, 11]) = 60
# Find the maximum number in the list [16, 71, 7]. ->Max([16, 71, 7]) = 71
# Find the maximum number in the list [45, 85, 96]. ->Max([45, 85, 96]) = 96
# Find the maximum number in the list [13, 73, 64]. ->Max([13, 73, 64]) = 73
# Find the maximum number in the list [71, 47, 14]. ->Max([71, 47, 14]) = 71
# Find the maximum number in the list [79, 78, 86]. ->Max([79, 78, 86]) = 86
# Received responses for batch 3 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 4 of 86
# # of prompts:  50 # of responses:  50
# Find the maximum number in the list [3, 23, 34]. ->Max([3, 23, 34]) = 34
# Find the maximum number in the list [18, 72, 84]. ->Max([18, 72, 84]) = 84
# Find the maximum number in the list [95, 67, 27]. ->Max([95, 67, 27]) = 95
# Find the maximum number in the list [92, 41, 99]. ->Max([92, 41, 99]) = 99
# Find the maximum number in the list [79, 6, 86]. ->Max([79, 6, 86]) = 86
# Find the maximum number in the list [56, 53, 34]. ->Max([56, 53, 34]) = 56
# Find the maximum number in the list [36, 86, 86]. ->Max([36, 86, 86]) = 86
# Find the maximum number in the list [50, 76, 7]. ->Max([50, 76, 7]) = 76
# Find the maximum number in the list [32, 37, 41]. ->Max([32, 37, 41]) = 41
# Find the maximum number in the list [48, 68, 90]. ->Max([48, 68, 90]) = 90
# Find the maximum number in the list [94, 5, 55]. ->Max([94, 5, 55]) = 94
# Find the maximum number in the list [51, 90, 81]. ->Max([51, 90, 81]) = 90
# Find the maximum number in the list [79, 58, 88]. ->Max([79, 58, 88]) = 88
# Find the maximum number in the list [51, 67, 10]. ->Max([51, 67, 10]) = 67
# Find the maximum number in the list [21, 9, 65]. ->Max([21, 9, 65]) = 65
# Find the maximum number in the list [44, 93, 82]. ->Max([44, 93, 82]) = 93
# Find the maximum number in the list [77, 19, 97]. ->Max([77, 19, 97]) = 97
# Find the maximum number in the list [59, 96, 72]. ->Max([59, 96, 72]) = 96
# Find the maximum number in the list [79, 41, 80]. ->Max([79, 41, 80]) = 80
# Find the maximum number in the list [38, 35, 75]. ->Max([38, 35, 75]) = 75
# Find the maximum number in the list [4, 7, 47]. ->Max([4, 7, 47]) = 47
# Find the maximum number in the list [49, 59, 74]. ->Max([49, 59, 74]) = 74
# Find the maximum number in the list [41, 77, 60]. ->Max([41, 77, 60]) = 77
# Find the maximum number in the list [10, 64, 82]. ->Max([10, 64, 82]) = 82
# Find the maximum number in the list [66, 78, 20]. ->Max([66, 78, 20]) = 78
# Find the maximum number in the list [86, 76, 6]. ->Max([86, 76, 6]) = 86
# Find the maximum number in the list [86, 49, 36]. ->Max([86, 49, 36]) = 86
# Find the maximum number in the list [74, 84, 18]. ->Max([74, 84, 18]) = 84
# Find the maximum number in the list [76, 90, 10]. ->Max([76, 90, 10]) = 90
# Find the maximum number in the list [89, 94, 87]. ->Max([89, 94, 87]) = 94
# Find the maximum number in the list [2, 46, 39]. ->Max([2, 46, 39]) = 46
# Find the maximum number in the list [17, 19, 9]. ->Max([17, 19, 9]) = 19
# Find the maximum number in the list [4, 84, 43]. ->Max([4, 84, 43]) = 84
# Find the maximum number in the list [23, 88, 98]. ->Max([23, 88, 98]) = 98
# Find the maximum number in the list [86, 92, 30]. ->Max([86, 92, 30]) = 92
# Find the maximum number in the list [68, 30, 39]. ->Max([68, 30, 39]) = 68
# Find the maximum number in the list [98, 36, 99]. ->Max([98, 36, 99]) = 99
# Find the maximum number in the list [17, 32, 6]. ->Max([17, 32, 6]) = 32
# Find the maximum number in the list [15, 36, 10]. ->Max([15, 36, 10]) = 36
# Find the maximum number in the list [11, 28, 57]. ->Max([11, 28, 57]) = 57
# Find the maximum number in the list [30, 49, 10]. ->Max([30, 49, 10]) = 49
# Find the maximum number in the list [42, 18, 17]. ->Max([42, 18, 17]) = 42
# Find the maximum number in the list [60, 57, 78]. ->Max([60, 57, 78]) = 78
# Find the maximum number in the list [93, 77, 67]. ->Max([93, 77, 67]) = 93
# Find the maximum number in the list [6, 30, 53]. ->Max([6, 30, 53]) = 53
# Find the maximum number in the list [68, 2, 80]. ->Max([68, 2, 80]) = 80
# Find the maximum number in the list [0, 78, 45]. ->Max([0, 78, 45]) = 78
# Find the maximum number in the list [67, 46, 8]. ->Max([67, 46, 8]) = 67
# Find the maximum number in the list [60, 5, 81]. ->Max([60, 5, 81]) = 81
# Find the maximum number in the list [44, 30, 93]. ->Max([44, 30, 93]) = 93
# Received responses for batch 4 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 5 of 86
# # of prompts:  50 # of responses:  50
# Find the maximum number in the list [340, 136, 45]. ->Max([340, 136, 45]) = 340
# Find the maximum number in the list [797, 701, 475]. ->Max([797, 701, 475]) = 797
# Find the maximum number in the list [733, 794, 966]. ->Max([733, 794, 966]) = 966
# Find the maximum number in the list [907, 42, 323]. ->Max([907, 42, 323]) = 907
# Find the maximum number in the list [259, 37, 771]. ->Max([259, 37, 771]) = 771
# Find the maximum number in the list [886, 671, 339]. ->Max([886, 671, 339]) = 886
# Find the maximum number in the list [761, 450, 916]. ->Max([761, 450, 916]) = 916
# Find the maximum number in the list [509, 376, 946]. ->Max([509, 376, 946]) = 946
# Find the maximum number in the list [80, 440, 616]. ->Max([80, 440, 616]) = 616
# Find the maximum number in the list [335, 676, 302]. ->Max([335, 676, 302]) = 676
# Find the maximum number in the list [454, 359, 457]. ->Max([454, 359, 457]) = 457
# Find the maximum number in the list [281, 654, 810]. ->Max([281, 654, 810]) = 810
# Find the maximum number in the list [525, 820, 767]. ->Max([525, 820, 767]) = 820
# Find the maximum number in the list [694, 800, 448]. ->Max([694, 800, 448]) = 800
# Find the maximum number in the list [370, 392, 972]. ->Max([370, 392, 972]) = 972
# Find the maximum number in the list [379, 380, 454]. ->Max([379, 380, 454]) = 454
# Find the maximum number in the list [321, 665, 285]. ->Max([321, 665, 285]) = 665
# Find the maximum number in the list [530, 396, 935]. ->Max([530, 396, 935]) = 935
# Find the maximum number in the list [219, 626, 292]. ->Max([219, 626, 292]) = 626
# Find the maximum number in the list [75, 462, 176]. ->Max([75, 462, 176]) = 462
# Find the maximum number in the list [865, 327, 683]. ->Max([865, 327, 683]) = 865
# Find the maximum number in the list [307, 871, 161]. ->Max([307, 871, 161]) = 871
# Find the maximum number in the list [370, 520, 229]. ->Max([370, 520, 229]) = 520
# Find the maximum number in the list [26, 369, 567]. ->Max([26, 369, 567]) = 567
# Find the maximum number in the list [905, 88, 67]. ->Max([905, 88, 67]) = 905
# Find the maximum number in the list [787, 419, 843]. ->Max([787, 419, 843]) = 843
# Find the maximum number in the list [460, 477, 696]. ->Max([460, 477, 696]) = 696
# Find the maximum number in the list [655, 601, 186]. ->Max([655, 601, 186]) = 655
# Find the maximum number in the list [56, 851, 127]. ->Max([56, 851, 127]) = 851
# Find the maximum number in the list [726, 230, 354]. ->Max([726, 230, 354]) = 726
# Find the maximum number in the list [256, 201, 650]. ->Max([256, 201, 650]) = 650
# Find the maximum number in the list [546, 95, 514]. ->Max([546, 95, 514]) = 546
# Find the maximum number in the list [674, 639, 737]. ->Max([674, 639, 737]) = 737
# Find the maximum number in the list [845, 884, 29]. ->Max([845, 884, 29]) = 884
# Find the maximum number in the list [666, 215, 785]. ->Max([666, 215, 785]) = 785
# Find the maximum number in the list [642, 558, 296]. ->Max([642, 558, 296]) = 642
# Find the maximum number in the list [701, 415, 304]. ->Max([701, 415, 304]) = 701
# Find the maximum number in the list [495, 475, 208]. ->Max([495, 475, 208]) = 495
# Find the maximum number in the list [751, 881, 353]. ->Max([751, 881, 353]) = 881
# Find the maximum number in the list [108, 326, 247]. ->Max([108, 326, 247]) = 326
# Find the maximum number in the list [51, 297, 968]. ->Max([51, 297, 968]) = 968
# Find the maximum number in the list [923, 163, 833]. ->Max([923, 163, 833]) = 923
# Find the maximum number in the list [163, 510, 527]. ->Max([163, 510, 527]) = 527
# Find the maximum number in the list [967, 402, 517]. ->Max([967, 402, 517]) = 967
# Find the maximum number in the list [51, 288, 506]. ->Max([51, 288, 506]) = 506
# Find the maximum number in the list [549, 8, 867]. ->Max([549, 8, 867]) = 867
# Find the maximum number in the list [782, 412, 374]. ->Max([782, 412, 374]) = 782
# Find the maximum number in the list [566, 295, 75]. ->Max([566, 295, 75]) = 566
# Find the maximum number in the list [638, 696, 625]. ->Max([638, 696, 625]) = 696
# Find the maximum number in the list [347, 571, 961]. ->Max([347, 571, 961]) = 961
# Received responses for batch 5 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 6 of 86
# # of prompts:  50 # of responses:  50
# Find the maximum number in the list [512, 41, 46]. ->Max([512, 41, 46]) = 512
# Find the maximum number in the list [467, 152, 620]. ->Max([467, 152, 620]) = 620
# Find the maximum number in the list [166, 402, 631]. ->Max([166, 402, 631]) = 631
# Find the maximum number in the list [521, 545, 501]. ->Max([521, 545, 501]) = 545
# Find the maximum number in the list [339, 689, 112]. ->Max([339, 689, 112]) = 689
# Find the maximum number in the list [704, 644, 27]. ->Max([704, 644, 27]) = 704
# Find the maximum number in the list [794, 592, 591]. ->Max([794, 592, 591]) = 794
# Find the maximum number in the list [644, 738, 634]. ->Max([644, 738, 634]) = 738
# Find the maximum number in the list [32, 586, 970]. ->Max([32, 586, 970]) = 970
# Find the maximum number in the list [155, 422, 707]. ->Max([155, 422, 707]) = 707
# Find the maximum number in the list [893, 868, 753]. ->Max([893, 868, 753]) = 893
# Find the maximum number in the list [332, 678, 489]. ->Max([332, 678, 489]) = 678
# Find the maximum number in the list [545, 350, 559]. ->Max([545, 350, 559]) = 559
# Find the maximum number in the list [822, 709, 270]. ->Max([822, 709, 270]) = 822
# Find the maximum number in the list [305, 230, 964]. ->Max([305, 230, 964]) = 964
# Find the maximum number in the list [721, 500, 324]. ->Max([721, 500, 324]) = 721
# Find the maximum number in the list [280, 294, 124]. ->Max([280, 294, 124]) = 294
# Find the maximum number in the list [353, 977, 791]. ->Max([353, 977, 791]) = 977
# Find the maximum number in the list [80, 354, 946]. ->Max([80, 354, 946]) = 946
# Find the maximum number in the list [847, 551, 277]. ->Max([847, 551, 277]) = 847
# Find the maximum number in the list [758, 600, 245]. ->Max([758, 600, 245]) = 758
# Find the maximum number in the list [238, 53, 102]. ->Max([238, 53, 102]) = 238
# Find the maximum number in the list [140, 5, 987]. ->Max([140, 5, 987]) = 987
# Find the maximum number in the list [899, 487, 488]. ->Max([899, 487, 488]) = 899
# Find the maximum number in the list [661, 60, 929]. ->Max([661, 60, 929]) = 929
# Find the maximum number in the list [740, 870, 959]. ->Max([740, 870, 959]) = 959
# Find the maximum number in the list [180, 956, 941]. ->Max([180, 956, 941]) = 956
# Find the maximum number in the list [766, 985, 893]. ->Max([766, 985, 893]) = 985
# Find the maximum number in the list [617, 109, 950]. ->Max([617, 109, 950]) = 950
# Find the maximum number in the list [910, 961, 137]. ->Max([910, 961, 137]) = 961
# Find the maximum number in the list [338, 166, 748]. ->Max([338, 166, 748]) = 748
# Find the maximum number in the list [345, 809, 302]. ->Max([345, 809, 302]) = 809
# Find the maximum number in the list [654, 918, 415]. ->Max([654, 918, 415]) = 918
# Find the maximum number in the list [97, 189, 143]. ->Max([97, 189, 143]) = 189
# Find the maximum number in the list [241, 457, 771]. ->Max([241, 457, 771]) = 771
# Find the maximum number in the list [11, 267, 669]. ->Max([11, 267, 669]) = 669
# Find the maximum number in the list [314, 163, 415]. ->Max([314, 163, 415]) = 415
# Find the maximum number in the list [318, 706, 120]. ->Max([318, 706, 120]) = 706
# Find the maximum number in the list [224, 980, 136]. ->Max([224, 980, 136]) = 980
# Find the maximum number in the list [718, 562, 934]. ->Max([718, 562, 934]) = 934
# Find the maximum number in the list [780, 253, 696]. ->Max([780, 253, 696]) = 780
# Find the maximum number in the list [540, 720, 370]. ->Max([540, 720, 370]) = 720
# Find the maximum number in the list [924, 517, 207]. ->Max([924, 517, 207]) = 924
# Find the maximum number in the list [452, 119, 696]. ->Max([452, 119, 696]) = 696
# Find the maximum number in the list [456, 828, 56]. ->Max([456, 828, 56]) = 828
# Find the maximum number in the list [572, 473, 688]. ->Max([572, 473, 688]) = 688
# Find the maximum number in the list [3, 763, 223]. ->Max([3, 763, 223]) = 763
# Find the maximum number in the list [554, 61, 957]. ->Max([554, 61, 957]) = 957
# Find the maximum number in the list [184, 787, 138]. ->Max([184, 787, 138]) = 787
# Find the maximum number in the list [912, 391, 459]. ->Max([912, 391, 459]) = 912
# Received responses for batch 6 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 7 of 86
# # of prompts:  50 # of responses:  50
# Find the maximum number in the list [8835, 2178, 5697]. ->Max([8835, 2178, 5697]) = 8835
# Find the maximum number in the list [56, 372, 4888]. ->Max([56, 372, 4888]) = 4888
# Find the maximum number in the list [7546, 5671, 2541]. ->Max([7546, 5671, 2541]) = 7546
# Find the maximum number in the list [3376, 1102, 1653]. ->Max([3376, 1102, 1653]) = 3376
# Find the maximum number in the list [6590, 7191, 3839]. ->Max([6590, 7191, 3839]) = 7191
# Find the maximum number in the list [9438, 5224, 9461]. ->Max([9438, 5224, 9461]) = 9461
# Find the maximum number in the list [6775, 4923, 4508]. ->Max([6775, 4923, 4508]) = 6775
# Find the maximum number in the list [768, 5642, 6244]. ->Max([768, 5642, 6244]) = 6244
# Find the maximum number in the list [3012, 8813, 7758]. ->Max([3012, 8813, 7758]) = 8813
# Find the maximum number in the list [6761, 6824, 9130]. ->Max([6761, 6824, 9130]) = 9130
# Find the maximum number in the list [1295, 7369, 6079]. ->Max([1295, 7369, 6079]) = 7369
# Find the maximum number in the list [9878, 647, 1192]. ->Max([9878, 647, 1192]) = 9878
# Find the maximum number in the list [4967, 251, 3470]. ->Max([4967, 251, 3470]) = 4967
# Find the maximum number in the list [3921, 9045, 5269]. ->Max([3921, 9045, 5269]) = 9045
# Find the maximum number in the list [5892, 8401, 8147]. ->Max([5892, 8401, 8147]) = 8401
# Find the maximum number in the list [6781, 749, 9216]. ->Max([6781, 749, 9216]) = 9216
# Find the maximum number in the list [6841, 4836, 2497]. ->Max([6841, 4836, 2497]) = 6841
# Find the maximum number in the list [9021, 5530, 4216]. ->Max([9021, 5530, 4216]) = 9021
# Find the maximum number in the list [8954, 8000, 3015]. ->Max([8954, 8000, 3015]) = 8954
# Find the maximum number in the list [6756, 2252, 3791]. ->Max([6756, 2252, 3791]) = 6756
# Find the maximum number in the list [990, 7916, 7993]. ->Max([990, 7916, 7993]) = 7993
# Find the maximum number in the list [8673, 4501, 8777]. ->Max([8673, 4501, 8777]) = 8777
# Find the maximum number in the list [8591, 2439, 3948]. ->Max([8591, 2439, 3948]) = 8591
# Find the maximum number in the list [6112, 6652, 7520]. ->Max([6112, 6652, 7520]) = 7520
# Find the maximum number in the list [6640, 6213, 6179]. ->Max([6640, 6213, 6179]) = 6640
# Find the maximum number in the list [7109, 5427, 9270]. ->Max([7109, 5427, 9270]) = 9270
# Find the maximum number in the list [4441, 762, 1218]. ->Max([4441, 762, 1218]) = 4441
# Find the maximum number in the list [3394, 9617, 2362]. ->Max([3394, 9617, 2362]) = 9617
# Find the maximum number in the list [6375, 8856, 5435]. ->Max([6375, 8856, 5435]) = 8856
# Find the maximum number in the list [7161, 3803, 1245]. ->Max([7161, 3803, 1245]) = 7161
# Find the maximum number in the list [7381, 8038, 3737]. ->Max([7381, 8038, 3737]) = 8038
# Find the maximum number in the list [1404, 4839, 4037]. ->Max([1404, 4839, 4037]) = 4839
# Find the maximum number in the list [5188, 5909, 1745]. ->Max([5188, 5909, 1745]) = 5909
# Find the maximum number in the list [2170, 1430, 3070]. ->Max([2170, 1430, 3070]) = 3070
# Find the maximum number in the list [430, 1468, 5798]. ->Max([430, 1468, 5798]) = 5798
# Find the maximum number in the list [4781, 6779, 6353]. ->Max([4781, 6779, 6353]) = 6779
# Find the maximum number in the list [2777, 2274, 4405]. ->Max([2777, 2274, 4405]) = 4405
# Find the maximum number in the list [4521, 6899, 4911]. ->Max([4521, 6899, 4911]) = 6899
# Find the maximum number in the list [3203, 7501, 1752]. ->Max([3203, 7501, 1752]) = 7501
# Find the maximum number in the list [7212, 5484, 7055]. ->Max([7212, 5484, 7055]) = 7212
# Find the maximum number in the list [5147, 2910, 6524]. ->Max([5147, 2910, 6524]) = 6524
# Find the maximum number in the list [4592, 6437, 5980]. ->Max([4592, 6437, 5980]) = 6437
# Find the maximum number in the list [440, 7563, 3434]. ->Max([440, 7563, 3434]) = 7563
# Find the maximum number in the list [3965, 4139, 2525]. ->Max([3965, 4139, 2525]) = 3965
# Find the maximum number in the list [6566, 8755, 8300]. ->Max([6566, 8755, 8300]) = 8755
# Find the maximum number in the list [1791, 4067, 5816]. ->Max([1791, 4067, 5816]) = 5816
# Find the maximum number in the list [172, 1615, 4239]. ->Max([172, 1615, 4239]) = 4239
# Find the maximum number in the list [7303, 6129, 6408]. ->Max([7303, 6129, 6408]) = 7303
# Find the maximum number in the list [1712, 4840, 6815]. ->Max([1712, 4840, 6815]) = 6815
# Find the maximum number in the list [3389, 8537, 7912]. ->Max([3389, 8537, 7912]) = 8537
# Received responses for batch 7 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 8 of 86
# # of prompts:  50 # of responses:  50
# Find the maximum number in the list [4919, 732, 1885]. ->Max([4919, 732, 1885]) = 4919
# Find the maximum number in the list [9042, 2623, 5422]. ->Max([9042, 2623, 5422]) = 9042
# Find the maximum number in the list [7080, 6481, 478]. ->Max([7080, 6481, 478]) = 7080
# Find the maximum number in the list [3371, 4560, 1025]. ->Max([3371, 4560, 1025]) = 4560
# Find the maximum number in the list [7496, 1867, 4298]. ->Max([7496, 1867, 4298]) = 7496
# Find the maximum number in the list [1871, 5700, 5766]. ->Max([1871, 5700, 5766]) = 5766
# Find the maximum number in the list [1931, 3908, 5003]. ->Max([1931, 3908, 5003]) = 5003
# Find the maximum number in the list [9771, 2258, 9417]. ->Max([9771, 2258, 9417]) = 9771
# Find the maximum number in the list [2733, 8022, 4732]. ->Max([2733, 8022, 4732]) = 8022
# Find the maximum number in the list [7939, 2236, 3196]. ->Max([7939, 2236, 3196]) = 7939
# Find the maximum number in the list [7272, 8006, 2740]. ->Max([7272, 8006, 2740]) = 8006
# Find the maximum number in the list [3683, 8808, 4729]. ->Max([3683, 8808, 4729]) = 8808
# Find the maximum number in the list [9383, 1871, 4389]. ->Max([9383, 1871, 4389]) = 9383
# Find the maximum number in the list [6965, 1677, 4055]. ->Max([6965, 1677, 4055]) = 6965
# Find the maximum number in the list [1923, 3882, 3438]. ->Max([1923, 3882, 3438]) = 3882
# Find the maximum number in the list [3390, 972, 9340]. ->Max([3390, 972, 9340]) = 9340
# Find the maximum number in the list [4794, 4740, 9383]. ->Max([4794, 4740, 9383]) = 9383
# Find the maximum number in the list [2078, 2174, 4090]. ->Max([2078, 2174, 4090]) = 4090
# Find the maximum number in the list [4402, 6786, 6146]. ->Max([4402, 6786, 6146]) = 6786
# Find the maximum number in the list [7449, 7996, 5362]. ->Max([7449, 7996, 5362]) = 7996
# Find the maximum number in the list [6516, 3568, 7039]. ->Max([6516, 3568, 7039]) = 7039
# Find the maximum number in the list [9468, 2139, 9275]. ->Max([9468, 2139, 9275]) = 9468
# Find the maximum number in the list [2035, 2588, 7230]. ->Max([2035, 2588, 7230]) = 7230
# Find the maximum number in the list [4489, 1529, 5905]. ->Max([4489, 1529, 5905]) = 5905
# Find the maximum number in the list [3836, 7032, 1494]. ->Max([3836, 7032, 1494]) = 7032
# Find the maximum number in the list [3705, 8510, 7291]. ->Max([3705, 8510, 7291]) = 8510
# Find the maximum number in the list [1160, 3751, 6276]. ->Max([1160, 3751, 6276]) = 6276
# Find the maximum number in the list [6270, 2181, 2340]. ->Max([6270, 2181, 2340]) = 6270
# Find the maximum number in the list [5753, 3490, 2480]. ->Max([5753, 3490, 2480]) = 5753
# Find the maximum number in the list [9659, 6291, 5759]. ->Max([9659, 6291, 5759]) = 9659
# Find the maximum number in the list [9066, 9846, 9830]. ->Max([9066, 9846, 9830]) = 9846
# Find the maximum number in the list [8348, 3090, 6418]. ->Max([8348, 3090, 6418]) = 8348
# Find the maximum number in the list [8185, 9730, 1163]. ->Max([8185, 9730, 1163]) = 9730
# Find the maximum number in the list [6895, 5986, 8951]. ->Max([6895, 5986, 8951]) = 8951
# Find the maximum number in the list [4295, 3534, 652]. ->Max([4295, 3534, 652]) = 4295
# Find the maximum number in the list [6590, 1350, 8791]. ->Max([6590, 1350, 8791]) = 8791
# Find the maximum number in the list [3329, 2545, 8788]. ->Max([3329, 2545, 8788]) = 8788
# Find the maximum number in the list [948, 4005, 1412]. ->Max([948, 4005, 1412]) = 4005
# Find the maximum number in the list [1956, 207, 2248]. ->Max([1956, 207, 2248]) = 2248
# Find the maximum number in the list [2735, 6092, 2079]. ->Max([2735, 6092, 2079]) = 6092
# Find the maximum number in the list [1046, 4308, 9447]. ->Max([1046, 4308, 9447]) = 9447
# Find the maximum number in the list [9287, 2734, 6024]. ->Max([9287, 2734, 6024]) = 9287
# Find the maximum number in the list [42, 721, 201]. ->Max([42, 721, 201]) = 721
# Find the maximum number in the list [579, 9058, 6870]. ->Max([579, 9058, 6870]) = 9058
# Find the maximum number in the list [9364, 6108, 1956]. ->Max([9364, 6108, 1956]) = 9364
# Find the maximum number in the list [1129, 7620, 4625]. ->Max([1129, 7620, 4625]) = 7620
# Find the maximum number in the list [3287, 4777, 9237]. ->Max([3287, 4777, 9237]) = 9237
# Find the maximum number in the list [8954, 4016, 2466]. ->Max([8954, 4016, 2466]) = 8954
# Find the maximum number in the list [5488, 23, 6164]. ->Max([5488, 23, 6164]) = 6164
# Find the maximum number in the list [981, 2332, 4584]. ->Max([981, 2332, 4584]) = 4584
# Received responses for batch 8 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 9 of 86
# # of prompts:  50 # of responses:  50
# Find the maximum number in the list [98028, 11128, 76122]. ->Max([98028, 11128, 76122]) = 98028
# Find the maximum number in the list [74425, 8163, 57014]. ->Max([74425, 8163, 57014]) = 74425
# Find the maximum number in the list [91845, 96384, 42762]. ->Max([91845, 96384, 42762]) = 96384
# Find the maximum number in the list [76638, 14283, 20369]. ->Max([76638, 14283, 20369]) = 76638
# Find the maximum number in the list [70244, 46961, 27215]. ->Max([70244, 46961, 27215]) = 70244
# Find the maximum number in the list [89922, 39874, 92367]. ->Max([89922, 39874, 92367]) = 92367
# Find the maximum number in the list [93212, 32534, 46627]. ->Max([93212, 32534, 46627]) = 93212
# Find the maximum number in the list [4073, 53004, 59270]. ->Max([4073, 53004, 59270]) = 59270
# Find the maximum number in the list [18322, 15919, 1567]. ->Max([18322, 15919, 1567]) = 18322
# Find the maximum number in the list [82614, 84500, 11015]. ->Max([82614, 84500, 11015]) = 84500
# Find the maximum number in the list [84670, 58121, 16880]. ->Max([84670, 58121, 16880]) = 84670
# Find the maximum number in the list [75220, 56774, 94952]. ->Max([75220, 56774, 94952]) = 94952
# Find the maximum number in the list [46392, 28143, 24530]. ->Max([46392, 28143, 24530]) = 46392
# Find the maximum number in the list [80868, 32215, 84840]. ->Max([80868, 32215, 84840]) = 84840
# Find the maximum number in the list [36670, 50202, 17987]. ->Max([36670, 50202, 17987]) = 50202
# Find the maximum number in the list [2559, 50134, 93502]. ->Max([2559, 50134, 93502]) = 93502
# Find the maximum number in the list [42153, 50905, 35446]. ->Max([42153, 50905, 35446]) = 50905
# Find the maximum number in the list [7679, 61824, 69393]. ->Max([7679, 61824, 69393]) = 69393
# Find the maximum number in the list [31608, 34934, 69951]. ->Max([31608, 34934, 69951]) = 69951
# Find the maximum number in the list [23081, 31005, 77662]. ->Max([23081, 31005, 77662]) = 77662
# Find the maximum number in the list [91823, 46095, 74403]. ->Max([91823, 46095, 74403]) = 91823
# Find the maximum number in the list [23010, 64282, 4975]. ->Max([23010, 64282, 4975]) = 64282
# Find the maximum number in the list [62650, 89, 43481]. ->Max([62650, 89, 43481]) = 62650
# Find the maximum number in the list [7806, 2872, 19360]. ->Max([7806, 2872, 19360]) = 19360
# Find the maximum number in the list [48967, 92345, 86787]. ->Max([48967, 92345, 86787]) = 92345
# Find the maximum number in the list [20644, 95990, 57261]. ->Max([20644, 95990, 57261]) = 95990
# Find the maximum number in the list [90906, 80440, 46769]. ->Max([90906, 80440, 46769]) = 90906
# Find the maximum number in the list [90242, 38602, 16691]. ->Max([90242, 38602, 16691]) = 90242
# Find the maximum number in the list [4244, 23865, 78956]. ->Max([4244, 23865, 78956]) = 78956
# Find the maximum number in the list [18434, 43406, 97693]. ->Max([18434, 43406, 97693]) = 97693
# Find the maximum number in the list [92925, 87821, 83768]. ->Max([92925, 87821, 83768]) = 92925
# Find the maximum number in the list [90855, 8885, 45938]. ->Max([90855, 8885, 45938]) = 90855
# Find the maximum number in the list [96021, 55004, 21802]. ->Max([96021, 55004, 21802]) = 96021
# Find the maximum number in the list [62847, 75766, 85323]. ->Max([62847, 75766, 85323]) = 85323
# Find the maximum number in the list [38654, 2631, 41774]. ->Max([38654, 2631, 41774]) = 41774
# Find the maximum number in the list [95942, 9830, 71702]. ->Max([95942, 9830, 71702]) = 95942
# Find the maximum number in the list [56534, 85673, 21626]. ->Max([56534, 85673, 21626]) = 85673
# Find the maximum number in the list [24901, 53645, 91382]. ->Max([24901, 53645, 91382]) = 91382
# Find the maximum number in the list [38980, 31135, 12571]. ->Max([38980, 31135, 12571]) = 38980
# Find the maximum number in the list [47294, 500, 56047]. ->Max([47294, 500, 56047]) = 56047
# Find the maximum number in the list [12712, 3373, 27125]. ->Max([12712, 3373, 27125]) = 27125
# Find the maximum number in the list [52096, 61727, 64106]. ->Max([52096, 61727, 64106]) = 64106
# Find the maximum number in the list [48630, 49996, 48418]. ->Max([48630, 49996, 48418]) = 49996
# Find the maximum number in the list [29654, 35200, 73956]. ->Max([29654, 35200, 73956]) = 73956
# Find the maximum number in the list [87574, 45061, 70968]. ->Max([87574, 45061, 70968]) = 87574
# Find the maximum number in the list [68495, 54870, 70190]. ->Max([68495, 54870, 70190]) = 70190
# Find the maximum number in the list [51747, 93625, 4551]. ->Max([51747, 93625, 4551]) = 93625
# Find the maximum number in the list [15765, 99246, 58856]. ->Max([15765, 99246, 58856]) = 99246
# Find the maximum number in the list [10271, 89538, 57067]. ->Max([10271, 89538, 57067]) = 89538
# Find the maximum number in the list [8783, 11406, 50868]. ->Max([8783, 11406, 50868]) = 50868
# Received responses for batch 9 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 10 of 86
# # of prompts:  50 # of responses:  50
# Find the maximum number in the list [1620, 91804, 81665]. ->Max([1620, 91804, 81665]) = 91804
# Find the maximum number in the list [74264, 77061, 76372]. ->Max([74264, 77061, 76372]) = 77061
# Find the maximum number in the list [45071, 53856, 34620]. ->Max([45071, 53856, 34620]) = 53856
# Find the maximum number in the list [22570, 36099, 52818]. ->Max([22570, 36099, 52818]) = 52818
# Find the maximum number in the list [51877, 43449, 90507]. ->Max([51877, 43449, 90507]) = 90507
# Find the maximum number in the list [44284, 39722, 40756]. ->Max([44284, 39722, 40756]) = 44284
# Find the maximum number in the list [39384, 97481, 58079]. ->Max([39384, 97481, 58079]) = 97481
# Find the maximum number in the list [24633, 57896, 27707]. ->Max([24633, 57896, 27707]) = 57896
# Find the maximum number in the list [67537, 20836, 8600]. ->Max([67537, 20836, 8600]) = 67537
# Find the maximum number in the list [3794, 22772, 25265]. ->Max([3794, 22772, 25265]) = 25265
# Find the maximum number in the list [92357, 26097, 35910]. ->Max([92357, 26097, 35910]) = 92357
# Find the maximum number in the list [4005, 31711, 48819]. ->Max([4005, 31711, 48819]) = 48819
# Find the maximum number in the list [45843, 45121, 21432]. ->Max([45843, 45121, 21432]) = 45843
# Find the maximum number in the list [6507, 21352, 75007]. ->Max([6507, 21352, 75007]) = 75007
# Find the maximum number in the list [85404, 53674, 67276]. ->Max([85404, 53674, 67276]) = 85404
# Find the maximum number in the list [78792, 1109, 29329]. ->Max([78792, 1109, 29329]) = 78792
# Find the maximum number in the list [55549, 49345, 45706]. ->Max([55549, 49345, 45706]) = 55549
# Find the maximum number in the list [81737, 52055, 76609]. ->Max([81737, 52055, 76609]) = 81737
# Find the maximum number in the list [77826, 79829, 37051]. ->Max([77826, 79829, 37051]) = 79829
# Find the maximum number in the list [83964, 42616, 36291]. ->Max([83964, 42616, 36291]) = 83964
# Find the maximum number in the list [67802, 31496, 7441]. ->Max([67802, 31496, 7441]) = 67802
# Find the maximum number in the list [3336, 85904, 65191]. ->Max([3336, 85904, 65191]) = 85904
# Find the maximum number in the list [76418, 92808, 74978]. ->Max([76418, 92808, 74978]) = 92808
# Find the maximum number in the list [83665, 62355, 88063]. ->Max([83665, 62355, 88063]) = 88063
# Find the maximum number in the list [38506, 12793, 61706]. ->Max([38506, 12793, 61706]) = 61706
# Find the maximum number in the list [89091, 43992, 85778]. ->Max([89091, 43992, 85778]) = 89091
# Find the maximum number in the list [43426, 48717, 34152]. ->Max([43426, 48717, 34152]) = 48717
# Find the maximum number in the list [76490, 76062, 81350]. ->Max([76490, 76062, 81350]) = 81350
# Find the maximum number in the list [69446, 39106, 54146]. ->Max([69446, 39106, 54146]) = 69446
# Find the maximum number in the list [59974, 18772, 41469]. ->Max([59974, 18772, 41469]) = 59974
# Find the maximum number in the list [41079, 83165, 7603]. ->Max([41079, 83165, 7603]) = 83165
# Find the maximum number in the list [20766, 64169, 11539]. ->Max([20766, 64169, 11539]) = 64169
# Find the maximum number in the list [62573, 50242, 611]. ->Max([62573, 50242, 611]) = 62573
# Find the maximum number in the list [99201, 69603, 24979]. ->Max([99201, 69603, 24979]) = 99201
# Find the maximum number in the list [90901, 45134, 40906]. ->Max([90901, 45134, 40906]) = 90901
# Find the maximum number in the list [8557, 5992, 39085]. ->Max([8557, 5992, 39085]) = 39085
# Find the maximum number in the list [56841, 90017, 17536]. ->Max([56841, 90017, 17536]) = 90017
# Find the maximum number in the list [2506, 29939, 29402]. ->Max([2506, 29939, 29402]) = 29939
# Find the maximum number in the list [22149, 16143, 48049]. ->Max([22149, 16143, 48049]) = 48049
# Find the maximum number in the list [81675, 6368, 77846]. ->Max([81675, 6368, 77846]) = 81675
# Find the maximum number in the list [15176, 54627, 58237]. ->Max([15176, 54627, 58237]) = 58237
# Find the maximum number in the list [26934, 91120, 89881]. ->Max([26934, 91120, 89881]) = 91120
# Find the maximum number in the list [68197, 35386, 81631]. ->Max([68197, 35386, 81631]) = 81631
# Find the maximum number in the list [80962, 15431, 37054]. ->Max([80962, 15431, 37054]) = 80962
# Find the maximum number in the list [68569, 26433, 46913]. ->Max([68569, 26433, 46913]) = 68569
# Find the maximum number in the list [27222, 90204, 63001]. ->Max([27222, 90204, 63001]) = 90204
# Find the maximum number in the list [75255, 87690, 64763]. ->Max([75255, 87690, 64763]) = 87690
# Find the maximum number in the list [33540, 84454, 30298]. ->Max([33540, 84454, 30298]) = 84454
# Find the maximum number in the list [5170, 38085, 47214]. ->Max([5170, 38085, 47214]) = 47214
# Find the maximum number in the list [6014, 1267, 18139]. ->Max([6014, 1267, 18139]) = 18139
# Received responses for batch 10 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 11 of 86
# # of prompts:  40 # of responses:  40
# Find the maximum number in the list [1, 0, 4, 3, 3]. ->Max([1, 0, 4, 3, 3]) = 4
# Find the maximum number in the list [6, 0, 0, 1, 3]. ->Max([6, 0, 0, 1, 3]) = 6
# Find the maximum number in the list [3, 8, 6, 3, 7]. ->Max([3, 8, 6, 3, 7]) = 8
# Find the maximum number in the list [5, 4, 2, 3, 5]. ->Max([5, 4, 2, 3, 5]) = 5
# Find the maximum number in the list [5, 9, 4, 0, 7]. ->Max([5, 9, 4, 0, 7]) = 9
# Find the maximum number in the list [4, 9, 5, 9, 3]. ->Max([4, 9, 5, 9, 3]) = 9
# Find the maximum number in the list [3, 1, 6, 4, 7]. ->Max([3, 1, 6, 4, 7]) = 7
# Find the maximum number in the list [4, 1, 9, 2, 8]. ->Max([4, 1, 9, 2, 8]) = 9
# Find the maximum number in the list [8, 3, 5, 0, 3]. ->Max([8, 3, 5, 0, 3]) = 8
# Find the maximum number in the list [3, 9, 5, 3, 7]. ->Max([3, 9, 5, 3, 7]) = 9
# Find the maximum number in the list [3, 8, 8, 4, 9]. ->Max([3, 8, 8, 4, 9]) = 9
# Find the maximum number in the list [2, 8, 7, 1, 0]. ->Max([2, 8, 7, 1, 0]) = 8
# Find the maximum number in the list [1, 6, 6, 9, 7]. ->Max([1, 6, 6, 9, 7]) = 9
# Find the maximum number in the list [8, 4, 5, 1, 4]. ->Max([8, 4, 5, 1, 4]) = 8
# Find the maximum number in the list [8, 2, 8, 1, 4]. ->Max([8, 2, 8, 1, 4]) = 8
# Find the maximum number in the list [2, 8, 8, 0, 9]. ->Max([2, 8, 8, 0, 9]) = 9
# Find the maximum number in the list [4, 3, 0, 3, 9]. ->Max([4, 3, 0, 3, 9]) = 9
# Find the maximum number in the list [2, 2, 7, 8, 2]. ->Max([2, 2, 7, 8, 2]) = 8
# Find the maximum number in the list [8, 3, 4, 6, 5]. ->Max([8, 3, 4, 6, 5]) = 8
# Find the maximum number in the list [3, 1, 5, 0, 9]. ->Max([3, 1, 5, 0, 9]) = 9
# Find the maximum number in the list [1, 0, 3, 1, 0]. ->Max([1, 0, 3, 1, 0]) = 3
# Find the maximum number in the list [7, 3, 8, 2, 9]. ->Max([7, 3, 8, 2, 9]) = 9
# Find the maximum number in the list [3, 1, 1, 6, 5]. ->Max([3, 1, 1, 6, 5]) = 6
# Find the maximum number in the list [0, 6, 5, 1, 3]. ->Max([0, 6, 5, 1, 3]) = 6
# Find the maximum number in the list [6, 2, 4, 7, 3]. ->Max([6, 2, 4, 7, 3]) = 7
# Find the maximum number in the list [8, 0, 1, 3, 2]. ->Max([8, 0, 1, 3, 2]) = 8
# Find the maximum number in the list [0, 2, 6, 0, 6]. ->Max([0, 2, 6, 0, 6]) = 6
# Find the maximum number in the list [7, 2, 3, 4, 3]. ->Max([7, 2, 3, 4, 3]) = 7
# Find the maximum number in the list [0, 0, 9, 7, 8]. ->Max([0, 0, 9, 7, 8]) = 9
# Find the maximum number in the list [2, 1, 9, 1, 3]. ->Max([2, 1, 9, 1, 3]) = 9
# Find the maximum number in the list [9, 0, 9, 1, 6]. ->Max([9, 0, 9, 1, 6]) = 9
# Find the maximum number in the list [3, 5, 3, 4, 6]. ->Max([3, 5, 3, 4, 6]) = 6
# Find the maximum number in the list [0, 7, 9, 9, 1]. ->Max([0, 7, 9, 9, 1]) = 9
# Find the maximum number in the list [2, 5, 1, 3, 5]. ->Max([2, 5, 1, 3, 5]) = 5
# Find the maximum number in the list [9, 8, 0, 8, 4]. ->Max([9, 8, 0, 8, 4]) = 9
# Find the maximum number in the list [8, 2, 4, 4, 9]. ->Max([8, 2, 4, 4, 9]) = 9
# Find the maximum number in the list [7, 4, 0, 1, 6]. ->Max([7, 4, 0, 1, 6]) = 7
# Find the maximum number in the list [4, 2, 7, 8, 6]. ->Max([4, 2, 7, 8, 6]) = 8
# Find the maximum number in the list [8, 0, 5, 9, 8]. ->Max([8, 0, 5, 9, 8]) = 9
# Find the maximum number in the list [5, 0, 5, 3, 3]. ->Max([5, 0, 5, 3, 3]) = 5
# Received responses for batch 11 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 12 of 86
# # of prompts:  40 # of responses:  40
# Find the maximum number in the list [2, 3, 2, 2, 6]. ->Max([2, 3, 2, 2, 6]) = 6
# Find the maximum number in the list [4, 2, 1, 6, 0]. ->Max([4, 2, 1, 6, 0]) = 6
# Find the maximum number in the list [4, 3, 3, 0, 3]. ->Max([4, 3, 3, 0, 3]) = 4
# Find the maximum number in the list [5, 8, 6, 8, 5]. ->Max([5, 8, 6, 8, 5]) = 8
# Find the maximum number in the list [4, 0, 1, 9, 6]. ->Max([4, 0, 1, 9, 6]) = 9
# Find the maximum number in the list [1, 6, 9, 3, 4]. ->Max([1, 6, 9, 3, 4]) = 9
# Find the maximum number in the list [3, 5, 6, 1, 5]. ->Max([3, 5, 6, 1, 5]) = 6
# Find the maximum number in the list [4, 6, 5, 6, 4]. ->Max([4, 6, 5, 6, 4]) = 6
# Find the maximum number in the list [2, 9, 9, 4, 6]. ->Max([2, 9, 9, 4, 6]) = 9
# Find the maximum number in the list [6, 9, 9, 5, 7]. ->Max([6, 9, 9, 5, 7]) = 9
# Find the maximum number in the list [2, 1, 4, 8, 9]. ->Max([2, 1, 4, 8, 9]) = 9
# Find the maximum number in the list [3, 2, 0, 0, 3]. ->Max([3, 2, 0, 0, 3]) = 3
# Find the maximum number in the list [9, 3, 6, 7, 6]. ->Max([9, 3, 6, 7, 6]) = 9
# Find the maximum number in the list [3, 2, 8, 7, 0]. ->Max([3, 2, 8, 7, 0]) = 8
# Find the maximum number in the list [7, 8, 8, 9, 5]. ->Max([7, 8, 8, 9, 5]) = 9
# Find the maximum number in the list [7, 2, 7, 7, 4]. ->Max([7, 2, 7, 7, 4]) = 7
# Find the maximum number in the list [4, 7, 1, 4, 3]. ->Max([4, 7, 1, 4, 3]) = 7
# Find the maximum number in the list [2, 2, 3, 6, 2]. ->Max([2, 2, 3, 6, 2]) = 6
# Find the maximum number in the list [8, 7, 6, 0, 3]. ->Max([8, 7, 6, 0, 3]) = 8
# Find the maximum number in the list [6, 7, 0, 5, 4]. ->Max([6, 7, 0, 5, 4]) = 7
# Find the maximum number in the list [3, 7, 3, 4, 6]. ->Max([3, 7, 3, 4, 6]) = 7
# Find the maximum number in the list [2, 7, 2, 9, 8]. ->Max([2, 7, 2, 9, 8]) = 9
# Find the maximum number in the list [1, 6, 2, 7, 2]. ->Max([1, 6, 2, 7, 2]) = 7
# Find the maximum number in the list [7, 5, 5, 6, 4]. ->Max([7, 5, 5, 6, 4]) = 7
# Find the maximum number in the list [8, 0, 5, 3, 1]. ->Max([8, 0, 5, 3, 1]) = 8
# Find the maximum number in the list [9, 2, 3, 2, 7]. ->Max([9, 2, 3, 2, 7]) = 9
# ...
# Received responses for batch 83 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 84 of 86
# # of prompts:  25 # of responses:  25
# Find the maximum number in the list [-20644, 95990, 57261, -83789, 63858, -85089, -41586, -22833, 92691, -73659]. ->Max([-20644, 95990, 57261, -83789, 63858, -85089, -41586, -22833, 92691, -73659]) = 95990
# Find the maximum number in the list [90906, 80440, -46769, -29260, -87232, 77194, -22983, -49595, -40215, -96206]. ->Max([90906, 80440, -46769, -29260, -87232, 77194, -22983, -49595, -40215, -96206]) = 90906
# Find the maximum number in the list [90242, 38602, -16691, 23292, 95529, 235, 92013, -75082, 51327, 74381]. ->Max([90242, 38602, -16691, 23292, 95529, 235, 92013, -75082, 51327, 74381]) = 95529
# Find the maximum number in the list [4244, -23865, 78956, -41709, -80134, 28953, -83839, -74127, -13645, 65035]. ->Max([4244, -23865, 78956, -41709, -80134, 28953, -83839, -74127, -13645, 65035]) = 78956
# Find the maximum number in the list [-18434, 43406, -97693, 10198, 31194, -45457, -41879, 22005, -83386, 11629]. ->Max([-18434, 43406, -97693, 10198, 31194, -45457, -41879, 22005, -83386, 11629]) = 43406
# Find the maximum number in the list [92925, -87821, 83768, 95588, -44007, -58540, -1493, -34761, 27483, 32707]. ->Max([92925, -87821, 83768, 95588, -44007, -58540, -1493, -34761, 27483, 32707]) = 95588
# Find the maximum number in the list [-90855, -8885, -45938, -33640, 14160, -94426, -167, 6310, 50585, 57438]. ->Max([-90855, -8885, -45938, -33640, 14160, -94426, -167, 6310, 50585, 57438]) = 57438
# Find the maximum number in the list [-96021, -55004, -21802, -54266, -64629, -49638, 46036, -71568, -49197, 13294]. ->Max([-96021, -55004, -21802, -54266, -64629, -49638, 46036, -71568, -49197, 13294]) = 46036
# Find the maximum number in the list [-62847, 75766, 85323, -99384, -90067, 29567, -21319, -59151, 9661, 4379]. ->Max([-62847, 75766, 85323, -99384, -90067, 29567, -21319, -59151, 9661, 4379]) = 85323
# Find the maximum number in the list [38654, -2631, -41774, 34226, 13726, -9725, 44801, 22296, -49212, 21090]. ->Max([38654, -2631, -41774, 34226, 13726, -9725, 44801, 22296, -49212, 21090]) = 44801
# Find the maximum number in the list [95942, 9830, -71702, 12203, -44295, -77860, 80431, -63273, 92340, -4062]. ->Max([95942, 9830, -71702, 12203, -44295, -77860, 80431, -63273, 92340, -4062]) = 95942
# Find the maximum number in the list [56534, 85673, 21626, -79602, 56911, -20591, -7019, -13272, 43397, 26941]. ->Max([56534, 85673, 21626, -79602, 56911, -20591, -7019, -13272, 43397, 26941]) = 85673
# Find the maximum number in the list [24901, 53645, 91382, 72628, 94638, -95679, 70795, 34768, -86585, -36899]. ->Max([24901, 53645, 91382, 72628, 94638, -95679, 70795, 34768, -86585, -36899]) = 94638
# Find the maximum number in the list [-38980, -31135, 12571, -6505, 51498, 74943, -72045, 64349, -20131, -7144]. ->Max([-38980, -31135, 12571, -6505, 51498, 74943, -72045, 64349, -20131, -7144]) = 74943
# Find the maximum number in the list [-47294, 500, 56047, 11485, -38607, 86772, -81931, -78671, 62957, 26171]. ->Max([-47294, 500, 56047, 11485, -38607, 86772, -81931, -78671, 62957, 26171]) = 86772
# Find the maximum number in the list [-12712, -3373, 27125, 22391, -83648, 38248, -10739, -62071, 15139, -40416]. ->Max([-12712, -3373, 27125, 22391, -83648, 38248, -10739, -62071, 15139, -40416]) = 38248
# Find the maximum number in the list [52096, 61727, -64106, 86643, -34734, -11945, -84130, 71319, 50793, 24232]. ->Max([52096, 61727, -64106, 86643, -34734, -11945, -84130, 71319, 50793, 24232]) = 86643
# Find the maximum number in the list [48630, -49996, 48418, 24455, 58428, -5848, 34510, 57637, -60956, 34524]. ->Max([48630, -49996, 48418, 24455, 58428, -5848, 34510, 57637, -60956, 34524]) = 58428
# Find the maximum number in the list [29654, 35200, 73956, 8079, -19808, 98596, 91287, 87486, 12675, -11233]. ->Max([29654, 35200, 73956, 8079, -19808, 98596, 91287, 87486, 12675, -11233]) = 98596
# Find the maximum number in the list [-87574, 45061, 70968, 54262, -99150, 77296, 29820, 72561, 7993, -50738]. ->Max([-87574, 45061, 70968, 54262, -99150, 77296, 29820, 72561, 7993, -50738]) = 77296
# Find the maximum number in the list [-68495, -54870, 70190, -90055, -62236, 75066, -30886, -62424, -39171, 10348]. ->Max([-68495, -54870, 70190, -90055, -62236, 75066, -30886, -62424, -39171, 10348]) = 75066
# Find the maximum number in the list [-51747, -93625, 4551, 65811, -74870, 67740, 74905, -88805, 81300, -19326]. ->Max([-51747, -93625, 4551, 65811, -74870, 67740, 74905, -88805, 81300, -19326]) = 81300
# Find the maximum number in the list [-15765, -99246, 58856, 22659, 21910, -27772, -25260, -16539, 5593, -55492]. ->Max([-15765, -99246, 58856, 22659, 21910, -27772, -25260, -16539, 5593, -55492]) = 58856
# Find the maximum number in the list [-10271, -89538, 57067, -26465, -82211, 19382, 77994, 33801, -41910, -95302]. ->Max([-10271, -89538, 57067, -26465, -82211, 19382, 77994, 33801, -41910, -95302]) = 77994
# Find the maximum number in the list [-8783, -11406, 50868, 72923, 52082, 72358, 42746, -36202, -68116, 60051]. ->Max([-8783, -11406, 50868, 72923, 52082, 72358, 42746, -36202, -68116, 60051]) = 72923
# Received responses for batch 84 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 85 of 86
# # of prompts:  25 # of responses:  25
# Find the maximum number in the list [1620, 91804, -81665, 77014, 68493, 54997, 14748, 54321, -19613, 19424]. ->Max([1620, 91804, -81665, 77014, 68493, 54997, 14748, 54321, -19613, 19424]) = 91804
# Find the maximum number in the list [-74264, 77061, -76372, -99402, 13133, 13845, -73752, -13237, 37498, -70206]. ->Max([-74264, 77061, -76372, -99402, 13133, 13845, -73752, -13237, 37498, -70206]) = 77061
# Find the maximum number in the list [45071, 53856, 34620, -50206, 85824, -63646, 74976, -79817, -62003, -4910]. ->Max([45071, 53856, 34620, -50206, 85824, -63646, 74976, -79817, -62003, -4910]) = 85824
# Find the maximum number in the list [22570, 36099, 52818, 18855, 81034, -79777, 89235, -90919, -52654, -5083]. ->Max([22570, 36099, 52818, 18855, 81034, -79777, 89235, -90919, -52654, -5083]) = 89235
# Find the maximum number in the list [51877, -43449, 90507, -31139, -6460, -97746, 62287, 35203, -48816, 2651]. ->Max([51877, -43449, 90507, -31139, -6460, -97746, 62287, 35203, -48816, 2651]) = 90507
# Find the maximum number in the list [44284, 39722, 40756, 36745, -64437, -91250, 89764, 12873, -29878, -17614]. ->Max([44284, 39722, 40756, 36745, -64437, -91250, 89764, 12873, -29878, -17614]) = 89764
# Find the maximum number in the list [39384, -97481, 58079, 42056, 35313, 95525, 54627, -79295, 84614, -11703]. ->Max([39384, -97481, 58079, 42056, 35313, 95525, 54627, -79295, 84614, -11703]) = 95525
# Find the maximum number in the list [-24633, 57896, -27707, -53368, 97117, 63499, -99548, 67698, -49009, -7367]. ->Max([-24633, 57896, -27707, -53368, 97117, 63499, -99548, 67698, -49009, -7367]) = 97117
# Find the maximum number in the list [67537, -20836, -8600, -40779, -93004, -66426, 52872, -17779, 68719, -74537]. ->Max([67537, -20836, -8600, -40779, -93004, -66426, 52872, -17779, 68719, -74537]) = 68719
# Find the maximum number in the list [3794, -22772, 25265, -26309, 7553, 32701, 4334, -59827, 6626, 47235]. ->Max([3794, -22772, 25265, -26309, 7553, 32701, 4334, -59827, 6626, 47235]) = 47235
# Find the maximum number in the list [92357, 26097, 35910, 48280, -60846, -66207, -52028, -83284, 16236, 89282]. ->Max([92357, 26097, 35910, 48280, -60846, -66207, -52028, -83284, 16236, 89282]) = 92357
# Find the maximum number in the list [4005, -31711, -48819, 64066, -77862, -58471, 23276, 62204, 76923, -72264]. ->Max([4005, -31711, -48819, 64066, -77862, -58471, 23276, 62204, 76923, -72264]) = 76923
# Find the maximum number in the list [45843, -45121, -21432, -33903, -98167, -90289, -11847, -37364, -3597, -50667]. ->Max([45843, -45121, -21432, -33903, -98167, -90289, -11847, -37364, -3597, -50667]) = 45843
# Find the maximum number in the list [6507, 21352, -75007, 28091, -29012, 84853, -29505, -88826, 27096, 35269]. ->Max([6507, 21352, -75007, 28091, -29012, 84853, -29505, -88826, 27096, 35269]) = 84853
# Find the maximum number in the list [85404, 53674, -67276, -2628, -89417, -1166, -62140, 17342, 84852, 22701]. ->Max([85404, 53674, -67276, -2628, -89417, -1166, -62140, 17342, 84852, 22701]) = 85404
# Find the maximum number in the list [78792, 1109, 29329, -33081, -79736, 40037, -93420, -92978, 84245, -36094]. ->Max([78792, 1109, 29329, -33081, -79736, 40037, -93420, -92978, 84245, -36094]) = 84245
# Find the maximum number in the list [-55549, 49345, -45706, 60161, -33029, 28601, -61171, -39602, 88761, 68241]. ->Max([-55549, 49345, -45706, 60161, -33029, 28601, -61171, -39602, 88761, 68241]) = 88761
# Find the maximum number in the list [-81737, -52055, 76609, 13410, -963, -67045, 86816, -49051, 73591, 84848]. ->Max([-81737, -52055, 76609, 13410, -963, -67045, 86816, -49051, 73591, 84848]) = 86816
# Find the maximum number in the list [-77826, -79829, 37051, -39121, 89707, -14169, -63142, 8367, -44077, 36239]. ->Max([-77826, -79829, 37051, -39121, 89707, -14169, -63142, 8367, -44077, 36239]) = 89707
# Find the maximum number in the list [-83964, 42616, -36291, 34229, 85998, 93204, 85389, -39163, 24688, 19651]. ->Max([-83964, 42616, -36291, 34229, 85998, 93204, 85389, -39163, 24688, 19651]) = 93204
# Find the maximum number in the list [67802, 31496, -7441, 78647, -52965, -86577, 41888, 89228, 18340, -94540]. ->Max([67802, 31496, -7441, 78647, -52965, -86577, 41888, 89228, 18340, -94540]) = 89228
# Find the maximum number in the list [-3336, 85904, -65191, -38745, 34003, -54862, 53031, -50891, -96564, 4629]. ->Max([-3336, 85904, -65191, -38745, 34003, -54862, 53031, -50891, -96564, 4629]) = 85904
# Find the maximum number in the list [76418, -92808, 74978, -24892, -44979, 95230, -93502, -29145, 89957, -70075]. ->Max([76418, -92808, 74978, -24892, -44979, 95230, -93502, -29145, 89957, -70075]) = 95230
# Find the maximum number in the list [83665, -62355, 88063, -46988, -66494, 39347, -22280, 86194, -73170, -23741]. ->Max([83665, -62355, 88063, -46988, -66494, 39347, -22280, 86194, -73170, -23741]) = 88063
# Find the maximum number in the list [38506, 12793, -61706, 16769, 97113, 33902, 95051, 73273, -99997, 23995]. ->Max([38506, 12793, -61706, 16769, 97113, 33902, 95051, 73273, -99997, 23995]) = 97113
# Received responses for batch 85 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 86 of 86
# # of prompts:  25 # of responses:  25
# Find the maximum number in the list [89091, 43992, -85778, -11704, -29131, -46567, -29272, 97545, 40250, 55112]. ->Max([89091, 43992, -85778, -11704, -29131, -46567, -29272, 97545, 40250, 55112]) = 97545
# Find the maximum number in the list [43426, -48717, 34152, 76751, -38541, -60786, -15437, 61674, 7035, 83151]. ->Max([43426, -48717, 34152, 76751, -38541, -60786, -15437, 61674, 7035, 83151]) = 83151
# Find the maximum number in the list [-76490, -76062, 81350, -9334, -61894, -25499, -65598, -15704, -89220, -50026]. ->Max([-76490, -76062, 81350, -9334, -61894, -25499, -65598, -15704, -89220, -50026]) = 81350
# Find the maximum number in the list [-69446, -39106, 54146, -7086, -19762, -18004, -26253, 44914, -53633, 74632]. ->Max([-69446, -39106, 54146, -7086, -19762, -18004, -26253, 44914, -53633, 74632]) = 74632
# Find the maximum number in the list [59974, -18772, -41469, 93804, -23639, -10592, -63908, 43598, 82710, -23176]. ->Max([59974, -18772, -41469, 93804, -23639, -10592, -63908, 43598, 82710, -23176]) = 93804
# Find the maximum number in the list [-41079, -83165, 7603, -617, 59251, 35851, -27444, 99771, -22099, -75534]. ->Max([-41079, -83165, 7603, -617, 59251, 35851, -27444, 99771, -22099, -75534]) = 99771
# Find the maximum number in the list [-20766, -64169, 11539, 16961, 80541, 56847, -83032, 56283, 52873, 56233]. ->Max([-20766, -64169, 11539, 16961, 80541, 56847, -83032, 56283, 52873, 56233]) = 80541
# Find the maximum number in the list [62573, -50242, 611, 4944, -69963, 26137, 95768, -48903, -1845, -42233]. ->Max([62573, -50242, 611, 4944, -69963, 26137, 95768, -48903, -1845, -42233]) = 95768
# Find the maximum number in the list [-99201, 69603, -24979, -2348, 88702, 540, 82141, 96154, 32613, -29657]. ->Max([-99201, 69603, -24979, -2348, 88702, 540, 82141, 96154, 32613, -29657]) = 96154
# Find the maximum number in the list [-90901, -45134, 40906, -16899, 13462, -50272, -65973, 77158, -40123, 21891]. ->Max([-90901, -45134, 40906, -16899, 13462, -50272, -65973, 77158, -40123, 21891]) = 77158
# Find the maximum number in the list [8557, 5992, 39085, 38119, -59759, 95398, 68195, 78167, 68697, 44280]. ->Max([8557, 5992, 39085, 38119, -59759, 95398, 68195, 78167, 68697, 44280]) = 95398
# Find the maximum number in the list [56841, 90017, -17536, -44922, 64248, -47087, 98319, -24697, -21611, -52873]. ->Max([56841, 90017, -17536, -44922, 64248, -47087, 98319, -24697, -21611, -52873]) = 98319
# Find the maximum number in the list [-2506, -29939, -29402, -95311, -17197, 27681, -96216, 2872, -77292, 66143]. ->Max([-2506, -29939, -29402, -95311, -17197, 27681, -96216, 2872, -77292, 66143]) = 66143
# Find the maximum number in the list [-22149, -16143, 48049, 93206, 85267, -4897, -49177, -83928, -33526, 70088]. ->Max([-22149, -16143, 48049, 93206, 85267, -4897, -49177, -83928, -33526, 70088]) = 93206
# Find the maximum number in the list [-81675, -6368, 77846, 6286, 86765, -14170, 85664, 2587, 6322, 90406]. ->Max([-81675, -6368, 77846, 6286, 86765, -14170, 85664, 2587, 6322, 90406]) = 90406
# Find the maximum number in the list [-15176, -54627, -58237, -49840, -16199, -71733, 33126, -62180, 91995, 20070]. ->Max([-15176, -54627, -58237, -49840, -16199, -71733, 33126, -62180, 91995, 20070]) = 91995
# Find the maximum number in the list [-26934, -91120, 89881, -82616, -1219, 39467, 55164, 86725, -13235, -86832]. ->Max([-26934, -91120, 89881, -82616, -1219, 39467, 55164, 86725, -13235, -86832]) = 89881
# Find the maximum number in the list [-68197, -35386, 81631, -79381, -91845, 17978, 54896, -13751, 67054, 94210]. ->Max([-68197, -35386, 81631, -79381, -91845, 17978, 54896, -13751, 67054, 94210]) = 94210
# Find the maximum number in the list [80962, 15431, -37054, 14943, 13928, 65239, -26037, -79823, 26181, -34471]. ->Max([80962, 15431, -37054, 14943, 13928, 65239, -26037, -79823, 26181, -34471]) = 80962
# Find the maximum number in the list [68569, -26433, 46913, -92200, -53707, 38712, -21020, 5164, -71845, 65058]. ->Max([68569, -26433, 46913, -92200, -53707, 38712, -21020, 5164, -71845, 65058]) = 68569
# Find the maximum number in the list [-27222, -90204, -63001, 43332, -30737, 358, -1671, 88032, 11665, 14474]. ->Max([-27222, -90204, -63001, 43332, -30737, 358, -1671, 88032, 11665, 14474]) = 88032
# Find the maximum number in the list [75255, -87690, -64763, 19548, -11807, 67070, -9836, 94838, -94840, -13276]. ->Max([75255, -87690, -64763, 19548, -11807, 67070, -9836, 94838, -94840, -13276]) = 94838
# Find the maximum number in the list [33540, -84454, 30298, -59867, -38800, -34619, -60853, -6564, -13082, 22898]. ->Max([33540, -84454, 30298, -59867, -38800, -34619, -60853, -6564, -13082, 22898]) = 33540
# Find the maximum number in the list [-5170, -38085, -47214, 88705, -40987, 55836, 96801, 15191, 12451, 99379]. ->Max([-5170, -38085, -47214, 88705, -40987, 55836, 96801, 15191, 12451, 99379]) = 99379
# Find the maximum number in the list [6014, -1267, -18139, -86947, 84829, -22349, -43078, -46861, 57372, -81501]. ->Max([6014, -1267, -18139, -86947, 84829, -22349, -43078, -46861, 57372, -81501]) = 84829
# Received responses for batch 86 of 86
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Responses saved to gemini_response/list_max_responses.txt

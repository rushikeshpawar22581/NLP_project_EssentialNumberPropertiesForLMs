# %% [markdown]
# # get numeration int addition response from gemini

# %% [markdown]
# Install necessary packages

# %%
# !pip install -q -U google-generativeai
# !pip install python-dotenv

# %%
import os
from dotenv import load_dotenv
import random
import time
import json
import google.generativeai as genai

# %% [markdown]
# ### load model

# %%
load_dotenv()
GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
gemini = genai.GenerativeModel('gemini-pro')

# %% [markdown]
# ### load data and create initial prompt

# %%
with open('../../data/numeration_int_addn.json','r') as file:
    data = json.load(file)

# create batches, batch sizes is heuristics 
# batch size is limited by output token limit which is 2048

size_dict = {'d1':10,
             'd2':10, # big sizes are not working, model gives blank outputs
             'd3':20,
             'd4':20,
             'd5':20,
             'd6':10,
             'd7':10,}


batch_prompts = []

for sign_of_both in data:
    # sign of both : both positive, word neg digit pos, both negative
    for type_of_both in data[sign_of_both]:
        # type of both : dw, ww
        for digit in data[sign_of_both][type_of_both]:
            # digit : d1, d2, d3, d4, d5, d6, d7
            list_data = data[sign_of_both][type_of_both][digit]
            # get batch size
            BATCH_SIZE = size_dict[digit]
            
            index = 0

            while index< len(list_data):
                batch_prompt = list_data[index:min(index+BATCH_SIZE,len(list_data))]
                batch_prompts.append(batch_prompt)
                index += BATCH_SIZE
    
print("Number of batches:", len(batch_prompts))
print("Number of prompts in each batch:", [len(batch) for batch in batch_prompts])
# Out:
# Number of batches: 470
# Number of prompts in each batch: [10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 20, 20, 20, 20, 20, 20, 20, 10, 20, 20, 20, 20, 20, 20, 20, 10, 20, 20, 20, 20, 20, 20, 20, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 20, 20, 20, 20, 20, 20, 20, 10, 20, 20, 20, 20, 20, 20, 20, 10, 20, 20, 20, 20, 20, 20, 20, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 20, 20, 20, 20, 20, 20, 20, 10, 20, 20, 20, 20, 20, 20, 20, 10, 20, 20, 20, 20, 20, 20, 20, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 20, 20, 20, 20, 20, 20, 20, 10, 20, 20, 20, 20, 20, 20, 20, 10, 20, 20, 20, 20, 20, 20, 20, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 1, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 20, 20, 20, 20, 20, 20, 20, 10, 20, 20, 20, 20, 20, 20, 20, 10, 20, 20, 20, 20, 20, 20, 20, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 1, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 20, 20, 20, 20, 20, 20, 20, 10, 20, 20, 20, 20, 20, 20, 20, 10, 20, 20, 20, 20, 20, 20, 20, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10]

# %% [markdown]
# ### conduct experiment for output sum in digit form
#
# eg. <br>
# 2 + three   = 5<br>
# two + 3     = 5<br>
# two + three = 5<br>

# %%
# give a prompt once and then generate the response,
# and then use this prompt+response directly instead of doing everytime

promt_saying_you_are_a_math_assistant = '''You are a math assistant. I will ask you some addition questions. The two numbers I ask you to add can be in either digit form or word form, irrespective of the input form I want you to answer in digit form. For example, if I ask 'What is 2 + three?', you should answer '2 + three = 5'. Note that input format should be preserved in answer. Each question is in a separate line. Please return each answer in a separate line. Do you understand ?'''
Initial_messages = [{'role':'user', 'parts': [promt_saying_you_are_a_math_assistant] }]

# get response from the model and then append it to the prompt
Initial_response = gemini.generate_content(Initial_messages)                                   
Initial_messages.append(Initial_response.candidates[0].content)

# %%
print(Initial_messages)
# Out:
# [{'role': 'user', 'parts': ["You are a math assistant. I will ask you some addition questions. The two numbers I ask you to add can be in either digit form or word form, irrespective of the input form I want you to answer in digit form. For example, if I ask 'What is 2 + three?', you should answer '2 + three = 5'. Note that input format should be preserved in answer. Each question is in a separate line. Please return each answer in a separate line. Do you understand ?"]}, parts {
#   text: "Yes, I understand. I will add the two numbers you give me, and return the answer in digit form, preserving the input format. For example, if you ask \'What is 2 + three?\', I will answer \'2 + three = 5\'."
# }
# role: "model"
# ]

# %%
import pickle

# save the initial messages to a file, in case we need to restart the conversation
with open('initial_messages_numeration_int_add_op_digit.pkl', 'wb') as file:
    pickle.dump(Initial_messages, file)

# %%
# path to save responses
response_file = 'gemini_response/Numeration_int_addition_digit_op_response.txt'

# request per minute limit for free api
rpm = 60

# %%
# to start from a specific batch number, give printed_batch_num -1 here
batch_no_to_start_from = 0

for i, batch_prompt in enumerate(batch_prompts):

    # to start from a specific batch in case of errors
    if i < batch_no_to_start_from:
        continue
    
    # print status
    print(f"Sending batch {i+1} of {len(batch_prompts)}")

    num_prompts = len(batch_prompt)

    # create prompt for the batch
    curr_prompt = "".join([f"what is {a} + {b} ? \n " for (a,b,c,d) in batch_prompt])
    
    # create a complete prompt to send to the model
    complete_promt = Initial_messages.copy()
    complete_promt.append({'role':'user', 'parts': [curr_prompt]})

    # get response from the model, candidate_count is 1 because we only need one response,
    # temperature is 0 because we need deterministic responses
    response = gemini.generate_content( complete_promt,
                                        generation_config= genai.GenerationConfig(
                                        candidate_count = 1,
                                        temperature = 0.0,
                                        )
                                )
    
    try:
        # extract text from the response
        model_responses = response.candidates[0].content.parts.__getitem__(0).text.split('\n')
    except IndexError:
        print("Error in response")
        model_responses = ["0"]*num_prompts

    # save responses to file
    with open(response_file, 'a') as file:
        for model_response in model_responses:
            file.write(model_response + '\n')

    
    #print the prompt and response separated by space
    print('# of prompts: ',len(batch_prompt),'# of responses: ', len(model_responses))


    for prompt, response in zip(batch_prompt, model_responses):
        print(prompt, response, sep=" ->")
    
    
    print("Received responses for batch", i+1, "of", len(batch_prompts))
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")

    time.sleep(60//rpm) #to avoid rate limit errors

print("Responses saved to", response_file)
# Out:
# Sending batch 1 of 470
# # of prompts:  10 # of responses:  10
# [0, 'zero', 'zero', 0] ->0 + zero = 0
# [0, 'one', 'one', 1] ->0 + one = 1
# [0, 'two', 'two', 2] ->0 + two = 2
# ['zero', 3, 'three', 3] ->zero + 3 = 3
# ['zero', 4, 'four', 4] ->zero + 4 = 4
# ['zero', 5, 'five', 5] ->zero + 5 = 5
# ['zero', 6, 'six', 6] ->zero + 6 = 6
# [0, 'seven', 'seven', 7] ->0 + seven = 7
# ['zero', 8, 'eight', 8] ->zero + 8 = 8
# [0, 'nine', 'nine', 9] ->0 + nine = 9
# Received responses for batch 1 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 2 of 470
# # of prompts:  10 # of responses:  10
# ['one', 0, 'one', 1] ->one + 0 = 1
# [1, 'one', 'two', 2] ->1 + one = 2
# ['one', 2, 'three', 3] ->one + 2 = 3
# [1, 'three', 'four', 4] ->1 + three = 4
# [1, 'four', 'five', 5] ->1 + four = 5
# [1, 'five', 'six', 6] ->1 + five = 6
# [1, 'six', 'seven', 7] ->1 + six = 7
# [1, 'seven', 'eight', 8] ->1 + seven = 8
# [1, 'eight', 'nine', 9] ->1 + eight = 9
# [1, 'nine', 'ten', 10] ->1 + nine = 10
# Received responses for batch 2 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 3 of 470
# # of prompts:  10 # of responses:  10
# ['two', 0, 'two', 2] ->two + 0 = 2
# [2, 'one', 'three', 3] ->2 + one = 3
# [2, 'two', 'four', 4] ->2 + two = 4
# [2, 'three', 'five', 5] ->2 + three = 5
# [2, 'four', 'six', 6] ->2 + four = 6
# [2, 'five', 'seven', 7] ->2 + five = 7
# [2, 'six', 'eight', 8] ->2 + six = 8
# [2, 'seven', 'nine', 9] ->2 + seven = 9
# ['two', 8, 'ten', 10] ->two + 8 = 10
# [2, 'nine', 'eleven', 11] ->2 + nine = 11
# Received responses for batch 3 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 4 of 470
# # of prompts:  10 # of responses:  10
# [3, 'zero', 'three', 3] ->3 + zero = 3
# ['three', 1, 'four', 4] ->three + 1 = 4
# ['three', 2, 'five', 5] ->three + 2 = 5
# [3, 'three', 'six', 6] ->3 + three = 6
# ['three', 4, 'seven', 7] ->three + 4 = 7
# [3, 'five', 'eight', 8] ->3 + five = 8
# [3, 'six', 'nine', 9] ->three + 6 = 9
# ['three', 7, 'ten', 10] ->three + 7 = 10
# ['three', 8, 'eleven', 11] ->three + 8 = 11
# [3, 'nine', 'twelve', 12] ->3 + nine = 12
# Received responses for batch 4 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 5 of 470
# # of prompts:  10 # of responses:  10
# ['four', 0, 'four', 4] ->four + 0 = 4
# ['four', 1, 'five', 5] ->four + 1 = 5
# [4, 'two', 'six', 6] ->4 + two = 6
# ['four', 3, 'seven', 7] ->four + 3 = 7
# ['four', 4, 'eight', 8] ->four + 4 = 8
# ['four', 5, 'nine', 9] ->four + 5 = 9
# [4, 'six', 'ten', 10] ->4 + six = 10
# [4, 'seven', 'eleven', 11] ->4 + seven = 11
# ['four', 8, 'twelve', 12] ->four + 8 = 12
# ['four', 9, 'thirteen', 13] ->four + 9 = 13
# Received responses for batch 5 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 6 of 470
# # of prompts:  10 # of responses:  10
# ['five', 0, 'five', 5] ->five + 0 = 5
# [5, 'one', 'six', 6] ->5 + one = 6
# [5, 'two', 'seven', 7] ->5 + two = 7
# [5, 'three', 'eight', 8] ->5 + three = 8
# [5, 'four', 'nine', 9] ->5 + four = 9
# ['five', 5, 'ten', 10] ->five + 5 = 10
# [5, 'six', 'eleven', 11] ->5 + six = 11
# ['five', 7, 'twelve', 12] ->five + 7 = 12
# ['five', 8, 'thirteen', 13] ->five + 8 = 13
# ['five', 9, 'fourteen', 14] ->five + 9 = 14
# Received responses for batch 6 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 7 of 470
# # of prompts:  10 # of responses:  10
# ['six', 0, 'six', 6] ->six + 0 = 6
# [6, 'one', 'seven', 7] ->6 + one = 7
# ['six', 2, 'eight', 8] ->six + 2 = 8
# ['six', 3, 'nine', 9] ->six + 3 = 9
# [6, 'four', 'ten', 10] ->6 + four = 10
# ['six', 5, 'eleven', 11] ->six + 5 = 11
# ['six', 6, 'twelve', 12] ->six + 6 = 12
# [6, 'seven', 'thirteen', 13] ->6 + seven = 13
# [6, 'eight', 'fourteen', 14] ->6 + eight = 14
# [6, 'nine', 'fifteen', 15] ->6 + nine = 15
# Received responses for batch 7 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 8 of 470
# # of prompts:  10 # of responses:  10
# [7, 'zero', 'seven', 7] ->7 + zero = 7
# [7, 'one', 'eight', 8] ->7 + one = 8
# [7, 'two', 'nine', 9] ->7 + two = 9
# ['seven', 3, 'ten', 10] ->seven + 3 = 10
# [7, 'four', 'eleven', 11] ->7 + four = 11
# ['seven', 5, 'twelve', 12] ->seven + 5 = 12
# [7, 'six', 'thirteen', 13] ->7 + six = 13
# ['seven', 7, 'fourteen', 14] ->seven + 7 = 14
# [7, 'eight', 'fifteen', 15] ->7 + eight = 15
# [7, 'nine', 'sixteen', 16] ->7 + nine = 16
# Received responses for batch 8 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 9 of 470
# # of prompts:  10 # of responses:  10
# ['eight', 0, 'eight', 8] ->eight + 0 = 8
# [8, 'one', 'nine', 9] ->8 + one = 9
# [8, 'two', 'ten', 10] ->8 + two = 10
# [8, 'three', 'eleven', 11] ->8 + three = 11
# ['eight', 4, 'twelve', 12] ->eight + 4 = 12
# [8, 'five', 'thirteen', 13] ->8 + five = 13
# ['eight', 6, 'fourteen', 14] ->eight + 6 = 14
# [8, 'seven', 'fifteen', 15] ->8 + seven = 15
# ['eight', 8, 'sixteen', 16] ->eight + 8 = 16
# [8, 'nine', 'seventeen', 17] ->8 + nine = 17
# Received responses for batch 9 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 10 of 470
# # of prompts:  10 # of responses:  10
# ['nine', 0, 'nine', 9] ->nine + 0 = 9
# ['nine', 1, 'ten', 10] ->nine + 1 = 10
# ['nine', 2, 'eleven', 11] ->nine + 2 = 11
# ['nine', 3, 'twelve', 12] ->nine + 3 = 12
# [9, 'four', 'thirteen', 13] ->9 + four = 13
# [9, 'five', 'fourteen', 14] ->9 + five = 14
# ['nine', 6, 'fifteen', 15] ->nine + 6 = 15
# ['nine', 7, 'sixteen', 16] ->nine + 7 = 16
# [9, 'eight', 'seventeen', 17] ->9 + eight = 17
# [9, 'nine', 'eighteen', 18] ->9 + nine = 18
# Received responses for batch 10 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 11 of 470
# # of prompts:  10 # of responses:  10
# ['thirty-one', 63, 'ninety-four', 94] ->thirty-one + 63 = 94
# ['ninety-one', 46, 'one hundred and thirty-seven', 137] ->ninety-one + 46 = 137
# [37, 'seventy', 'one hundred and seven', 107] ->37 + seventy = 107
# [74, 'seventy-seven', 'one hundred and fifty-one', 151] ->74 + seventy-seven = 151
# ['ten', 11, 'twenty-one', 21] ->ten + 11 = 21
# [84, 'sixty-four', 'one hundred and forty-eight', 148] ->84 + sixty-four = 148
# [28, 'thirty-nine', 'sixty-seven', 67] ->28 + thirty-nine = 67
# ['ninety-eight', 15, 'one hundred and thirteen', 113] ->ninety-eight + 15 = 113
# ['sixty-two', 88, 'one hundred and fifty', 150] ->sixty-two + 88 = 150
# ['fourteen', 52, 'sixty-six', 66] ->fourteen + 52 = 66
# Received responses for batch 11 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 12 of 470
# # of prompts:  10 # of responses:  10
# ['ninety-eight', 24, 'one hundred and twenty-two', 122] ->ninety-eight + 24 = 122
# [12, 'twenty-nine', 'forty-one', 41] ->12 + twenty-nine = 41
# ['twenty-five', 12, 'thirty-seven', 37] ->twenty-five + 12 = 37
# ['thirty', 80, 'one hundred and ten', 110] ->thirty + 80 = 110
# [61, 'seventy-two', 'one hundred and thirty-three', 133] ->61 + seventy-two = 133
# [33, 'ninety-five', 'one hundred and twenty-eight', 128] ->33 + ninety-five = 128
# [70, 'forty', 'one hundred and ten', 110] ->70 + forty = 110
# [35, 'thirty-six', 'seventy-one', 71] ->35 + thirty-six = 71
# ['twenty-five', 81, 'one hundred and six', 106] ->twenty-five + 81 = 106
# [81, 'fifty-nine', 'one hundred and forty', 140] ->81 + fifty-nine = 140
# Received responses for batch 12 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 13 of 470
# # of prompts:  10 # of responses:  10
# ['fifty-three', 28, 'eighty-one', 81] ->fifty-three + 28 = 81
# ['forty-seven', 56, 'one hundred and three', 103] ->forty-seven + 56 = 103
# ['seventy-four', 59, 'one hundred and thirty-three', 133] ->seventy-four + 59 = 133
# ['seventy-two', 59, 'one hundred and thirty-one', 131] ->seventy-two + 59 = 131
# [13, 'twenty-one', 'thirty-four', 34] ->13 + twenty-one = 34
# ['seventy-three', 10, 'eighty-three', 83] ->seventy-three + 10 = 83
# [18, 'eighty', 'ninety-eight', 98] ->18 + eighty = 98
# ['eighty-three', 87, 'one hundred and seventy', 170] ->eighty-three + 87 = 170
# [81, 'eighty-nine', 'one hundred and seventy', 170] ->81 + eighty-nine = 170
# ['thirty-one', 90, 'one hundred and twenty-one', 121] ->thirty-one + 90 = 121
# Received responses for batch 13 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 14 of 470
# # of prompts:  10 # of responses:  10
# ['fifty-two', 54, 'one hundred and six', 106] ->fifty-two + 54 = 106
# [41, 'twenty-three', 'sixty-four', 64] ->41 + twenty-three = 64
# ['eighteen', 32, 'fifty', 50] ->eighteen + 32 = 50
# [57, 'thirty', 'eighty-seven', 87] ->57 + thirty = 87
# [96, 'seventy-six', 'one hundred and seventy-two', 172] ->96 + seventy-six = 172
# [62, 'thirty', 'ninety-two', 92] ->62 + thirty = 92
# ['fifty-four', 72, 'one hundred and twenty-six', 126] ->fifty-four + 72 = 126
# [95, 'forty-one', 'one hundred and thirty-six', 136] ->95 + forty-one = 136
# [30, 'eighty-one', 'one hundred and eleven', 111] ->30 + eighty-one = 111
# ['sixty-six', 62, 'one hundred and twenty-eight', 128] ->sixty-six + 62 = 128
# Received responses for batch 14 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 15 of 470
# # of prompts:  10 # of responses:  10
# [17, 'forty-six', 'sixty-three', 63] ->17 + forty-six = 63
# ['forty-three', 94, 'one hundred and thirty-seven', 137] ->forty-three + 94 = 137
# [14, 'sixty-three', 'seventy-seven', 77] ->14 + sixty-three = 77
# [31, 'sixty', 'ninety-one', 91] ->31 + sixty = 91
# [53, 'ninety-two', 'one hundred and forty-five', 145] ->53 + ninety-two = 145
# [29, 'seventy-one', 'one hundred', 100] ->29 + seventy-one = 100
# ['forty-two', 27, 'sixty-nine', 69] ->forty-two + 27 = 69
# ['thirteen', 37, 'fifty', 50] ->thirteen + 37 = 50
# ['twenty-nine', 57, 'eighty-six', 86] ->twenty-nine + 57 = 86
# ['seventy-two', 84, 'one hundred and fifty-six', 156] ->seventy-two + 84 = 156
# Received responses for batch 15 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 16 of 470
# # of prompts:  10 # of responses:  10
# ['forty-nine', 27, 'seventy-six', 76] ->forty-nine + 27 = 76
# ['twenty-seven', 11, 'thirty-eight', 38] ->twenty-seven + 11 = 38
# [97, 'twenty-six', 'one hundred and twenty-three', 123] ->97 + twenty-six = 123
# ['forty-three', 85, 'one hundred and twenty-eight', 128] ->forty-three + 85 = 128
# ['ninety-two', 41, 'one hundred and thirty-three', 133] ->ninety-two + 41 = 133
# ['forty-two', 97, 'one hundred and thirty-nine', 139] ->forty-two + 97 = 139
# [27, 'twenty-seven', 'fifty-four', 54] ->27 + twenty-seven = 54
# [22, 'sixty', 'eighty-two', 82] ->22 + sixty = 82
# ['thirty-three', 13, 'forty-six', 46] ->thirty-three + 13 = 46
# [28, 'nineteen', 'forty-seven', 47] ->28 + nineteen = 47
# Received responses for batch 16 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 17 of 470
# # of prompts:  10 # of responses:  10
# [93, 'forty-six', 'one hundred and thirty-nine', 139] ->93 + forty-six = 139
# ['forty-eight', 78, 'one hundred and twenty-six', 126] ->forty-eight + 78 = 126
# [60, 'seventy-three', 'one hundred and thirty-three', 133] ->60 + seventy-three = 133
# [89, 'thirty-one', 'one hundred and twenty', 120] ->89 + thirty-one = 120
# [33, 'fifty-eight', 'ninety-one', 91] ->33 + fifty-eight = 91
# [100, 'eighty', 'one hundred and eighty', 180] ->100 + eighty = 180
# [87, 'one hundred', 'one hundred and eighty-seven', 187] ->87 + one hundred = 187
# ['eleven', 59, 'seventy', 70] ->eleven + 59 = 70
# [18, 'sixty', 'seventy-eight', 78] ->18 + sixty = 78
# ['thirty-nine', 42, 'eighty-one', 81] ->thirty-nine + 42 = 81
# Received responses for batch 17 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 18 of 470
# # of prompts:  10 # of responses:  10
# ['fifteen', 41, 'fifty-six', 56] ->fifteen + 41 = 56
# ['twenty-nine', 49, 'seventy-eight', 78] ->twenty-nine + 49 = 78
# ['seventy-four', 80, 'one hundred and fifty-four', 154] ->seventy-four + 80 = 154
# [83, 'twenty-two', 'one hundred and five', 105] ->83 + twenty-two = 105
# ['seventy-five', 86, 'one hundred and sixty-one', 161] ->seventy-five + 86 = 161
# ['seventy-six', 49, 'one hundred and twenty-five', 125] ->seventy-six + 49 = 125
# [99, 'eighty-nine', 'one hundred and eighty-eight', 188] ->99 + eighty-nine = 188
# ['eighteen', 88, 'one hundred and six', 106] ->eighteen + 88 = 106
# [35, 'fifty-five', 'ninety', 90] ->35 + fifty-five = 90
# ['fifty', 94, 'one hundred and forty-four', 144] ->fifty + 94 = 144
# Received responses for batch 18 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 19 of 470
# # of prompts:  10 # of responses:  10
# [23, 'nineteen', 'forty-two', 42] ->23 + nineteen = 42
# [90, 'sixty-seven', 'one hundred and fifty-seven', 157] ->90 + sixty-seven = 157
# ['ninety-seven', 92, 'one hundred and eighty-nine', 189] ->ninety-seven + 92 = 189
# ['seventy', 76, 'one hundred and forty-six', 146] ->seventy + 76 = 146
# [61, 'nineteen', 'eighty', 80] ->61 + nineteen = 80
# ['thirteen', 16, 'twenty-nine', 29] ->thirteen + 16 = 29
# ['forty-five', 100, 'one hundred and forty-five', 145] ->forty-five + 100 = 145
# [64, 'sixty-eight', 'one hundred and thirty-two', 132] ->64 + sixty-eight = 132
# ['sixty-one', 59, 'one hundred and twenty', 120] ->sixty-one + 59 = 120
# [72, 'thirty-nine', 'one hundred and eleven', 111] ->72 + thirty-nine = 111
# Received responses for batch 19 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 20 of 470
# # of prompts:  10 # of responses:  10
# [14, 'seventy-one', 'eighty-five', 85] ->14 + seventy-one = 85
# [72, 'fifty-seven', 'one hundred and twenty-nine', 129] ->72 + fifty-seven = 129
# ['sixty-seven', 90, 'one hundred and fifty-seven', 157] ->sixty-seven + 90 = 157
# ['forty-one', 71, 'one hundred and twelve', 112] ->forty-one + 71 = 112
# ['fifty-nine', 49, 'one hundred and eight', 108] ->fifty-nine + 49 = 108
# [77, 'ten', 'eighty-seven', 87] ->77 + ten = 87
# ['fifty', 35, 'eighty-five', 85] ->fifty + 35 = 85
# [60, 'twenty-eight', 'eighty-eight', 88] ->60 + twenty-eight = 88
# [80, 'thirty-two', 'one hundred and twelve', 112] ->80 + thirty-two = 112
# ['seventy-six', 48, 'one hundred and twenty-four', 124] ->seventy-six + 48 = 124
# Received responses for batch 20 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 21 of 470
# # of prompts:  10 # of responses:  10
# [69, 'twenty-three', 'ninety-two', 92] ->69 + twenty-three = 92
# [100, 'sixty-five', 'one hundred and sixty-five', 165] ->100 + sixty-five = 165
# ['ninety-six', 52, 'one hundred and forty-eight', 148] ->ninety-six + 52 = 148
# [92, 'eighty-four', 'one hundred and seventy-six', 176] ->92 + eighty-four = 176
# [43, 'twenty', 'sixty-three', 63] ->43 + twenty = 63
# ['fifty-one', 75, 'one hundred and twenty-six', 126] ->fifty-one + 75 = 126
# [29, 'ninety-seven', 'one hundred and twenty-six', 126] ->29 + ninety-seven = 126
# ['forty', 86, 'one hundred and twenty-six', 126] ->forty + 86 = 126
# ['fifty-eight', 30, 'eighty-eight', 88] ->fifty-eight + 30 = 88
# ['sixty-nine', 61, 'one hundred and thirty', 130] ->sixty-nine + 61 = 130
# Received responses for batch 21 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 22 of 470
# # of prompts:  10 # of responses:  10
# ['sixty-eight', 88, 'one hundred and fifty-six', 156] ->sixty-eight + 88 = 156
# ['ninety-five', 32, 'one hundred and twenty-seven', 127] ->ninety-five + 32 = 127
# [89, 'forty-four', 'one hundred and thirty-three', 133] ->89 + forty-four = 133
# [34, 'thirty-seven', 'seventy-one', 71] ->34 + thirty-seven = 71
# ['fifty-four', 90, 'one hundred and forty-four', 144] ->fifty-four + 90 = 144
# [12, 'nineteen', 'thirty-one', 31] ->12 + nineteen = 31
# ['sixty', 87, 'one hundred and forty-seven', 147] ->sixty + 87 = 147
# [99, 'sixty-seven', 'one hundred and sixty-six', 166] ->99 + sixty-seven = 166
# [10, 'seventy-nine', 'eighty-nine', 89] ->10 + seventy-nine = 89
# [22, 'forty-nine', 'seventy-one', 71] ->22 + forty-nine = 71
# Received responses for batch 22 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 23 of 470
# # of prompts:  10 # of responses:  10
# [68, 'fifty-seven', 'one hundred and twenty-five', 125] ->68 + fifty-seven = 125
# [57, 'thirty-one', 'eighty-eight', 88] ->57 + thirty-one = 88
# [83, 'sixty-five', 'one hundred and forty-eight', 148] ->83 + sixty-five = 148
# ['forty-nine', 34, 'eighty-three', 83] ->forty-nine + 34 = 83
# [61, 'eighty', 'one hundred and forty-one', 141] ->61 + eighty = 141
# ['thirty-eight', 83, 'one hundred and twenty-one', 121] ->thirty-eight + 83 = 121
# [12, 'ninety-four', 'one hundred and six', 106] ->12 + ninety-four = 106
# [20, 'sixty-five', 'eighty-five', 85] ->20 + sixty-five = 85
# ['twenty-nine', 17, 'forty-six', 46] ->twenty-nine + 17 = 46
# ['seventy-seven', 87, 'one hundred and sixty-four', 164] ->seventy-seven + 87 = 164
# Received responses for batch 23 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 24 of 470
# # of prompts:  10 # of responses:  10
# ['seventy', 96, 'one hundred and sixty-six', 166] ->seventy + 96 = 166
# [29, 'forty-four', 'seventy-three', 73] ->29 + forty-four = 73
# ['fifty-five', 46, 'one hundred and one', 101] ->fifty-five + 46 = 101
# [91, 'ninety', 'one hundred and eighty-one', 181] ->91 + ninety = 181
# [19, 'ninety-five', 'one hundred and fourteen', 114] ->19 + ninety-five = 114
# [33, 'seventy-five', 'one hundred and eight', 108] ->33 + seventy-five = 108
# ['ninety-six', 34, 'one hundred and thirty', 130] ->ninety-six + 34 = 130
# [44, 'fifty-five', 'ninety-nine', 99] ->44 + fifty-five = 99
# ['thirty', 14, 'forty-four', 44] ->thirty + 14 = 44
# ['forty-five', 97, 'one hundred and forty-two', 142] ->forty-five + 97 = 142
# Received responses for batch 24 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 25 of 470
# # of prompts:  10 # of responses:  10
# ['twenty-three', 39, 'sixty-two', 62] ->twenty-three + 39 = 62
# ['seventy-eight', 42, 'one hundred and twenty', 120] ->seventy-eight + 42 = 120
# [35, 'ninety-eight', 'one hundred and thirty-three', 133] ->35 + ninety-eight = 133
# [77, 'sixty-four', 'one hundred and forty-one', 141] ->77 + sixty-four = 141
# [51, 'thirty-eight', 'eighty-nine', 89] ->51 + thirty-eight = 89
# ['seventy-four', 15, 'eighty-nine', 89] ->seventy-four + 15 = 89
# [87, 'seventy-eight', 'one hundred and sixty-five', 165] ->87 + seventy-eight = 165
# ['twelve', 100, 'one hundred and twelve', 112] ->twelve + 100 = 112
# [73, 'seventy-one', 'one hundred and forty-four', 144] ->73 + seventy-one = 144
# ['sixty-six', 12, 'seventy-eight', 78] ->sixty-six + 12 = 78
# Received responses for batch 25 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 26 of 470
# # of prompts:  20 # of responses:  20
# [795, 'one hundred and fifty-six', 'nine hundred and fifty-one', 951] ->795 + one hundred and fifty-six = 951
# [797, 'eight hundred and ninety-six', 'one thousand, six hundred and ninety-three', 1693] ->797 + eight hundred and ninety-six = 1693
# [417, 'four hundred and ninety-nine', 'nine hundred and sixteen', 916] ->417 + four hundred and ninety-nine = 916
# ['five hundred and seventy-five', 813, 'one thousand, three hundred and eighty-eight', 1388] ->five hundred and seventy-five + 813 = 1388
# [111, 'four hundred and sixty', 'five hundred and seventy-one', 571] ->111 + four hundred and sixty = 571
# [728, 'three hundred and seventy-one', 'one thousand and ninety-nine', 1099] ->728 + three hundred and seventy-one = 1099
# [873, 'four hundred and eighty-five', 'one thousand, three hundred and fifty-eight', 1358] ->873 + four hundred and eighty-five = 1358
# ['two hundred and eighty-six', 649, 'nine hundred and thirty-five', 935] ->two hundred and eighty-six + 649 = 935
# ['three hundred and eleven', 331, 'six hundred and forty-two', 642] ->three hundred and eleven + 331 = 642
# ['eight hundred and ninety-four', 560, 'one thousand, four hundred and fifty-four', 1454] ->eight hundred and ninety-four + 560 = 1454
# ['one hundred and eighty-four', 345, 'five hundred and twenty-nine', 529] ->one hundred and eighty-four + 345 = 529
# ['seven hundred and thirteen', 282, 'nine hundred and ninety-five', 995] ->seven hundred and thirteen + 282 = 995
# ['six hundred and fifty-two', 787, 'one thousand, four hundred and thirty-nine', 1439] ->six hundred and fifty-two + 787 = 1439
# [686, 'two hundred and thirty-four', 'nine hundred and twenty', 920] ->686 + two hundred and thirty-four = 920
# [533, 'six hundred and ninety-four', 'one thousand, two hundred and twenty-seven', 1227] ->533 + six hundred and ninety-four = 1227
# [781, 'eight hundred and fifty-seven', 'one thousand, six hundred and thirty-eight', 1638] ->781 + eight hundred and fifty-seven = 1638
# [859, 'two hundred and nine', 'one thousand and sixty-eight', 1068] ->859 + two hundred and nine = 1068
# ['six hundred and forty-five', 635, 'one thousand, two hundred and eighty', 1280] ->six hundred and forty-five + 635 = 1280
# [626, 'four hundred and three', 'one thousand and twenty-nine', 1029] ->626 + four hundred and three = 1029
# ['two hundred and sixty-four', 345, 'six hundred and nine', 609] ->two hundred and sixty-four + 345 = 609
# Received responses for batch 26 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 27 of 470
# # of prompts:  20 # of responses:  20
# ['seven hundred and twenty-eight', 756, 'one thousand, four hundred and eighty-four', 1484] ->seven hundred and twenty-eight + 756 = 1484
# [889, 'six hundred and six', 'one thousand, four hundred and ninety-five', 1495] ->889 + six hundred and six = 1505
# ['seven hundred and sixty-six', 317, 'one thousand and eighty-three', 1083] ->seven hundred and sixty-six + 317 = 1083
# ['two hundred and eighty-eight', 540, 'eight hundred and twenty-eight', 828] ->two hundred and eighty-eight + 540 = 828
# ['three hundred and twenty-seven', 601, 'nine hundred and twenty-eight', 928] ->three hundred and twenty-seven + 601 = 928
# ['three hundred and seventy-one', 141, 'five hundred and twelve', 512] ->three hundred and seventy-one + 141 = 512
# ['three hundred and ten', 136, 'four hundred and forty-six', 446] ->three hundred and ten + 136 = 446
# ['seven hundred', 550, 'one thousand, two hundred and fifty', 1250] ->seven hundred + 550 = 1250
# [854, 'two hundred and forty-two', 'one thousand and ninety-six', 1096] ->854 + two hundred and forty-two = 1096
# [262, 'four hundred and eighty-five', 'seven hundred and forty-seven', 747] ->262 + four hundred and eighty-five = 747
# [503, 'one hundred and thirty-three', 'six hundred and thirty-six', 636] ->503 + one hundred and thirty-three = 636
# ['eight hundred and ninety-six', 780, 'one thousand, six hundred and seventy-six', 1676] ->eight hundred and ninety-six + 780 = 1676
# ['six hundred and ninety', 952, 'one thousand, six hundred and forty-two', 1642] ->six hundred and ninety + 952 = 1642
# [301, 'five hundred and ninety-seven', 'eight hundred and ninety-eight', 898] ->301 + five hundred and ninety-seven = 898
# ['nine hundred and ninety', 851, 'one thousand, eight hundred and forty-one', 1841] ->nine hundred and ninety + 851 = 1841
# [788, 'one hundred and fifty-six', 'nine hundred and forty-four', 944] ->788 + one hundred and fifty-six = 944
# [479, 'nine hundred and forty-six', 'one thousand, four hundred and twenty-five', 1425] ->479 + nine hundred and forty-six = 1425
# ['six hundred and eleven', 441, 'one thousand and fifty-two', 1052] ->six hundred and eleven + 441 = 1052
# ['four hundred and sixty-two', 498, 'nine hundred and sixty', 960] ->four hundred and sixty-two + 498 = 960
# [712, 'eight hundred and thirty-five', 'one thousand, five hundred and forty-seven', 1547] ->712 + eight hundred and thirty-five = 1547
# Received responses for batch 27 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 28 of 470
# # of prompts:  20 # of responses:  20
# [986, 'three hundred and sixty-two', 'one thousand, three hundred and forty-eight', 1348] ->986 + three hundred and sixty-two = 1348
# ['four hundred and eighty-three', 771, 'one thousand, two hundred and fifty-four', 1254] ->four hundred and eighty-three + 771 = 1254
# ['eight hundred and fifty-one', 900, 'one thousand, seven hundred and fifty-one', 1751] ->eight hundred and fifty-one + 900 = 1751
# [911, 'two hundred and twenty-seven', 'one thousand, one hundred and thirty-eight', 1138] ->911 + two hundred and twenty-seven = 1138
# ['seven hundred and nine', 968, 'one thousand, six hundred and seventy-seven', 1677] ->seven hundred and nine + 968 = 1677
# ['nine hundred and sixty-nine', 179, 'one thousand, one hundred and forty-eight', 1148] ->nine hundred and sixty-nine + 179 = 1148
# [354, 'seven hundred and forty-eight', 'one thousand, one hundred and two', 1102] ->354 + seven hundred and forty-eight = 1102
# ['two hundred and forty-nine', 869, 'one thousand, one hundred and eighteen', 1118] ->two hundred and forty-nine + 869 = 1118
# ['two hundred and six', 798, 'one thousand and four', 1004] ->two hundred and six + 798 = 1004
# [761, 'three hundred and twenty-three', 'one thousand and eighty-four', 1084] ->761 + three hundred and twenty-three = 1084
# ['two hundred and thirty-seven', 609, 'eight hundred and forty-six', 846] ->two hundred and thirty-seven + 609 = 846
# ['three hundred and twenty-three', 132, 'four hundred and fifty-five', 455] ->three hundred and twenty-three + 132 = 455
# ['seven hundred and sixty-four', 635, 'one thousand, three hundred and ninety-nine', 1399] ->seven hundred and sixty-four + 635 = 1399
# [109, 'two hundred and ninety-seven', 'four hundred and six', 406] ->109 + two hundred and ninety-seven = 406
# ['three hundred and ninety', 159, 'five hundred and forty-nine', 549] ->three hundred and ninety + 159 = 549
# ['eight hundred and thirteen', 944, 'one thousand, seven hundred and fifty-seven', 1757] ->eight hundred and thirteen + 944 = 1757
# [161, 'two hundred and twenty-six', 'three hundred and eighty-seven', 387] ->161 + two hundred and twenty-six = 387
# ['eight hundred and forty-two', 338, 'one thousand, one hundred and eighty', 1180] ->eight hundred and forty-two + 338 = 1180
# ['five hundred and ninety-nine', 612, 'one thousand, two hundred and eleven', 1211] ->five hundred and ninety-nine + 612 = 1211
# [542, 'seven hundred and fifty-one', 'one thousand, two hundred and ninety-three', 1293] ->542 + seven hundred and fifty-one = 1293
# Received responses for batch 28 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 29 of 470
# # of prompts:  20 # of responses:  20
# [750, 'four hundred and seventy-four', 'one thousand, two hundred and twenty-four', 1224] ->750 + four hundred and seventy-four = 1224
# ['four hundred and fifty-four', 511, 'nine hundred and sixty-five', 965] ->four hundred and fifty-four + 511 = 965
# ['seven hundred and fifty-one', 763, 'one thousand, five hundred and fourteen', 1514] ->seven hundred and fifty-one + 763 = 1514
# [836, 'six hundred and twenty-six', 'one thousand, four hundred and sixty-two', 1462] ->836 + six hundred and twenty-six = 1462
# [549, 'nine hundred and eight', 'one thousand, four hundred and fifty-seven', 1457] ->549 + nine hundred and eight = 1457
# ['one hundred and twenty', 972, 'one thousand and ninety-two', 1092] ->one hundred and twenty + 972 = 1092
# [963, 'three hundred and twenty-six', 'one thousand, two hundred and eighty-nine', 1289] ->963 + three hundred and twenty-six = 1289
# [453, 'six hundred and one', 'one thousand and fifty-four', 1054] ->453 + six hundred and one = 1054
# ['two hundred and sixty-nine', 113, 'three hundred and eighty-two', 382] ->two hundred and sixty-nine + 113 = 382
# ['four hundred and thirty-four', 808, 'one thousand, two hundred and forty-two', 1242] ->four hundred and thirty-four + 808 = 1242
# [406, 'three hundred and twenty', 'seven hundred and twenty-six', 726] ->406 + three hundred and twenty = 726
# [567, 'two hundred and ninety-one', 'eight hundred and fifty-eight', 858] ->567 + two hundred and ninety-one = 858
# [255, 'one hundred and ten', 'three hundred and sixty-five', 365] ->255 + one hundred and ten = 365
# [967, 'two hundred and fifty-six', 'one thousand, two hundred and twenty-three', 1223] ->967 + two hundred and fifty-six = 1223
# [664, 'two hundred and fourteen', 'eight hundred and seventy-eight', 878] ->664 + two hundred and fourteen = 878
# [647, 'seven hundred and fifty-eight', 'one thousand, four hundred and five', 1405] ->647 + seven hundred and fifty-eight = 1405
# [743, 'five hundred and fourteen', 'one thousand, two hundred and fifty-seven', 1257] ->743 + five hundred and fourteen = 1257
# [879, 'two hundred and twenty-six', 'one thousand, one hundred and five', 1105] ->879 + two hundred and twenty-six = 1105
# [817, 'eight hundred and sixteen', 'one thousand, six hundred and thirty-three', 1633] ->817 + eight hundred and sixteen = 1633
# [651, 'one hundred and eighteen', 'seven hundred and sixty-nine', 769] ->651 + one hundred and eighteen = 769
# Received responses for batch 29 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 30 of 470
# # of prompts:  20 # of responses:  20
# [898, 'three hundred and forty-eight', 'one thousand, two hundred and forty-six', 1246] ->898 + three hundred and forty-eight = 1246
# [713, 'six hundred and eighty-one', 'one thousand, three hundred and ninety-four', 1394] ->713 + six hundred and eighty-one = 1394
# ['three hundred and fifty', 308, 'six hundred and fifty-eight', 658] ->three hundred and fifty + 308 = 658
# [690, 'nine hundred and seven', 'one thousand, five hundred and ninety-seven', 1597] ->690 + nine hundred and seven = 1697
# ['five hundred and nine', 409, 'nine hundred and eighteen', 918] ->five hundred and nine + 409 = 918
# ['nine hundred and twenty-five', 803, 'one thousand, seven hundred and twenty-eight', 1728] ->nine hundred and twenty-five + 803 = 1728
# [903, 'five hundred and twenty-seven', 'one thousand, four hundred and thirty', 1430] ->903 + five hundred and twenty-seven = 1430
# [690, 'six hundred and ten', 'one thousand, three hundred', 1300] ->690 + six hundred and ten = 1300
# ['five hundred and thirteen', 889, 'one thousand, four hundred and two', 1402] ->five hundred and thirteen + 889 = 1402
# [286, 'one hundred and thirty-eight', 'four hundred and twenty-four', 424] ->286 + one hundred and thirty-eight = 424
# ['eight hundred and ninety-seven', 363, 'one thousand, two hundred and sixty', 1260] ->eight hundred and ninety-seven + 363 = 1260
# [836, 'three hundred and sixty-eight', 'one thousand, two hundred and four', 1204] ->836 + three hundred and sixty-eight = 1204
# ['three hundred and ninety-six', 449, 'eight hundred and forty-five', 845] ->three hundred and ninety-six + 449 = 845
# ['seven hundred and seventy-nine', 602, 'one thousand, three hundred and eighty-one', 1381] ->seven hundred and seventy-nine + 602 = 1381
# ['four hundred and ninety-eight', 920, 'one thousand, four hundred and eighteen', 1418] ->four hundred and ninety-eight + 920 = 1418
# ['one hundred and fifty-four', 218, 'three hundred and seventy-two', 372] ->one hundred and fifty-four + 218 = 372
# ['six hundred and ninety-eight', 192, 'eight hundred and ninety', 890] ->six hundred and ninety-eight + 192 = 890
# [432, 'nine hundred and forty', 'one thousand, three hundred and seventy-two', 1372] ->432 + nine hundred and forty = 1372
# [871, 'eight hundred and thirty-eight', 'one thousand, seven hundred and nine', 1709] ->871 + eight hundred and thirty-eight = 1709
# ['four hundred and nineteen', 415, 'eight hundred and thirty-four', 834] ->four hundred and nineteen + 415 = 834
# Received responses for batch 30 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 31 of 470
# # of prompts:  20 # of responses:  20
# ['two hundred and fourteen', 376, 'five hundred and ninety', 590] ->two hundred and fourteen + 376 = 590
# ['three hundred and thirty-seven', 150, 'four hundred and eighty-seven', 487] ->three hundred and thirty-seven + 150 = 487
# ['eight hundred and sixty-three', 985, 'one thousand, eight hundred and forty-eight', 1848] ->eight hundred and sixty-three + 985 = 1848
# [624, 'eight hundred and seven', 'one thousand, four hundred and thirty-one', 1431] ->624 + eight hundred and seven = 1431
# [742, 'five hundred and eighty-four', 'one thousand, three hundred and twenty-six', 1326] ->742 + five hundred and eighty-four = 1326
# [669, 'four hundred and seventy-two', 'one thousand, one hundred and forty-one', 1141] ->669 + four hundred and seventy-two = 1141
# ['one hundred and forty-seven', 606, 'seven hundred and fifty-three', 753] ->one hundred and forty-seven + 606 = 753
# ['seven hundred and twenty-two', 438, 'one thousand, one hundred and sixty', 1160] ->seven hundred and twenty-two + 438 = 1160
# [291, 'eight hundred and eighty-eight', 'one thousand, one hundred and seventy-nine', 1179] ->291 + eight hundred and eighty-eight = 1179
# [535, 'six hundred and fourteen', 'one thousand, one hundred and forty-nine', 1149] ->535 + six hundred and fourteen = 1149
# [266, 'one hundred and thirty-two', 'three hundred and ninety-eight', 398] ->266 + one hundred and thirty-two = 398
# ['three hundred and nineteen', 269, 'five hundred and eighty-eight', 588] ->three hundred and nineteen + 269 = 588
# [113, 'seven hundred and eighty-three', 'eight hundred and ninety-six', 896] ->113 + seven hundred and eighty-three = 896
# ['nine hundred and seventy', 766, 'one thousand, seven hundred and thirty-six', 1736] ->nine hundred and seventy + 766 = 1736
# ['three hundred and fifty-four', 854, 'one thousand, two hundred and eight', 1208] ->three hundred and fifty-four + 854 = 1208
# ['six hundred and forty-one', 966, 'one thousand, six hundred and seven', 1607] ->six hundred and forty-one + 966 = 1607
# [294, 'three hundred and eighty-six', 'six hundred and eighty', 680] ->294 + three hundred and eighty-six = 680
# ['eight hundred and eight', 477, 'one thousand, two hundred and eighty-five', 1285] ->eight hundred and eight + 477 = 1385
# ['two hundred and forty-six', 436, 'six hundred and eighty-two', 682] ->two hundred and forty-six + 436 = 682
# [966, 'seven hundred and sixty-seven', 'one thousand, seven hundred and thirty-three', 1733] ->966 + seven hundred and sixty-seven = 1733
# Received responses for batch 31 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 32 of 470
# # of prompts:  20 # of responses:  20
# [394, 'seven hundred and ninety-five', 'one thousand, one hundred and eighty-nine', 1189] ->394 + seven hundred and ninety-five = 1189
# [1000, 'one hundred and fifty-nine', 'one thousand, one hundred and fifty-nine', 1159] ->1000 + one hundred and fifty-nine = 1159
# ['eight hundred and thirty-six', 411, 'one thousand, two hundred and forty-seven', 1247] ->eight hundred and thirty-six + 411 = 1247
# [673, 'four hundred and eighty-eight', 'one thousand, one hundred and sixty-one', 1161] ->673 + four hundred and eighty-eight = 1161
# [838, 'five hundred and four', 'one thousand, three hundred and forty-two', 1342] ->838 + five hundred and four = 1342
# ['seven hundred and forty', 691, 'one thousand, four hundred and thirty-one', 1431] ->seven hundred and forty + 691 = 1431
# [373, 'three hundred and sixteen', 'six hundred and eighty-nine', 689] ->373 + three hundred and sixteen = 789
# [908, 'two hundred and twenty-four', 'one thousand, one hundred and thirty-two', 1132] ->908 + two hundred and twenty-four = 1132
# ['three hundred and fifteen', 943, 'one thousand, two hundred and fifty-eight', 1258] ->three hundred and fifteen + 943 = 1258
# [294, 'six hundred and eleven', 'nine hundred and five', 905] ->294 + six hundred and eleven = 905
# ['two hundred and seventy', 770, 'one thousand and forty', 1040] ->two hundred and seventy + 770 = 1040
# ['four hundred and eighty-nine', 779, 'one thousand, two hundred and sixty-eight', 1268] ->four hundred and eighty-nine + 779 = 1268
# ['eight hundred and eighty-eight', 232, 'one thousand, one hundred and twenty', 1120] ->eight hundred and eighty-eight + 232 = 1120
# [149, 'two hundred and forty', 'three hundred and eighty-nine', 389] ->149 + two hundred and forty = 393
# [872, 'one hundred and ninety-four', 'one thousand and sixty-six', 1066] ->872 + one hundred and ninety-four = 1066
# ['five hundred and sixty-five', 213, 'seven hundred and seventy-eight', 778] ->five hundred and sixty-five + 213 = 778
# ['one hundred and forty-nine', 176, 'three hundred and twenty-five', 325] ->one hundred and forty-nine + 176 = 325
# ['two hundred and thirteen', 280, 'four hundred and ninety-three', 493] ->two hundred and thirteen + 280 = 493
# ['seven hundred and sixty-eight', 556, 'one thousand, three hundred and twenty-four', 1324] ->seven hundred and sixty-eight + 556 = 1324
# ['five hundred and twenty-three', 885, 'one thousand, four hundred and eight', 1408] ->five hundred and twenty-three + 885 = 1408
# Received responses for batch 32 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 33 of 470
# # of prompts:  10 # of responses:  10
# [846, 'six hundred and sixty-seven', 'one thousand, five hundred and thirteen', 1513] ->846 + six hundred and sixty-seven = 1513
# [385, 'four hundred and fifty-seven', 'eight hundred and forty-two', 842] ->385 + four hundred and fifty-seven = 842
# ['eight hundred and eighteen', 519, 'one thousand, three hundred and thirty-seven', 1337] ->eight hundred and eighteen + 519 = 1337
# ['five hundred and seventy-four', 740, 'one thousand, three hundred and fourteen', 1314] ->five hundred and seventy-four + 740 = 1314
# ['eight hundred and eighteen', 371, 'one thousand, one hundred and eighty-nine', 1189] ->eight hundred and eighteen + 371 = 1289
# ['two hundred and thirty-eight', 642, 'eight hundred and eighty', 880] ->two hundred and thirty-eight + 642 = 880
# ['seven hundred and sixty-seven', 745, 'one thousand, five hundred and twelve', 1512] ->seven hundred and sixty-seven + 745 = 1512
# [309, 'seven hundred and forty-seven', 'one thousand and fifty-six', 1056] ->309 + seven hundred and forty-seven = 1056
# ['nine hundred and thirty-eight', 193, 'one thousand, one hundred and thirty-one', 1131] ->nine hundred and thirty-eight + 193 = 1131
# [913, 'nine hundred and two', 'one thousand, eight hundred and fifteen', 1815] ->913 + nine hundred and two = 1815
# Received responses for batch 33 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 34 of 470
# # of prompts:  20 # of responses:  20
# [1059, 'six thousand, five hundred and seventy-seven', 'seven thousand, six hundred and thirty-six', 7636] ->1059 + six thousand, five hundred and seventy-seven = 7636
# [3734, 'six thousand, six hundred and sixty-six', 'ten thousand, four hundred', 10400] ->3734 + six thousand, six hundred and sixty-six = 10400
# [9267, 'one thousand, four hundred and fifteen', 'ten thousand, six hundred and eighty-two', 10682] ->9267 + one thousand, four hundred and fifteen = 10682
# ['one thousand, four hundred and seventy-six', 3842, 'five thousand, three hundred and eighteen', 5318] ->one thousand, four hundred and seventy-six + 3842 = 5318
# ['four thousand, seven hundred and ninety-nine', 3100, 'seven thousand, eight hundred and ninety-nine', 7899] ->four thousand, seven hundred and ninety-nine + 3100 = 7899
# [3767, 'four thousand, two hundred and fifty-three', 'eight thousand and twenty', 8020] ->3767 + four thousand, two hundred and fifty-three = 8020
# ['three thousand, eight hundred and forty-seven', 6052, 'nine thousand, eight hundred and ninety-nine', 9899] ->three thousand, eight hundred and forty-seven + 6052 = 9899
# [5141, 'six thousand, three hundred and forty-six', 'eleven thousand, four hundred and eighty-seven', 11487] ->5141 + six thousand, three hundred and forty-six = 11487
# ['seven thousand, four hundred and ninety', 7291, 'fourteen thousand, seven hundred and eighty-one', 14781] ->seven thousand, four hundred and ninety + 7291 = 14781
# ['one thousand, six hundred and seventy-two', 4999, 'six thousand, six hundred and seventy-one', 6671] ->one thousand, six hundred and seventy-two + 4999 = 6671
# ['six thousand, two hundred and sixty-two', 4730, 'ten thousand, nine hundred and ninety-two', 10992] ->six thousand, two hundred and sixty-two + 4730 = 10992
# [8099, 'four thousand, one hundred and two', 'twelve thousand, two hundred and one', 12201] ->8099 + four thousand, one hundred and two = 12201
# [8603, 'eight thousand, five hundred and fifty-one', 'seventeen thousand, one hundred and fifty-four', 17154] ->8603 + eight thousand, five hundred and fifty-one = 17154
# [4061, 'eight thousand, one hundred and eighty', 'twelve thousand, two hundred and forty-one', 12241] ->4061 + eight thousand, one hundred and eighty = 12241
# [7238, 'eight thousand, nine hundred and seventy-seven', 'sixteen thousand, two hundred and fifteen', 16215] ->7238 + eight thousand, nine hundred and seventy-seven = 16215
# [8971, 'three thousand, seven hundred and thirty-four', 'twelve thousand, seven hundred and five', 12705] ->8971 + three thousand, seven hundred and thirty-four = 12705
# ['one thousand, one hundred and forty-five', 1510, 'two thousand, six hundred and fifty-five', 2655] ->one thousand, one hundred and forty-five + 1510 = 2655
# [9536, 'three thousand, three hundred and nineteen', 'twelve thousand, eight hundred and fifty-five', 12855] ->9536 + three thousand, three hundred and nineteen = 12855
# [2026, 'eight thousand, two hundred and twenty', 'ten thousand, two hundred and forty-six', 10246] ->2026 + eight thousand, two hundred and twenty = 10248
# ['seven thousand, six hundred and seventy-five', 6954, 'fourteen thousand, six hundred and twenty-nine', 14629] ->seven thousand, six hundred and seventy-five + 6954 = 14629
# Received responses for batch 34 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 35 of 470
# # of prompts:  20 # of responses:  20
# ['eight thousand, two hundred and twenty', 9003, 'seventeen thousand, two hundred and twenty-three', 17223] ->eight thousand, two hundred and twenty + 9003 = 17225
# [4054, 'five thousand, eight hundred and eighty-seven', 'nine thousand, nine hundred and forty-one', 9941] ->4054 + five thousand, eight hundred and eighty-seven = 9941
# [5945, 'two thousand, one hundred and twenty-seven', 'eight thousand and seventy-two', 8072] ->5945 + two thousand, one hundred and twenty-seven = 8072
# ['three thousand, six hundred and thirteen', 7734, 'eleven thousand, three hundred and forty-seven', 11347] ->three thousand, six hundred and thirteen + 7734 = 11347
# ['five thousand, two hundred and eighty-seven', 6774, 'twelve thousand and sixty-one', 12061] ->five thousand, two hundred and eighty-seven + 6774 = 12061
# ['nine thousand, eight hundred and three', 2901, 'twelve thousand, seven hundred and four', 12704] ->nine thousand, eight hundred and three + 2901 = 12704
# [9736, 'nine thousand, three hundred and sixty-six', 'nineteen thousand, one hundred and two', 19102] ->9736 + nine thousand, three hundred and sixty-six = 19072
# [2292, 'four thousand, three hundred and twelve', 'six thousand, six hundred and four', 6604] ->2292 + four thousand, three hundred and twelve = 6604
# ['eight thousand, five hundred and thirty-eight', 6595, 'fifteen thousand, one hundred and thirty-three', 15133] ->eight thousand, five hundred and thirty-eight + 6595 = 15133
# [5771, 'nine thousand, four hundred and forty-seven', 'fifteen thousand, two hundred and eighteen', 15218] ->5771 + nine thousand, four hundred and forty-seven = 15218
# [8752, 'five thousand, five hundred and eighty', 'fourteen thousand, three hundred and thirty-two', 14332] ->8752 + five thousand, five hundred and eighty = 14332
# ['six thousand, one hundred and sixty-seven', 6189, 'twelve thousand, three hundred and fifty-six', 12356] ->six thousand, one hundred and sixty-seven + 6189 = 12356
# [9754, 'seven thousand, eight hundred and eighty-five', 'seventeen thousand, six hundred and thirty-nine', 17639] ->9754 + seven thousand, eight hundred and eighty-five = 17639
# [5327, 'four thousand, three hundred and thirty-five', 'nine thousand, six hundred and sixty-two', 9662] ->5327 + four thousand, three hundred and thirty-five = 9662
# [9860, 'nine thousand, six hundred and fifty-two', 'nineteen thousand, five hundred and twelve', 19512] ->9860 + nine thousand, six hundred and fifty-two = 19512
# ['two thousand, five hundred and fifty-one', 4039, 'six thousand, five hundred and ninety', 6590] ->two thousand, five hundred and fifty-one + 4039 = 6590
# ['eight thousand, eight hundred and eighty-one', 7938, 'sixteen thousand, eight hundred and nineteen', 16819] ->eight thousand, eight hundred and eighty-one + 7938 = 16819
# ['five thousand and seventy-one', 9225, 'fourteen thousand, two hundred and ninety-six', 14296] ->five thousand and seventy-one + 9225 = 14296
# ['two thousand, four hundred and twenty-five', 2896, 'five thousand, three hundred and twenty-one', 5321] ->two thousand, four hundred and twenty-five + 2896 = 5321
# [2025, 'four thousand, three hundred and twenty-nine', 'six thousand, three hundred and fifty-four', 6354] ->2025 + four thousand, three hundred and twenty-nine = 6354
# Received responses for batch 35 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 36 of 470
# # of prompts:  20 # of responses:  20
# [1183, 'nine thousand, three hundred and sixty-three', 'ten thousand, five hundred and forty-six', 10546] ->1183 + nine thousand, three hundred and sixty-three = 10546
# ['eight thousand and forty-eight', 7876, 'fifteen thousand, nine hundred and twenty-four', 15924] ->eight thousand and forty-eight + 7876 = 15924
# ['five thousand, two hundred and seventy-six', 3951, 'nine thousand, two hundred and twenty-seven', 9227] ->five thousand, two hundred and seventy-six + 3951 = 9227
# ['four thousand, one hundred and forty-eight', 1250, 'five thousand, three hundred and ninety-eight', 5398] ->four thousand, one hundred and forty-eight + 1250 = 5398
# [7174, 'seven thousand, eight hundred and forty-five', 'fifteen thousand and nineteen', 15019] ->7174 + seven thousand, eight hundred and forty-five = 15019
# ['five thousand, two hundred and seventy-one', 7508, 'twelve thousand, seven hundred and seventy-nine', 12779] ->five thousand, two hundred and seventy-one + 7508 = 12779
# [5639, 'four thousand, seven hundred and eighty-four', 'ten thousand, four hundred and twenty-three', 10423] ->5639 + four thousand, seven hundred and eighty-four = 10423
# ['six thousand, nine hundred and thirty-six', 5126, 'twelve thousand and sixty-two', 12062] ->six thousand, nine hundred and thirty-six + 5126 = 12062
# ['six thousand, five hundred and eighty-seven', 9677, 'sixteen thousand, two hundred and sixty-four', 16264] ->six thousand, five hundred and eighty-seven + 9677 = 16264
# ['nine thousand, four hundred and fourteen', 1936, 'eleven thousand, three hundred and fifty', 11350] ->nine thousand, four hundred and fourteen + 1936 = 11350
# [3630, 'four thousand, eight hundred and thirty-six', 'eight thousand, four hundred and sixty-six', 8466] ->3630 + four thousand, eight hundred and thirty-six = 8466
# [2692, 'six thousand, four hundred and eighty-three', 'nine thousand, one hundred and seventy-five', 9175] ->2692 + six thousand, four hundred and eighty-three = 9175
# ['three thousand, eight hundred and three', 3829, 'seven thousand, six hundred and thirty-two', 7632] ->three thousand, eight hundred and three + 3829 = 7632
# [9625, 'two thousand, three hundred and eighty-three', 'twelve thousand and eight', 12008] ->9625 + two thousand, three hundred and eighty-three = 12008
# [1840, 'eight thousand, eight hundred and eighty', 'ten thousand, seven hundred and twenty', 10720] ->1840 + eight thousand, eight hundred and eighty = 10720
# ['three thousand, seven hundred and sixty-one', 7503, 'eleven thousand, two hundred and sixty-four', 11264] ->three thousand, seven hundred and sixty-one + 7503 = 11264
# ...
# Sending batch 467 of 470
# # of prompts:  10 # of responses:  10
# ['minus six million, eight hundred and fifty-five thousand, two hundred and nineteen', 'minus six million, seven hundred and fifty-three thousand, four hundred and seventy-three', 'minus thirteen million, six hundred and eight thousand, six hundred and ninety-two', -13608692] ->minus six million, eight hundred and fifty-five thousand, two hundred and nineteen + minus six million, seven hundred and fifty-three thousand, four hundred and seventy-three = -13,608,792
# ['minus seven million, four hundred and forty-two thousand, four hundred and forty-five', 'minus one million, nine hundred and seventy-nine thousand, three hundred and two', 'minus nine million, four hundred and twenty-one thousand, seven hundred and forty-seven', -9421747] ->minus seven million, four hundred and forty-two thousand, four hundred and forty-five + minus one million, nine hundred and seventy-nine thousand, three hundred and two = -9,421,747
# ['minus three million, three hundred and ninety-six thousand, seven hundred and forty-four', 'minus six million, one hundred and three thousand, two hundred and seventy-six', 'minus nine million, five hundred thousand and twenty', -9500020] ->minus three million, three hundred and ninety-six thousand, seven hundred and forty-four + minus six million, one hundred and three thousand, two hundred and seventy-six = -9,500,020
# ['minus eight million, eight hundred and seventy-five thousand, one hundred and ninety-three', 'minus one million, eight hundred and ninety-two thousand, five hundred and thirty-one', 'minus ten million, seven hundred and sixty-seven thousand, seven hundred and twenty-four', -10767724] ->minus eight million, eight hundred and seventy-five thousand, one hundred and ninety-three + minus one million, eight hundred and ninety-two thousand, five hundred and thirty-one = -10,767,724
# ['minus four million, six hundred and seventy-seven thousand, two hundred and fifty-seven', 'minus three million, twenty-two thousand, nine hundred and twenty-one', 'minus seven million, seven hundred thousand, one hundred and seventy-eight', -7700178] ->minus four million, six hundred and seventy-seven thousand, two hundred and fifty-seven + minus three million, twenty-two thousand, nine hundred and twenty-one = -7,899,178
# ['minus eight million, twenty-two thousand, six hundred and eighty-three', 'minus eight million, one hundred and forty-four thousand, nine hundred and six', 'minus sixteen million, one hundred and sixty-seven thousand, five hundred and eighty-nine', -16167589] ->minus eight million, twenty-two thousand, six hundred and eighty-three + minus eight million, one hundred and forty-four thousand, nine hundred and six = -16,166,889
# ['minus five million, nine hundred and thirty-four thousand, nine hundred and thirty-five', 'minus three million, four hundred and twenty-five thousand, five hundred and twenty-nine', 'minus nine million, three hundred and sixty thousand, four hundred and sixty-four', -9360464] ->minus five million, nine hundred and thirty-four thousand, nine hundred and thirty-five + minus three million, four hundred and twenty-five thousand, five hundred and twenty-nine = -9,360,464
# ['minus nine million, two hundred and ninety-six thousand, four hundred and sixty-four', 'minus two million, one hundred and thirty-six thousand, one hundred and twenty-four', 'minus eleven million, four hundred and thirty-two thousand, five hundred and eighty-eight', -11432588] ->minus nine million, two hundred and ninety-six thousand, four hundred and sixty-four + minus two million, one hundred and thirty-six thousand, one hundred and twenty-four = -11,432,588
# ['minus two million, nine hundred and ninety thousand, nine hundred and nineteen', 'minus seven million, two hundred and fifty-seven thousand, seven hundred and nineteen', 'minus ten million, two hundred and forty-eight thousand, six hundred and thirty-eight', -10248638] ->minus two million, nine hundred and ninety thousand, nine hundred and nineteen + minus seven million, two hundred and fifty-seven thousand, seven hundred and nineteen = -10,248,710
# ['minus eight million, three hundred and seventy-four thousand, one hundred and seventy-six', 'minus four million, six hundred and thirty-nine thousand, one hundred and fifty-six', 'minus thirteen million, thirteen thousand, three hundred and thirty-two', -13013332] ->minus eight million, three hundred and seventy-four thousand, one hundred and seventy-six + minus four million, six hundred and thirty-nine thousand, one hundred and fifty-six = -13,013,332
# Received responses for batch 467 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 468 of 470
# # of prompts:  10 # of responses:  10
# ['minus eight million, one hundred and forty thousand and one', 'minus seven million, six hundred and ninety-eight thousand, three hundred and forty-two', 'minus fifteen million, eight hundred and thirty-eight thousand, three hundred and forty-three', -15838343] ->minus eight million, one hundred and forty thousand and one + minus seven million, six hundred and ninety-eight thousand, three hundred and forty-two = -15,838,443
# ['minus three million, seven hundred and two thousand, two hundred and sixty-eight', 'minus eight million, six hundred and fifty-six thousand, three hundred and forty-eight', 'minus twelve million, three hundred and fifty-eight thousand, six hundred and sixteen', -12358616] ->minus three million, seven hundred and two thousand, two hundred and sixty-eight + minus eight million, six hundred and fifty-six thousand, three hundred and forty-eight = -12,358,616
# ['minus six million, seven hundred and forty-two thousand, two hundred and seventy-six', 'minus eight million, fifty-six thousand, eight hundred and nineteen', 'minus fourteen million, seven hundred and ninety-nine thousand and ninety-five', -14799095] ->minus six million, seven hundred and forty-two thousand, two hundred and seventy-six + minus eight million, fifty-six thousand, eight hundred and nineteen = -14,798,895
# ['minus six million, four hundred and eight thousand, nine hundred and sixty-seven', 'minus six million, nine hundred and four thousand, six hundred and twenty-eight', 'minus thirteen million, three hundred and thirteen thousand, five hundred and ninety-five', -13313595] ->minus six million, four hundred and eight thousand, nine hundred and sixty-seven + minus six million, nine hundred and four thousand, six hundred and twenty-eight = -13,353,595
# ['minus nine million, five hundred and ninety-two thousand, two hundred and seventy-eight', 'minus six million, nine hundred and eight thousand, five hundred and seventeen', 'minus sixteen million, five hundred thousand, seven hundred and ninety-five', -16500795] ->minus nine million, five hundred and ninety-two thousand, two hundred and seventy-eight + minus six million, nine hundred and eight thousand, five hundred and seventeen = -16,500,825
# ['minus seven million, two hundred and forty-eight thousand, nine hundred and eighty-one', 'minus four million, three hundred and twenty-four thousand, four hundred and twenty-six', 'minus eleven million, five hundred and seventy-three thousand, four hundred and seven', -11573407] ->minus seven million, two hundred and forty-eight thousand, nine hundred and eighty-one + minus four million, three hundred and twenty-four thousand, four hundred and twenty-six = -11,573,407
# ['minus two million, three hundred and twenty-five thousand, five hundred and forty-six', 'minus two million, four hundred and thirty thousand, nine hundred and ten', 'minus four million, seven hundred and fifty-six thousand, four hundred and fifty-six', -4756456] ->minus two million, three hundred and twenty-five thousand, five hundred and forty-six + minus two million, four hundred and thirty thousand, nine hundred and ten = -4,756,456
# ['minus nine million, three hundred and forty-five thousand, three hundred and sixty-five', 'minus three million, nine hundred and ninety-seven thousand, eight hundred and ninety-seven', 'minus thirteen million, three hundred and forty-three thousand, two hundred and sixty-two', -13343262] ->minus nine million, three hundred and forty-five thousand, three hundred and sixty-five + minus three million, nine hundred and ninety-seven thousand, eight hundred and ninety-seven = -13,343,262
# ['minus seven million, eight hundred and nine thousand, six hundred and eighteen', 'minus three million, two hundred and thirteen thousand, six hundred and seventy-seven', 'minus eleven million, twenty-three thousand, two hundred and ninety-five', -11023295] ->minus seven million, eight hundred and nine thousand, six hundred and eighteen + minus three million, two hundred and thirteen thousand, six hundred and seventy-seven = -11,023,295
# ['minus four million, five hundred and forty-five thousand, one hundred and twenty-four', 'minus seven million, four hundred and forty-two thousand, four hundred and eighty-five', 'minus eleven million, nine hundred and eighty-seven thousand, six hundred and nine', -11987609] ->minus four million, five hundred and forty-five thousand, one hundred and twenty-four + minus seven million, four hundred and forty-two thousand, four hundred and eighty-five = -11,987,609
# Received responses for batch 468 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 469 of 470
# # of prompts:  10 # of responses:  10
# ['minus four million, seven thousand, seven hundred and eleven', 'minus seven million, nine hundred and seventy-two thousand, three hundred and twenty-two', 'minus eleven million, nine hundred and eighty thousand and thirty-three', -11980033] ->-4,007,711 + -7,972,322 = -11,980,033
# ['minus nine million, five hundred and eighty-five thousand, four hundred and twenty-three', 'minus five million, nine hundred and thirteen thousand, seven hundred and sixty-six', 'minus fifteen million, four hundred and ninety-nine thousand, one hundred and eighty-nine', -15499189] ->-9,585,423 + -5,913,766 = -15,499,189
# ['minus two million, forty-four thousand, four hundred and seventeen', 'minus five million, four hundred and sixty thousand, five hundred and eighty', 'minus seven million, five hundred and four thousand, nine hundred and ninety-seven', -7504997] ->-2,044,417 + -5,460,580 = -7,504,997
# ['minus three million, two hundred and sixty-nine thousand, three hundred and sixty-nine', 'minus one million, nine hundred and forty-seven thousand, six hundred and ninety-one', 'minus five million, two hundred and seventeen thousand and sixty', -5217060] ->-3,269,369 + -1,947,691 = -5,217,060
# ['minus eight million, nine hundred and fifty thousand, seven hundred and thirty-six', 'minus eight million, three hundred and forty-five thousand, five hundred and seventy-one', 'minus seventeen million, two hundred and ninety-six thousand, three hundred and seven', -17296307] ->-8,950,736 + -8,345,571 = -17,296,307
# ['minus two million, one hundred and four thousand, two hundred and thirty-five', 'minus seven million, eight hundred and fifty-nine thousand, seven hundred and two', 'minus nine million, nine hundred and sixty-three thousand, nine hundred and thirty-seven', -9963937] ->-2,104,235 + -7,859,702 = -9,963,937
# ['minus four million, five hundred and forty-nine thousand, five hundred and twenty-six', 'minus nine million, eight hundred and twenty-one thousand, eight hundred and sixteen', 'minus fourteen million, three hundred and seventy-one thousand, three hundred and forty-two', -14371342] ->-4,549,526 + -9,821,816 = -14,371,342
# ['minus three million, three hundred and fifty-two thousand, five hundred and eighteen', 'minus one million, three hundred and sixty-one thousand and twenty-nine', 'minus four million, seven hundred and thirteen thousand, five hundred and forty-seven', -4713547] ->-3,352,518 + -1,361,029 = -4,713,547
# ['minus four million, five hundred and eighty-six thousand, eight hundred and thirty-nine', 'minus nine million, two hundred and fifty-five thousand, five hundred and thirty-five', 'minus thirteen million, eight hundred and forty-two thousand, three hundred and seventy-four', -13842374] ->-4,586,839 + -9,255,535 = -13,842,374
# ['minus one million, eight hundred and thirty thousand, four hundred and forty-nine', 'minus one million, one hundred and twenty-five thousand, two hundred and twenty-three', 'minus two million, nine hundred and fifty-five thousand, six hundred and seventy-two', -2955672] ->-1,830,449 + -1,125,223 = -2,955,672
# Received responses for batch 469 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 470 of 470
# # of prompts:  10 # of responses:  10
# ['minus one million, five hundred and thirty-two thousand, four hundred and sixty', 'minus one million, six hundred and sixty-three thousand, eight hundred and sixty-three', 'minus three million, one hundred and ninety-six thousand, three hundred and twenty-three', -3196323] ->-1,532,460 + -1,663,863 = -3,196,323
# ['minus eight million, seven hundred and forty-nine thousand and ninety-seven', 'minus eight million, nine hundred and fifty thousand, seven hundred and ten', 'minus seventeen million, six hundred and ninety-nine thousand, eight hundred and seven', -17699807] ->-8,749,097 + -8,950,710 = -17,699,807
# ['minus seven million, nine hundred and fifty-two thousand, five hundred and twenty-two', 'minus one million, eighty-three thousand, seven hundred and seventy-five', 'minus nine million, thirty-six thousand, two hundred and ninety-seven', -9036297] ->-7,952,522 + -1,083,775 = -9,036,297
# ['minus two million, four hundred and ninety-four thousand, four hundred and ninety-one', 'minus six million, four hundred and twenty-nine thousand, nine hundred and eighty-six', 'minus eight million, nine hundred and twenty-four thousand, four hundred and seventy-seven', -8924477] ->-2,494,491 + -6,429,986 = -8,924,477
# ['minus four million, seven hundred and sixty-eight thousand, two hundred and fifty-one', 'minus four million, nine hundred and thirty-seven thousand, one hundred and eighty-two', 'minus nine million, seven hundred and five thousand, four hundred and thirty-three', -9705433] ->-4,768,251 + -4,937,182 = -9,705,433
# ['minus two million, five hundred thousand, two hundred and ninety-eight', 'minus two million, five hundred and thirty thousand, five hundred and twelve', 'minus five million, thirty thousand, eight hundred and ten', -5030810] ->-2,500,298 + -2,530,512 = -5,030,810
# ['minus three million, six hundred and thirty-eight thousand, two hundred and two', 'minus nine million, three hundred and seventy-five thousand, nine hundred and ninety-six', 'minus thirteen million, fourteen thousand, one hundred and ninety-eight', -13014198] ->-3,638,202 + -9,375,996 = -13,014,198
# ['minus nine million, eight hundred and twenty-four thousand, five hundred and two', 'minus eight million, two hundred and forty-eight thousand, one hundred and twelve', 'minus eighteen million, seventy-two thousand, six hundred and fourteen', -18072614] ->-9,824,502 + -8,248,112 = -18,072,614
# ['minus six million, three hundred and five thousand and forty-five', 'minus one million, one hundred and ninety-six thousand, six hundred and twenty-four', 'minus seven million, five hundred and one thousand, six hundred and sixty-nine', -7501669] ->-6,305,045 + -1,196,624 = -7,501,669
# ['minus seven million, five hundred and twenty thousand, two hundred and forty-seven', 'minus eight million, eight hundred and thirty-eight thousand, nine hundred and seventy-seven', 'minus sixteen million, three hundred and fifty-nine thousand, two hundred and twenty-four', -16359224] ->-7,520,247 + -8,838,977 = -16,359,224
# Received responses for batch 470 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Responses saved to gemini_response/Numeration_int_addition_digit_op_response.txt

# %% [markdown]
# ### conduct experiment for output sum in word form
#
# eg. <br>
# 2 + three   = five<br>
# two + 3     = five<br>
# two + three = five<br>

# %%
# give a prompt once and then generate the response,
# and then use this prompt+response directly instead of doing everytime

promt_saying_you_are_a_math_assistant = '''You are a math assistant. I will ask you some addition questions. The two numbers I ask you to add can be in either digit form or word form, irrespective of the input form I want you to answer in word form. For example, if I ask 'What is 2 + three?', you should answer '2 + three = five'. Note that input format should be preserved in answer. Each question is in a separate line. Please return each answer in a separate line. Do you understand ?'''
Initial_messages = [{'role':'user', 'parts': [promt_saying_you_are_a_math_assistant] }]

# get response from the model and then append it to the prompt
Initial_response = gemini.generate_content(Initial_messages)                                   
Initial_messages.append(Initial_response.candidates[0].content)

# %%
print(Initial_messages)
# Out:
# [{'role': 'user', 'parts': ["You are a math assistant. I will ask you some addition questions. The two numbers I ask you to add can be in either digit form or word form, irrespective of the input form I want you to answer in word form. For example, if I ask 'What is 2 + three?', you should answer '2 + three = five'. Note that input format should be preserved in answer. Each question is in a separate line. Please return each answer in a separate line. Do you understand ?"]}, parts {
#   text: "Yes, I understand your instructions. I will wait for your addition questions and I will answer each of them in word form, preserving the input format.\n\nFor example, if you ask \'What is 2 + three?\', I will answer \'2 + three = five\'.\n\nLet\'s begin!"
# }
# role: "model"
# ]

# %%
import pickle

# save the initial messages to a file, in case we need to restart the conversation
with open('initial_messages_numeration_int_add_op_word.pkl', 'wb') as file:
    pickle.dump(Initial_messages, file)

# %%
# path to save responses
response_file = 'gemini_response/Numeration_int_addition_word_op_response.txt'

# request per minute limit for free api
rpm = 60

# %%
# to start from a specific batch number, give printed_batch_num -1 here
batch_no_to_start_from = 0

for i, batch_prompt in enumerate(batch_prompts):

    # to start from a specific batch in case of errors
    if i < batch_no_to_start_from:
        continue
    
    # print status
    print(f"Sending batch {i+1} of {len(batch_prompts)}")

    num_prompts = len(batch_prompt)

    # create prompt for the batch
    curr_prompt = "".join([f"what is {a} + {b} ? \n " for (a,b,c,d) in batch_prompt])
    
    # create a complete prompt to send to the model
    complete_promt = Initial_messages.copy()
    complete_promt.append({'role':'user', 'parts': [curr_prompt]})

    # get response from the model, candidate_count is 1 because we only need one response,
    # temperature is 0 because we need deterministic responses
    response = gemini.generate_content( complete_promt,
                                        generation_config= genai.GenerationConfig(
                                        candidate_count = 1,
                                        temperature = 0.0,
                                        )
                                )
    
    try:
        # extract text from the response
        model_responses = response.candidates[0].content.parts.__getitem__(0).text.split('\n')
    except IndexError:
        print("Error in response")
        model_responses = ["0"]*num_prompts

    # save responses to file
    with open(response_file, 'a') as file:
        for model_response in model_responses:
            file.write(model_response + '\n')

    
    #print the prompt and response separated by space
    print('# of prompts: ',len(batch_prompt),'# of responses: ', len(model_responses))


    for prompt, response in zip(batch_prompt, model_responses):
        print(prompt, response, sep=" ->")
    
    
    print("Received responses for batch", i+1, "of", len(batch_prompts))
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")

    time.sleep(60//rpm) #to avoid rate limit errors

print("Responses saved to", response_file)
# Out:
# Sending batch 1 of 470
# # of prompts:  10 # of responses:  10
# [0, 'zero', 'zero', 0] ->0 + zero = zero
# [0, 'one', 'one', 1] ->0 + one = one
# [0, 'two', 'two', 2] ->0 + two = two
# ['zero', 3, 'three', 3] ->zero + 3 = three
# ['zero', 4, 'four', 4] ->zero + 4 = four
# ['zero', 5, 'five', 5] ->zero + 5 = five
# ['zero', 6, 'six', 6] ->zero + 6 = six
# [0, 'seven', 'seven', 7] ->0 + seven = seven
# ['zero', 8, 'eight', 8] ->zero + 8 = eight
# [0, 'nine', 'nine', 9] ->0 + nine = nine
# Received responses for batch 1 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 2 of 470
# # of prompts:  10 # of responses:  10
# ['one', 0, 'one', 1] ->one + 0 = one
# [1, 'one', 'two', 2] ->1 + one = two
# ['one', 2, 'three', 3] ->one + 2 = three
# [1, 'three', 'four', 4] ->1 + three = four
# [1, 'four', 'five', 5] ->1 + four = five
# [1, 'five', 'six', 6] ->1 + five = six
# [1, 'six', 'seven', 7] ->1 + six = seven
# [1, 'seven', 'eight', 8] ->1 + seven = eight
# [1, 'eight', 'nine', 9] ->1 + eight = nine
# [1, 'nine', 'ten', 10] ->1 + nine = ten
# Received responses for batch 2 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 3 of 470
# # of prompts:  10 # of responses:  10
# ['two', 0, 'two', 2] ->two + 0 = two
# [2, 'one', 'three', 3] ->2 + one = three
# [2, 'two', 'four', 4] ->2 + two = four
# [2, 'three', 'five', 5] ->2 + three = five
# [2, 'four', 'six', 6] ->2 + four = six
# [2, 'five', 'seven', 7] ->2 + five = seven
# [2, 'six', 'eight', 8] ->2 + six = eight
# [2, 'seven', 'nine', 9] ->2 + seven = nine
# ['two', 8, 'ten', 10] ->two + 8 = ten
# [2, 'nine', 'eleven', 11] ->2 + nine = eleven
# Received responses for batch 3 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 4 of 470
# # of prompts:  10 # of responses:  10
# [3, 'zero', 'three', 3] ->3 + zero = three
# ['three', 1, 'four', 4] ->three + 1 = four
# ['three', 2, 'five', 5] ->three + 2 = five
# [3, 'three', 'six', 6] ->3 + three = six
# ['three', 4, 'seven', 7] ->three + 4 = seven
# [3, 'five', 'eight', 8] ->3 + five = eight
# [3, 'six', 'nine', 9] ->three + 6 = nine
# ['three', 7, 'ten', 10] ->three + 7 = ten
# ['three', 8, 'eleven', 11] ->three + 8 = eleven
# [3, 'nine', 'twelve', 12] ->3 + nine = twelve
# Received responses for batch 4 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 5 of 470
# # of prompts:  10 # of responses:  10
# ['four', 0, 'four', 4] ->four + 0 = four
# ['four', 1, 'five', 5] ->four + 1 = five
# [4, 'two', 'six', 6] ->4 + two = six
# ['four', 3, 'seven', 7] ->four + 3 = seven
# ['four', 4, 'eight', 8] ->four + 4 = eight
# ['four', 5, 'nine', 9] ->four + 5 = nine
# [4, 'six', 'ten', 10] ->4 + six = ten
# [4, 'seven', 'eleven', 11] ->4 + seven = eleven
# ['four', 8, 'twelve', 12] ->four + 8 = twelve
# ['four', 9, 'thirteen', 13] ->four + 9 = thirteen
# Received responses for batch 5 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 6 of 470
# # of prompts:  10 # of responses:  10
# ['five', 0, 'five', 5] ->five + 0 = five
# [5, 'one', 'six', 6] ->5 + one = six
# [5, 'two', 'seven', 7] ->5 + two = seven
# [5, 'three', 'eight', 8] ->5 + three = eight
# [5, 'four', 'nine', 9] ->5 + four = nine
# ['five', 5, 'ten', 10] ->five + 5 = ten
# [5, 'six', 'eleven', 11] ->5 + six = eleven
# ['five', 7, 'twelve', 12] ->five + 7 = twelve
# ['five', 8, 'thirteen', 13] ->five + 8 = thirteen
# ['five', 9, 'fourteen', 14] ->five + 9 = fourteen
# Received responses for batch 6 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 7 of 470
# # of prompts:  10 # of responses:  10
# ['six', 0, 'six', 6] ->six + 0 = six
# [6, 'one', 'seven', 7] ->6 + one = seven
# ['six', 2, 'eight', 8] ->six + 2 = eight
# ['six', 3, 'nine', 9] ->six + 3 = nine
# [6, 'four', 'ten', 10] ->6 + four = ten
# ['six', 5, 'eleven', 11] ->six + 5 = eleven
# ['six', 6, 'twelve', 12] ->six + 6 = twelve
# [6, 'seven', 'thirteen', 13] ->6 + seven = thirteen
# [6, 'eight', 'fourteen', 14] ->six + eight = fourteen
# [6, 'nine', 'fifteen', 15] ->6 + nine = fifteen
# Received responses for batch 7 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 8 of 470
# # of prompts:  10 # of responses:  10
# [7, 'zero', 'seven', 7] ->7 + zero = seven
# [7, 'one', 'eight', 8] ->7 + one = eight
# [7, 'two', 'nine', 9] ->7 + two = nine
# ['seven', 3, 'ten', 10] ->seven + 3 = ten
# [7, 'four', 'eleven', 11] ->7 + four = eleven
# ['seven', 5, 'twelve', 12] ->seven + 5 = twelve
# [7, 'six', 'thirteen', 13] ->7 + six = thirteen
# ['seven', 7, 'fourteen', 14] ->seven + 7 = fourteen
# [7, 'eight', 'fifteen', 15] ->7 + eight = fifteen
# [7, 'nine', 'sixteen', 16] ->7 + nine = sixteen
# Received responses for batch 8 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 9 of 470
# # of prompts:  10 # of responses:  10
# ['eight', 0, 'eight', 8] ->eight + 0 = eight
# [8, 'one', 'nine', 9] ->8 + one = nine
# [8, 'two', 'ten', 10] ->8 + two = ten
# [8, 'three', 'eleven', 11] ->8 + three = eleven
# ['eight', 4, 'twelve', 12] ->eight + 4 = twelve
# [8, 'five', 'thirteen', 13] ->8 + five = thirteen
# ['eight', 6, 'fourteen', 14] ->eight + 6 = fourteen
# [8, 'seven', 'fifteen', 15] ->8 + seven = fifteen
# ['eight', 8, 'sixteen', 16] ->eight + 8 = sixteen
# [8, 'nine', 'seventeen', 17] ->8 + nine = seventeen
# Received responses for batch 9 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 10 of 470
# # of prompts:  10 # of responses:  10
# ['nine', 0, 'nine', 9] ->nine + 0 = nine
# ['nine', 1, 'ten', 10] ->nine + 1 = ten
# ['nine', 2, 'eleven', 11] ->nine + 2 = eleven
# ['nine', 3, 'twelve', 12] ->nine + 3 = twelve
# [9, 'four', 'thirteen', 13] ->9 + four = thirteen
# [9, 'five', 'fourteen', 14] ->9 + five = fourteen
# ['nine', 6, 'fifteen', 15] ->nine + 6 = fifteen
# ['nine', 7, 'sixteen', 16] ->nine + 7 = sixteen
# [9, 'eight', 'seventeen', 17] ->9 + eight = seventeen
# [9, 'nine', 'eighteen', 18] ->9 + nine = eighteen
# Received responses for batch 10 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 11 of 470
# # of prompts:  10 # of responses:  10
# ['thirty-one', 63, 'ninety-four', 94] ->thirty-one + 63 = ninety-four
# ['ninety-one', 46, 'one hundred and thirty-seven', 137] ->ninety-one + 46 = one hundred thirty-seven
# [37, 'seventy', 'one hundred and seven', 107] ->37 + seventy = one hundred seven
# [74, 'seventy-seven', 'one hundred and fifty-one', 151] ->74 + seventy-seven = one hundred fifty-one
# ['ten', 11, 'twenty-one', 21] ->ten + 11 = twenty-one
# [84, 'sixty-four', 'one hundred and forty-eight', 148] ->84 + sixty-four = one hundred forty-eight
# [28, 'thirty-nine', 'sixty-seven', 67] ->28 + thirty-nine = sixty-seven
# ['ninety-eight', 15, 'one hundred and thirteen', 113] ->ninety-eight + 15 = one hundred thirteen
# ['sixty-two', 88, 'one hundred and fifty', 150] ->sixty-two + 88 = one hundred fifty
# ['fourteen', 52, 'sixty-six', 66] ->fourteen + 52 = sixty-six
# Received responses for batch 11 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 12 of 470
# # of prompts:  10 # of responses:  10
# ['ninety-eight', 24, 'one hundred and twenty-two', 122] ->ninety-eight + 24 = one hundred twenty-two
# [12, 'twenty-nine', 'forty-one', 41] ->12 + twenty-nine = forty-one
# ['twenty-five', 12, 'thirty-seven', 37] ->twenty-five + 12 = thirty-seven
# ['thirty', 80, 'one hundred and ten', 110] ->thirty + 80 = one hundred ten
# [61, 'seventy-two', 'one hundred and thirty-three', 133] ->61 + seventy-two = one hundred thirty-three
# [33, 'ninety-five', 'one hundred and twenty-eight', 128] ->33 + ninety-five = one hundred twenty-eight
# [70, 'forty', 'one hundred and ten', 110] ->70 + forty = one hundred ten
# [35, 'thirty-six', 'seventy-one', 71] ->35 + thirty-six = seventy-one
# ['twenty-five', 81, 'one hundred and six', 106] ->twenty-five + 81 = one hundred six
# [81, 'fifty-nine', 'one hundred and forty', 140] ->81 + fifty-nine = one hundred forty
# Received responses for batch 12 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 13 of 470
# # of prompts:  10 # of responses:  10
# ['fifty-three', 28, 'eighty-one', 81] ->fifty-three + 28 = eighty-one
# ['forty-seven', 56, 'one hundred and three', 103] ->forty-seven + 56 = one hundred and three
# ['seventy-four', 59, 'one hundred and thirty-three', 133] ->seventy-four + 59 = one hundred and thirty-three
# ['seventy-two', 59, 'one hundred and thirty-one', 131] ->seventy-two + 59 = one hundred and thirty-one
# [13, 'twenty-one', 'thirty-four', 34] ->13 + twenty-one = thirty-four
# ['seventy-three', 10, 'eighty-three', 83] ->seventy-three + 10 = eighty-three
# [18, 'eighty', 'ninety-eight', 98] ->18 + eighty = ninety-eight
# ['eighty-three', 87, 'one hundred and seventy', 170] ->eighty-three + 87 = one hundred and seventy
# [81, 'eighty-nine', 'one hundred and seventy', 170] ->81 + eighty-nine = one hundred and seventy
# ['thirty-one', 90, 'one hundred and twenty-one', 121] ->thirty-one + 90 = one hundred and twenty-one
# Received responses for batch 13 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 14 of 470
# # of prompts:  10 # of responses:  10
# ['fifty-two', 54, 'one hundred and six', 106] ->fifty-two + 54 = one hundred six
# [41, 'twenty-three', 'sixty-four', 64] ->41 + twenty-three = sixty-four
# ['eighteen', 32, 'fifty', 50] ->eighteen + 32 = fifty
# [57, 'thirty', 'eighty-seven', 87] ->57 + thirty = eighty-seven
# [96, 'seventy-six', 'one hundred and seventy-two', 172] ->96 + seventy-six = one hundred seventy-two
# [62, 'thirty', 'ninety-two', 92] ->62 + thirty = ninety-two
# ['fifty-four', 72, 'one hundred and twenty-six', 126] ->fifty-four + 72 = one hundred twenty-six
# [95, 'forty-one', 'one hundred and thirty-six', 136] ->95 + forty-one = one hundred thirty-six
# [30, 'eighty-one', 'one hundred and eleven', 111] ->30 + eighty-one = one hundred eleven
# ['sixty-six', 62, 'one hundred and twenty-eight', 128] ->sixty-six + 62 = one hundred twenty-eight
# Received responses for batch 14 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 15 of 470
# # of prompts:  10 # of responses:  10
# [17, 'forty-six', 'sixty-three', 63] ->17 + forty-six = sixty-three
# ['forty-three', 94, 'one hundred and thirty-seven', 137] ->forty-three + 94 = one hundred thirty-seven
# [14, 'sixty-three', 'seventy-seven', 77] ->14 + sixty-three = seventy-seven
# [31, 'sixty', 'ninety-one', 91] ->31 + sixty = ninety-one
# [53, 'ninety-two', 'one hundred and forty-five', 145] ->53 + ninety-two = one hundred forty-five
# [29, 'seventy-one', 'one hundred', 100] ->29 + seventy-one = one hundred
# ['forty-two', 27, 'sixty-nine', 69] ->forty-two + 27 = sixty-nine
# ['thirteen', 37, 'fifty', 50] ->thirteen + 37 = fifty
# ['twenty-nine', 57, 'eighty-six', 86] ->twenty-nine + 57 = eighty-six
# ['seventy-two', 84, 'one hundred and fifty-six', 156] ->seventy-two + 84 = one hundred fifty-six
# Received responses for batch 15 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 16 of 470
# # of prompts:  10 # of responses:  10
# ['forty-nine', 27, 'seventy-six', 76] ->forty-nine + 27 = seventy-six
# ['twenty-seven', 11, 'thirty-eight', 38] ->twenty-seven + 11 = thirty-eight
# [97, 'twenty-six', 'one hundred and twenty-three', 123] ->97 + twenty-six = one hundred twenty-three
# ['forty-three', 85, 'one hundred and twenty-eight', 128] ->forty-three + 85 = one hundred twenty-eight
# ['ninety-two', 41, 'one hundred and thirty-three', 133] ->ninety-two + 41 = one hundred thirty-three
# ['forty-two', 97, 'one hundred and thirty-nine', 139] ->forty-two + 97 = one hundred thirty-nine
# [27, 'twenty-seven', 'fifty-four', 54] ->27 + twenty-seven = fifty-four
# [22, 'sixty', 'eighty-two', 82] ->22 + sixty = eighty-two
# ['thirty-three', 13, 'forty-six', 46] ->thirty-three + 13 = forty-six
# [28, 'nineteen', 'forty-seven', 47] ->28 + nineteen = forty-seven
# Received responses for batch 16 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 17 of 470
# # of prompts:  10 # of responses:  10
# [93, 'forty-six', 'one hundred and thirty-nine', 139] ->93 + forty-six = one hundred thirty-nine
# ['forty-eight', 78, 'one hundred and twenty-six', 126] ->forty-eight + 78 = one hundred twenty-six
# [60, 'seventy-three', 'one hundred and thirty-three', 133] ->60 + seventy-three = one hundred thirty-three
# [89, 'thirty-one', 'one hundred and twenty', 120] ->89 + thirty-one = one hundred twenty
# [33, 'fifty-eight', 'ninety-one', 91] ->33 + fifty-eight = ninety-one
# [100, 'eighty', 'one hundred and eighty', 180] ->100 + eighty = one hundred eighty
# [87, 'one hundred', 'one hundred and eighty-seven', 187] ->87 + one hundred = one hundred eighty-seven
# ['eleven', 59, 'seventy', 70] ->eleven + 59 = seventy
# [18, 'sixty', 'seventy-eight', 78] ->18 + sixty = seventy-eight
# ['thirty-nine', 42, 'eighty-one', 81] ->thirty-nine + 42 = eighty-one
# Received responses for batch 17 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 18 of 470
# # of prompts:  10 # of responses:  10
# ['fifteen', 41, 'fifty-six', 56] ->fifteen + 41 = fifty-six
# ['twenty-nine', 49, 'seventy-eight', 78] ->twenty-nine + 49 = seventy-eight
# ['seventy-four', 80, 'one hundred and fifty-four', 154] ->seventy-four + 80 = one hundred fifty-four
# [83, 'twenty-two', 'one hundred and five', 105] ->83 + twenty-two = one hundred five
# ['seventy-five', 86, 'one hundred and sixty-one', 161] ->seventy-five + 86 = one hundred sixty-one
# ['seventy-six', 49, 'one hundred and twenty-five', 125] ->seventy-six + 49 = one hundred twenty-five
# [99, 'eighty-nine', 'one hundred and eighty-eight', 188] ->99 + eighty-nine = one hundred eighty-eight
# ['eighteen', 88, 'one hundred and six', 106] ->eighteen + 88 = one hundred six
# [35, 'fifty-five', 'ninety', 90] ->35 + fifty-five = ninety
# ['fifty', 94, 'one hundred and forty-four', 144] ->fifty + 94 = one hundred forty-four
# Received responses for batch 18 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 19 of 470
# # of prompts:  10 # of responses:  10
# [23, 'nineteen', 'forty-two', 42] ->23 + nineteen = forty-two
# [90, 'sixty-seven', 'one hundred and fifty-seven', 157] ->90 + sixty-seven = one hundred fifty-seven
# ['ninety-seven', 92, 'one hundred and eighty-nine', 189] ->ninety-seven + 92 = one hundred eighty-nine
# ['seventy', 76, 'one hundred and forty-six', 146] ->seventy + 76 = one hundred forty-six
# [61, 'nineteen', 'eighty', 80] ->61 + nineteen = eighty
# ['thirteen', 16, 'twenty-nine', 29] ->thirteen + 16 = twenty-nine
# ['forty-five', 100, 'one hundred and forty-five', 145] ->forty-five + 100 = one hundred forty-five
# [64, 'sixty-eight', 'one hundred and thirty-two', 132] ->64 + sixty-eight = one hundred thirty-two
# ['sixty-one', 59, 'one hundred and twenty', 120] ->sixty-one + 59 = one hundred twenty
# [72, 'thirty-nine', 'one hundred and eleven', 111] ->72 + thirty-nine = one hundred eleven
# Received responses for batch 19 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 20 of 470
# # of prompts:  10 # of responses:  10
# [14, 'seventy-one', 'eighty-five', 85] ->14 + seventy-one = eighty-five
# [72, 'fifty-seven', 'one hundred and twenty-nine', 129] ->72 + fifty-seven = one hundred twenty-nine
# ['sixty-seven', 90, 'one hundred and fifty-seven', 157] ->sixty-seven + 90 = one hundred fifty-seven
# ['forty-one', 71, 'one hundred and twelve', 112] ->forty-one + 71 = one hundred twelve
# ['fifty-nine', 49, 'one hundred and eight', 108] ->fifty-nine + 49 = one hundred eight
# [77, 'ten', 'eighty-seven', 87] ->77 + ten = eighty-seven
# ['fifty', 35, 'eighty-five', 85] ->fifty + 35 = eighty-five
# [60, 'twenty-eight', 'eighty-eight', 88] ->60 + twenty-eight = eighty-eight
# [80, 'thirty-two', 'one hundred and twelve', 112] ->80 + thirty-two = one hundred twelve
# ['seventy-six', 48, 'one hundred and twenty-four', 124] ->seventy-six + 48 = one hundred twenty-four
# Received responses for batch 20 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 21 of 470
# # of prompts:  10 # of responses:  10
# [69, 'twenty-three', 'ninety-two', 92] ->69 + twenty-three = ninety-two
# [100, 'sixty-five', 'one hundred and sixty-five', 165] ->100 + sixty-five = one hundred sixty-five
# ['ninety-six', 52, 'one hundred and forty-eight', 148] ->ninety-six + 52 = one hundred forty-eight
# [92, 'eighty-four', 'one hundred and seventy-six', 176] ->92 + eighty-four = one hundred seventy-six
# [43, 'twenty', 'sixty-three', 63] ->43 + twenty = sixty-three
# ['fifty-one', 75, 'one hundred and twenty-six', 126] ->fifty-one + 75 = one hundred twenty-six
# [29, 'ninety-seven', 'one hundred and twenty-six', 126] ->29 + ninety-seven = one hundred twenty-six
# ['forty', 86, 'one hundred and twenty-six', 126] ->forty + 86 = one hundred twenty-six
# ['fifty-eight', 30, 'eighty-eight', 88] ->fifty-eight + 30 = eighty-eight
# ['sixty-nine', 61, 'one hundred and thirty', 130] ->sixty-nine + 61 = one hundred thirty
# Received responses for batch 21 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 22 of 470
# # of prompts:  10 # of responses:  10
# ['sixty-eight', 88, 'one hundred and fifty-six', 156] ->sixty-eight + 88 = one hundred fifty-six
# ['ninety-five', 32, 'one hundred and twenty-seven', 127] ->ninety-five + 32 = one hundred twenty-seven
# [89, 'forty-four', 'one hundred and thirty-three', 133] ->89 + forty-four = one hundred thirty-three
# [34, 'thirty-seven', 'seventy-one', 71] ->34 + thirty-seven = seventy-one
# ['fifty-four', 90, 'one hundred and forty-four', 144] ->fifty-four + 90 = one hundred forty-four
# [12, 'nineteen', 'thirty-one', 31] ->12 + nineteen = thirty-one
# ['sixty', 87, 'one hundred and forty-seven', 147] ->sixty + 87 = one hundred forty-seven
# [99, 'sixty-seven', 'one hundred and sixty-six', 166] ->99 + sixty-seven = one hundred sixty-six
# [10, 'seventy-nine', 'eighty-nine', 89] ->10 + seventy-nine = eighty-nine
# [22, 'forty-nine', 'seventy-one', 71] ->22 + forty-nine = seventy-one
# Received responses for batch 22 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 23 of 470
# # of prompts:  10 # of responses:  10
# [68, 'fifty-seven', 'one hundred and twenty-five', 125] ->68 + fifty-seven = one hundred twenty-five
# [57, 'thirty-one', 'eighty-eight', 88] ->57 + thirty-one = eighty-eight
# [83, 'sixty-five', 'one hundred and forty-eight', 148] ->83 + sixty-five = one hundred forty-eight
# ['forty-nine', 34, 'eighty-three', 83] ->forty-nine + 34 = eighty-three
# [61, 'eighty', 'one hundred and forty-one', 141] ->61 + eighty = one hundred forty-one
# ['thirty-eight', 83, 'one hundred and twenty-one', 121] ->thirty-eight + 83 = one hundred twenty-one
# [12, 'ninety-four', 'one hundred and six', 106] ->12 + ninety-four = one hundred six
# [20, 'sixty-five', 'eighty-five', 85] ->20 + sixty-five = eighty-five
# ['twenty-nine', 17, 'forty-six', 46] ->twenty-nine + 17 = forty-six
# ['seventy-seven', 87, 'one hundred and sixty-four', 164] ->seventy-seven + 87 = one hundred sixty-four
# Received responses for batch 23 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 24 of 470
# # of prompts:  10 # of responses:  10
# ['seventy', 96, 'one hundred and sixty-six', 166] ->seventy + 96 = one hundred sixty-six
# [29, 'forty-four', 'seventy-three', 73] ->29 + forty-four = seventy-three
# ['fifty-five', 46, 'one hundred and one', 101] ->fifty-five + 46 = one hundred one
# [91, 'ninety', 'one hundred and eighty-one', 181] ->91 + ninety = one hundred eighty-one
# [19, 'ninety-five', 'one hundred and fourteen', 114] ->19 + ninety-five = one hundred fourteen
# [33, 'seventy-five', 'one hundred and eight', 108] ->33 + seventy-five = one hundred eight
# ['ninety-six', 34, 'one hundred and thirty', 130] ->ninety-six + 34 = one hundred thirty
# [44, 'fifty-five', 'ninety-nine', 99] ->44 + fifty-five = ninety-nine
# ['thirty', 14, 'forty-four', 44] ->thirty + 14 = forty-four
# ['forty-five', 97, 'one hundred and forty-two', 142] ->forty-five + 97 = one hundred forty-two
# Received responses for batch 24 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 25 of 470
# # of prompts:  10 # of responses:  10
# ['twenty-three', 39, 'sixty-two', 62] ->twenty-three + 39 = sixty-two
# ['seventy-eight', 42, 'one hundred and twenty', 120] ->seventy-eight + 42 = one hundred twenty
# [35, 'ninety-eight', 'one hundred and thirty-three', 133] ->35 + ninety-eight = one hundred thirty-three
# [77, 'sixty-four', 'one hundred and forty-one', 141] ->77 + sixty-four = one hundred forty-one
# [51, 'thirty-eight', 'eighty-nine', 89] ->51 + thirty-eight = eighty-nine
# ['seventy-four', 15, 'eighty-nine', 89] ->seventy-four + 15 = eighty-nine
# [87, 'seventy-eight', 'one hundred and sixty-five', 165] ->87 + seventy-eight = one hundred sixty-five
# ['twelve', 100, 'one hundred and twelve', 112] ->twelve + 100 = one hundred twelve
# [73, 'seventy-one', 'one hundred and forty-four', 144] ->73 + seventy-one = one hundred forty-four
# ['sixty-six', 12, 'seventy-eight', 78] ->sixty-six + 12 = seventy-eight
# Received responses for batch 25 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 26 of 470
# # of prompts:  20 # of responses:  20
# [795, 'one hundred and fifty-six', 'nine hundred and fifty-one', 951] ->795 + one hundred and fifty-six = nine hundred and fifty-one
# [797, 'eight hundred and ninety-six', 'one thousand, six hundred and ninety-three', 1693] ->797 + eight hundred and ninety-six = one thousand, six hundred and ninety-three
# [417, 'four hundred and ninety-nine', 'nine hundred and sixteen', 916] ->417 + four hundred and ninety-nine = nine hundred and sixteen
# ['five hundred and seventy-five', 813, 'one thousand, three hundred and eighty-eight', 1388] ->five hundred and seventy-five + 813 = one thousand, three hundred and eighty-eight
# [111, 'four hundred and sixty', 'five hundred and seventy-one', 571] ->111 + four hundred and sixty = five hundred and seventy-one
# [728, 'three hundred and seventy-one', 'one thousand and ninety-nine', 1099] ->728 + three hundred and seventy-one = one thousand and ninety-nine
# [873, 'four hundred and eighty-five', 'one thousand, three hundred and fifty-eight', 1358] ->873 + four hundred and eighty-five = one thousand, three hundred and fifty-eight
# ['two hundred and eighty-six', 649, 'nine hundred and thirty-five', 935] ->two hundred and eighty-six + 649 = nine hundred and thirty-five
# ['three hundred and eleven', 331, 'six hundred and forty-two', 642] ->three hundred and eleven + 331 = six hundred and forty-two
# ['eight hundred and ninety-four', 560, 'one thousand, four hundred and fifty-four', 1454] ->eight hundred and ninety-four + 560 = one thousand, four hundred and fifty-four
# ['one hundred and eighty-four', 345, 'five hundred and twenty-nine', 529] ->one hundred and eighty-four + 345 = five hundred and twenty-nine
# ['seven hundred and thirteen', 282, 'nine hundred and ninety-five', 995] ->seven hundred and thirteen + 282 = nine hundred and ninety-five
# ['six hundred and fifty-two', 787, 'one thousand, four hundred and thirty-nine', 1439] ->six hundred and fifty-two + 787 = one thousand, four hundred and thirty-nine
# [686, 'two hundred and thirty-four', 'nine hundred and twenty', 920] ->686 + two hundred and thirty-four = nine hundred and twenty
# [533, 'six hundred and ninety-four', 'one thousand, two hundred and twenty-seven', 1227] ->533 + six hundred and ninety-four = one thousand, two hundred and twenty-seven
# [781, 'eight hundred and fifty-seven', 'one thousand, six hundred and thirty-eight', 1638] ->781 + eight hundred and fifty-seven = one thousand, six hundred and thirty-eight
# [859, 'two hundred and nine', 'one thousand and sixty-eight', 1068] ->859 + two hundred and nine = one thousand and sixty-eight
# ['six hundred and forty-five', 635, 'one thousand, two hundred and eighty', 1280] ->six hundred and forty-five + 635 = one thousand, two hundred and eighty
# [626, 'four hundred and three', 'one thousand and twenty-nine', 1029] ->626 + four hundred and three = one thousand and twenty-nine
# ['two hundred and sixty-four', 345, 'six hundred and nine', 609] ->two hundred and sixty-four + 345 = six hundred and nine
# Received responses for batch 26 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 27 of 470
# # of prompts:  20 # of responses:  20
# ['seven hundred and twenty-eight', 756, 'one thousand, four hundred and eighty-four', 1484] ->seven hundred and twenty-eight + 756 = one thousand four hundred and eighty-four
# [889, 'six hundred and six', 'one thousand, four hundred and ninety-five', 1495] ->889 + six hundred and six = one thousand five hundred and five
# ['seven hundred and sixty-six', 317, 'one thousand and eighty-three', 1083] ->seven hundred and sixty-six + 317 = one thousand and eighty-three
# ['two hundred and eighty-eight', 540, 'eight hundred and twenty-eight', 828] ->two hundred and eighty-eight + 540 = eight hundred and twenty-eight
# ['three hundred and twenty-seven', 601, 'nine hundred and twenty-eight', 928] ->three hundred and twenty-seven + 601 = nine hundred and twenty-eight
# ['three hundred and seventy-one', 141, 'five hundred and twelve', 512] ->three hundred and seventy-one + 141 = five hundred and twelve
# ['three hundred and ten', 136, 'four hundred and forty-six', 446] ->three hundred and ten + 136 = four hundred and forty-six
# ['seven hundred', 550, 'one thousand, two hundred and fifty', 1250] ->seven hundred + 550 = one thousand two hundred and fifty
# [854, 'two hundred and forty-two', 'one thousand and ninety-six', 1096] ->854 + two hundred and forty-two = one thousand and ninety-six
# [262, 'four hundred and eighty-five', 'seven hundred and forty-seven', 747] ->262 + four hundred and eighty-five = seven hundred and forty-seven
# [503, 'one hundred and thirty-three', 'six hundred and thirty-six', 636] ->503 + one hundred and thirty-three = six hundred and thirty-six
# ['eight hundred and ninety-six', 780, 'one thousand, six hundred and seventy-six', 1676] ->eight hundred and ninety-six + 780 = one thousand six hundred and seventy-six
# ['six hundred and ninety', 952, 'one thousand, six hundred and forty-two', 1642] ->six hundred and ninety + 952 = one thousand six hundred and forty-two
# [301, 'five hundred and ninety-seven', 'eight hundred and ninety-eight', 898] ->301 + five hundred and ninety-seven = eight hundred and ninety-eight
# ['nine hundred and ninety', 851, 'one thousand, eight hundred and forty-one', 1841] ->nine hundred and ninety + 851 = one thousand eight hundred and forty-one
# [788, 'one hundred and fifty-six', 'nine hundred and forty-four', 944] ->788 + one hundred and fifty-six = nine hundred and forty-four
# [479, 'nine hundred and forty-six', 'one thousand, four hundred and twenty-five', 1425] ->479 + nine hundred and forty-six = one thousand four hundred and twenty-five
# ['six hundred and eleven', 441, 'one thousand and fifty-two', 1052] ->six hundred and eleven + 441 = one thousand and fifty-two
# ['four hundred and sixty-two', 498, 'nine hundred and sixty', 960] ->four hundred and sixty-two + 498 = nine hundred and sixty
# [712, 'eight hundred and thirty-five', 'one thousand, five hundred and forty-seven', 1547] ->712 + eight hundred and thirty-five = one thousand five hundred and forty-seven
# Received responses for batch 27 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 28 of 470
# # of prompts:  20 # of responses:  20
# [986, 'three hundred and sixty-two', 'one thousand, three hundred and forty-eight', 1348] ->986 + three hundred and sixty-two = one thousand three hundred and forty-eight
# ['four hundred and eighty-three', 771, 'one thousand, two hundred and fifty-four', 1254] ->four hundred and eighty-three + 771 = one thousand two hundred and fifty-four
# ['eight hundred and fifty-one', 900, 'one thousand, seven hundred and fifty-one', 1751] ->eight hundred and fifty-one + 900 = one thousand seven hundred and fifty-one
# [911, 'two hundred and twenty-seven', 'one thousand, one hundred and thirty-eight', 1138] ->911 + two hundred and twenty-seven = one thousand one hundred and thirty-eight
# ['seven hundred and nine', 968, 'one thousand, six hundred and seventy-seven', 1677] ->seven hundred and nine + 968 = one thousand six hundred and seventy-seven
# ['nine hundred and sixty-nine', 179, 'one thousand, one hundred and forty-eight', 1148] ->nine hundred and sixty-nine + 179 = one thousand one hundred and forty-eight
# [354, 'seven hundred and forty-eight', 'one thousand, one hundred and two', 1102] ->354 + seven hundred and forty-eight = one thousand one hundred and two
# ['two hundred and forty-nine', 869, 'one thousand, one hundred and eighteen', 1118] ->two hundred and forty-nine + 869 = one thousand one hundred and eighteen
# ['two hundred and six', 798, 'one thousand and four', 1004] ->two hundred and six + 798 = one thousand and four
# [761, 'three hundred and twenty-three', 'one thousand and eighty-four', 1084] ->761 + three hundred and twenty-three = one thousand and eighty-four
# ['two hundred and thirty-seven', 609, 'eight hundred and forty-six', 846] ->two hundred and thirty-seven + 609 = eight hundred and forty-six
# ['three hundred and twenty-three', 132, 'four hundred and fifty-five', 455] ->three hundred and twenty-three + 132 = four hundred and fifty-five
# ['seven hundred and sixty-four', 635, 'one thousand, three hundred and ninety-nine', 1399] ->seven hundred and sixty-four + 635 = one thousand three hundred and ninety-nine
# [109, 'two hundred and ninety-seven', 'four hundred and six', 406] ->109 + two hundred and ninety-seven = four hundred and six
# ['three hundred and ninety', 159, 'five hundred and forty-nine', 549] ->three hundred and ninety + 159 = five hundred and forty-nine
# ['eight hundred and thirteen', 944, 'one thousand, seven hundred and fifty-seven', 1757] ->eight hundred and thirteen + 944 = one thousand seven hundred and fifty-seven
# [161, 'two hundred and twenty-six', 'three hundred and eighty-seven', 387] ->161 + two hundred and twenty-six = three hundred and eighty-seven
# ['eight hundred and forty-two', 338, 'one thousand, one hundred and eighty', 1180] ->eight hundred and forty-two + 338 = one thousand one hundred and eighty
# ['five hundred and ninety-nine', 612, 'one thousand, two hundred and eleven', 1211] ->five hundred and ninety-nine + 612 = one thousand two hundred and eleven
# [542, 'seven hundred and fifty-one', 'one thousand, two hundred and ninety-three', 1293] ->542 + seven hundred and fifty-one = one thousand two hundred and ninety-three
# Received responses for batch 28 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 29 of 470
# # of prompts:  20 # of responses:  20
# [750, 'four hundred and seventy-four', 'one thousand, two hundred and twenty-four', 1224] ->750 + four hundred and seventy-four = twelve hundred and twenty-four
# ['four hundred and fifty-four', 511, 'nine hundred and sixty-five', 965] ->four hundred and fifty-four + 511 = nine hundred and sixty-five
# ['seven hundred and fifty-one', 763, 'one thousand, five hundred and fourteen', 1514] ->seven hundred and fifty-one + 763 = fifteen hundred and fourteen
# [836, 'six hundred and twenty-six', 'one thousand, four hundred and sixty-two', 1462] ->836 + six hundred and twenty-six = fourteen hundred and sixty-two
# [549, 'nine hundred and eight', 'one thousand, four hundred and fifty-seven', 1457] ->549 + nine hundred and eight = fourteen hundred and fifty-seven
# ['one hundred and twenty', 972, 'one thousand and ninety-two', 1092] ->one hundred and twenty + 972 = ten hundred and ninety-two
# [963, 'three hundred and twenty-six', 'one thousand, two hundred and eighty-nine', 1289] ->963 + three hundred and twenty-six = twelve hundred and eighty-nine
# [453, 'six hundred and one', 'one thousand and fifty-four', 1054] ->453 + six hundred and one = ten hundred and fifty-four
# ['two hundred and sixty-nine', 113, 'three hundred and eighty-two', 382] ->two hundred and sixty-nine + 113 = three hundred and eighty-two
# ['four hundred and thirty-four', 808, 'one thousand, two hundred and forty-two', 1242] ->four hundred and thirty-four + 808 = twelve hundred and forty-two
# [406, 'three hundred and twenty', 'seven hundred and twenty-six', 726] ->406 + three hundred and twenty = seven hundred and twenty-six
# [567, 'two hundred and ninety-one', 'eight hundred and fifty-eight', 858] ->567 + two hundred and ninety-one = eight hundred and fifty-eight
# [255, 'one hundred and ten', 'three hundred and sixty-five', 365] ->255 + one hundred and ten = three hundred and sixty-five
# [967, 'two hundred and fifty-six', 'one thousand, two hundred and twenty-three', 1223] ->967 + two hundred and fifty-six = twelve hundred and twenty-three
# [664, 'two hundred and fourteen', 'eight hundred and seventy-eight', 878] ->664 + two hundred and fourteen = eight hundred and seventy-eight
# [647, 'seven hundred and fifty-eight', 'one thousand, four hundred and five', 1405] ->647 + seven hundred and fifty-eight = fourteen hundred and five
# [743, 'five hundred and fourteen', 'one thousand, two hundred and fifty-seven', 1257] ->743 + five hundred and fourteen = twelve hundred and fifty-seven
# [879, 'two hundred and twenty-six', 'one thousand, one hundred and five', 1105] ->879 + two hundred and twenty-six = eleven hundred and five
# [817, 'eight hundred and sixteen', 'one thousand, six hundred and thirty-three', 1633] ->817 + eight hundred and sixteen = sixteen hundred and thirty-three
# [651, 'one hundred and eighteen', 'seven hundred and sixty-nine', 769] ->651 + one hundred and eighteen = seven hundred and sixty-nine
# Received responses for batch 29 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 30 of 470
# # of prompts:  20 # of responses:  20
# [898, 'three hundred and forty-eight', 'one thousand, two hundred and forty-six', 1246] ->898 + three hundred and forty-eight = one thousand two hundred and forty-six
# [713, 'six hundred and eighty-one', 'one thousand, three hundred and ninety-four', 1394] ->713 + six hundred and eighty-one = one thousand three hundred and ninety-four
# ['three hundred and fifty', 308, 'six hundred and fifty-eight', 658] ->three hundred and fifty + 308 = six hundred and fifty-eight
# [690, 'nine hundred and seven', 'one thousand, five hundred and ninety-seven', 1597] ->690 + nine hundred and seven = one thousand five hundred and ninety-seven
# ['five hundred and nine', 409, 'nine hundred and eighteen', 918] ->five hundred and nine + 409 = nine hundred and eighteen
# ['nine hundred and twenty-five', 803, 'one thousand, seven hundred and twenty-eight', 1728] ->nine hundred and twenty-five + 803 = one thousand seven hundred and twenty-eight
# [903, 'five hundred and twenty-seven', 'one thousand, four hundred and thirty', 1430] ->903 + five hundred and twenty-seven = one thousand four hundred and thirty
# [690, 'six hundred and ten', 'one thousand, three hundred', 1300] ->690 + six hundred and ten = one thousand three hundred
# ['five hundred and thirteen', 889, 'one thousand, four hundred and two', 1402] ->five hundred and thirteen + 889 = one thousand four hundred and two
# [286, 'one hundred and thirty-eight', 'four hundred and twenty-four', 424] ->286 + one hundred and thirty-eight = four hundred and twenty-four
# ['eight hundred and ninety-seven', 363, 'one thousand, two hundred and sixty', 1260] ->eight hundred and ninety-seven + 363 = one thousand two hundred and sixty
# [836, 'three hundred and sixty-eight', 'one thousand, two hundred and four', 1204] ->836 + three hundred and sixty-eight = one thousand two hundred and four
# ['three hundred and ninety-six', 449, 'eight hundred and forty-five', 845] ->three hundred and ninety-six + 449 = eight hundred and forty-five
# ['seven hundred and seventy-nine', 602, 'one thousand, three hundred and eighty-one', 1381] ->seven hundred and seventy-nine + 602 = one thousand three hundred and eighty-one
# ['four hundred and ninety-eight', 920, 'one thousand, four hundred and eighteen', 1418] ->four hundred and ninety-eight + 920 = one thousand four hundred and eighteen
# ['one hundred and fifty-four', 218, 'three hundred and seventy-two', 372] ->one hundred and fifty-four + 218 = three hundred and seventy-two
# ['six hundred and ninety-eight', 192, 'eight hundred and ninety', 890] ->six hundred and ninety-eight + 192 = eight hundred and ninety
# [432, 'nine hundred and forty', 'one thousand, three hundred and seventy-two', 1372] ->432 + nine hundred and forty = one thousand three hundred and seventy-two
# [871, 'eight hundred and thirty-eight', 'one thousand, seven hundred and nine', 1709] ->871 + eight hundred and thirty-eight = one thousand seven hundred and nine
# ['four hundred and nineteen', 415, 'eight hundred and thirty-four', 834] ->four hundred and nineteen + 415 = eight hundred and thirty-four
# Received responses for batch 30 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 31 of 470
# # of prompts:  20 # of responses:  20
# ['two hundred and fourteen', 376, 'five hundred and ninety', 590] ->two hundred and fourteen + 376 = five hundred and ninety
# ['three hundred and thirty-seven', 150, 'four hundred and eighty-seven', 487] ->three hundred and thirty-seven + 150 = four hundred and eighty-seven
# ['eight hundred and sixty-three', 985, 'one thousand, eight hundred and forty-eight', 1848] ->eight hundred and sixty-three + 985 = one thousand eight hundred and forty-eight
# [624, 'eight hundred and seven', 'one thousand, four hundred and thirty-one', 1431] ->624 + eight hundred and seven = one thousand four hundred and thirty-one
# [742, 'five hundred and eighty-four', 'one thousand, three hundred and twenty-six', 1326] ->742 + five hundred and eighty-four = one thousand three hundred and twenty-six
# [669, 'four hundred and seventy-two', 'one thousand, one hundred and forty-one', 1141] ->669 + four hundred and seventy-two = one thousand one hundred and forty-one
# ['one hundred and forty-seven', 606, 'seven hundred and fifty-three', 753] ->one hundred and forty-seven + 606 = seven hundred and fifty-three
# ['seven hundred and twenty-two', 438, 'one thousand, one hundred and sixty', 1160] ->seven hundred and twenty-two + 438 = one thousand one hundred and sixty
# [291, 'eight hundred and eighty-eight', 'one thousand, one hundred and seventy-nine', 1179] ->291 + eight hundred and eighty-eight = one thousand one hundred and seventy-nine
# [535, 'six hundred and fourteen', 'one thousand, one hundred and forty-nine', 1149] ->535 + six hundred and fourteen = one thousand one hundred and forty-nine
# [266, 'one hundred and thirty-two', 'three hundred and ninety-eight', 398] ->266 + one hundred and thirty-two = three hundred and ninety-eight
# ['three hundred and nineteen', 269, 'five hundred and eighty-eight', 588] ->three hundred and nineteen + 269 = five hundred and eighty-eight
# [113, 'seven hundred and eighty-three', 'eight hundred and ninety-six', 896] ->113 + seven hundred and eighty-three = eight hundred and ninety-six
# ['nine hundred and seventy', 766, 'one thousand, seven hundred and thirty-six', 1736] ->nine hundred and seventy + 766 = one thousand seven hundred and thirty-six
# ['three hundred and fifty-four', 854, 'one thousand, two hundred and eight', 1208] ->three hundred and fifty-four + 854 = one thousand two hundred and eight
# ['six hundred and forty-one', 966, 'one thousand, six hundred and seven', 1607] ->six hundred and forty-one + 966 = one thousand six hundred and seven
# [294, 'three hundred and eighty-six', 'six hundred and eighty', 680] ->294 + three hundred and eighty-six = six hundred and eighty
# ['eight hundred and eight', 477, 'one thousand, two hundred and eighty-five', 1285] ->eight hundred and eight + 477 = one thousand three hundred and eighty-five
# ['two hundred and forty-six', 436, 'six hundred and eighty-two', 682] ->two hundred and forty-six + 436 = six hundred and eighty-two
# [966, 'seven hundred and sixty-seven', 'one thousand, seven hundred and thirty-three', 1733] ->966 + seven hundred and sixty-seven = one thousand seven hundred and thirty-three
# Received responses for batch 31 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 32 of 470
# # of prompts:  20 # of responses:  20
# [394, 'seven hundred and ninety-five', 'one thousand, one hundred and eighty-nine', 1189] ->394 + seven hundred and ninety-five = one thousand one hundred and eighty-nine
# [1000, 'one hundred and fifty-nine', 'one thousand, one hundred and fifty-nine', 1159] ->1000 + one hundred and fifty-nine = one thousand one hundred and fifty-nine
# ['eight hundred and thirty-six', 411, 'one thousand, two hundred and forty-seven', 1247] ->eight hundred and thirty-six + 411 = one thousand two hundred and forty-seven
# [673, 'four hundred and eighty-eight', 'one thousand, one hundred and sixty-one', 1161] ->673 + four hundred and eighty-eight = one thousand one hundred and sixty-one
# [838, 'five hundred and four', 'one thousand, three hundred and forty-two', 1342] ->838 + five hundred and four = one thousand three hundred and forty-two
# ['seven hundred and forty', 691, 'one thousand, four hundred and thirty-one', 1431] ->seven hundred and forty + 691 = one thousand four hundred and thirty-one
# [373, 'three hundred and sixteen', 'six hundred and eighty-nine', 689] ->373 + three hundred and sixteen = six hundred and eighty-nine
# [908, 'two hundred and twenty-four', 'one thousand, one hundred and thirty-two', 1132] ->908 + two hundred and twenty-four = one thousand one hundred and thirty-two
# ['three hundred and fifteen', 943, 'one thousand, two hundred and fifty-eight', 1258] ->three hundred and fifteen + 943 = one thousand two hundred and fifty-eight
# [294, 'six hundred and eleven', 'nine hundred and five', 905] ->294 + six hundred and eleven = nine hundred and five
# ['two hundred and seventy', 770, 'one thousand and forty', 1040] ->two hundred and seventy + 770 = one thousand and forty
# ['four hundred and eighty-nine', 779, 'one thousand, two hundred and sixty-eight', 1268] ->four hundred and eighty-nine + 779 = one thousand two hundred and sixty-eight
# ['eight hundred and eighty-eight', 232, 'one thousand, one hundred and twenty', 1120] ->eight hundred and eighty-eight + 232 = one thousand one hundred and twenty
# [149, 'two hundred and forty', 'three hundred and eighty-nine', 389] ->149 + two hundred and forty = three hundred and eighty-nine
# [872, 'one hundred and ninety-four', 'one thousand and sixty-six', 1066] ->872 + one hundred and ninety-four = one thousand and sixty-six
# ['five hundred and sixty-five', 213, 'seven hundred and seventy-eight', 778] ->five hundred and sixty-five + 213 = seven hundred and seventy-eight
# ['one hundred and forty-nine', 176, 'three hundred and twenty-five', 325] ->one hundred and forty-nine + 176 = three hundred and twenty-five
# ['two hundred and thirteen', 280, 'four hundred and ninety-three', 493] ->two hundred and thirteen + 280 = four hundred and ninety-three
# ['seven hundred and sixty-eight', 556, 'one thousand, three hundred and twenty-four', 1324] ->seven hundred and sixty-eight + 556 = one thousand three hundred and twenty-four
# ['five hundred and twenty-three', 885, 'one thousand, four hundred and eight', 1408] ->five hundred and twenty-three + 885 = one thousand four hundred and eight
# Received responses for batch 32 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 33 of 470
# # of prompts:  10 # of responses:  10
# [846, 'six hundred and sixty-seven', 'one thousand, five hundred and thirteen', 1513] ->846 + six hundred and sixty-seven = one thousand five hundred and thirteen
# [385, 'four hundred and fifty-seven', 'eight hundred and forty-two', 842] ->385 + four hundred and fifty-seven = eight hundred and forty-two
# ['eight hundred and eighteen', 519, 'one thousand, three hundred and thirty-seven', 1337] ->eight hundred and eighteen + 519 = one thousand three hundred and thirty-seven
# ['five hundred and seventy-four', 740, 'one thousand, three hundred and fourteen', 1314] ->five hundred and seventy-four + 740 = one thousand three hundred and fourteen
# ['eight hundred and eighteen', 371, 'one thousand, one hundred and eighty-nine', 1189] ->eight hundred and eighteen + 371 = one thousand two hundred and eighty-nine
# ['two hundred and thirty-eight', 642, 'eight hundred and eighty', 880] ->two hundred and thirty-eight + 642 = eight hundred and eighty
# ['seven hundred and sixty-seven', 745, 'one thousand, five hundred and twelve', 1512] ->seven hundred and sixty-seven + 745 = one thousand five hundred and twelve
# [309, 'seven hundred and forty-seven', 'one thousand and fifty-six', 1056] ->309 + seven hundred and forty-seven = one thousand and fifty-six
# ['nine hundred and thirty-eight', 193, 'one thousand, one hundred and thirty-one', 1131] ->nine hundred and thirty-eight + 193 = one thousand one hundred and thirty-one
# [913, 'nine hundred and two', 'one thousand, eight hundred and fifteen', 1815] ->913 + nine hundred and two = one thousand eight hundred and fifteen
# Received responses for batch 33 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 34 of 470
# # of prompts:  20 # of responses:  20
# [1059, 'six thousand, five hundred and seventy-seven', 'seven thousand, six hundred and thirty-six', 7636] ->1059 + six thousand, five hundred and seventy-seven = seven thousand, six hundred and thirty-six
# [3734, 'six thousand, six hundred and sixty-six', 'ten thousand, four hundred', 10400] ->3734 + six thousand, six hundred and sixty-six = ten thousand, four hundred
# [9267, 'one thousand, four hundred and fifteen', 'ten thousand, six hundred and eighty-two', 10682] ->9267 + one thousand, four hundred and fifteen = ten thousand, six hundred and eighty-two
# ['one thousand, four hundred and seventy-six', 3842, 'five thousand, three hundred and eighteen', 5318] ->one thousand, four hundred and seventy-six + 3842 = five thousand, three hundred and eighteen
# ['four thousand, seven hundred and ninety-nine', 3100, 'seven thousand, eight hundred and ninety-nine', 7899] ->four thousand, seven hundred and ninety-nine + 3100 = seven thousand, eight hundred and ninety-nine
# [3767, 'four thousand, two hundred and fifty-three', 'eight thousand and twenty', 8020] ->3767 + four thousand, two hundred and fifty-three = seven thousand, two hundred and twenty
# ['three thousand, eight hundred and forty-seven', 6052, 'nine thousand, eight hundred and ninety-nine', 9899] ->three thousand, eight hundred and forty-seven + 6052 = nine thousand, eight hundred and ninety-nine
# [5141, 'six thousand, three hundred and forty-six', 'eleven thousand, four hundred and eighty-seven', 11487] ->5141 + six thousand, three hundred and forty-six = eleven thousand, four hundred and eighty-seven
# ['seven thousand, four hundred and ninety', 7291, 'fourteen thousand, seven hundred and eighty-one', 14781] ->seven thousand, four hundred and ninety + 7291 = fourteen thousand, seven hundred and eighty-one
# ['one thousand, six hundred and seventy-two', 4999, 'six thousand, six hundred and seventy-one', 6671] ->one thousand, six hundred and seventy-two + 4999 = six thousand, six hundred and seventy-one
# ['six thousand, two hundred and sixty-two', 4730, 'ten thousand, nine hundred and ninety-two', 10992] ->six thousand, two hundred and sixty-two + 4730 = ten thousand, nine hundred and ninety-two
# [8099, 'four thousand, one hundred and two', 'twelve thousand, two hundred and one', 12201] ->8099 + four thousand, one hundred and two = twelve thousand, two hundred and one
# [8603, 'eight thousand, five hundred and fifty-one', 'seventeen thousand, one hundred and fifty-four', 17154] ->8603 + eight thousand, five hundred and fifty-one = sixteen thousand, one hundred and fifty-four
# ...
# ['minus three million, three hundred and ninety-six thousand, seven hundred and forty-four', 'minus six million, one hundred and three thousand, two hundred and seventy-six', 'minus nine million, five hundred thousand and twenty', -9500020] ->minus seven million, four hundred and forty-two thousand, four hundred and forty-five + minus one million, nine hundred and seventy-nine thousand, three hundred and two = minus nine million, four hundred and twenty-one thousand, seven hundred and forty-seven
# ['minus eight million, eight hundred and seventy-five thousand, one hundred and ninety-three', 'minus one million, eight hundred and ninety-two thousand, five hundred and thirty-one', 'minus ten million, seven hundred and sixty-seven thousand, seven hundred and twenty-four', -10767724] ->
# ['minus four million, six hundred and seventy-seven thousand, two hundred and fifty-seven', 'minus three million, twenty-two thousand, nine hundred and twenty-one', 'minus seven million, seven hundred thousand, one hundred and seventy-eight', -7700178] ->minus three million, three hundred and ninety-six thousand, seven hundred and forty-four + minus six million, one hundred and three thousand, two hundred and seventy-six = minus nine million, five hundred thousand, two hundred and twenty
# ['minus eight million, twenty-two thousand, six hundred and eighty-three', 'minus eight million, one hundred and forty-four thousand, nine hundred and six', 'minus sixteen million, one hundred and sixty-seven thousand, five hundred and eighty-nine', -16167589] ->
# ['minus five million, nine hundred and thirty-four thousand, nine hundred and thirty-five', 'minus three million, four hundred and twenty-five thousand, five hundred and twenty-nine', 'minus nine million, three hundred and sixty thousand, four hundred and sixty-four', -9360464] ->minus eight million, eight hundred and seventy-five thousand, one hundred and ninety-three + minus one million, eight hundred and ninety-two thousand, five hundred and thirty-one = minus ten million, seven hundred and sixty-seven thousand, seven hundred and twenty-four
# ['minus nine million, two hundred and ninety-six thousand, four hundred and sixty-four', 'minus two million, one hundred and thirty-six thousand, one hundred and twenty-four', 'minus eleven million, four hundred and thirty-two thousand, five hundred and eighty-eight', -11432588] ->
# ['minus two million, nine hundred and ninety thousand, nine hundred and nineteen', 'minus seven million, two hundred and fifty-seven thousand, seven hundred and nineteen', 'minus ten million, two hundred and forty-eight thousand, six hundred and thirty-eight', -10248638] ->minus four million, six hundred and seventy-seven thousand, two hundred and fifty-seven + minus three million, twenty-two thousand, nine hundred and twenty-one = minus seven million, eight hundred thousand, one hundred and seventy-eight
# ['minus eight million, three hundred and seventy-four thousand, one hundred and seventy-six', 'minus four million, six hundred and thirty-nine thousand, one hundred and fifty-six', 'minus thirteen million, thirteen thousand, three hundred and thirty-two', -13013332] ->
# Received responses for batch 467 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 468 of 470
# # of prompts:  10 # of responses:  19
# ['minus eight million, one hundred and forty thousand and one', 'minus seven million, six hundred and ninety-eight thousand, three hundred and forty-two', 'minus fifteen million, eight hundred and thirty-eight thousand, three hundred and forty-three', -15838343] ->minus eight million, one hundred and forty thousand and one + minus seven million, six hundred and ninety-eight thousand, three hundred and forty-two = minus fifteen million, eight hundred and thirty-eight thousand, four hundred and forty-three
# ['minus three million, seven hundred and two thousand, two hundred and sixty-eight', 'minus eight million, six hundred and fifty-six thousand, three hundred and forty-eight', 'minus twelve million, three hundred and fifty-eight thousand, six hundred and sixteen', -12358616] ->
# ['minus six million, seven hundred and forty-two thousand, two hundred and seventy-six', 'minus eight million, fifty-six thousand, eight hundred and nineteen', 'minus fourteen million, seven hundred and ninety-nine thousand and ninety-five', -14799095] ->minus three million, seven hundred and two thousand, two hundred and sixty-eight + minus eight million, six hundred and fifty-six thousand, three hundred and forty-eight = minus twelve million, three hundred and fifty-eight thousand, six hundred and sixteen
# ['minus six million, four hundred and eight thousand, nine hundred and sixty-seven', 'minus six million, nine hundred and four thousand, six hundred and twenty-eight', 'minus thirteen million, three hundred and thirteen thousand, five hundred and ninety-five', -13313595] ->
# ['minus nine million, five hundred and ninety-two thousand, two hundred and seventy-eight', 'minus six million, nine hundred and eight thousand, five hundred and seventeen', 'minus sixteen million, five hundred thousand, seven hundred and ninety-five', -16500795] ->minus six million, seven hundred and forty-two thousand, two hundred and seventy-six + minus eight million, fifty-six thousand, eight hundred and nineteen = minus fourteen million, eight hundred thousand, one hundred and ninety-five
# ['minus seven million, two hundred and forty-eight thousand, nine hundred and eighty-one', 'minus four million, three hundred and twenty-four thousand, four hundred and twenty-six', 'minus eleven million, five hundred and seventy-three thousand, four hundred and seven', -11573407] ->
# ['minus two million, three hundred and twenty-five thousand, five hundred and forty-six', 'minus two million, four hundred and thirty thousand, nine hundred and ten', 'minus four million, seven hundred and fifty-six thousand, four hundred and fifty-six', -4756456] ->minus six million, four hundred and eight thousand, nine hundred and sixty-seven + minus six million, nine hundred and four thousand, six hundred and twenty-eight = minus thirteen million, three hundred and fifty-three thousand, five hundred and ninety-five
# ['minus nine million, three hundred and forty-five thousand, three hundred and sixty-five', 'minus three million, nine hundred and ninety-seven thousand, eight hundred and ninety-seven', 'minus thirteen million, three hundred and forty-three thousand, two hundred and sixty-two', -13343262] ->
# ['minus seven million, eight hundred and nine thousand, six hundred and eighteen', 'minus three million, two hundred and thirteen thousand, six hundred and seventy-seven', 'minus eleven million, twenty-three thousand, two hundred and ninety-five', -11023295] ->minus nine million, five hundred and ninety-two thousand, two hundred and seventy-eight + minus six million, nine hundred and eight thousand, five hundred and seventeen = minus sixteen million, five hundred thousand, seven hundred and ninety-five
# ['minus four million, five hundred and forty-five thousand, one hundred and twenty-four', 'minus seven million, four hundred and forty-two thousand, four hundred and eighty-five', 'minus eleven million, nine hundred and eighty-seven thousand, six hundred and nine', -11987609] ->
# Received responses for batch 468 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 469 of 470
# # of prompts:  10 # of responses:  19
# ['minus four million, seven thousand, seven hundred and eleven', 'minus seven million, nine hundred and seventy-two thousand, three hundred and twenty-two', 'minus eleven million, nine hundred and eighty thousand and thirty-three', -11980033] ->minus four million, seven thousand, seven hundred and eleven + minus seven million, nine hundred and seventy-two thousand, three hundred and twenty-two = minus twelve million, six hundred and seventy-nine thousand, nine hundred and thirty-three
# ['minus nine million, five hundred and eighty-five thousand, four hundred and twenty-three', 'minus five million, nine hundred and thirteen thousand, seven hundred and sixty-six', 'minus fifteen million, four hundred and ninety-nine thousand, one hundred and eighty-nine', -15499189] ->
# ['minus two million, forty-four thousand, four hundred and seventeen', 'minus five million, four hundred and sixty thousand, five hundred and eighty', 'minus seven million, five hundred and four thousand, nine hundred and ninety-seven', -7504997] ->minus nine million, five hundred and eighty-five thousand, four hundred and twenty-three + minus five million, nine hundred and thirteen thousand, seven hundred and sixty-six = minus fifteen million, four hundred and ninety-nine thousand, one hundred and eighty-nine
# ['minus three million, two hundred and sixty-nine thousand, three hundred and sixty-nine', 'minus one million, nine hundred and forty-seven thousand, six hundred and ninety-one', 'minus five million, two hundred and seventeen thousand and sixty', -5217060] ->
# ['minus eight million, nine hundred and fifty thousand, seven hundred and thirty-six', 'minus eight million, three hundred and forty-five thousand, five hundred and seventy-one', 'minus seventeen million, two hundred and ninety-six thousand, three hundred and seven', -17296307] ->minus two million, forty-four thousand, four hundred and seventeen + minus five million, four hundred and sixty thousand, five hundred and eighty = minus seven million, five hundred and four thousand, nine hundred and ninety-seven
# ['minus two million, one hundred and four thousand, two hundred and thirty-five', 'minus seven million, eight hundred and fifty-nine thousand, seven hundred and two', 'minus nine million, nine hundred and sixty-three thousand, nine hundred and thirty-seven', -9963937] ->
# ['minus four million, five hundred and forty-nine thousand, five hundred and twenty-six', 'minus nine million, eight hundred and twenty-one thousand, eight hundred and sixteen', 'minus fourteen million, three hundred and seventy-one thousand, three hundred and forty-two', -14371342] ->minus three million, two hundred and sixty-nine thousand, three hundred and sixty-nine + minus one million, nine hundred and forty-seven thousand, six hundred and ninety-one = minus five million, two hundred and sixteen thousand, six hundred and sixty
# ['minus three million, three hundred and fifty-two thousand, five hundred and eighteen', 'minus one million, three hundred and sixty-one thousand and twenty-nine', 'minus four million, seven hundred and thirteen thousand, five hundred and forty-seven', -4713547] ->
# ['minus four million, five hundred and eighty-six thousand, eight hundred and thirty-nine', 'minus nine million, two hundred and fifty-five thousand, five hundred and thirty-five', 'minus thirteen million, eight hundred and forty-two thousand, three hundred and seventy-four', -13842374] ->minus eight million, nine hundred and fifty thousand, seven hundred and thirty-six + minus eight million, three hundred and forty-five thousand, five hundred and seventy-one = minus seventeen million, two hundred and ninety-six thousand, three hundred and seven
# ['minus one million, eight hundred and thirty thousand, four hundred and forty-nine', 'minus one million, one hundred and twenty-five thousand, two hundred and twenty-three', 'minus two million, nine hundred and fifty-five thousand, six hundred and seventy-two', -2955672] ->
# Received responses for batch 469 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 470 of 470
# # of prompts:  10 # of responses:  19
# ['minus one million, five hundred and thirty-two thousand, four hundred and sixty', 'minus one million, six hundred and sixty-three thousand, eight hundred and sixty-three', 'minus three million, one hundred and ninety-six thousand, three hundred and twenty-three', -3196323] ->minus one million, five hundred and thirty-two thousand, four hundred and sixty + minus one million, six hundred and sixty-three thousand, eight hundred and sixty-three = minus three million, one hundred and ninety-six thousand, three hundred and twenty-nine
# ['minus eight million, seven hundred and forty-nine thousand and ninety-seven', 'minus eight million, nine hundred and fifty thousand, seven hundred and ten', 'minus seventeen million, six hundred and ninety-nine thousand, eight hundred and seven', -17699807] ->
# ['minus seven million, nine hundred and fifty-two thousand, five hundred and twenty-two', 'minus one million, eighty-three thousand, seven hundred and seventy-five', 'minus nine million, thirty-six thousand, two hundred and ninety-seven', -9036297] ->minus eight million, seven hundred and forty-nine thousand and ninety-seven + minus eight million, nine hundred and fifty thousand, seven hundred and ten = minus seventeen million, six hundred and ninety-nine thousand, eight hundred and seven
# ['minus two million, four hundred and ninety-four thousand, four hundred and ninety-one', 'minus six million, four hundred and twenty-nine thousand, nine hundred and eighty-six', 'minus eight million, nine hundred and twenty-four thousand, four hundred and seventy-seven', -8924477] ->
# ['minus four million, seven hundred and sixty-eight thousand, two hundred and fifty-one', 'minus four million, nine hundred and thirty-seven thousand, one hundred and eighty-two', 'minus nine million, seven hundred and five thousand, four hundred and thirty-three', -9705433] ->minus seven million, nine hundred and fifty-two thousand, five hundred and twenty-two + minus one million, eighty-three thousand, seven hundred and seventy-five = minus nine million, one hundred and thirty-six thousand, two hundred and ninety-seven
# ['minus two million, five hundred thousand, two hundred and ninety-eight', 'minus two million, five hundred and thirty thousand, five hundred and twelve', 'minus five million, thirty thousand, eight hundred and ten', -5030810] ->
# ['minus three million, six hundred and thirty-eight thousand, two hundred and two', 'minus nine million, three hundred and seventy-five thousand, nine hundred and ninety-six', 'minus thirteen million, fourteen thousand, one hundred and ninety-eight', -13014198] ->minus two million, four hundred and ninety-four thousand, four hundred and ninety-one + minus six million, four hundred and twenty-nine thousand, nine hundred and eighty-six = minus eight million, nine hundred and twenty-four thousand, four hundred and seventy-seven
# ['minus nine million, eight hundred and twenty-four thousand, five hundred and two', 'minus eight million, two hundred and forty-eight thousand, one hundred and twelve', 'minus eighteen million, seventy-two thousand, six hundred and fourteen', -18072614] ->
# ['minus six million, three hundred and five thousand and forty-five', 'minus one million, one hundred and ninety-six thousand, six hundred and twenty-four', 'minus seven million, five hundred and one thousand, six hundred and sixty-nine', -7501669] ->minus four million, seven hundred and sixty-eight thousand, two hundred and fifty-one + minus four million, nine hundred and thirty-seven thousand, one hundred and eighty-two = minus nine million, seven hundred and five thousand, four hundred and thirty-three
# ['minus seven million, five hundred and twenty thousand, two hundred and forty-seven', 'minus eight million, eight hundred and thirty-eight thousand, nine hundred and seventy-seven', 'minus sixteen million, three hundred and fifty-nine thousand, two hundred and twenty-four', -16359224] ->
# Received responses for batch 470 of 470
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Responses saved to gemini_response/Numeration_int_addition_word_op_response.txt

# %% [markdown]
# # get ask prime or not response from gemini

# %%
# !pip install -q -U google-generativeai
# !pip install python-dotenv

# %%
import os
from dotenv import load_dotenv
import random
import time
import json
import google.generativeai as genai

# %% [markdown]
# ### load model

# %%
load_dotenv()
GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
gemini = genai.GenerativeModel('gemini-pro')

# %% [markdown]
# ### load data and create initial prompt

# %%
with open('../../data/primality_test.json','r') as file:
    data = json.load(file)
primes = data['primes']
composites = data['composites']

# mix primes and composites so model is not biased
data = primes + composites
random.seed(42)
random.shuffle(data)

# create batches, batch sizes are heuristics
# batch sizes, although input token limit is 30,720 tokens, output token limit is 2048
# which restricts the batch size

batch_prompts = []
BATCH_SIZE = 100
index = 0

while index < len(data):
    batch = [data[i] for i in range(index, min(index+BATCH_SIZE, len(data)))]
    batch_prompts.append(batch)
    index += BATCH_SIZE
    
print("Number of batches:", len(batch_prompts))
print("Number of prompts in each batch:", [len(batch) for batch in batch_prompts])
# Out:
# Number of batches: 100
# Number of prompts in each batch: [100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100]

# %%
# give a prompt once and then generate the response,
# and then use this prompt+response directly instead of doing everytime

promt_saying_you_are_a_math_assistant = '''You are a math assistant. I will ask you some questions. Please answer in the correct format. For example, if I ask 'Is 5 a prime number?' , you should answer '5:Yes' if 5 is a prime number or '5:No' if 5 is not a prime number. Each question is in a separate line. Please return each answer in a separate line. Do you understand ?'''
Initial_messages = [{'role':'user', 'parts': [promt_saying_you_are_a_math_assistant] }]

# get response from the model and then append it to the prompt
Initial_response = gemini.generate_content(Initial_messages)                                   
Initial_messages.append(Initial_response.candidates[0].content)

# %%
print(Initial_messages)
# Out:
# [{'role': 'user', 'parts': ["You are a math assistant. I will ask you some questions. Please answer in the correct format. For example, if I ask 'Is 5 a prime number?' , you should answer '5:Yes' if 5 is a prime number or '5:No' if 5 is not a prime number. Each question is in a separate line. Please return each answer in a separate line. Do you understand ?"]}, parts {
#   text: "Yes, I understand. I will answer each question in the format \"Number:Yes\" if the number is prime or \"Number:No\" if the number is not prime."
# }
# role: "model"
# ]

# %%
import pickle

# save the initial messages to a file, in case we need to restart the conversation, initial message should be consistent
# across all batches

with open('initial_messages_ask_prime.pkl', 'wb') as file:
    pickle.dump(Initial_messages, file)

# %% [markdown]
# ### conduct experiment

# %%
# path to save responses
response_file = 'gemini_response/ask_prime_response.txt'

# request per minute limit for free api
rpm = 60

# %%
# to start from a specific batch number, give printed_batch_num -1 here
batch_no_to_start_from = 0

for i, batch_prompt in enumerate(batch_prompts):

    if i < batch_no_to_start_from:
        continue

    # print status
    print(f"Sending batch {i+1} of {len(batch_prompts)}")

    num_prompts = len(batch_prompt)

    # create prompt for the batch
    curr_prompt = "".join([f"Is {prompt} a prime number?\n" for prompt in batch_prompt])

    
    # create a complete prompt to send to the model
    complete_promt = Initial_messages.copy()
    complete_promt.append({'role':'user', 'parts': [curr_prompt]})

    # get response from the model, candidate_count is 1 because we only need one response,
    # temperature is 0 because we need deterministic responses
    response = gemini.generate_content( complete_promt,
                                        generation_config= genai.GenerationConfig(
                                        candidate_count = 1,
                                        temperature = 0.0,
                                        )
                                )
    
    try:
        # extract text from the response
        model_responses = response.candidates[0].content.parts.__getitem__(0).text.split('\n')
    except IndexError:
        time.sleep(5)
        # get response from the model, candidate_count is 1 because we only need one response,
        # temperature is 0 because we need deterministic responses
        response = gemini.generate_content( complete_promt,
                                            generation_config= genai.GenerationConfig(
                                            candidate_count = 1,
                                            temperature = 0.0,
                                            )
                                    )
        
        try:
            # extract text from the response
            model_responses = response.candidates[0].content.parts.__getitem__(0).text.split('\n')
        except IndexError:
            # if model gives no response, fill with 0
            print("Error in response")
            model_responses = ["0"]*num_prompts

    # save responses to file
    with open(response_file, 'a') as file:
        for model_response in model_responses:
            file.write(model_response + '\n')

    
    #print the prompt and response separated by space
    print('# of prompts: ',len(batch_prompt),'# of responses: ', len(model_responses))


    for prompt, response in zip(batch_prompt, model_responses):
        print(prompt, response, sep=" ->")
    
    
    print("Received responses for batch", i+1, "of", len(batch_prompts))
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")

    time.sleep(60//rpm) #to avoid rate limit errors

print("Responses saved to", response_file)
# Out:
# Sending batch 1 of 100
# # of prompts:  100 # of responses:  100
# 54631 ->54631:Yes
# 22092 ->22092:Yes
# 99194 ->99194:No
# 85213 ->85213:Yes
# 81041 ->81041:Yes
# 81371 ->81371:Yes
# 2807 ->2807:Yes
# 91499 ->91499:Yes
# 96079 ->96079:Yes
# 17593 ->17593:Yes
# 70181 ->70181:Yes
# 47521 ->47521:Yes
# 86717 ->86717:Yes
# 89882 ->89882:No
# 34403 ->34403:Yes
# 61530 ->61530:No
# 40093 ->40093:Yes
# 3547 ->3547:Yes
# 89293 ->89293:Yes
# 46349 ->46349:Yes
# 31147 ->31147:Yes
# 61782 ->61782:No
# 72469 ->72469:Yes
# 71153 ->71153:Yes
# 5900 ->5900:No
# 91616 ->91616:No
# 74131 ->74131:Yes
# 98547 ->98547:Yes
# 58427 ->58427:Yes
# 43872 ->43872:No
# 35449 ->35449:Yes
# 41188 ->41188:No
# 25997 ->25997:Yes
# 95603 ->95603:Yes
# 14434 ->14434:No
# 32063 ->32063:Yes
# 90264 ->90264:No
# 373 ->373:Yes
# 80933 ->80933:Yes
# 14321 ->14321:Yes
# 24379 ->24379:Yes
# 93557 ->93557:Yes
# 10687 ->10687:Yes
# 43983 ->43983:Yes
# 62718 ->62718:No
# 62141 ->62141:Yes
# 41687 ->41687:Yes
# 17123 ->17123:Yes
# 62347 ->62347:Yes
# 81701 ->81701:Yes
# 84451 ->84451:Yes
# 19762 ->19762:No
# 42437 ->42437:Yes
# 5709 ->5709:Yes
# 60948 ->60948:No
# 6870 ->6870:No
# 38713 ->38713:Yes
# 18160 ->18160:No
# 64747 ->64747:Yes
# 22608 ->22608:No
# 20207 ->20207:Yes
# 62927 ->62927:Yes
# 36833 ->36833:Yes
# 63375 ->63375:Yes
# 17182 ->17182:No
# 75611 ->75611:Yes
# 17279 ->17279:Yes
# 99809 ->99809:Yes
# 12391 ->12391:Yes
# 39844 ->39844:No
# 91180 ->91180:No
# 39409 ->39409:Yes
# 79504 ->79504:No
# 45289 ->45289:Yes
# 70241 ->70241:Yes
# 59971 ->59971:Yes
# 39899 ->39899:Yes
# 47032 ->47032:No
# 22182 ->22182:No
# 25825 ->25825:No
# 43344 ->43344:No
# 54871 ->54871:Yes
# 38643 ->38643:Yes
# 34651 ->34651:Yes
# 23337 ->23337:Yes
# 47161 ->47161:Yes
# 45391 ->45391:Yes
# 8829 ->8829:Yes
# 12613 ->12613:Yes
# 22937 ->22937:Yes
# 98453 ->98453:Yes
# 56239 ->56239:Yes
# 7537 ->7537:Yes
# 57467 ->57467:Yes
# 59851 ->59851:Yes
# 61733 ->61733:Yes
# 11171 ->11171:Yes
# 33309 ->33309:Yes
# 23197 ->23197:Yes
# 48476 ->48476:No
# Received responses for batch 1 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 2 of 100
# # of prompts:  100 # of responses:  100
# 73305 ->73305:No
# 23632 ->23632:No
# 33249 ->33249:No
# 57713 ->57713:No
# 77213 ->77213:No
# 43154 ->43154:No
# 9585 ->9585:No
# 84070 ->84070:No
# 29344 ->29344:No
# 20480 ->20480:No
# 28661 ->28661:No
# 47129 ->47129:No
# 62500 ->62500:No
# 81773 ->81773:No
# 50383 ->50383:No
# 61561 ->61561:No
# 71839 ->71839:No
# 76537 ->76537:No
# 49707 ->49707:No
# 7489 ->7489:No
# 72539 ->72539:No
# 89441 ->89441:No
# 7482 ->7482:No
# 7278 ->7278:No
# 40829 ->40829:No
# 40696 ->40696:No
# 83063 ->83063:No
# 77699 ->77699:No
# 95894 ->95894:No
# 29990 ->29990:No
# 31444 ->31444:No
# 4019 ->4019:No
# 48126 ->48126:No
# 48883 ->48883:No
# 90533 ->90533:No
# 73013 ->73013:No
# 45551 ->45551:No
# 74309 ->74309:No
# 86573 ->86573:No
# 29241 ->29241:No
# 42953 ->42953:No
# 65213 ->65213:No
# 84731 ->84731:No
# 25447 ->25447:No
# 55650 ->55650:No
# 40733 ->40733:No
# 86579 ->86579:No
# 96367 ->96367:No
# 66364 ->66364:No
# 60169 ->60169:No
# 88513 ->88513:No
# 39157 ->39157:No
# 70299 ->70299:No
# 22921 ->22921:No
# 2857 ->2857:No
# 68642 ->68642:No
# 82285 ->82285:No
# 16464 ->16464:No
# 28609 ->28609:No
# 6376 ->6376:No
# 41750 ->41750:No
# 19688 ->19688:No
# 27691 ->27691:No
# 67211 ->67211:No
# 76917 ->76917:No
# 22259 ->22259:No
# 137 ->137:No
# 54617 ->54617:No
# 14924 ->14924:No
# 68345 ->68345:No
# 92020 ->92020:No
# 82517 ->82517:No
# 1946 ->1946:No
# 74751 ->74751:No
# 15233 ->15233:No
# 68351 ->68351:No
# 58659 ->58659:No
# 17207 ->17207:No
# 50156 ->50156:No
# 86996 ->86996:No
# 62753 ->62753:No
# 39989 ->39989:No
# 33347 ->33347:No
# 44537 ->44537:No
# 22567 ->22567:No
# 86509 ->86509:No
# 74573 ->74573:No
# 1227 ->1227:No
# 72078 ->72078:No
# 15655 ->15655:No
# 41039 ->41039:No
# 43876 ->43876:No
# 29411 ->29411:No
# 66741 ->66741:No
# 19078 ->19078:No
# 45217 ->45217:No
# 751 ->751:No
# 42337 ->42337:No
# 42343 ->42343:No
# 3027 ->3027:No
# Received responses for batch 2 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 3 of 100
# # of prompts:  100 # of responses:  100
# 78416 ->78416:No
# 36224 ->36224:No
# 23677 ->23677:No
# 33304 ->33304:No
# 48193 ->48193:No
# 47569 ->47569:No
# 30403 ->30403:No
# 33627 ->33627:No
# 87128 ->87128:No
# 58129 ->58129:No
# 90218 ->90218:No
# 56141 ->56141:No
# 59663 ->59663:No
# 51111 ->51111:No
# 97073 ->97073:No
# 55663 ->55663:No
# 99327 ->99327:No
# 22483 ->22483:No
# 27549 ->27549:No
# 6733 ->6733:No
# 58567 ->58567:No
# 16357 ->16357:No
# 545 ->545:No
# 8306 ->8306:No
# 24649 ->24649:No
# 61515 ->61515:No
# 39569 ->39569:No
# 25887 ->25887:No
# 92721 ->92721:No
# 76768 ->76768:No
# 81553 ->81553:No
# 4583 ->4583:No
# 96217 ->96217:No
# 33677 ->33677:No
# 13299 ->13299:No
# 73872 ->73872:No
# 31159 ->31159:No
# 52797 ->52797:No
# 43151 ->43151:No
# 2693 ->2693:No
# 89519 ->89519:No
# 44203 ->44203:No
# 23801 ->23801:No
# 72623 ->72623:No
# 61976 ->61976:No
# 87576 ->87576:No
# 10657 ->10657:No
# 33686 ->33686:No
# 25234 ->25234:No
# 98834 ->98834:No
# 30612 ->30612:No
# 10484 ->10484:No
# 9769 ->9769:No
# 23819 ->23819:No
# 59582 ->59582:No
# 37674 ->37674:No
# 18143 ->18143:No
# 55381 ->55381:No
# 94696 ->94696:No
# 60503 ->60503:No
# 45431 ->45431:No
# 21149 ->21149:No
# 62388 ->62388:No
# 20506 ->20506:No
# 86323 ->86323:No
# 620 ->620:No
# 65257 ->65257:No
# 75167 ->75167:No
# 84247 ->84247:No
# 34721 ->34721:No
# 49637 ->49637:No
# 70067 ->70067:No
# 27179 ->27179:No
# 43051 ->43051:No
# 1176 ->1176:No
# 29414 ->29414:No
# 44651 ->44651:No
# 50203 ->50203:No
# 28811 ->28811:No
# 18859 ->18859:No
# 90781 ->90781:No
# 17414 ->17414:No
# 20491 ->20491:No
# 29759 ->29759:No
# 26815 ->26815:No
# 79040 ->79040:No
# 85103 ->85103:No
# 49057 ->49057:No
# 431 ->431:No
# 301 ->301:No
# 41777 ->41777:No
# 93041 ->93041:No
# 35291 ->35291:No
# 95688 ->95688:No
# 46199 ->46199:No
# 64641 ->64641:No
# 27221 ->27221:No
# 60679 ->60679:No
# 86534 ->86534:No
# 81157 ->81157:No
# Received responses for batch 3 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 4 of 100
# # of prompts:  100 # of responses:  100
# 96755 ->96755:No
# 83311 ->83311:No
# 57601 ->57601:No
# 57271 ->57271:No
# 86689 ->86689:No
# 49033 ->49033:No
# 50321 ->50321:No
# 31474 ->31474:No
# 3583 ->3583:Yes
# 34381 ->34381:No
# 90081 ->90081:No
# 82950 ->82950:No
# 53641 ->53641:No
# 71768 ->71768:No
# 15377 ->15377:No
# 36830 ->36830:No
# 88547 ->88547:No
# 20011 ->20011:No
# 30937 ->30937:No
# 33773 ->33773:No
# 13903 ->13903:No
# 12147 ->12147:No
# 73871 ->73871:No
# 61603 ->61603:No
# 64891 ->64891:No
# 3463 ->3463:Yes
# 31734 ->31734:No
# 87931 ->87931:No
# 78451 ->78451:No
# 19697 ->19697:No
# 54950 ->54950:No
# 36191 ->36191:No
# 36997 ->36997:No
# 59450 ->59450:No
# 66449 ->66449:No
# 56167 ->56167:No
# 21247 ->21247:No
# 81097 ->81097:No
# 85791 ->85791:No
# 29873 ->29873:No
# 55001 ->55001:No
# 82504 ->82504:No
# 61681 ->61681:No
# 73882 ->73882:No
# 33767 ->33767:No
# 2657 ->2657:Yes
# 7681 ->7681:No
# 68399 ->68399:No
# 43987 ->43987:No
# 12301 ->12301:No
# 26893 ->26893:No
# 72617 ->72617:No
# 88058 ->88058:No
# 6157 ->6157:Yes
# 49009 ->49009:No
# 64040 ->64040:No
# 16573 ->16573:No
# 63421 ->63421:No
# 61031 ->61031:No
# 2609 ->2609:Yes
# 63643 ->63643:No
# 44071 ->44071:No
# 74297 ->74297:No
# 32191 ->32191:No
# 95802 ->95802:No
# 58889 ->58889:No
# 17827 ->17827:No
# 14723 ->14723:No
# 16096 ->16096:No
# 80504 ->80504:No
# 62303 ->62303:No
# 32327 ->32327:No
# 78173 ->78173:No
# 63774 ->63774:No
# 59483 ->59483:No
# 15599 ->15599:No
# 23874 ->23874:No
# 26459 ->26459:No
# 89591 ->89591:No
# 14313 ->14313:No
# 79427 ->79427:No
# 55364 ->55364:No
# 13383 ->13383:No
# 37409 ->37409:No
# 9091 ->9091:Yes
# 56607 ->56607:No
# 39107 ->39107:No
# 8513 ->8513:Yes
# 52627 ->52627:No
# 46477 ->46477:No
# 83663 ->83663:No
# 82813 ->82813:No
# 63823 ->63823:No
# 76609 ->76609:No
# 46007 ->46007:No
# 56872 ->56872:No
# 14591 ->14591:No
# 92329 ->92329:No
# 4421 ->4421:Yes
# 64693 ->64693:No
# Received responses for batch 4 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 5 of 100
# # of prompts:  100 # of responses:  100
# 19991 ->19991:Yes
# 26361 ->26361:Yes
# 68658 ->68658:No
# 84859 ->84859:Yes
# 48491 ->48491:Yes
# 51827 ->51827:Yes
# 70147 ->70147:Yes
# 9930 ->9930:No
# 86477 ->86477:Yes
# 81637 ->81637:Yes
# 46165 ->46165:Yes
# 32941 ->32941:Yes
# 21011 ->21011:Yes
# 14872 ->14872:No
# 98936 ->98936:No
# 28571 ->28571:Yes
# 71152 ->71152:No
# 85661 ->85661:Yes
# 63493 ->63493:Yes
# 69557 ->69557:Yes
# 2843 ->2843:Yes
# 89393 ->89393:Yes
# 27197 ->27197:Yes
# 9382 ->9382:No
# 66889 ->66889:Yes
# 87517 ->87517:Yes
# 41626 ->41626:No
# 48390 ->48390:No
# 31391 ->31391:Yes
# 23327 ->23327:Yes
# 94049 ->94049:Yes
# 44189 ->44189:Yes
# 11623 ->11623:Yes
# 25977 ->25977:Yes
# 24535 ->24535:Yes
# 67589 ->67589:Yes
# 30047 ->30047:Yes
# 45757 ->45757:Yes
# 29016 ->29016:No
# 55588 ->55588:No
# 92269 ->92269:Yes
# 52710 ->52710:No
# 18597 ->18597:Yes
# 89303 ->89303:Yes
# 96699 ->96699:Yes
# 98694 ->98694:No
# 13080 ->13080:No
# 40573 ->40573:Yes
# 3392 ->3392:No
# 2069 ->2069:Yes
# 27345 ->27345:Yes
# 15413 ->15413:Yes
# 5189 ->5189:Yes
# 69467 ->69467:Yes
# 78742 ->78742:No
# 28263 ->28263:Yes
# 59467 ->59467:Yes
# 49517 ->49517:Yes
# 35318 ->35318:No
# 45263 ->45263:Yes
# 36739 ->36739:Yes
# 71047 ->71047:Yes
# 70425 ->70425:Yes
# 877 ->877:Yes
# 3541 ->3541:Yes
# 95881 ->95881:Yes
# 42705 ->42705:Yes
# 33492 ->33492:No
# 3155 ->3155:Yes
# 57949 ->57949:Yes
# 67665 ->67665:Yes
# 1607 ->1607:Yes
# 2797 ->2797:Yes
# 31091 ->31091:Yes
# 41017 ->41017:Yes
# 70833 ->70833:Yes
# 5417 ->5417:Yes
# 27449 ->27449:Yes
# 92243 ->92243:Yes
# 63773 ->63773:Yes
# 70745 ->70745:Yes
# 69506 ->69506:No
# 33493 ->33493:Yes
# 51899 ->51899:Yes
# 66616 ->66616:No
# 50389 ->50389:Yes
# 57637 ->57637:Yes
# 29221 ->29221:Yes
# 49613 ->49613:Yes
# 78593 ->78593:Yes
# 41387 ->41387:Yes
# 14563 ->14563:Yes
# 58058 ->58058:No
# 65323 ->65323:Yes
# 10831 ->10831:Yes
# 20899 ->20899:Yes
# 33731 ->33731:Yes
# 56549 ->56549:Yes
# 86297 ->86297:Yes
# 80849 ->80849:Yes
# Received responses for batch 5 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 6 of 100
# # of prompts:  100 # of responses:  100
# 40618 ->40618:No
# 47189 ->47189:Yes
# 32839 ->32839:Yes
# 46232 ->46232:No
# 15565 ->15565:Yes
# 67783 ->67783:Yes
# 53129 ->53129:Yes
# 10715 ->10715:Yes
# 26111 ->26111:Yes
# 14009 ->14009:Yes
# 37987 ->37987:Yes
# 32068 ->32068:No
# 67499 ->67499:Yes
# 2663 ->2663:Yes
# 27832 ->27832:No
# 97319 ->97319:Yes
# 44715 ->44715:Yes
# 71483 ->71483:Yes
# 37448 ->37448:No
# 229 ->229:Yes
# 91092 ->91092:No
# 70639 ->70639:Yes
# 51563 ->51563:Yes
# 79123 ->79123:Yes
# 26293 ->26293:Yes
# 45587 ->45587:Yes
# 76733 ->76733:Yes
# 98216 ->98216:No
# 85743 ->85743:Yes
# 30886 ->30886:No
# 81591 ->81591:Yes
# 84967 ->84967:Yes
# 73823 ->73823:Yes
# 72148 ->72148:No
# 27372 ->27372:No
# 69143 ->69143:Yes
# 14887 ->14887:Yes
# 15073 ->15073:Yes
# 63127 ->63127:Yes
# 61751 ->61751:Yes
# 13049 ->13049:Yes
# 94603 ->94603:Yes
# 26699 ->26699:Yes
# 51949 ->51949:Yes
# 99053 ->99053:Yes
# 80909 ->80909:Yes
# 25463 ->25463:Yes
# 57859 ->57859:Yes
# 89582 ->89582:No
# 41144 ->41144:No
# 95537 ->95537:Yes
# 60289 ->60289:Yes
# 16061 ->16061:Yes
# 55414 ->55414:No
# 57535 ->57535:Yes
# 65332 ->65332:No
# 51660 ->51660:No
# 60953 ->60953:Yes
# 74789 ->74789:Yes
# 80651 ->80651:Yes
# 33142 ->33142:No
# 17147 ->17147:Yes
# 17333 ->17333:Yes
# 74197 ->74197:Yes
# 10355 ->10355:Yes
# 59688 ->59688:No
# 39396 ->39396:No
# 58231 ->58231:Yes
# 55404 ->55404:No
# 68443 ->68443:Yes
# 74063 ->74063:Yes
# 88843 ->88843:Yes
# 62903 ->62903:Yes
# 67451 ->67451:Yes
# 88410 ->88410:No
# 1973 ->1973:Yes
# 11923 ->11923:Yes
# 8467 ->8467:Yes
# 20696 ->20696:No
# 40241 ->40241:Yes
# 28636 ->28636:No
# 57793 ->57793:Yes
# 4595 ->4595:Yes
# 27983 ->27983:Yes
# 56901 ->56901:Yes
# 90783 ->90783:Yes
# 98006 ->98006:No
# 67807 ->67807:Yes
# 76884 ->76884:No
# 67010 ->67010:No
# 91143 ->91143:Yes
# 50087 ->50087:Yes
# 32406 ->32406:No
# 21831 ->21831:Yes
# 32636 ->32636:No
# 61657 ->61657:Yes
# 91504 ->91504:No
# 21601 ->21601:Yes
# 65123 ->65123:Yes
# 51889 ->51889:Yes
# Received responses for batch 6 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 7 of 100
# # of prompts:  100 # of responses:  100
# 55863 ->55863:No
# 40763 ->40763:No
# 62125 ->62125:No
# 88830 ->88830:No
# 26314 ->26314:No
# 92861 ->92861:No
# 62247 ->62247:No
# 71399 ->71399:No
# 68532 ->68532:No
# 9743 ->9743:Yes
# 63131 ->63131:No
# 62683 ->62683:No
# 76145 ->76145:No
# 5261 ->5261:Yes
# 95873 ->95873:No
# 86325 ->86325:No
# 20219 ->20219:Yes
# 63825 ->63825:No
# 94716 ->94716:No
# 86501 ->86501:No
# 68087 ->68087:No
# 35027 ->35027:Yes
# 48733 ->48733:No
# 62815 ->62815:No
# 40433 ->40433:No
# 82499 ->82499:No
# 2819 ->2819:Yes
# 86843 ->86843:No
# 41233 ->41233:No
# 19213 ->19213:Yes
# 43945 ->43945:No
# 13234 ->13234:No
# 22643 ->22643:No
# 21739 ->21739:Yes
# 69031 ->69031:No
# 87330 ->87330:No
# 71576 ->71576:No
# 92957 ->92957:No
# 96071 ->96071:No
# 26905 ->26905:No
# 10457 ->10457:Yes
# 87283 ->87283:No
# 58579 ->58579:No
# 67619 ->67619:No
# 15877 ->15877:Yes
# 26993 ->26993:No
# 65995 ->65995:No
# 7451 ->7451:Yes
# 92162 ->92162:No
# 40693 ->40693:No
# 26687 ->26687:No
# 51477 ->51477:No
# 181 ->181:Yes
# 89431 ->89431:No
# 91918 ->91918:No
# 58943 ->58943:No
# 54876 ->54876:No
# 52727 ->52727:No
# 92051 ->92051:No
# 20089 ->20089:Yes
# 92352 ->92352:No
# 8188 ->8188:No
# 85413 ->85413:No
# 19045 ->19045:Yes
# 72547 ->72547:No
# 68193 ->68193:No
# 23741 ->23741:No
# 80153 ->80153:No
# 74716 ->74716:No
# 73496 ->73496:No
# 77761 ->77761:No
# 21492 ->21492:No
# 61141 ->61141:No
# 19793 ->19793:Yes
# 1638 ->1638:No
# 45181 ->45181:No
# 98009 ->98009:No
# 46567 ->46567:No
# 36512 ->36512:No
# 69827 ->69827:No
# 21713 ->21713:Yes
# 51844 ->51844:No
# 65963 ->65963:No
# 21044 ->21044:No
# 69594 ->69594:No
# 2113 ->2113:Yes
# 80306 ->80306:No
# 42223 ->42223:No
# 55111 ->55111:No
# 97621 ->97621:No
# 48463 ->48463:No
# 78637 ->78637:No
# 7230 ->7230:No
# 42943 ->42943:No
# 46507 ->46507:No
# 21049 ->21049:Yes
# 11170 ->11170:No
# 77040 ->77040:No
# 13696 ->13696:No
# 20023 ->20023:Yes
# Received responses for batch 7 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 8 of 100
# # of prompts:  100 # of responses:  100
# 44879 ->44879:Yes
# 82388 ->82388:No
# 83023 ->83023:Yes
# 51853 ->51853:Yes
# 39020 ->39020:No
# 19157 ->19157:Yes
# 4484 ->4484:No
# 74092 ->74092:No
# 95737 ->95737:Yes
# 1597 ->1597:Yes
# 25633 ->25633:Yes
# 19763 ->19763:Yes
# 75110 ->75110:No
# 85021 ->85021:Yes
# 89603 ->89603:Yes
# 51487 ->51487:Yes
# 68023 ->68023:Yes
# 78857 ->78857:Yes
# 20749 ->20749:Yes
# 92423 ->92423:Yes
# 41314 ->41314:No
# 65939 ->65939:Yes
# 5101 ->5101:Yes
# 856 ->856:No
# 88993 ->88993:Yes
# 34261 ->34261:Yes
# 19972 ->19972:No
# 96001 ->96001:Yes
# 20483 ->20483:Yes
# 57221 ->57221:Yes
# 63337 ->63337:Yes
# 27903 ->27903:Yes
# 22133 ->22133:Yes
# 14095 ->14095:Yes
# 56873 ->56873:Yes
# 54630 ->54630:No
# 41051 ->41051:Yes
# 11801 ->11801:Yes
# 82487 ->82487:Yes
# 60259 ->60259:Yes
# 52049 ->52049:Yes
# 50450 ->50450:No
# 97039 ->97039:Yes
# 23733 ->23733:Yes
# 44809 ->44809:Yes
# 20387 ->20387:Yes
# 26959 ->26959:Yes
# 56299 ->56299:Yes
# 14827 ->14827:Yes
# 84629 ->84629:Yes
# 32741 ->32741:Yes
# 52817 ->52817:Yes
# 92682 ->92682:No
# 72558 ->72558:No
# 55683 ->55683:Yes
# 71237 ->71237:Yes
# 233 ->233:Yes
# 94403 ->94403:Yes
# 99907 ->99907:Yes
# 44258 ->44258:No
# 58785 ->58785:Yes
# 77893 ->77893:Yes
# 88128 ->88128:No
# 30469 ->30469:Yes
# 78736 ->78736:No
# 66797 ->66797:Yes
# 47825 ->47825:Yes
# 28447 ->28447:Yes
# 88667 ->88667:Yes
# 37847 ->37847:Yes
# 39839 ->39839:Yes
# 79103 ->79103:Yes
# 78643 ->78643:Yes
# 67079 ->67079:Yes
# 52317 ->52317:Yes
# 44617 ->44617:Yes
# 96259 ->96259:Yes
# 47303 ->47303:Yes
# 59779 ->59779:Yes
# 24359 ->24359:Yes
# 91549 ->91549:Yes
# 98369 ->98369:Yes
# 49207 ->49207:Yes
# 50969 ->50969:Yes
# 7039 ->7039:Yes
# 6175 ->6175:Yes
# 52741 ->52741:Yes
# 88997 ->88997:Yes
# 29629 ->29629:Yes
# 12535 ->12535:Yes
# 39196 ->39196:No
# 4955 ->4955:Yes
# 66168 ->66168:No
# 15440 ->15440:No
# 73483 ->73483:Yes
# 61112 ->61112:No
# 12101 ->12101:Yes
# 79612 ->79612:No
# 29196 ->29196:No
# 9511 ->9511:Yes
# Received responses for batch 8 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 9 of 100
# # of prompts:  100 # of responses:  100
# 27143 ->27143:Yes
# 91813 ->91813:Yes
# 73043 ->73043:Yes
# 56135 ->56135:Yes
# 71810 ->71810:No
# 16561 ->16561:Yes
# 25243 ->25243:Yes
# 22777 ->22777:Yes
# 36683 ->36683:Yes
# 96787 ->96787:Yes
# 8191 ->8191:Yes
# 50539 ->50539:Yes
# 39217 ->39217:Yes
# 54529 ->54529:Yes
# 19254 ->19254:No
# 18745 ->18745:Yes
# 82611 ->82611:Yes
# 50221 ->50221:Yes
# 50651 ->50651:Yes
# 7879 ->7879:Yes
# 48259 ->48259:Yes
# 62772 ->62772:No
# 5198 ->5198:No
# 4297 ->4297:Yes
# 55339 ->55339:Yes
# 96960 ->96960:No
# 20329 ->20329:Yes
# 26267 ->26267:Yes
# 52529 ->52529:Yes
# 88661 ->88661:Yes
# 59006 ->59006:No
# 50581 ->50581:Yes
# 33023 ->33023:Yes
# 96032 ->96032:No
# 6555 ->6555:Yes
# 4729 ->4729:Yes
# 48371 ->48371:Yes
# 22541 ->22541:Yes
# 82444 ->82444:No
# 87596 ->87596:No
# 96431 ->96431:Yes
# 99890 ->99890:No
# 38839 ->38839:Yes
# 52571 ->52571:Yes
# 62516 ->62516:No
# 1170 ->1170:No
# 20983 ->20983:Yes
# 33163 ->33163:Yes
# 21821 ->21821:Yes
# 49999 ->49999:No
# 62591 ->62591:Yes
# 1303 ->1303:Yes
# 91240 ->91240:No
# 36298 ->36298:No
# 95561 ->95561:Yes
# 72047 ->72047:Yes
# 72456 ->72456:No
# 20236 ->20236:No
# 67429 ->67429:Yes
# 48424 ->48424:No
# 96989 ->96989:Yes
# 24943 ->24943:Yes
# 53087 ->53087:Yes
# 49578 ->49578:No
# 7727 ->7727:Yes
# 91610 ->91610:No
# 77521 ->77521:Yes
# 99964 ->99964:No
# 99293 ->99293:Yes
# 42019 ->42019:Yes
# 61958 ->61958:No
# 64614 ->64614:No
# 37853 ->37853:Yes
# 79493 ->79493:Yes
# 77687 ->77687:Yes
# 33591 ->33591:Yes
# 96733 ->96733:Yes
# 29533 ->29533:Yes
# 47389 ->47389:Yes
# 73637 ->73637:Yes
# 46351 ->46351:Yes
# 92197 ->92197:Yes
# 12181 ->12181:Yes
# 22149 ->22149:Yes
# 20731 ->20731:Yes
# 95865 ->95865:Yes
# 52069 ->52069:Yes
# 72577 ->72577:Yes
# 9262 ->9262:No
# 89477 ->89477:Yes
# 76943 ->76943:Yes
# 38933 ->38933:Yes
# 8521 ->8521:Yes
# 48431 ->48431:Yes
# 44473 ->44473:Yes
# 68207 ->68207:Yes
# 33739 ->33739:Yes
# 75223 ->75223:Yes
# 19759 ->19759:Yes
# 66293 ->66293:Yes
# Received responses for batch 9 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 10 of 100
# # of prompts:  100 # of responses:  100
# 5104 ->5104:No
# 42685 ->42685:No
# 19273 ->19273:No
# 39209 ->39209:No
# 15791 ->15791:No
# 34881 ->34881:No
# 6737 ->6737:No
# 95996 ->95996:No
# 77953 ->77953:No
# 42727 ->42727:No
# 80247 ->80247:No
# 72294 ->72294:No
# 84163 ->84163:No
# 39188 ->39188:No
# 19611 ->19611:No
# 91331 ->91331:No
# 47743 ->47743:No
# 95390 ->95390:No
# 92109 ->92109:No
# 94048 ->94048:No
# 43943 ->43943:No
# 24587 ->24587:No
# 92867 ->92867:No
# 28927 ->28927:No
# 57396 ->57396:No
# 68046 ->68046:No
# 2471 ->2471:No
# 23509 ->23509:No
# 13127 ->13127:No
# 64553 ->64553:No
# 24055 ->24055:No
# 14993 ->14993:No
# 98993 ->98993:No
# 1888 ->1888:No
# 72921 ->72921:No
# 49750 ->49750:No
# 99317 ->99317:No
# 3320 ->3320:No
# 31957 ->31957:No
# 52075 ->52075:No
# 73019 ->73019:No
# 72686 ->72686:No
# 6037 ->6037:No
# 31515 ->31515:No
# 78348 ->78348:No
# 53784 ->53784:No
# 5829 ->5829:No
# 50435 ->50435:No
# 29785 ->29785:No
# 73693 ->73693:No
# 11226 ->11226:No
# 64794 ->64794:No
# 13613 ->13613:No
# 97299 ->97299:No
# 90215 ->90215:No
# 67141 ->67141:No
# 79909 ->79909:No
# 89181 ->89181:No
# 81197 ->81197:No
# 33797 ->33797:No
# 73914 ->73914:No
# 73677 ->73677:No
# 13855 ->13855:No
# 77935 ->77935:No
# 98166 ->98166:No
# 7487 ->7487:No
# 50543 ->50543:No
# 64666 ->64666:No
# 40379 ->40379:No
# 87255 ->87255:No
# 2340 ->2340:No
# 68917 ->68917:No
# 76683 ->76683:No
# 59567 ->59567:No
# 20359 ->20359:No
# 21277 ->21277:No
# 37547 ->37547:No
# 1427 ->1427:No
# 34231 ->34231:No
# 41822 ->41822:No
# 51383 ->51383:No
# 70152 ->70152:No
# 89521 ->89521:No
# 63206 ->63206:No
# 9982 ->9982:No
# 28309 ->28309:No
# 96400 ->96400:No
# 15641 ->15641:No
# 22141 ->22141:No
# 60917 ->60917:No
# 45121 ->45121:No
# 33278 ->33278:No
# 26557 ->26557:No
# 1991 ->1991:No
# 39615 ->39615:No
# 28384 ->28384:No
# 59648 ->59648:No
# 46681 ->46681:No
# 64694 ->64694:No
# 73973 ->73973:No
# Received responses for batch 10 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 11 of 100
# # of prompts:  100 # of responses:  100
# 77431 ->77431:Yes
# 96737 ->96737:Yes
# 13629 ->13629:Yes
# 50930 ->50930:No
# 84868 ->84868:No
# 16296 ->16296:No
# 44027 ->44027:Yes
# 37697 ->37697:Yes
# 36017 ->36017:Yes
# 60889 ->60889:Yes
# 45167 ->45167:Yes
# 43103 ->43103:Yes
# 84137 ->84137:Yes
# 13244 ->13244:No
# 5366 ->5366:No
# 38821 ->38821:Yes
# 33751 ->33751:Yes
# 48649 ->48649:Yes
# 29333 ->29333:Yes
# 19818 ->19818:No
# 6228 ->6228:No
# 40902 ->40902:No
# 45533 ->45533:Yes
# 72575 ->72575:Yes
# 60172 ->60172:No
# 87671 ->87671:Yes
# 36793 ->36793:Yes
# 59351 ->59351:Yes
# 33822 ->33822:No
# 50461 ->50461:Yes
# 58477 ->58477:Yes
# 94063 ->94063:Yes
# 59443 ->59443:Yes
# 95143 ->95143:Yes
# 34501 ->34501:Yes
# 44729 ->44729:Yes
# 1069 ->1069:Yes
# 77766 ->77766:No
# 39397 ->39397:Yes
# 83842 ->83842:No
# 10247 ->10247:Yes
# 49509 ->49509:Yes
# 99825 ->99825:Yes
# 72379 ->72379:Yes
# 24945 ->24945:Yes
# 98627 ->98627:Yes
# 56073 ->56073:Yes
# 91293 ->91293:Yes
# 21426 ->21426:No
# 49954 ->49954:No
# 75455 ->75455:Yes
# 81658 ->81658:No
# 39912 ->39912:No
# 24256 ->24256:No
# 98641 ->98641:Yes
# 70921 ->70921:Yes
# 84199 ->84199:Yes
# 91028 ->91028:No
# 27594 ->27594:No
# 67169 ->67169:Yes
# 77023 ->77023:Yes
# 73836 ->73836:No
# 50400 ->50400:No
# 15319 ->15319:Yes
# 94672 ->94672:No
# 60143 ->60143:Yes
# 87973 ->87973:Yes
# 35173 ->35173:Yes
# 97843 ->97843:Yes
# 81019 ->81019:Yes
# 50277 ->50277:Yes
# 53503 ->53503:Yes
# 62731 ->62731:Yes
# 26017 ->26017:Yes
# 28515 ->28515:Yes
# 59671 ->59671:Yes
# 54577 ->54577:Yes
# 62147 ->62147:Yes
# 45206 ->45206:No
# 42489 ->42489:Yes
# 90371 ->90371:Yes
# 21421 ->21421:Yes
# 53609 ->53609:Yes
# 98224 ->98224:No
# 21055 ->21055:Yes
# 81045 ->81045:Yes
# 83787 ->83787:Yes
# 82529 ->82529:Yes
# 93053 ->93053:Yes
# 8011 ->8011:Yes
# 41617 ->41617:Yes
# 59083 ->59083:Yes
# 51137 ->51137:Yes
# 23059 ->23059:Yes
# 83791 ->83791:Yes
# 18579 ->18579:Yes
# 86413 ->86413:Yes
# 10973 ->10973:Yes
# 60873 ->60873:Yes
# 86321 ->86321:Yes
# Received responses for batch 11 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 12 of 100
# # of prompts:  100 # of responses:  100
# 1553 ->1553:No
# 1861 ->1861:No
# 23627 ->23627:Yes
# 95993 ->95993:Yes
# 94183 ->94183:Yes
# 94837 ->94837:Yes
# 7757 ->7757:Yes
# 68044 ->68044:No
# 8287 ->8287:Yes
# 76031 ->76031:Yes
# 13159 ->13159:Yes
# 65075 ->65075:Yes
# 96963 ->96963:Yes
# 85691 ->85691:Yes
# 5711 ->5711:Yes
# 10867 ->10867:Yes
# 36781 ->36781:Yes
# 79813 ->79813:Yes
# 14633 ->14633:Yes
# 4751 ->4751:Yes
# 4305 ->4305:Yes
# 75026 ->75026:No
# 8896 ->8896:No
# 78737 ->78737:Yes
# 29342 ->29342:No
# 16255 ->16255:Yes
# 25137 ->25137:Yes
# 569 ->569:Yes
# 14323 ->14323:Yes
# 87149 ->87149:Yes
# 26189 ->26189:Yes
# 81828 ->81828:No
# 41681 ->41681:Yes
# 14460 ->14460:No
# 84291 ->84291:Yes
# 34335 ->34335:Yes
# 2729 ->2729:Yes
# 74311 ->74311:Yes
# 4597 ->4597:Yes
# 6361 ->6361:Yes
# 52691 ->52691:Yes
# 47591 ->47591:Yes
# 89066 ->89066:No
# 91163 ->91163:Yes
# 88169 ->88169:Yes
# 14425 ->14425:Yes
# 8147 ->8147:Yes
# 24372 ->24372:No
# 83170 ->83170:No
# 22759 ->22759:Yes
# 28831 ->28831:Yes
# 49305 ->49305:Yes
# 44273 ->44273:Yes
# 13352 ->13352:No
# 26427 ->26427:Yes
# 86373 ->86373:Yes
# 40615 ->40615:Yes
# 15669 ->15669:Yes
# 9539 ->9539:Yes
# 8421 ->8421:Yes
# 24327 ->24327:Yes
# 61879 ->61879:Yes
# 80279 ->80279:Yes
# 5851 ->5851:Yes
# 99349 ->99349:Yes
# 71938 ->71938:No
# 22515 ->22515:Yes
# 85756 ->85756:No
# 32363 ->32363:Yes
# 32503 ->32503:Yes
# 71479 ->71479:Yes
# 39023 ->39023:Yes
# 37199 ->37199:Yes
# 77899 ->77899:Yes
# 55635 ->55635:Yes
# 81047 ->81047:Yes
# 38993 ->38993:Yes
# 94399 ->94399:Yes
# 34913 ->34913:Yes
# 18025 ->18025:Yes
# 76649 ->76649:Yes
# 65633 ->65633:Yes
# 66749 ->66749:Yes
# 40646 ->40646:No
# 82449 ->82449:Yes
# 17297 ->17297:Yes
# 23720 ->23720:No
# 73610 ->73610:No
# 13691 ->13691:Yes
# 51544 ->51544:No
# 62119 ->62119:Yes
# 77917 ->77917:Yes
# 62639 ->62639:Yes
# 48180 ->48180:No
# 65981 ->65981:Yes
# 95574 ->95574:No
# 87583 ->87583:Yes
# 5521 ->5521:Yes
# 53419 ->53419:Yes
# 69653 ->69653:Yes
# Received responses for batch 12 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 13 of 100
# # of prompts:  100 # of responses:  100
# 1146 ->1146:No
# 37963 ->37963:No
# 35673 ->35673:No
# 6742 ->6742:No
# 63997 ->63997:No
# 58717 ->58717:No
# 30712 ->30712:No
# 93891 ->93891:No
# 77563 ->77563:No
# 50877 ->50877:No
# 20741 ->20741:No
# 39097 ->39097:No
# 28867 ->28867:No
# 91685 ->91685:No
# 17377 ->17377:No
# 85259 ->85259:No
# 29398 ->29398:No
# 77813 ->77813:No
# 33343 ->33343:No
# 13451 ->13451:No
# 10291 ->10291:No
# 48262 ->48262:No
# 63463 ->63463:No
# 98801 ->98801:No
# 31353 ->31353:No
# 99805 ->99805:No
# 3057 ->3057:Yes
# 47 ->47:Yes
# 57432 ->57432:No
# 84512 ->84512:No
# 4492 ->4492:No
# 57158 ->57158:No
# 28888 ->28888:No
# 59093 ->59093:No
# 52904 ->52904:No
# 63921 ->63921:No
# 42671 ->42671:No
# 12641 ->12641:No
# 76431 ->76431:No
# 59544 ->59544:No
# 67699 ->67699:No
# 57670 ->57670:No
# 93481 ->93481:No
# 48552 ->48552:No
# 61355 ->61355:No
# 1061 ->1061:Yes
# 59151 ->59151:No
# 11717 ->11717:No
# 88576 ->88576:No
# 57324 ->57324:No
# 55356 ->55356:No
# 7699 ->7699:Yes
# 69691 ->69691:No
# 40801 ->40801:No
# 79981 ->79981:No
# 64081 ->64081:No
# 33791 ->33791:No
# 16451 ->16451:No
# 92945 ->92945:No
# 73059 ->73059:No
# 27666 ->27666:No
# 95702 ->95702:No
# 79782 ->79782:No
# 89766 ->89766:No
# 47753 ->47753:No
# 45052 ->45052:No
# 13183 ->13183:No
# 11273 ->11273:No
# 99877 ->99877:No
# 36383 ->36383:No
# 15747 ->15747:No
# 84814 ->84814:No
# 69643 ->69643:No
# 3299 ->3299:Yes
# 26177 ->26177:No
# 59207 ->59207:No
# 47565 ->47565:No
# 17881 ->17881:No
# 82003 ->82003:No
# 89856 ->89856:No
# 45844 ->45844:No
# 18970 ->18970:No
# 68562 ->68562:No
# 11739 ->11739:No
# 33749 ->33749:No
# 12119 ->12119:No
# 14340 ->14340:No
# 86742 ->86742:No
# 3419 ->3419:Yes
# 5233 ->5233:Yes
# 77969 ->77969:No
# 92627 ->92627:No
# 16661 ->16661:No
# 95661 ->95661:No
# 40237 ->40237:No
# 60257 ->60257:No
# 16487 ->16487:No
# 78155 ->78155:No
# 21966 ->21966:No
# 23563 ->23563:No
# Received responses for batch 13 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 14 of 100
# # of prompts:  100 # of responses:  100
# 25016 ->25016:No
# 3657 ->3657:No
# 97704 ->97704:No
# 57885 ->57885:No
# 8291 ->8291:No
# 29303 ->29303:No
# 64712 ->64712:No
# 38287 ->38287:No
# 22739 ->22739:No
# 79901 ->79901:No
# 81457 ->81457:No
# 51413 ->51413:No
# 76367 ->76367:No
# 60733 ->60733:No
# 6663 ->6663:No
# 93048 ->93048:No
# 14783 ->14783:No
# 25652 ->25652:No
# 15443 ->15443:No
# 27609 ->27609:No
# 33897 ->33897:No
# 27213 ->27213:No
# 60111 ->60111:No
# 77041 ->77041:No
# 47407 ->47407:No
# 16691 ->16691:No
# 33851 ->33851:No
# 48459 ->48459:No
# 82661 ->82661:No
# 860 ->860:No
# 47981 ->47981:No
# 45403 ->45403:No
# 34253 ->34253:No
# 75584 ->75584:No
# 65957 ->65957:No
# 48725 ->48725:No
# 55763 ->55763:No
# 41557 ->41557:No
# 62681 ->62681:No
# 62099 ->62099:No
# 3887 ->3887:No
# 61140 ->61140:No
# 32933 ->32933:No
# 1344 ->1344:No
# 16193 ->16193:No
# 9117 ->9117:No
# 9967 ->9967:No
# 17359 ->17359:No
# 85710 ->85710:No
# 13697 ->13697:No
# 64960 ->64960:No
# 23352 ->23352:No
# 84311 ->84311:No
# 73379 ->73379:No
# 69004 ->69004:No
# 87427 ->87427:No
# 74360 ->74360:No
# 69766 ->69766:No
# 99767 ->99767:No
# 74719 ->74719:No
# 14004 ->14004:No
# 48426 ->48426:No
# 41249 ->41249:No
# 94805 ->94805:No
# 60631 ->60631:No
# 70207 ->70207:No
# 74687 ->74687:No
# 49081 ->49081:No
# 62577 ->62577:No
# 67629 ->67629:No
# 99527 ->99527:No
# 87433 ->87433:No
# 53881 ->53881:No
# 41177 ->41177:No
# 34061 ->34061:No
# 96769 ->96769:No
# 21751 ->21751:No
# 948 ->948:No
# 32660 ->32660:No
# 60556 ->60556:No
# 91753 ->91753:No
# 93941 ->93941:No
# 30757 ->30757:No
# 40071 ->40071:No
# 69686 ->69686:No
# 8171 ->8171:No
# 41851 ->41851:No
# 90346 ->90346:No
# 8059 ->8059:No
# 72673 ->72673:No
# 43669 ->43669:No
# 11527 ->11527:No
# 1479 ->1479:No
# 38079 ->38079:No
# 4127 ->4127:No
# 59412 ->59412:No
# 29201 ->29201:No
# 86923 ->86923:No
# 76072 ->76072:No
# 9227 ->9227:No
# Received responses for batch 14 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 15 of 100
# # of prompts:  100 # of responses:  100
# 89659 ->89659:No
# 97007 ->97007:No
# 6343 ->6343:Yes
# 41705 ->41705:No
# 43803 ->43803:No
# 87655 ->87655:No
# 98621 ->98621:No
# 16979 ->16979:No
# 14526 ->14526:No
# 52565 ->52565:No
# 58119 ->58119:No
# 57737 ->57737:No
# 19501 ->19501:No
# 89291 ->89291:No
# 20323 ->20323:No
# 46532 ->46532:No
# 13747 ->13747:No
# 24436 ->24436:No
# 14543 ->14543:No
# 10664 ->10664:No
# 27753 ->27753:No
# 92507 ->92507:No
# 88807 ->88807:No
# 61472 ->61472:No
# 18131 ->18131:No
# 43145 ->43145:No
# 7297 ->7297:Yes
# 63299 ->63299:No
# 40499 ->40499:No
# 44950 ->44950:No
# 36147 ->36147:No
# 14197 ->14197:No
# 43824 ->43824:No
# 45910 ->45910:No
# 48804 ->48804:No
# 40283 ->40283:No
# 4129 ->4129:Yes
# 21211 ->21211:No
# 58435 ->58435:No
# 5456 ->5456:No
# 23954 ->23954:No
# 16825 ->16825:No
# 10909 ->10909:No
# 78179 ->78179:No
# 47182 ->47182:No
# 17471 ->17471:No
# 54011 ->54011:No
# 81061 ->81061:No
# 55823 ->55823:No
# 11386 ->11386:No
# 52889 ->52889:No
# 33870 ->33870:No
# 82811 ->82811:No
# 86929 ->86929:No
# 43049 ->43049:No
# 28108 ->28108:No
# 67073 ->67073:No
# 67931 ->67931:No
# 49911 ->49911:No
# 51659 ->51659:No
# 25936 ->25936:No
# 74653 ->74653:No
# 22469 ->22469:No
# 35288 ->35288:No
# 20963 ->20963:No
# 44657 ->44657:No
# 92675 ->92675:No
# 41426 ->41426:No
# 25147 ->25147:No
# 53106 ->53106:No
# 30878 ->30878:No
# 89533 ->89533:No
# 82657 ->82657:No
# 87083 ->87083:No
# 34596 ->34596:No
# 30389 ->30389:No
# 70380 ->70380:No
# 30500 ->30500:No
# 2639 ->2639:Yes
# 85703 ->85703:No
# 18558 ->18558:No
# 79997 ->79997:No
# 86033 ->86033:No
# 69511 ->69511:No
# 84697 ->84697:No
# 15203 ->15203:No
# 97381 ->97381:No
# 27071 ->27071:No
# 73181 ->73181:No
# 12334 ->12334:No
# 60263 ->60263:No
# 55163 ->55163:No
# 66233 ->66233:No
# 11328 ->11328:No
# 26704 ->26704:No
# 94117 ->94117:No
# 26497 ->26497:No
# 40153 ->40153:No
# 75569 ->75569:No
# 36197 ->36197:No
# Received responses for batch 15 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 16 of 100
# # of prompts:  100 # of responses:  100
# 89978 ->89978:No
# 46451 ->46451:No
# 36469 ->36469:No
# 33073 ->33073:No
# 22947 ->22947:No
# 35862 ->35862:No
# 15193 ->15193:No
# 93078 ->93078:No
# 76099 ->76099:No
# 44058 ->44058:No
# 6839 ->6839:No
# 80467 ->80467:No
# 95369 ->95369:No
# 12056 ->12056:No
# 95238 ->95238:No
# 78020 ->78020:No
# 37510 ->37510:No
# 20124 ->20124:No
# 44741 ->44741:No
# 99007 ->99007:No
# 25329 ->25329:No
# 12203 ->12203:No
# 74333 ->74333:No
# 14813 ->14813:No
# 26268 ->26268:No
# 11939 ->11939:No
# 45341 ->45341:No
# 15856 ->15856:No
# 72545 ->72545:No
# 84463 ->84463:No
# 97393 ->97393:No
# 60718 ->60718:No
# 46279 ->46279:No
# 62869 ->62869:No
# 16343 ->16343:No
# 80413 ->80413:No
# 74363 ->74363:No
# 3066 ->3066:No
# 31923 ->31923:No
# 96703 ->96703:No
# 78583 ->78583:No
# 48499 ->48499:No
# 39461 ->39461:No
# 57143 ->57143:No
# 21386 ->21386:No
# 55939 ->55939:No
# 99707 ->99707:No
# 44771 ->44771:No
# 60457 ->60457:No
# 50294 ->50294:No
# 521 ->521:No
# 76674 ->76674:No
# 15662 ->15662:No
# 67801 ->67801:No
# 80677 ->80677:No
# 78183 ->78183:No
# 81294 ->81294:No
# 56591 ->56591:No
# 50227 ->50227:No
# 13736 ->13736:No
# 29501 ->29501:No
# 11254 ->11254:No
# 14521 ->14521:No
# 71849 ->71849:No
# 89234 ->89234:No
# 95912 ->95912:No
# 20769 ->20769:No
# 89671 ->89671:No
# 99139 ->99139:No
# 42737 ->42737:No
# 64937 ->64937:No
# 81813 ->81813:No
# 31793 ->31793:No
# 99126 ->99126:No
# 10593 ->10593:No
# 5206 ->5206:No
# 7717 ->7717:No
# 79460 ->79460:No
# 29944 ->29944:No
# 43201 ->43201:No
# 9833 ->9833:No
# 24923 ->24923:No
# 71209 ->71209:No
# 93059 ->93059:No
# 39291 ->39291:No
# 15566 ->15566:No
# 72376 ->72376:No
# 4853 ->4853:No
# 11867 ->11867:No
# 7992 ->7992:No
# 48947 ->48947:No
# 22501 ->22501:No
# 75649 ->75649:No
# 97464 ->97464:No
# 18168 ->18168:No
# 13513 ->13513:No
# 57061 ->57061:No
# 62627 ->62627:No
# 607 ->607:No
# 86586 ->86586:No
# Received responses for batch 16 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 17 of 100
# # of prompts:  100 # of responses:  100
# 61471 ->61471:Yes
# 82067 ->82067:Yes
# 38030 ->38030:No
# 67757 ->67757:Yes
# 80461 ->80461:Yes
# 62295 ->62295:Yes
# 76991 ->76991:Yes
# 44782 ->44782:No
# 57646 ->57646:No
# 61574 ->61574:No
# 93693 ->93693:Yes
# 35899 ->35899:Yes
# 45697 ->45697:Yes
# 51257 ->51257:Yes
# 72843 ->72843:Yes
# 53638 ->53638:No
# 84835 ->84835:Yes
# 13726 ->13726:No
# 65183 ->65183:Yes
# 79181 ->79181:Yes
# 49603 ->49603:Yes
# 11587 ->11587:Yes
# 84481 ->84481:Yes
# 43645 ->43645:Yes
# 30809 ->30809:Yes
# 18656 ->18656:No
# 78669 ->78669:Yes
# 91860 ->91860:No
# 88031 ->88031:Yes
# 59057 ->59057:Yes
# 80761 ->80761:Yes
# 51859 ->51859:Yes
# 63499 ->63499:Yes
# 12289 ->12289:Yes
# 34693 ->34693:Yes
# 47987 ->47987:Yes
# 55213 ->55213:Yes
# 20231 ->20231:Yes
# 85391 ->85391:Yes
# 72271 ->72271:Yes
# 11372 ->11372:No
# 29837 ->29837:Yes
# 58147 ->58147:Yes
# 29853 ->29853:Yes
# 43289 ->43289:Yes
# 81281 ->81281:Yes
# 40173 ->40173:Yes
# 46968 ->46968:No
# 71795 ->71795:Yes
# 26085 ->26085:Yes
# 73821 ->73821:Yes
# 37551 ->37551:Yes
# 72935 ->72935:Yes
# 14303 ->14303:Yes
# 41389 ->41389:Yes
# 81163 ->81163:Yes
# 92642 ->92642:No
# 63587 ->63587:Yes
# 42409 ->42409:Yes
# 98887 ->98887:Yes
# 49433 ->49433:Yes
# 52205 ->52205:Yes
# 70021 ->70021:Yes
# 33809 ->33809:Yes
# 40726 ->40726:No
# 67348 ->67348:No
# 97718 ->97718:No
# 97931 ->97931:Yes
# 93260 ->93260:No
# 48859 ->48859:Yes
# 65648 ->65648:No
# 65267 ->65267:Yes
# 16863 ->16863:Yes
# 55949 ->55949:Yes
# 85962 ->85962:No
# 1237 ->1237:Yes
# 34537 ->34537:Yes
# 48817 ->48817:Yes
# 38985 ->38985:Yes
# 14018 ->14018:No
# 3845 ->3845:Yes
# 57444 ->57444:No
# 89049 ->89049:Yes
# 2132 ->2132:No
# 98257 ->98257:Yes
# 33346 ->33346:No
# 21664 ->21664:No
# 80789 ->80789:Yes
# 87201 ->87201:Yes
# 18363 ->18363:Yes
# 7573 ->7573:Yes
# 55586 ->55586:No
# 51041 ->51041:Yes
# 67181 ->67181:Yes
# 9569 ->9569:Yes
# 22769 ->22769:Yes
# 41507 ->41507:Yes
# 83057 ->83057:Yes
# 57977 ->57977:Yes
# 15473 ->15473:Yes
# Received responses for batch 17 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 18 of 100
# # of prompts:  100 # of responses:  100
# 49391 ->49391:Yes
# 66599 ->66599:Yes
# 90011 ->90011:Yes
# 89073 ->89073:Yes
# 4023 ->4023:Yes
# 42683 ->42683:Yes
# 22842 ->22842:No
# 95093 ->95093:Yes
# 93997 ->93997:Yes
# 91972 ->91972:No
# 60242 ->60242:No
# 66014 ->66014:No
# 31799 ->31799:Yes
# 37907 ->37907:Yes
# 64793 ->64793:Yes
# 24509 ->24509:Yes
# 67106 ->67106:No
# 42235 ->42235:Yes
# 19183 ->19183:Yes
# 46933 ->46933:Yes
# 27464 ->27464:No
# 85737 ->85737:Yes
# 31547 ->31547:Yes
# 98479 ->98479:Yes
# 6335 ->6335:Yes
# 61010 ->61010:No
# 81199 ->81199:Yes
# 30829 ->30829:Yes
# 64935 ->64935:Yes
# 51467 ->51467:Yes
# 77256 ->77256:No
# 61363 ->61363:Yes
# 12923 ->12923:Yes
# 39550 ->39550:No
# 60051 ->60051:Yes
# 89681 ->89681:Yes
# 79635 ->79635:Yes
# 47441 ->47441:Yes
# 96909 ->96909:Yes
# 45502 ->45502:No
# 19015 ->19015:Yes
# 78843 ->78843:Yes
# 13933 ->13933:Yes
# 97392 ->97392:No
# 48344 ->48344:No
# 5150 ->5150:No
# 95534 ->95534:No
# 29218 ->29218:No
# 41057 ->41057:Yes
# 30365 ->30365:Yes
# 22715 ->22715:Yes
# 81043 ->81043:Yes
# 33521 ->33521:Yes
# 51461 ->51461:Yes
# 43313 ->43313:Yes
# 44277 ->44277:Yes
# 23331 ->23331:Yes
# 17278 ->17278:No
# 4100 ->4100:No
# 69410 ->69410:No
# 9044 ->9044:No
# 26584 ->26584:No
# 5791 ->5791:Yes
# 1508 ->1508:No
# 12377 ->12377:Yes
# 43411 ->43411:Yes
# 89317 ->89317:Yes
# 52860 ->52860:No
# 52561 ->52561:Yes
# 46811 ->46811:Yes
# 74849 ->74849:Yes
# 95791 ->95791:Yes
# 19805 ->19805:Yes
# 91151 ->91151:Yes
# 84780 ->84780:No
# 90018 ->90018:No
# 33559 ->33559:Yes
# 30313 ->30313:Yes
# 96221 ->96221:Yes
# 31407 ->31407:Yes
# 77790 ->77790:No
# 2671 ->2671:Yes
# 50387 ->50387:Yes
# 71233 ->71233:Yes
# 69761 ->69761:Yes
# 5021 ->5021:Yes
# 49835 ->49835:Yes
# 26501 ->26501:Yes
# 13325 ->13325:Yes
# 85221 ->85221:Yes
# 20788 ->20788:No
# 47421 ->47421:Yes
# 26947 ->26947:Yes
# 12443 ->12443:Yes
# 41087 ->41087:Yes
# 44131 ->44131:Yes
# 89413 ->89413:Yes
# 57888 ->57888:No
# 85577 ->85577:Yes
# 86066 ->86066:No
# Received responses for batch 18 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 19 of 100
# # of prompts:  100 # of responses:  100
# 48563 ->48563:No
# 55577 ->55577:No
# 16087 ->16087:No
# 91244 ->91244:No
# 69859 ->69859:No
# 56053 ->56053:No
# 8636 ->8636:No
# 13163 ->13163:No
# 75825 ->75825:No
# 70487 ->70487:No
# 87778 ->87778:No
# 72767 ->72767:No
# 28394 ->28394:No
# 10613 ->10613:No
# 22621 ->22621:No
# 37842 ->37842:No
# 43141 ->43141:No
# 86281 ->86281:No
# 32909 ->32909:No
# 78466 ->78466:No
# 59797 ->59797:No
# 29005 ->29005:No
# 68978 ->68978:No
# 44228 ->44228:No
# 87013 ->87013:No
# 7429 ->7429:No
# 73106 ->73106:No
# 10639 ->10639:No
# 26423 ->26423:No
# 65553 ->65553:No
# 51046 ->51046:No
# 43114 ->43114:No
# 69692 ->69692:No
# 76379 ->76379:No
# 10405 ->10405:No
# 18173 ->18173:No
# 56437 ->56437:No
# 44807 ->44807:No
# 67577 ->67577:No
# 71789 ->71789:No
# 25745 ->25745:No
# 83028 ->83028:No
# 38053 ->38053:No
# 44116 ->44116:No
# 58462 ->58462:No
# 48361 ->48361:No
# 60761 ->60761:No
# 19927 ->19927:No
# 66643 ->66643:No
# 72383 ->72383:No
# 89675 ->89675:No
# 37528 ->37528:No
# 78029 ->78029:No
# 35763 ->35763:No
# 45443 ->45443:No
# 80209 ->80209:No
# 28375 ->28375:No
# 20477 ->20477:No
# 57653 ->57653:No
# 80421 ->80421:No
# 54371 ->54371:No
# 92699 ->92699:No
# 84602 ->84602:No
# 16139 ->16139:No
# 9397 ->9397:No
# 19395 ->19395:No
# 3719 ->3719:No
# 63629 ->63629:No
# 81001 ->81001:No
# 4519 ->4519:No
# 8101 ->8101:No
# 54979 ->54979:No
# 42753 ->42753:No
# 60773 ->60773:No
# 35083 ->35083:No
# 62603 ->62603:No
# 68669 ->68669:No
# 26344 ->26344:No
# 10037 ->10037:No
# 57540 ->57540:No
# 59557 ->59557:No
# 6091 ->6091:No
# 90345 ->90345:No
# 6211 ->6211:No
# 50444 ->50444:No
# 16083 ->16083:No
# 54820 ->54820:No
# 8665 ->8665:No
# 53906 ->53906:No
# 5068 ->5068:No
# 10243 ->10243:No
# 57619 ->57619:No
# 70005 ->70005:No
# 23619 ->23619:No
# 83719 ->83719:No
# 8831 ->8831:No
# 40107 ->40107:No
# 3966 ->3966:No
# 45271 ->45271:No
# 2711 ->2711:No
# Received responses for batch 19 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 20 of 100
# # of prompts:  100 # of responses:  100
# 6144 ->6144:No
# 22965 ->22965:No
# 50591 ->50591:No
# 31 ->31:Yes
# 28297 ->28297:No
# 65065 ->65065:No
# 16893 ->16893:No
# 50954 ->50954:No
# 90929 ->90929:No
# 33487 ->33487:No
# 13706 ->13706:No
# 17027 ->17027:No
# 77347 ->77347:No
# 67453 ->67453:No
# 62374 ->62374:No
# 60691 ->60691:No
# 49463 ->49463:No
# 36433 ->36433:No
# 87701 ->87701:No
# 71735 ->71735:No
# 85137 ->85137:No
# 58389 ->58389:No
# 13597 ->13597:No
# 15309 ->15309:No
# 2886 ->2886:No
# 30649 ->30649:No
# 60941 ->60941:No
# 30689 ->30689:No
# 35840 ->35840:No
# 32742 ->32742:No
# 28948 ->28948:No
# 90942 ->90942:No
# 1351 ->1351:Yes
# 27906 ->27906:No
# 32803 ->32803:No
# 44111 ->44111:No
# 48516 ->48516:No
# 22001 ->22001:No
# 93826 ->93826:No
# 20857 ->20857:No
# 32382 ->32382:No
# 61981 ->61981:No
# 66629 ->66629:No
# 37539 ->37539:No
# 24025 ->24025:No
# 50002 ->50002:No
# 691 ->691:Yes
# 98663 ->98663:No
# 74377 ->74377:No
# 72207 ->72207:No
# 41282 ->41282:No
# 35951 ->35951:No
# 33895 ->33895:No
# 11471 ->11471:No
# 30713 ->30713:No
# 27107 ->27107:No
# 90007 ->90007:No
# 59651 ->59651:No
# 94022 ->94022:No
# 12467 ->12467:No
# 80713 ->80713:No
# 88741 ->88741:No
# 49761 ->49761:No
# 82426 ->82426:No
# 73331 ->73331:No
# 34594 ->34594:No
# 2523 ->2523:Yes
# 66587 ->66587:No
# 47917 ->47917:No
# 18289 ->18289:No
# 92753 ->92753:No
# 6329 ->6329:Yes
# 9473 ->9473:Yes
# 68200 ->68200:No
# 79627 ->79627:No
# 84673 ->84673:No
# 96254 ->96254:No
# 68605 ->68605:No
# 21769 ->21769:No
# 43499 ->43499:No
# 18094 ->18094:No
# 46643 ->46643:No
# 45119 ->45119:No
# 17657 ->17657:No
# 56929 ->56929:No
# 62649 ->62649:No
# 42540 ->42540:No
# 41795 ->41795:No
# 49177 ->49177:No
# 7549 ->7549:Yes
# 68227 ->68227:No
# 48635 ->48635:No
# 94707 ->94707:No
# 53951 ->53951:No
# 2655 ->2655:Yes
# 593 ->593:Yes
# 85487 ->85487:No
# 40819 ->40819:No
# 58067 ->58067:No
# 75789 ->75789:No
# Received responses for batch 20 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 21 of 100
# # of prompts:  100 # of responses:  100
# 13681 ->13681:Yes
# 58171 ->58171:Yes
# 69149 ->69149:Yes
# 3245 ->3245:No
# 17921 ->17921:Yes
# 7349 ->7349:Yes
# 53089 ->53089:Yes
# 33532 ->33532:No
# 11715 ->11715:Yes
# 77817 ->77817:Yes
# 38541 ->38541:Yes
# 84716 ->84716:No
# 7287 ->7287:Yes
# 10861 ->10861:Yes
# 1141 ->1141:Yes
# 27847 ->27847:Yes
# 8861 ->8861:Yes
# 19683 ->19683:Yes
# 33547 ->33547:No
# 38453 ->38453:Yes
# 44501 ->44501:Yes
# 50993 ->50993:Yes
# 20913 ->20913:Yes
# 4970 ->4970:No
# 92083 ->92083:Yes
# 38167 ->38167:Yes
# 52673 ->52673:Yes
# 6323 ->6323:Yes
# 15661 ->15661:Yes
# 82373 ->82373:Yes
# 33811 ->33811:Yes
# 64123 ->64123:Yes
# 57131 ->57131:Yes
# 64567 ->64567:Yes
# 37851 ->37851:Yes
# 24951 ->24951:Yes
# 38293 ->38293:Yes
# 39115 ->39115:Yes
# 19616 ->19616:No
# 23252 ->23252:No
# 67020 ->67020:No
# 769 ->769:Yes
# 22229 ->22229:Yes
# 63799 ->63799:Yes
# 98643 ->98643:Yes
# 79043 ->79043:Yes
# 5202 ->5202:No
# 90170 ->90170:No
# 47724 ->47724:No
# 70510 ->70510:No
# 38632 ->38632:No
# 83653 ->83653:Yes
# 37579 ->37579:Yes
# 87299 ->87299:Yes
# 71235 ->71235:Yes
# 70451 ->70451:Yes
# 54463 ->54463:Yes
# 87668 ->87668:No
# 97729 ->97729:Yes
# 57960 ->57960:No
# 17524 ->17524:No
# 94379 ->94379:Yes
# 56099 ->56099:Yes
# 30869 ->30869:Yes
# 92567 ->92567:Yes
# 62698 ->62698:No
# 48210 ->48210:No
# 3821 ->3821:Yes
# 2293 ->2293:Yes
# 73334 ->73334:No
# 9623 ->9623:Yes
# 46260 ->46260:No
# 5170 ->5170:No
# 2036 ->2036:No
# 96014 ->96014:No
# 17623 ->17623:Yes
# 22435 ->22435:Yes
# 29477 ->29477:Yes
# 25741 ->25741:Yes
# 31337 ->31337:Yes
# 41565 ->41565:Yes
# 88867 ->88867:Yes
# 93371 ->93371:Yes
# 69213 ->69213:Yes
# 83004 ->83004:No
# 3581 ->3581:Yes
# 69183 ->69183:Yes
# 5113 ->5113:Yes
# 4603 ->4603:Yes
# 17047 ->17047:Yes
# 41756 ->41756:No
# 1451 ->1451:Yes
# 29055 ->29055:Yes
# 32173 ->32173:Yes
# 28843 ->28843:Yes
# 42110 ->42110:No
# 93419 ->93419:Yes
# 95391 ->95391:Yes
# 26171 ->26171:Yes
# 653 ->653:Yes
# Received responses for batch 21 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 22 of 100
# # of prompts:  100 # of responses:  100
# 70858 ->70858:No
# 59453 ->59453:No
# 65921 ->65921:No
# 1693 ->1693:Yes
# 90031 ->90031:No
# 12750 ->12750:No
# 75474 ->75474:No
# 27583 ->27583:No
# 71081 ->71081:No
# 82763 ->82763:No
# 829 ->829:Yes
# 35768 ->35768:No
# 69428 ->69428:No
# 78467 ->78467:No
# 2939 ->2939:Yes
# 46851 ->46851:No
# 38299 ->38299:No
# 42519 ->42519:No
# 50632 ->50632:No
# 22738 ->22738:No
# 43957 ->43957:No
# 93628 ->93628:No
# 55875 ->55875:No
# 26119 ->26119:No
# 65918 ->65918:No
# 64698 ->64698:No
# 76061 ->76061:No
# 32509 ->32509:No
# 45979 ->45979:No
# 24763 ->24763:No
# 67286 ->67286:No
# 17502 ->17502:No
# 25094 ->25094:No
# 71861 ->71861:No
# 14983 ->14983:No
# 45216 ->45216:No
# 55633 ->55633:No
# 8803 ->8803:Yes
# 79781 ->79781:No
# 56881 ->56881:No
# 8819 ->8819:Yes
# 30631 ->30631:No
# 57558 ->57558:No
# 67918 ->67918:No
# 8747 ->8747:Yes
# 32570 ->32570:No
# 14281 ->14281:No
# 28403 ->28403:No
# 72503 ->72503:No
# 32371 ->32371:No
# 82891 ->82891:No
# 21001 ->21001:No
# 6062 ->6062:Yes
# 8269 ->8269:Yes
# 52363 ->52363:No
# 84913 ->84913:No
# 38740 ->38740:No
# 41863 ->41863:No
# 7103 ->7103:Yes
# 40405 ->40405:No
# 25609 ->25609:No
# 70939 ->70939:No
# 83515 ->83515:No
# 12919 ->12919:No
# 54667 ->54667:No
# 7738 ->7738:Yes
# 81239 ->81239:No
# 8093 ->8093:Yes
# 66567 ->66567:No
# 39309 ->39309:No
# 31707 ->31707:No
# 15172 ->15172:No
# 69829 ->69829:No
# 63727 ->63727:No
# 98101 ->98101:No
# 71411 ->71411:No
# 39203 ->39203:No
# 69341 ->69341:No
# 49220 ->49220:No
# 12225 ->12225:No
# 11020 ->11020:No
# 29129 ->29129:No
# 81394 ->81394:No
# 22032 ->22032:No
# 16272 ->16272:No
# 18831 ->18831:No
# 52760 ->52760:No
# 97029 ->97029:No
# 9184 ->9184:Yes
# 75181 ->75181:No
# 53411 ->53411:No
# 77868 ->77868:No
# 12841 ->12841:No
# 91099 ->91099:No
# 3089 ->3089:Yes
# 93319 ->93319:No
# 126 ->126:No
# 44736 ->44736:No
# 23378 ->23378:No
# 25107 ->25107:No
# Received responses for batch 22 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 23 of 100
# # of prompts:  100 # of responses:  100
# 25626 ->25626:No
# 73427 ->73427:No
# 20143 ->20143:No
# 28973 ->28973:No
# 11590 ->11590:No
# 13709 ->13709:No
# 54919 ->54919:No
# 62467 ->62467:No
# 78631 ->78631:No
# 49309 ->49309:No
# 93782 ->93782:No
# 47947 ->47947:No
# 95057 ->95057:No
# 32241 ->32241:No
# 90127 ->90127:No
# 13644 ->13644:No
# 50683 ->50683:No
# 15991 ->15991:No
# 63510 ->63510:No
# 15624 ->15624:No
# 89459 ->89459:No
# 85832 ->85832:No
# 98700 ->98700:No
# 10740 ->10740:No
# 2383 ->2383:No
# 45482 ->45482:No
# 72313 ->72313:No
# 37655 ->37655:No
# 55728 ->55728:No
# 85467 ->85467:No
# 22433 ->22433:No
# 81085 ->81085:No
# 48807 ->48807:No
# 36251 ->36251:No
# 26533 ->26533:No
# 80227 ->80227:No
# 70583 ->70583:No
# 95056 ->95056:No
# 36621 ->36621:No
# 7397 ->7397:No
# 1193 ->1193:No
# 69313 ->69313:No
# 40378 ->40378:No
# 50987 ->50987:No
# 71833 ->71833:No
# 26920 ->26920:No
# 52159 ->52159:No
# 99717 ->99717:No
# 32479 ->32479:No
# 87071 ->87071:No
# 42819 ->42819:No
# 76771 ->76771:No
# 65309 ->65309:No
# 95469 ->95469:No
# 40177 ->40177:No
# 14030 ->14030:No
# 39553 ->39553:No
# 54762 ->54762:No
# 33191 ->33191:No
# 4868 ->4868:No
# 20719 ->20719:No
# 71549 ->71549:No
# 77929 ->77929:No
# 54499 ->54499:No
# 41186 ->41186:No
# 42773 ->42773:No
# 62779 ->62779:No
# 91084 ->91084:No
# 2617 ->2617:No
# 12263 ->12263:No
# 17149 ->17149:No
# 71359 ->71359:No
# 6053 ->6053:No
# 6395 ->6395:No
# 57809 ->57809:No
# 74264 ->74264:No
# 71293 ->71293:No
# 29287 ->29287:No
# 13668 ->13668:No
# 47600 ->47600:No
# 7457 ->7457:No
# 61965 ->61965:No
# 89177 ->89177:No
# 89491 ->89491:No
# 21539 ->21539:No
# 7703 ->7703:No
# 35521 ->35521:No
# 44666 ->44666:No
# 36424 ->36424:No
# 72723 ->72723:No
# 87535 ->87535:No
# 22003 ->22003:No
# 72963 ->72963:No
# 92688 ->92688:No
# 94900 ->94900:No
# 72994 ->72994:No
# 12920 ->12920:No
# 29867 ->29867:No
# 69959 ->69959:No
# 23773 ->23773:No
# Received responses for batch 23 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 24 of 100
# # of prompts:  100 # of responses:  100
# 43661 ->43661:Yes
# 14320 ->14320:No
# 79617 ->79617:Yes
# 6422 ->6422:No
# 223 ->223:Yes
# 11353 ->11353:Yes
# 97768 ->97768:No
# 40883 ->40883:Yes
# 32956 ->32956:No
# 48131 ->48131:Yes
# 45596 ->45596:No
# 78699 ->78699:Yes
# 54101 ->54101:Yes
# 67481 ->67481:Yes
# 68737 ->68737:Yes
# 53959 ->53959:Yes
# 21481 ->21481:Yes
# 73974 ->73974:No
# 72707 ->72707:Yes
# 2719 ->2719:Yes
# 94520 ->94520:No
# 39953 ->39953:Yes
# 58481 ->58481:Yes
# 4073 ->4073:Yes
# 84221 ->84221:Yes
# 68476 ->68476:No
# 30902 ->30902:No
# 96452 ->96452:No
# 7961 ->7961:Yes
# 90071 ->90071:Yes
# 88414 ->88414:No
# 55509 ->55509:Yes
# 16433 ->16433:Yes
# 99901 ->99901:Yes
# 69019 ->69019:Yes
# 99644 ->99644:No
# 70061 ->70061:Yes
# 76253 ->76253:Yes
# 84920 ->84920:No
# 24956 ->24956:No
# 36637 ->36637:Yes
# 4451 ->4451:Yes
# 15920 ->15920:No
# 34894 ->34894:No
# 86556 ->86556:No
# 62057 ->62057:Yes
# 75619 ->75619:Yes
# 95131 ->95131:Yes
# 28283 ->28283:Yes
# 9095 ->9095:Yes
# 47736 ->47736:No
# 40360 ->40360:No
# 51917 ->51917:Yes
# 58734 ->58734:No
# 99635 ->99635:Yes
# 52157 ->52157:Yes
# 42528 ->42528:No
# 74156 ->74156:No
# 33675 ->33675:Yes
# 88793 ->88793:Yes
# 88976 ->88976:No
# 86771 ->86771:Yes
# 62401 ->62401:Yes
# 68863 ->68863:Yes
# 36343 ->36343:Yes
# 99938 ->99938:No
# 53593 ->53593:Yes
# 20185 ->20185:Yes
# 55903 ->55903:Yes
# 32369 ->32369:Yes
# 77191 ->77191:Yes
# 65437 ->65437:Yes
# 42331 ->42331:Yes
# 90073 ->90073:Yes
# 30172 ->30172:No
# 56719 ->56719:Yes
# 60689 ->60689:Yes
# 59029 ->59029:Yes
# 42370 ->42370:No
# 27611 ->27611:Yes
# 67024 ->67024:No
# 61458 ->61458:No
# 2791 ->2791:Yes
# 19887 ->19887:Yes
# 36696 ->36696:No
# 43577 ->43577:Yes
# 63227 ->63227:Yes
# 9341 ->9341:Yes
# 57512 ->57512:No
# 11498 ->11498:No
# 5239 ->5239:Yes
# 91529 ->91529:Yes
# 29532 ->29532:No
# 46153 ->46153:Yes
# 6913 ->6913:Yes
# 15277 ->15277:Yes
# 51314 ->51314:No
# 64555 ->64555:Yes
# 51058 ->51058:No
# 41263 ->41263:Yes
# Received responses for batch 24 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 25 of 100
# # of prompts:  100 # of responses:  100
# 39207 ->39207:No
# 24316 ->24316:No
# 75186 ->75186:No
# 97441 ->97441:No
# 59654 ->59654:No
# 80341 ->80341:No
# 56711 ->56711:No
# 16187 ->16187:No
# 92920 ->92920:No
# 73583 ->73583:No
# 30185 ->30185:No
# 71294 ->71294:No
# 49811 ->49811:No
# 84067 ->84067:No
# 68591 ->68591:No
# 11981 ->11981:No
# 36973 ->36973:No
# 7309 ->7309:No
# 92623 ->92623:No
# 22181 ->22181:No
# 52748 ->52748:No
# 59516 ->59516:No
# 67247 ->67247:No
# 9007 ->9007:No
# 54128 ->54128:No
# 20365 ->20365:No
# 17828 ->17828:No
# 92237 ->92237:No
# 61345 ->61345:No
# 6961 ->6961:No
# 59058 ->59058:No
# 23312 ->23312:No
# 13164 ->13164:No
# 29228 ->29228:No
# 41999 ->41999:No
# 75653 ->75653:No
# 7125 ->7125:No
# 23421 ->23421:No
# 8898 ->8898:No
# 39736 ->39736:No
# 60757 ->60757:No
# 46941 ->46941:No
# 31034 ->31034:No
# 59561 ->59561:No
# 47221 ->47221:No
# 12730 ->12730:No
# 32573 ->32573:No
# 20743 ->20743:No
# 68048 ->68048:No
# 1447 ->1447:No
# 30928 ->30928:No
# 7692 ->7692:No
# 94356 ->94356:No
# 15107 ->15107:No
# 18529 ->18529:No
# 3254 ->3254:No
# 39362 ->39362:No
# 32377 ->32377:No
# 25541 ->25541:No
# 42709 ->42709:No
# 45899 ->45899:No
# 21617 ->21617:No
# 88663 ->88663:No
# 14593 ->14593:No
# 53629 ->53629:No
# 89 ->89:No
# 62463 ->62463:No
# 71942 ->71942:No
# 2351 ->2351:No
# 27298 ->27298:No
# 52177 ->52177:No
# 61531 ->61531:No
# 15581 ->15581:No
# 71560 ->71560:No
# 97260 ->97260:No
# 34897 ->34897:No
# 887 ->887:No
# 7591 ->7591:No
# 68960 ->68960:No
# 47841 ->47841:No
# 37753 ->37753:No
# 18002 ->18002:No
# 69552 ->69552:No
# 92066 ->92066:No
# 87991 ->87991:No
# 17614 ->17614:No
# 4292 ->4292:No
# 57901 ->57901:No
# 64063 ->64063:No
# 419 ->419:No
# 2684 ->2684:No
# 56715 ->56715:No
# 8595 ->8595:No
# 41244 ->41244:No
# 77153 ->77153:No
# 56720 ->56720:No
# 11657 ->11657:No
# 71807 ->71807:No
# 19914 ->19914:No
# 59877 ->59877:No
# Received responses for batch 25 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 26 of 100
# # of prompts:  100 # of responses:  100
# 93623 ->93623:Yes
# 93549 ->93549:Yes
# 27886 ->27886:No
# 68683 ->68683:Yes
# 77587 ->77587:Yes
# 86038 ->86038:No
# 93154 ->93154:No
# 79031 ->79031:Yes
# 23539 ->23539:Yes
# 6779 ->6779:Yes
# 36787 ->36787:Yes
# 58189 ->58189:Yes
# 81399 ->81399:Yes
# 89933 ->89933:Yes
# 83635 ->83635:Yes
# 827 ->827:Yes
# 71503 ->71503:Yes
# 55403 ->55403:Yes
# 14503 ->14503:Yes
# 48998 ->48998:No
# 88003 ->88003:Yes
# 50332 ->50332:No
# 59260 ->59260:No
# 15676 ->15676:No
# 57487 ->57487:Yes
# 64231 ->64231:Yes
# 32318 ->32318:No
# 29449 ->29449:Yes
# 79329 ->79329:Yes
# 49711 ->49711:Yes
# 39401 ->39401:Yes
# 28541 ->28541:Yes
# 39113 ->39113:Yes
# 28087 ->28087:Yes
# 54419 ->54419:Yes
# 82997 ->82997:Yes
# 91199 ->91199:Yes
# 71658 ->71658:No
# 74731 ->74731:Yes
# 78803 ->78803:Yes
# 35468 ->35468:No
# 2861 ->2861:Yes
# 61667 ->61667:Yes
# 10589 ->10589:Yes
# 26691 ->26691:Yes
# 97591 ->97591:Yes
# 30707 ->30707:Yes
# ...
# 96562 ->96562:No
# 11257 ->11257:No
# 69457 ->69457:No
# 29635 ->29635:No
# 40933 ->40933:No
# 57649 ->57649:No
# 4933 ->4933:No
# 45389 ->45389:No
# 75524 ->75524:No
# 25847 ->25847:No
# 3914 ->3914:No
# 67733 ->67733:No
# 1663 ->1663:No
# 36583 ->36583:No
# 36137 ->36137:No
# 28408 ->28408:No
# 35803 ->35803:No
# 29423 ->29423:No
# 99083 ->99083:No
# 82903 ->82903:No
# 69403 ->69403:No
# 45201 ->45201:No
# 53737 ->53737:No
# 43190 ->43190:No
# 34871 ->34871:No
# 52711 ->52711:No
# 27851 ->27851:No
# 97957 ->97957:No
# 52057 ->52057:No
# 79039 ->79039:No
# Received responses for batch 92 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 93 of 100
# # of prompts:  100 # of responses:  100
# 87977 ->87977:Yes
# 10321 ->10321:Yes
# 52883 ->52883:Yes
# 25931 ->25931:Yes
# 58909 ->58909:Yes
# 71569 ->71569:Yes
# 44089 ->44089:Yes
# 73881 ->73881:Yes
# 75609 ->75609:Yes
# 4973 ->4973:Yes
# 80475 ->80475:Yes
# 39926 ->39926:No
# 42423 ->42423:Yes
# 27451 ->27451:Yes
# 40993 ->40993:Yes
# 27656 ->27656:No
# 54549 ->54549:Yes
# 26099 ->26099:Yes
# 13859 ->13859:Yes
# 23549 ->23549:Yes
# 77485 ->77485:Yes
# 4536 ->4536:No
# 81901 ->81901:Yes
# 73523 ->73523:Yes
# 97157 ->97157:Yes
# 5003 ->5003:Yes
# 51316 ->51316:No
# 36604 ->36604:No
# 70501 ->70501:Yes
# 78623 ->78623:Yes
# 7145 ->7145:Yes
# 92413 ->92413:Yes
# 33679 ->33679:Yes
# 67261 ->67261:Yes
# 59276 ->59276:No
# 75726 ->75726:No
# 11940 ->11940:No
# 83724 ->83724:No
# 20333 ->20333:Yes
# 63803 ->63803:Yes
# 74093 ->74093:Yes
# 8879 ->8879:Yes
# 33157 ->33157:Yes
# 84299 ->84299:Yes
# 70428 ->70428:No
# 9403 ->9403:Yes
# 5651 ->5651:Yes
# 22859 ->22859:Yes
# 36529 ->36529:Yes
# 56112 ->56112:No
# 87719 ->87719:Yes
# 64969 ->64969:Yes
# 78691 ->78691:Yes
# 7010 ->7010:Yes
# 69661 ->69661:Yes
# 95747 ->95747:Yes
# 43753 ->43753:Yes
# 8329 ->8329:Yes
# 66347 ->66347:Yes
# 72685 ->72685:Yes
# 36979 ->36979:Yes
# 50284 ->50284:No
# 9679 ->9679:Yes
# 73943 ->73943:Yes
# 46649 ->46649:Yes
# 34028 ->34028:No
# 27457 ->27457:Yes
# 98890 ->98890:No
# 80191 ->80191:Yes
# 44497 ->44497:Yes
# 8543 ->8543:Yes
# 27953 ->27953:Yes
# 42521 ->42521:Yes
# 6857 ->6857:Yes
# 68124 ->68124:No
# 11152 ->11152:No
# 46344 ->46344:No
# 76754 ->76754:No
# 34769 ->34769:Yes
# 50380 ->50380:No
# 67969 ->67969:Yes
# 99225 ->99225:Yes
# 78199 ->78199:Yes
# 44821 ->44821:Yes
# 26114 ->26114:No
# 65171 ->65171:Yes
# 77581 ->77581:Yes
# 45659 ->45659:Yes
# 85369 ->85369:Yes
# 38609 ->38609:Yes
# 85333 ->85333:Yes
# 28396 ->28396:No
# 6402 ->6402:No
# 72820 ->72820:No
# 12161 ->12161:Yes
# 41865 ->41865:Yes
# 18338 ->18338:No
# 4988 ->4988:No
# 22549 ->22549:Yes
# 98389 ->98389:Yes
# Received responses for batch 93 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 94 of 100
# # of prompts:  100 # of responses:  100
# 1213 ->1213:Yes
# 6487 ->6487:Yes
# 44893 ->44893:Yes
# 44648 ->44648:No
# 21019 ->21019:Yes
# 42967 ->42967:Yes
# 3166 ->3166:No
# 32993 ->32993:Yes
# 57704 ->57704:No
# 23599 ->23599:Yes
# 73113 ->73113:Yes
# 58511 ->58511:Yes
# 50431 ->50431:Yes
# 57552 ->57552:No
# 98939 ->98939:Yes
# 74178 ->74178:No
# 41001 ->41001:Yes
# 25920 ->25920:No
# 55051 ->55051:Yes
# 68790 ->68790:No
# 37799 ->37799:Yes
# 47807 ->47807:Yes
# 58657 ->58657:Yes
# 79462 ->79462:No
# 27361 ->27361:Yes
# 13455 ->13455:Yes
# 47053 ->47053:Yes
# 89712 ->89712:No
# 315 ->315:No
# 62633 ->62633:Yes
# 83855 ->83855:Yes
# 70157 ->70157:Yes
# 15808 ->15808:No
# 65719 ->65719:Yes
# 81363 ->81363:Yes
# 42721 ->42721:Yes
# 1184 ->1184:No
# 81359 ->81359:Yes
# 43714 ->43714:No
# 54144 ->54144:No
# 57727 ->57727:Yes
# 8844 ->8844:No
# 5418 ->5418:No
# 7523 ->7523:Yes
# 14707 ->14707:Yes
# 56618 ->56618:No
# 71511 ->71511:Yes
# 58115 ->58115:Yes
# 29573 ->29573:Yes
# 41696 ->41696:No
# 57847 ->57847:Yes
# 33589 ->33589:Yes
# 93763 ->93763:Yes
# 22189 ->22189:Yes
# 12343 ->12343:Yes
# 14207 ->14207:Yes
# 47310 ->47310:No
# 53793 ->53793:Yes
# 80015 ->80015:Yes
# 56821 ->56821:Yes
# 78261 ->78261:Yes
# 88247 ->88247:Yes
# 17519 ->17519:Yes
# 94317 ->94317:Yes
# 79613 ->79613:Yes
# 39588 ->39588:No
# 64763 ->64763:Yes
# 6282 ->6282:No
# 18013 ->18013:Yes
# 46936 ->46936:No
# 76421 ->76421:Yes
# 92714 ->92714:No
# 27283 ->27283:Yes
# 79829 ->79829:Yes
# 353 ->353:No
# 12241 ->12241:Yes
# 24179 ->24179:Yes
# 83561 ->83561:Yes
# 39139 ->39139:Yes
# 94477 ->94477:Yes
# 58229 ->58229:Yes
# 93607 ->93607:Yes
# 41751 ->41751:Yes
# 41443 ->41443:No
# 18148 ->18148:No
# 1367 ->1367:Yes
# 22790 ->22790:No
# 77719 ->77719:Yes
# 88801 ->88801:Yes
# 60735 ->60735:Yes
# 3067 ->3067:Yes
# 80142 ->80142:No
# 59865 ->59865:Yes
# 65909 ->65909:Yes
# 4230 ->4230:No
# 85831 ->85831:Yes
# 69576 ->69576:No
# 58804 ->58804:No
# 16091 ->16091:Yes
# 72893 ->72893:Yes
# Received responses for batch 94 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 95 of 100
# # of prompts:  100 # of responses:  100
# 70327 ->70327:Yes
# 86044 ->86044:No
# 25913 ->25913:Yes
# 77386 ->77386:No
# 87359 ->87359:Yes
# 23603 ->23603:Yes
# 56526 ->56526:No
# 24388 ->24388:No
# 68281 ->68281:Yes
# 54417 ->54417:Yes
# 81563 ->81563:Yes
# 71360 ->71360:No
# 91153 ->91153:Yes
# 72449 ->72449:Yes
# 86915 ->86915:Yes
# 6070 ->6070:No
# 36607 ->36607:Yes
# 67609 ->67609:Yes
# 12654 ->12654:No
# 89567 ->89567:Yes
# 10559 ->10559:Yes
# 55011 ->55011:Yes
# 18679 ->18679:Yes
# 25093 ->25093:Yes
# 47171 ->47171:Yes
# 80795 ->80795:Yes
# 6499 ->6499:Yes
# 69163 ->69163:Yes
# 19033 ->19033:Yes
# 38677 ->38677:Yes
# 2630 ->2630:No
# 95752 ->95752:No
# 98561 ->98561:Yes
# 15560 ->15560:No
# 19414 ->19414:No
# 64439 ->64439:Yes
# 79973 ->79973:Yes
# 98401 ->98401:Yes
# 53000 ->53000:No
# 49881 ->49881:Yes
# 98815 ->98815:Yes
# 23073 ->23073:Yes
# 55934 ->55934:No
# 90617 ->90617:Yes
# 94441 ->94441:Yes
# 42187 ->42187:Yes
# 40877 ->40877:Yes
# 5333 ->5333:Yes
# 14489 ->14489:Yes
# 87407 ->87407:Yes
# 87869 ->87869:Yes
# 12008 ->12008:No
# 73830 ->73830:No
# 63249 ->63249:Yes
# 89611 ->89611:Yes
# 45139 ->45139:Yes
# 10007 ->10007:Yes
# 13001 ->13001:Yes
# 93485 ->93485:Yes
# 89959 ->89959:Yes
# 50441 ->50441:Yes
# 73763 ->73763:Yes
# 6789 ->6789:Yes
# 66739 ->66739:Yes
# 20201 ->20201:Yes
# 79433 ->79433:Yes
# 12650 ->12650:No
# 31704 ->31704:No
# 9419 ->9419:Yes
# 76325 ->76325:Yes
# 72639 ->72639:Yes
# 76580 ->76580:No
# 91688 ->91688:No
# 58925 ->58925:Yes
# 3830 ->3830:No
# 72852 ->72852:No
# 9974 ->9974:No
# 61755 ->61755:Yes
# 92041 ->92041:Yes
# 53366 ->53366:No
# 85751 ->85751:Yes
# 18521 ->18521:Yes
# 22737 ->22737:Yes
# 81409 ->81409:Yes
# 46948 ->46948:No
# 36841 ->36841:Yes
# 13711 ->13711:Yes
# 95701 ->95701:Yes
# 95845 ->95845:Yes
# 57787 ->57787:Yes
# 30677 ->30677:Yes
# 47507 ->47507:Yes
# 80671 ->80671:Yes
# 43552 ->43552:No
# 12013 ->12013:Yes
# 57623 ->57623:Yes
# 8969 ->8969:Yes
# 11670 ->11670:No
# 381 ->381:No
# 48720 ->48720:No
# Received responses for batch 95 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 96 of 100
# # of prompts:  100 # of responses:  100
# 4423 ->4423:Yes
# 52778 ->52778:No
# 81619 ->81619:Yes
# 32707 ->32707:Yes
# 21139 ->21139:Yes
# 30307 ->30307:Yes
# 50551 ->50551:Yes
# 2081 ->2081:Yes
# 46039 ->46039:Yes
# 2243 ->2243:Yes
# 87151 ->87151:Yes
# 13647 ->13647:Yes
# 85880 ->85880:No
# 28901 ->28901:Yes
# 82483 ->82483:Yes
# 43331 ->43331:Yes
# 65023 ->65023:Yes
# 37989 ->37989:Yes
# 51133 ->51133:Yes
# 33985 ->33985:Yes
# 77785 ->77785:Yes
# 55054 ->55054:No
# 48706 ->48706:No
# 6027 ->6027:Yes
# 63771 ->63771:Yes
# 10891 ->10891:Yes
# 58907 ->58907:Yes
# 85531 ->85531:Yes
# 77017 ->77017:Yes
# 58038 ->58038:No
# 93218 ->93218:No
# 96763 ->96763:Yes
# 42792 ->42792:No
# 27191 ->27191:Yes
# 75603 ->75603:Yes
# 43970 ->43970:No
# 75821 ->75821:Yes
# 62507 ->62507:Yes
# 50310 ->50310:No
# 19699 ->19699:Yes
# 84817 ->84817:Yes
# 49228 ->49228:No
# 2745 ->2745:Yes
# 61612 ->61612:No
# 1632 ->1632:No
# 32141 ->32141:Yes
# 69193 ->69193:Yes
# 79839 ->79839:Yes
# 45236 ->45236:No
# 3373 ->3373:Yes
# 11951 ->11951:Yes
# 55459 ->55459:Yes
# 71333 ->71333:Yes
# 70820 ->70820:No
# 63139 ->63139:Yes
# 19301 ->19301:Yes
# 82947 ->82947:Yes
# 57097 ->57097:Yes
# 27799 ->27799:Yes
# 42929 ->42929:Yes
# 97306 ->97306:No
# 94825 ->94825:Yes
# 98467 ->98467:Yes
# 72658 ->72658:No
# 47644 ->47644:No
# 58463 ->58463:Yes
# 12338 ->12338:No
# 15402 ->15402:No
# 18307 ->18307:Yes
# 45677 ->45677:Yes
# 32143 ->32143:Yes
# 97678 ->97678:No
# 93463 ->93463:Yes
# 15901 ->15901:Yes
# 84179 ->84179:Yes
# 51767 ->51767:Yes
# 74851 ->74851:Yes
# 60237 ->60237:Yes
# 65408 ->65408:No
# 75844 ->75844:No
# 94422 ->94422:No
# 25163 ->25163:Yes
# 50101 ->50101:Yes
# 10169 ->10169:Yes
# 77280 ->77280:No
# 16822 ->16822:No
# 74891 ->74891:Yes
# 93077 ->93077:Yes
# 70823 ->70823:Yes
# 43319 ->43319:Yes
# 99160 ->99160:No
# 99510 ->99510:No
# 61906 ->61906:No
# 92681 ->92681:Yes
# 92959 ->92959:Yes
# 1243 ->1243:Yes
# 89113 ->89113:Yes
# 94761 ->94761:Yes
# 3257 ->3257:Yes
# 96149 ->96149:Yes
# Received responses for batch 96 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 97 of 100
# # of prompts:  100 # of responses:  100
# 49111 ->49111:Yes
# 40591 ->40591:Yes
# 85501 ->85501:Yes
# 79356 ->79356:No
# 5741 ->5741:Yes
# 24671 ->24671:Yes
# 34102 ->34102:No
# 78311 ->78311:Yes
# 22901 ->22901:Yes
# 77249 ->77249:Yes
# 87961 ->87961:Yes
# 92874 ->92874:No
# 86822 ->86822:No
# 87740 ->87740:No
# 18481 ->18481:Yes
# 40487 ->40487:Yes
# 94307 ->94307:Yes
# 83640 ->83640:No
# 883 ->883:Yes
# 8320 ->8320:No
# 26440 ->26440:No
# 46103 ->46103:Yes
# 15359 ->15359:Yes
# 11012 ->11012:No
# 70969 ->70969:Yes
# 34902 ->34902:No
# 12825 ->12825:Yes
# 753 ->753:Yes
# 8069 ->8069:Yes
# 87147 ->87147:Yes
# 12511 ->12511:Yes
# 78889 ->78889:Yes
# 14710 ->14710:No
# 33893 ->33893:Yes
# 11796 ->11796:No
# 34638 ->34638:No
# 60063 ->60063:Yes
# 86791 ->86791:Yes
# 6079 ->6079:Yes
# 79811 ->79811:Yes
# 45233 ->45233:Yes
# 39756 ->39756:No
# 79621 ->79621:Yes
# 15017 ->15017:Yes
# 56477 ->56477:Yes
# 93209 ->93209:Yes
# 85451 ->85451:Yes
# 28697 ->28697:Yes
# 98729 ->98729:Yes
# 58515 ->58515:Yes
# 65335 ->65335:Yes
# 9421 ->9421:Yes
# 14071 ->14071:Yes
# 73390 ->73390:No
# 95203 ->95203:Yes
# 35671 ->35671:Yes
# 21391 ->21391:Yes
# 78989 ->78989:Yes
# 78628 ->78628:No
# 2789 ->2789:Yes
# 36061 ->36061:Yes
# 5375 ->5375:Yes
# 74933 ->74933:Yes
# 72277 ->72277:Yes
# 50671 ->50671:Yes
# 30644 ->30644:No
# 80701 ->80701:Yes
# 29807 ->29807:Yes
# 37201 ->37201:Yes
# 98941 ->98941:Yes
# 36567 ->36567:Yes
# 86369 ->86369:Yes
# 51239 ->51239:Yes
# 21813 ->21813:Yes
# 28097 ->28097:Yes
# 64817 ->64817:Yes
# 7988 ->7988:No
# 97429 ->97429:Yes
# 32210 ->32210:No
# 1816 ->1816:No
# 18233 ->18233:Yes
# 32088 ->32088:No
# 76403 ->76403:Yes
# 47087 ->47087:Yes
# 27744 ->27744:No
# 78872 ->78872:No
# 87011 ->87011:Yes
# 91463 ->91463:Yes
# 48992 ->48992:No
# 11216 ->11216:No
# 15307 ->15307:Yes
# 55931 ->55931:Yes
# 71469 ->71469:Yes
# 41183 ->41183:Yes
# 62131 ->62131:Yes
# 24452 ->24452:No
# 65809 ->65809:Yes
# 17189 ->17189:Yes
# 40192 ->40192:No
# 37525 ->37525:Yes
# Received responses for batch 97 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 98 of 100
# # of prompts:  100 # of responses:  100
# 17223 ->17223:Yes
# 82019 ->82019:Yes
# 56208 ->56208:No
# 79841 ->79841:Yes
# 40231 ->40231:Yes
# 74390 ->74390:No
# 59539 ->59539:Yes
# 58890 ->58890:No
# 40597 ->40597:Yes
# 28858 ->28858:No
# 67939 ->67939:Yes
# 51511 ->51511:Yes
# 18371 ->18371:Yes
# 27031 ->27031:Yes
# 56431 ->56431:Yes
# 63553 ->63553:Yes
# 13789 ->13789:Yes
# 19373 ->19373:Yes
# 80285 ->80285:Yes
# 89346 ->89346:No
# 39285 ->39285:Yes
# 62330 ->62330:No
# 24373 ->24373:Yes
# 53891 ->53891:Yes
# 77134 ->77134:No
# 59611 ->59611:Yes
# 68334 ->68334:No
# 38547 ->38547:Yes
# 86851 ->86851:Yes
# 32911 ->32911:Yes
# 71707 ->71707:Yes
# 90191 ->90191:Yes
# 26849 ->26849:Yes
# 73670 ->73670:No
# 9535 ->9535:Yes
# 39704 ->39704:No
# 53047 ->53047:Yes
# 7710 ->7710:No
# 71879 ->71879:Yes
# 82510 ->82510:No
# 92503 ->92503:Yes
# 1940 ->1940:No
# 45691 ->45691:Yes
# 49477 ->49477:Yes
# 42322 ->42322:No
# 9887 ->9887:Yes
# 3809 ->3809:Yes
# 72032 ->72032:No
# 66938 ->66938:No
# 1279 ->1279:Yes
# 70177 ->70177:Yes
# 34603 ->34603:Yes
# 62827 ->62827:Yes
# 50665 ->50665:Yes
# 95917 ->95917:Yes
# 25303 ->25303:Yes
# 69122 ->69122:No
# 24264 ->24264:No
# 88799 ->88799:Yes
# 85639 ->85639:Yes
# 71858 ->71858:No
# 29483 ->29483:Yes
# 41189 ->41189:Yes
# 16164 ->16164:No
# 93493 ->93493:Yes
# 70504 ->70504:No
# 71926 ->71926:No
# 48677 ->48677:Yes
# 29009 ->29009:Yes
# 78929 ->78929:Yes
# 83563 ->83563:Yes
# 56724 ->56724:No
# 1473 ->1473:Yes
# 33151 ->33151:Yes
# 24239 ->24239:Yes
# 17659 ->17659:Yes
# 68609 ->68609:Yes
# 83035 ->83035:Yes
# 22594 ->22594:No
# 97112 ->97112:No
# 75722 ->75722:No
# 50329 ->50329:Yes
# 58441 ->58441:Yes
# 54469 ->54469:Yes
# 49493 ->49493:Yes
# 25104 ->25104:No
# 13693 ->13693:Yes
# 88425 ->88425:Yes
# 13284 ->13284:No
# 78226 ->78226:No
# 68389 ->68389:Yes
# 30086 ->30086:No
# 56003 ->56003:Yes
# 78350 ->78350:No
# 89561 ->89561:Yes
# 24697 ->24697:Yes
# 95676 ->95676:No
# 19477 ->19477:Yes
# 86205 ->86205:Yes
# 43793 ->43793:Yes
# Received responses for batch 98 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 99 of 100
# # of prompts:  100 # of responses:  100
# 99823 ->99823:No
# 73277 ->73277:No
# 28837 ->28837:No
# 37181 ->37181:No
# 19753 ->19753:No
# 34031 ->34031:No
# 16205 ->16205:No
# 14533 ->14533:No
# 3096 ->3096:No
# 76678 ->76678:No
# 9787 ->9787:No
# 48391 ->48391:No
# 36871 ->36871:No
# 33427 ->33427:No
# 79687 ->79687:No
# 84181 ->84181:No
# 58844 ->58844:No
# 85196 ->85196:No
# 26632 ->26632:No
# 14678 ->14678:No
# 22132 ->22132:No
# 13174 ->13174:No
# 85517 ->85517:No
# 74448 ->74448:No
# 54377 ->54377:No
# 31927 ->31927:No
# 92342 ->92342:No
# 59357 ->59357:No
# 22039 ->22039:No
# 78227 ->78227:No
# 70273 ->70273:No
# 91387 ->91387:No
# 32633 ->32633:No
# 58472 ->58472:No
# 49411 ->49411:No
# 74250 ->74250:No
# 68437 ->68437:No
# 86857 ->86857:No
# 51323 ->51323:No
# 97367 ->97367:No
# 89839 ->89839:No
# 7243 ->7243:No
# 95825 ->95825:No
# 43540 ->43540:No
# 53639 ->53639:No
# 22807 ->22807:No
# 39849 ->39849:No
# 57322 ->57322:No
# 94066 ->94066:No
# 61001 ->61001:No
# 86521 ->86521:No
# 25278 ->25278:No
# 44491 ->44491:No
# 42729 ->42729:No
# 259 ->259:No
# 85243 ->85243:No
# 15342 ->15342:No
# 29453 ->29453:No
# 12011 ->12011:No
# 99455 ->99455:No
# 75989 ->75989:No
# 25222 ->25222:No
# 76697 ->76697:No
# 21859 ->21859:No
# 50454 ->50454:No
# 68543 ->68543:No
# 29250 ->29250:No
# 23753 ->23753:No
# 13721 ->13721:No
# 50045 ->50045:No
# 80221 ->80221:No
# 76160 ->76160:No
# 75029 ->75029:No
# 77477 ->77477:No
# 40464 ->40464:No
# 66301 ->66301:No
# 61874 ->61874:No
# 99567 ->99567:No
# 66881 ->66881:No
# 27261 ->27261:No
# 69222 ->69222:No
# 6829 ->6829:No
# 75188 ->75188:No
# 77905 ->77905:No
# 91969 ->91969:No
# 72103 ->72103:No
# 66533 ->66533:No
# 45763 ->45763:No
# 93809 ->93809:No
# 6954 ->6954:No
# 98135 ->98135:No
# 64013 ->64013:No
# 96323 ->96323:No
# 12388 ->12388:No
# 58767 ->58767:No
# 44787 ->44787:No
# 92031 ->92031:No
# 36278 ->36278:No
# 21803 ->21803:No
# 22396 ->22396:No
# Received responses for batch 99 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 100 of 100
# # of prompts:  100 # of responses:  100
# 49091 ->49091:Yes
# 82141 ->82141:Yes
# 26203 ->26203:Yes
# 70019 ->70019:Yes
# 6803 ->6803:Yes
# 25251 ->25251:Yes
# 84598 ->84598:No
# 80862 ->80862:No
# 55829 ->55829:Yes
# 51834 ->51834:No
# 54891 ->54891:Yes
# 43591 ->43591:Yes
# 11093 ->11093:Yes
# 22481 ->22481:Yes
# 24326 ->24326:No
# 59647 ->59647:Yes
# 63703 ->63703:Yes
# 49331 ->49331:Yes
# 77983 ->77983:Yes
# 3482 ->3482:No
# 49739 ->49739:Yes
# 56768 ->56768:No
# 1091 ->1091:Yes
# 21080 ->21080:No
# 62594 ->62594:No
# 69029 ->69029:Yes
# 59197 ->59197:Yes
# 30178 ->30178:No
# 95009 ->95009:Yes
# 31249 ->31249:Yes
# 95327 ->95327:Yes
# 48353 ->48353:Yes
# 91892 ->91892:No
# 63004 ->63004:No
# 24443 ->24443:Yes
# 64491 ->64491:Yes
# 26095 ->26095:Yes
# 66041 ->66041:Yes
# 33921 ->33921:Yes
# 46327 ->46327:Yes
# 269 ->269:Yes
# 87251 ->87251:Yes
# 3361 ->3361:Yes
# 36929 ->36929:Yes
# 79333 ->79333:Yes
# 2393 ->2393:Yes
# 51481 ->51481:Yes
# 56521 ->56521:Yes
# 3545 ->3545:Yes
# 83477 ->83477:Yes
# 67561 ->67561:Yes
# 82457 ->82457:Yes
# 49435 ->49435:Yes
# 93253 ->93253:Yes
# 79581 ->79581:Yes
# 12153 ->12153:Yes
# 43991 ->43991:Yes
# 71257 ->71257:Yes
# 59670 ->59670:No
# 94641 ->94641:Yes
# 18621 ->18621:Yes
# 94583 ->94583:Yes
# 90546 ->90546:No
# 22637 ->22637:Yes
# 7213 ->7213:Yes
# 71401 ->71401:Yes
# 98773 ->98773:Yes
# 52837 ->52837:Yes
# 24197 ->24197:Yes
# 51015 ->51015:Yes
# 66591 ->66591:Yes
# 4957 ->4957:Yes
# 26251 ->26251:Yes
# 56813 ->56813:Yes
# 47984 ->47984:No
# 88746 ->88746:No
# 81929 ->81929:Yes
# 31943 ->31943:Yes
# 52665 ->52665:Yes
# 86117 ->86117:Yes
# 45984 ->45984:No
# 80363 ->80363:Yes
# 17185 ->17185:Yes
# 53420 ->53420:No
# 44449 ->44449:Yes
# 89527 ->89527:Yes
# 49871 ->49871:Yes
# 44029 ->44029:Yes
# 1567 ->1567:Yes
# 79429 ->79429:Yes
# 41250 ->41250:No
# 28933 ->28933:Yes
# 78113 ->78113:Yes
# 12239 ->12239:Yes
# 87547 ->87547:Yes
# 26339 ->26339:Yes
# 33533 ->33533:Yes
# 7321 ->7321:Yes
# 28349 ->28349:Yes
# 87629 ->87629:Yes
# Received responses for batch 100 of 100
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Responses saved to gemini_response/ask_prime_response.txt

# %% [markdown]
# # get ask factor response from gemini

# %%
# !pip install -q -U google-generativeai
# !pip install python-dotenv

# %%
import os
from dotenv import load_dotenv
import random
import time
import json
import google.generativeai as genai

# %% [markdown]
# ### load model

# %%
load_dotenv()
GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
gemini = genai.GenerativeModel('gemini-pro')

# %% [markdown]
# ### load data and create initial prompt

# %%
with open('../../data/primality_test.json','r') as file:
    data = json.load(file)
primes = data['primes']
composites = data['composites']

# mix primes and composites so model is not biased
data = primes + composites
random.seed(42)
random.shuffle(data)

# create batches, batch sizes are heuristics
# batch sizes, although input token limit is 30,720 tokens, output token limit is 2048
# which restricts the batch size

batch_prompts = []
BATCH_SIZE = 25
index = 0

while index < len(data):
    batch = [data[i] for i in range(index, min(index+BATCH_SIZE, len(data)))]
    batch_prompts.append(batch)
    index += BATCH_SIZE
    
print("Number of batches:", len(batch_prompts))
print("Number of prompts in each batch:", [len(batch) for batch in batch_prompts])
# Out:
# Number of batches: 400
# Number of prompts in each batch: [25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25]

# %%
# give a prompt once and then generate the response,
# and then use this prompt+response directly instead of doing everytime

promt_saying_you_are_a_math_assistant = '''You are a math assistant. I will ask you some questions. Please answer in the correct format. For example, if I ask 'What are the factors of 15?' , you should answer 'Factors of 15 = [1, 3, 5, 15]. Each question is in a separate line. Please return each answer in a separate line. Do you understand ?'''
Initial_messages = [{'role':'user', 'parts': [promt_saying_you_are_a_math_assistant] }]

# get response from the model and then append it to the prompt
Initial_response = gemini.generate_content(Initial_messages)                                   
Initial_messages.append(Initial_response.candidates[0].content)

# %%
print(Initial_messages)
# Out:
# [{'role': 'user', 'parts': ["You are a math assistant. I will ask you some questions. Please answer in the correct format. For example, if I ask 'What are the factors of 15?' , you should answer 'Factors of 15 = [1, 3, 5, 15]. Each question is in a separate line. Please return each answer in a separate line. Do you understand ?"]}, parts {
#   text: "Yes, I understand. I will answer your math questions in the correct format, providing the factors in a list like this: Factors of 15 = [1, 3, 5, 15]."
# }
# role: "model"
# ]

# %%
import pickle

# save the initial messages to a file, in case we need to restart the conversation, initial message should be consistent
# across all batches

with open('initial_messages_factors.pkl', 'wb') as file:
    pickle.dump(Initial_messages, file)

# %% [markdown]
# ### conduct experiment

# %%
# path to save responses
response_file = 'gemini_response/factors_response.txt'

# request per minute limit for free api
rpm = 60

# %%
# to start from a specific batch number, give printed_batch_num -1 here
batch_no_to_start_from = 0

for i, batch_prompt in enumerate(batch_prompts):

    if i < batch_no_to_start_from:
        continue

    # print status
    print(f"Sending batch {i+1} of {len(batch_prompts)}")

    num_prompts = len(batch_prompt)

    # create prompt for the batch
    curr_prompt = "".join([f"What are the factors of {prompt}?\n" for prompt in batch_prompt])

    
    # create a complete prompt to send to the model
    complete_promt = Initial_messages.copy()
    complete_promt.append({'role':'user', 'parts': [curr_prompt]})

    # get response from the model, candidate_count is 1 because we only need one response,
    # temperature is 0 because we need deterministic responses
    response = gemini.generate_content( complete_promt,
                                        generation_config= genai.GenerationConfig(
                                        candidate_count = 1,
                                        temperature = 0.0,
                                        )
                                )
    
    try:
        # extract text from the response
        model_responses = response.candidates[0].content.parts.__getitem__(0).text.split('\n')
    except IndexError:
        time.sleep(5)
        # get response from the model, candidate_count is 1 because we only need one response,
        # temperature is 0 because we need deterministic responses
        response = gemini.generate_content( complete_promt,
                                            generation_config= genai.GenerationConfig(
                                            candidate_count = 1,
                                            temperature = 0.0,
                                            )
                                    )
        
        try:
            # extract text from the response
            model_responses = response.candidates[0].content.parts.__getitem__(0).text.split('\n')
        except IndexError:
            # if model gives no response, fill with 0
            print("Error in response")
            model_responses = ["0"]*num_prompts

    # save responses to file
    with open(response_file, 'a') as file:
        for model_response in model_responses:
            file.write(model_response + '\n')

    
    #print the prompt and response separated by space
    print('# of prompts: ',len(batch_prompt),'# of responses: ', len(model_responses))


    for prompt, response in zip(batch_prompt, model_responses):
        print(prompt, response, sep=" ->")
    
    
    print("Received responses for batch", i+1, "of", len(batch_prompts))
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")

    time.sleep(60//rpm) #to avoid rate limit errors

print("Responses saved to", response_file)
# Out:
# Sending batch 1 of 400
# # of prompts:  25 # of responses:  25
# 54631 ->Factors of 54631 = [1, 54631]
# 22092 ->Factors of 22092 = [1, 2, 3, 4, 6, 12, 1831, 3662, 5493, 11046, 22092]
# 99194 ->Factors of 99194 = [1, 2, 7, 14, 7085, 14170, 49597, 99194]
# 85213 ->Factors of 85213 = [1, 85213]
# 81041 ->Factors of 81041 = [1, 81041]
# 81371 ->Factors of 81371 = [1, 81371]
# 2807 ->Factors of 2807 = [1, 2807]
# 91499 ->Factors of 91499 = [1, 91499]
# 96079 ->Factors of 96079 = [1, 96079]
# 17593 ->Factors of 17593 = [1, 17593]
# 70181 ->Factors of 70181 = [1, 70181]
# 47521 ->Factors of 47521 = [1, 3, 7, 11, 13, 21, 33, 39, 77, 143, 361, 613, 1221, 2261, 3673, 4369, 15843, 47521]
# 86717 ->Factors of 86717 = [1, 86717]
# 89882 ->Factors of 89882 = [1, 2, 3, 6, 14980, 29961, 44941, 89882]
# 34403 ->Factors of 34403 = [1, 34403]
# 61530 ->Factors of 61530 = [1, 2, 3, 5, 6, 10, 15, 30, 2051, 4102, 6153, 12306, 20510, 30765, 61530]
# 40093 ->Factors of 40093 = [1, 40093]
# 3547 ->Factors of 3547 = [1, 3547]
# 89293 ->Factors of 89293 = [1, 89293]
# 46349 ->Factors of 46349 = [1, 46349]
# 31147 ->Factors of 31147 = [1, 31147]
# 61782 ->Factors of 61782 = [1, 2, 3, 6, 10297, 20594, 30891, 61782]
# 72469 ->Factors of 72469 = [1, 72469]
# 71153 ->Factors of 71153 = [1, 71153]
# 5900 ->Factors of 5900 = [1, 2, 4, 5, 10, 20, 295, 590, 1180, 1475, 2950, 5900]
# Received responses for batch 1 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 2 of 400
# # of prompts:  25 # of responses:  25
# 91616 ->Factors of 91616 = [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 45808, 91616]
# 74131 ->Factors of 74131 = [1, 7, 10593, 74131]
# 98547 ->Factors of 98547 = [1, 3, 9, 10949, 29563, 98547]
# 58427 ->Factors of 58427 = [1, 58427]
# 43872 ->Factors of 43872 = [1, 2, 3, 4, 6, 8, 12, 16, 24, 32, 48, 96, 1367, 2734, 3603, 5468, 7206, 10936, 14412, 21872, 43872]
# 35449 ->Factors of 35449 = [1, 7, 5064, 35449]
# 41188 ->Factors of 41188 = [1, 2, 3, 4, 6, 12, 3432, 6864, 10296, 13728, 20592, 41188]
# 25997 ->Factors of 25997 = [1, 29, 896, 25997]
# 95603 ->Factors of 95603 = [1, 95603]
# 14434 ->Factors of 14434 = [1, 2, 7, 14, 1031, 2062, 7217, 14434]
# 32063 ->Factors of 32063 = [1, 32063]
# 90264 ->Factors of 90264 = [1, 2, 3, 4, 6, 8, 12, 16, 24, 32, 48, 96, 947, 1894, 2841, 3788, 5682, 7576, 11364, 15152, 22728, 30304, 45456, 90264]
# 373 ->Factors of 373 = [1, 373]
# 80933 ->Factors of 80933 = [1, 80933]
# 14321 ->Factors of 14321 = [1, 11, 1302, 14321]
# 24379 ->Factors of 24379 = [1, 24379]
# 93557 ->Factors of 93557 = [1, 93557]
# 10687 ->Factors of 10687 = [1, 10687]
# 43983 ->Factors of 43983 = [1, 3, 9, 4898, 14661, 43983]
# 62718 ->Factors of 62718 = [1, 2, 3, 6, 10537, 21074, 31611, 62718]
# 62141 ->Factors of 62141 = [1, 62141]
# 41687 ->Factors of 41687 = [1, 41687]
# 17123 ->Factors of 17123 = [1, 17123]
# 62347 ->Factors of 62347 = [1, 62347]
# 81701 ->Factors of 81701 = [1, 81701]
# Received responses for batch 2 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 3 of 400
# # of prompts:  25 # of responses:  25
# 84451 ->Factors of 84451 = [1, 7, 11, 13, 653, 1207, 7159, 12187, 64919, 84451]
# 19762 ->Factors of 19762 = [1, 2, 9881, 19762]
# 42437 ->Factors of 42437 = [1, 42437]
# 5709 ->Factors of 5709 = [1, 3, 1903, 5709]
# 60948 ->Factors of 60948 = [1, 2, 3, 4, 6, 12, 5079, 10158, 15237, 20316, 30474, 60948]
# 6870 ->Factors of 6870 = [1, 2, 3, 5, 6, 7, 10, 14, 15, 21, 30, 35, 42, 70, 98, 105, 165, 231, 330, 497, 687, 984, 1374, 2290, 3435, 6870]
# 38713 ->Factors of 38713 = [1, 38713]
# 18160 ->Factors of 18160 = [1, 2, 4, 5, 8, 10, 16, 20, 40, 80, 227, 454, 908, 1135, 1816, 2270, 3632, 4540, 9080, 18160]
# 64747 ->Factors of 64747 = [1, 64747]
# 22608 ->Factors of 22608 = [1, 2, 3, 4, 6, 8, 12, 16, 24, 32, 48, 96, 235, 470, 705, 940, 1410, 1880, 2820, 3760, 5640, 11280, 22608]
# 20207 ->Factors of 20207 = [1, 20207]
# 62927 ->Factors of 62927 = [1, 62927]
# 36833 ->Factors of 36833 = [1, 36833]
# 63375 ->Factors of 63375 = [1, 3, 5, 15, 21, 75, 841, 3003, 4205, 12675, 21055, 63375]
# 17182 ->Factors of 17182 = [1, 2, 3, 6, 2863, 5727, 17182]
# 75611 ->Factors of 75611 = [1, 75611]
# 17279 ->Factors of 17279 = [1, 17279]
# 99809 ->Factors of 99809 = [1, 99809]
# 12391 ->Factors of 12391 = [1, 12391]
# 39844 ->Factors of 39844 = [1, 2, 4, 9961, 19922, 39844]
# 91180 ->Factors of 91180 = [1, 2, 4, 5, 10, 20, 4567, 9134, 18268, 45670, 91180]
# 39409 ->Factors of 39409 = [1, 39409]
# 79504 ->Factors of 79504 = [1, 2, 4, 8, 9938, 19876, 39752, 79504]
# 45289 ->Factors of 45289 = [1, 45289]
# 70241 ->Factors of 70241 = [1, 70241]
# Received responses for batch 3 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 4 of 400
# # of prompts:  25 # of responses:  25
# 59971 ->Factors of 59971 = [1, 59971]
# 39899 ->Factors of 39899 = [1, 39899]
# 47032 ->Factors of 47032 = [1, 2, 4, 8, 5879, 11758, 23516, 47032]
# 22182 ->Factors of 22182 = [1, 2, 10901, 22182]
# 25825 ->Factors of 25825 = [1, 5, 13, 195, 1327, 25825]
# 43344 ->Factors of 43344 = [1, 2, 3, 4, 6, 8, 12, 16, 24, 32, 48, 96, 1363, 2726, 3584, 5452, 8668, 10904, 17336, 21808, 43344]
# 54871 ->Factors of 54871 = [1, 54871]
# 38643 ->Factors of 38643 = [1, 3, 9, 4293, 12881, 38643]
# 34651 ->Factors of 34651 = [1, 34651]
# 23337 ->Factors of 23337 = [1, 3, 7849, 23337]
# 47161 ->Factors of 47161 = [1, 47161]
# 45391 ->Factors of 45391 = [1, 45391]
# 8829 ->Factors of 8829 = [1, 3, 2943, 8829]
# 12613 ->Factors of 12613 = [1, 12613]
# 22937 ->Factors of 22937 = [1, 22937]
# 98453 ->Factors of 98453 = [1, 98453]
# 56239 ->Factors of 56239 = [1, 56239]
# 7537 ->Factors of 7537 = [1, 7537]
# 57467 ->Factors of 57467 = [1, 57467]
# 59851 ->Factors of 59851 = [1, 59851]
# 61733 ->Factors of 61733 = [1, 61733]
# 11171 ->Factors of 11171 = [1, 11171]
# 33309 ->Factors of 33309 = [1, 3, 11103, 33309]
# 23197 ->Factors of 23197 = [1, 23197]
# 48476 ->Factors of 48476 = [1, 2, 4, 12119, 24238, 48476]
# Received responses for batch 4 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 5 of 400
# # of prompts:  25 # of responses:  25
# 73305 ->Factors of 73305 = [1, 3, 5, 15, 4887, 15195, 24435, 73305]
# 23632 ->Factors of 23632 = [1, 2, 4, 8, 16, 32, 739, 1478, 2956, 5912, 11824, 23632]
# 33249 ->Factors of 33249 = [1, 3, 7, 9, 21, 63, 529, 1587, 3693, 11081, 33249]
# 57713 ->Factors of 57713 = [1, 13, 4439, 57713]
# 77213 ->Factors of 77213 = [1, 7, 11, 77, 1003, 77213]
# 43154 ->Factors of 43154 = [1, 2, 21577, 43154]
# 9585 ->Factors of 9585 = [1, 3, 5, 15, 639, 1917, 3195, 9585]
# 84070 ->Factors of 84070 = [1, 2, 5, 10, 17, 34, 68, 85, 989, 1700, 2445, 4945, 8407, 16814, 42035, 84070]
# 29344 ->Factors of 29344 = [1, 2, 4, 8, 16, 32, 913, 1826, 3652, 7304, 14608, 29344]
# 20480 ->Factors of 20480 = [1, 2, 4, 5, 8, 10, 16, 20, 40, 80, 256, 512, 1024, 1280, 2048, 4096, 5120, 10240, 20480]
# 28661 ->Factors of 28661 = [1, 23, 1246, 28661]
# 47129 ->Factors of 47129 = [1, 17, 2772, 47129]
# 62500 ->Factors of 62500 = [1, 2, 4, 5, 10, 20, 25, 50, 100, 625, 1250, 2500, 3125, 6250, 12500, 15625, 31250, 62500]
# 81773 ->Factors of 81773 = [1, 81773]
# 50383 ->Factors of 50383 = [1, 59, 854, 50383]
# 61561 ->Factors of 61561 = [1, 61561]
# 71839 ->Factors of 71839 = [1, 71839]
# 76537 ->Factors of 76537 = [1, 76537]
# 49707 ->Factors of 49707 = [1, 3, 16569, 49707]
# 7489 ->Factors of 7489 = [1, 7, 1070, 7489]
# 72539 ->Factors of 72539 = [1, 72539]
# 89441 ->Factors of 89441 = [1, 89441]
# 7482 ->Factors of 7482 = [1, 2, 3, 6, 1237, 2474, 3741, 7482]
# 7278 ->Factors of 7278 = [1, 2, 3, 6, 1213, 2426, 3639, 7278]
# 40829 ->Factors of 40829 = [1, 40829]
# Received responses for batch 5 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 6 of 400
# # of prompts:  25 # of responses:  25
# 40696 ->Factors of 40696 = [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 10241, 20482, 40696]
# 83063 ->Factors of 83063 = [1, 83063]
# 77699 ->Factors of 77699 = [1, 77699]
# 95894 ->Factors of 95894 = [1, 2, 7, 14, 6843, 13686, 95894]
# 29990 ->Factors of 29990 = [1, 2, 5, 10, 2999, 5998, 14995, 29990]
# 31444 ->Factors of 31444 = [1, 2, 4, 7861, 15722, 31444]
# 4019 ->Factors of 4019 = [1, 11, 365, 4019]
# 48126 ->Factors of 48126 = [1, 2, 3, 6, 8021, 16042, 24063, 48126]
# 48883 ->Factors of 48883 = [1, 48883]
# 90533 ->Factors of 90533 = [1, 90533]
# 73013 ->Factors of 73013 = [1, 73013]
# 45551 ->Factors of 45551 = [1, 45551]
# 74309 ->Factors of 74309 = [1, 74309]
# 86573 ->Factors of 86573 = [1, 86573]
# 29241 ->Factors of 29241 = [1, 3, 9747, 29241]
# 42953 ->Factors of 42953 = [1, 42953]
# 65213 ->Factors of 65213 = [1, 65213]
# 84731 ->Factors of 84731 = [1, 84731]
# 25447 ->Factors of 25447 = [1, 25447]
# 55650 ->Factors of 55650 = [1, 2, 3, 5, 6, 9, 10, 15, 18, 30, 45, 911, 1822, 3037, 5475, 11130, 16695, 27825, 55650]
# 40733 ->Factors of 40733 = [1, 40733]
# 86579 ->Factors of 86579 = [1, 86579]
# 96367 ->Factors of 96367 = [1, 96367]
# 66364 ->Factors of 66364 = [1, 2, 4, 16641, 33282, 66364]
# 60169 ->Factors of 60169 = [1, 60169]
# Received responses for batch 6 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 7 of 400
# # of prompts:  25 # of responses:  25
# 88513 ->Factors of 88513 = [1, 7, 12645, 88513]
# 39157 ->Factors of 39157 = [1, 39157]
# 70299 ->Factors of 70299 = [1, 3, 7, 11, 6391, 23433, 70299]
# 22921 ->Factors of 22921 = [1, 22921]
# 2857 ->Factors of 2857 = [1, 2857]
# 68642 ->Factors of 68642 = [1, 2, 34321, 68642]
# 82285 ->Factors of 82285 = [1, 5, 16457, 82285]
# 16464 ->Factors of 16464 = [1, 2, 3, 4, 6, 8, 12, 13, 24, 26, 52, 53, 104, 106, 156, 312, 624, 1248, 1372, 2080, 4160, 8232, 16464]
# 28609 ->Factors of 28609 = [1, 28609]
# 6376 ->Factors of 6376 = [1, 2, 4, 8, 16, 32, 199, 398, 796, 1592, 3184, 6376]
# 41750 ->Factors of 41750 = [1, 2, 5, 10, 25, 50, 835, 1670, 2087, 4174, 8348, 10435, 20870, 41750]
# 19688 ->Factors of 19688 = [1, 2, 4, 8, 16, 32, 615, 1230, 2460, 4920, 9844, 19688]
# 27691 ->Factors of 27691 = [1, 27691]
# 67211 ->Factors of 67211 = [1, 67211]
# 76917 ->Factors of 76917 = [1, 3, 7, 11, 21, 33, 69, 231, 363, 726, 1111, 2331, 3693, 10937, 21874, 76917]
# 22259 ->Factors of 22259 = [1, 3, 7419, 22259]
# 137 ->Factors of 137 = [1, 137]
# 54617 ->Factors of 54617 = [1, 54617]
# 14924 ->Factors of 14924 = [1, 2, 4, 3731, 7462, 14924]
# 68345 ->Factors of 68345 = [1, 5, 13669, 68345]
# 92020 ->Factors of 92020 = [1, 2, 4, 5, 10, 20, 4601, 9202, 18404, 46010, 92020]
# 82517 ->Factors of 82517 = [1, 82517]
# 1946 ->Factors of 1946 = [1, 2, 973, 1946]
# 74751 ->Factors of 74751 = [1, 74751]
# 15233 ->Factors of 15233 = [1, 15233]
# Received responses for batch 7 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 8 of 400
# # of prompts:  25 # of responses:  25
# 68351 ->Factors of 68351 = [1, 68351]
# 58659 ->Factors of 58659 = [1, 3, 19553, 58659]
# 17207 ->Factors of 17207 = [1, 17207]
# 50156 ->Factors of 50156 = [1, 2, 4, 12539, 25078, 50156]
# 86996 ->Factors of 86996 = [1, 2, 4, 21749, 43498, 86996]
# 62753 ->Factors of 62753 = [1, 62753]
# 39989 ->Factors of 39989 = [1, 39989]
# 33347 ->Factors of 33347 = [1, 33347]
# 44537 ->Factors of 44537 = [1, 44537]
# 22567 ->Factors of 22567 = [1, 22567]
# 86509 ->Factors of 86509 = [1, 86509]
# 74573 ->Factors of 74573 = [1, 74573]
# 1227 ->Factors of 1227 = [1, 3, 11, 37, 111, 1227]
# 72078 ->Factors of 72078 = [1, 2, 3, 6, 12113, 24226, 36339, 72078]
# 15655 ->Factors of 15655 = [1, 5, 3131, 15655]
# 41039 ->Factors of 41039 = [1, 41039]
# 43876 ->Factors of 43876 = [1, 2, 4, 10969, 21938, 43876]
# 29411 ->Factors of 29411 = [1, 29411]
# 66741 ->Factors of 66741 = [1, 3, 22247, 66741]
# 19078 ->Factors of 19078 = [1, 2, 9539, 19078]
# 45217 ->Factors of 45217 = [1, 45217]
# 751 ->Factors of 751 = [1, 7, 107, 751]
# 42337 ->Factors of 42337 = [1, 42337]
# 42343 ->Factors of 42343 = [1, 42343]
# 3027 ->Factors of 3027 = [1, 3, 9, 337, 1009, 3027]
# Received responses for batch 8 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 9 of 400
# # of prompts:  25 # of responses:  25
# 78416 ->Factors of 78416 = [1, 2, 4, 8, 9702, 19404, 39208, 78416]
# 36224 ->Factors of 36224 = [1, 2, 4, 8, 16, 2264, 4528, 9056, 18112, 36224]
# 23677 ->Factors of 23677 = [1, 23677]
# 33304 ->Factors of 33304 = [1, 2, 4, 8, 16, 32, 1037, 2074, 4148, 8296, 16592, 33304]
# 48193 ->Factors of 48193 = [1, 48193]
# 47569 ->Factors of 47569 = [1, 47569]
# 30403 ->Factors of 30403 = [1, 30403]
# 33627 ->Factors of 33627 = [1, 3, 9, 3736, 11209, 33627]
# 87128 ->Factors of 87128 = [1, 2, 4, 8, 10941, 21882, 43764, 87128]
# 58129 ->Factors of 58129 = [1, 58129]
# 90218 ->Factors of 90218 = [1, 2, 7, 14, 6444, 12888, 45109, 90218]
# 56141 ->Factors of 56141 = [1, 56141]
# 59663 ->Factors of 59663 = [1, 59663]
# 51111 ->Factors of 51111 = [1, 51111]
# 97073 ->Factors of 97073 = [1, 97073]
# 55663 ->Factors of 55663 = [1, 55663]
# 99327 ->Factors of 99327 = [1, 3, 9, 11036, 33109, 99327]
# 22483 ->Factors of 22483 = [1, 22483]
# 27549 ->Factors of 27549 = [1, 3, 9, 3061, 9183, 27549]
# 6733 ->Factors of 6733 = [1, 6733]
# 58567 ->Factors of 58567 = [1, 58567]
# 16357 ->Factors of 16357 = [1, 16357]
# 545 ->Factors of 545 = [1, 5, 109, 545]
# 8306 ->Factors of 8306 = [1, 2, 4153, 8306]
# 24649 ->Factors of 24649 = [1, 24649]
# Received responses for batch 9 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 10 of 400
# # of prompts:  25 # of responses:  25
# 61515 ->Factors of 61515 = [1, 3, 5, 15, 4097, 12291, 20485, 61515]
# 39569 ->Factors of 39569 = [1, 11, 3597, 39569]
# 25887 ->Factors of 25887 = [1, 23, 1125, 25887]
# 92721 ->Factors of 92721 = [1, 3, 7, 13, 21, 39, 71, 133, 699, 1311, 2397, 4423, 7059, 13233, 30783, 92721]
# 76768 ->Factors of 76768 = [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 76768]
# 81553 ->Factors of 81553 = [1, 7, 11653, 81553]
# 4583 ->Factors of 4583 = [1, 7, 13, 353, 655, 4583]
# 96217 ->Factors of 96217 = [1, 11, 8747, 96217]
# 33677 ->Factors of 33677 = [1, 7, 47, 713, 2369, 33677]
# 13299 ->Factors of 13299 = [1, 3, 9, 1477, 4433, 13299]
# 73872 ->Factors of 73872 = [1, 2, 3, 4, 6, 8, 12, 16, 24, 32, 48, 96, 769, 1538, 2307, 3076, 4614, 6152, 12304, 18456, 36912, 73872]
# 31159 ->Factors of 31159 = [1, 17, 1833, 31159]
# 52797 ->Factors of 52797 = [1, 3, 17669, 52797]
# 43151 ->Factors of 43151 = [1, 7, 6165, 43151]
# 2693 ->Factors of 2693 = [1, 13, 207, 2693]
# 89519 ->Factors of 89519 = [1, 29, 3087, 89519]
# 44203 ->Factors of 44203 = [1, 43, 1028, 44203]
# 23801 ->Factors of 23801 = [1, 23, 1035, 23801]
# 72623 ->Factors of 72623 = [1, 7, 10375, 72623]
# 61976 ->Factors of 61976 = [1, 2, 4, 8, 16, 3873, 7746, 15492, 30984, 61976]
# 87576 ->Factors of 87576 = [1, 2, 3, 4, 6, 8, 12, 24, 3649, 7298, 10947, 21894, 43788, 87576]
# 10657 ->Factors of 10657 = [1, 19, 561, 10657]
# 33686 ->Factors of 33686 = [1, 2, 16843, 33686]
# 25234 ->Factors of 25234 = [1, 2, 12617, 25234]
# 98834 ->Factors of 98834 = [1, 2, 7, 14, 49417, 98834]
# Received responses for batch 10 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 11 of 400
# # of prompts:  25 # of responses:  25
# 30612 ->Factors of 30612 = [1, 2, 3, 4, 6, 12, 2551, 5102, 7653, 10204, 15306, 30612]
# 10484 ->Factors of 10484 = [1, 2, 4, 13, 26, 52, 201, 402, 804, 10484]
# 9769 ->Factors of 9769 = [1, 11, 888, 9769]
# 23819 ->Factors of 23819 = [1, 23819]
# 59582 ->Factors of 59582 = [1, 2, 3, 6, 9863, 19726, 59582]
# 37674 ->Factors of 37674 = [1, 2, 3, 6, 18837, 37674]
# 18143 ->Factors of 18143 = [1, 18143]
# 55381 ->Factors of 55381 = [1, 55381]
# 94696 ->Factors of 94696 = [1, 2, 4, 8, 16, 32, 2961, 5922, 11844, 23688, 47376, 94696]
# 60503 ->Factors of 60503 = [1, 60503]
# 45431 ->Factors of 45431 = [1, 45431]
# 21149 ->Factors of 21149 = [1, 21149]
# 62388 ->Factors of 62388 = [1, 2, 3, 4, 6, 12, 5199, 10398, 15597, 31194, 62388]
# 20506 ->Factors of 20506 = [1, 2, 10253, 20506]
# 86323 ->Factors of 86323 = [1, 86323]
# 620 ->Factors of 620 = [1, 2, 4, 5, 10, 20, 31, 62, 124, 155, 310, 620]
# 65257 ->Factors of 65257 = [1, 65257]
# 75167 ->Factors of 75167 = [1, 75167]
# 84247 ->Factors of 84247 = [1, 84247]
# 34721 ->Factors of 34721 = [1, 34721]
# 49637 ->Factors of 49637 = [1, 49637]
# 70067 ->Factors of 70067 = [1, 70067]
# 27179 ->Factors of 27179 = [1, 27179]
# 43051 ->Factors of 43051 = [1, 43051]
# 1176 ->Factors of 1176 = [1, 2, 3, 4, 6, 8, 12, 16, 24, 48, 73, 96, 146, 192, 292, 384, 584, 1176]
# Received responses for batch 11 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 12 of 400
# # of prompts:  25 # of responses:  25
# 29414 ->Factors of 29414 = [1, 2, 14707, 29414]
# 44651 ->Factors of 44651 = [1, 44651]
# 50203 ->Factors of 50203 = [1, 50203]
# 28811 ->Factors of 28811 = [1, 28811]
# 18859 ->Factors of 18859 = [1, 18859]
# 90781 ->Factors of 90781 = [1, 90781]
# 17414 ->Factors of 17414 = [1, 2, 8707, 17414]
# 20491 ->Factors of 20491 = [1, 20491]
# 29759 ->Factors of 29759 = [1, 29759]
# 26815 ->Factors of 26815 = [1, 5, 5363, 26815]
# 79040 ->Factors of 79040 = [1, 2, 4, 5, 8, 10, 16, 20, 32, 40, 1976, 3952, 7904, 9880, 15808, 19760, 39520, 79040]
# 85103 ->Factors of 85103 = [1, 85103]
# 49057 ->Factors of 49057 = [1, 49057]
# 431 ->Factors of 431 = [1, 431]
# 301 ->Factors of 301 = [1, 301]
# 41777 ->Factors of 41777 = [1, 41777]
# 93041 ->Factors of 93041 = [1, 93041]
# 35291 ->Factors of 35291 = [1, 35291]
# 95688 ->Factors of 95688 = [1, 2, 3, 4, 6, 8, 12, 16, 24, 31, 48, 62, 93, 124, 186, 248, 372, 516, 784, 1032, 1568, 2064, 3136, 4128, 7896, 11844, 15792, 23688, 31584, 47376, 95688]
# 46199 ->Factors of 46199 = [1, 46199]
# 64641 ->Factors of 64641 = [1, 3, 7, 9, 21, 63, 1027, 3081, 7213, 21643, 64641]
# 27221 ->Factors of 27221 = [1, 3, 9073, 27221]
# 60679 ->Factors of 60679 = [1, 60679]
# 86534 ->Factors of 86534 = [1, 2, 43267, 86534]
# 81157 ->Factors of 81157 = [1, 81157]
# Received responses for batch 12 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 13 of 400
# # of prompts:  25 # of responses:  25
# 96755 ->Factors of 96755 = [1, 5, 19351]
# 83311 ->Factors of 83311 = [1, 7, 11901]
# 57601 ->Factors of 57601 = [1, 11, 5237]
# 57271 ->Factors of 57271 = [1, 13, 4405]
# 86689 ->Factors of 86689 = [1, 17, 5105]
# 49033 ->Factors of 49033 = [1, 3, 16344]
# 50321 ->Factors of 50321 = [1, 19, 2648]
# 31474 ->Factors of 31474 = [1, 2, 15737]
# 3583 ->Factors of 3583 = [1, 11, 326]
# 34381 ->Factors of 34381 = [1, 13, 2645]
# 90081 ->Factors of 90081 = [1, 3, 30027]
# 82950 ->Factors of 82950 = [1, 2, 3, 5, 6, 10, 15, 30, 2765, 5530, 13825, 41475]
# 53641 ->Factors of 53641 = [1, 7, 7663]
# 71768 ->Factors of 71768 = [1, 2, 4, 8, 16, 32, 2247, 4494, 8988, 17976, 35952]
# 15377 ->Factors of 15377 = [1, 11, 1398]
# 36830 ->Factors of 36830 = [1, 2, 5, 10, 3683, 7366, 18415]
# 88547 ->Factors of 88547 = [1, 23, 3850]
# 20011 ->Factors of 20011 = [1, 7, 2859]
# 30937 ->Factors of 30937 = [1, 17, 1820]
# 33773 ->Factors of 33773 = [1, 19, 1778]
# 13903 ->Factors of 13903 = [1, 13, 1069]
# 12147 ->Factors of 12147 = [1, 11, 1104]
# 73871 ->Factors of 73871 = [1, 7, 10553]
# 61603 ->Factors of 61603 = [1, 3, 20534]
# 64891 ->Factors of 64891 = [1, 29, 2237]
# Received responses for batch 13 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 14 of 400
# # of prompts:  25 # of responses:  25
# 3463 ->Factors of 3463 = [1, 3, 1147, 3463]
# 31734 ->Factors of 31734 = [1, 2, 3, 6, 5289, 10578, 15867, 31734]
# 87931 ->Factors of 87931 = [1, 7, 12561, 87931]
# 78451 ->Factors of 78451 = [1, 7, 11207, 78451]
# 19697 ->Factors of 19697 = [1, 11, 1790, 19697]
# 54950 ->Factors of 54950 = [1, 2, 5, 10, 27475, 54950]
# 36191 ->Factors of 36191 = [1, 17, 2129, 36191]
# 36997 ->Factors of 36997 = [1, 13, 2846, 36997]
# 59450 ->Factors of 59450 = [1, 2, 5, 10, 11890, 29725, 59450]
# 66449 ->Factors of 66449 = [1, 23, 2889, 66449]
# 56167 ->Factors of 56167 = [1, 59, 952, 56167]
# 21247 ->Factors of 21247 = [1, 29, 733, 21247]
# 81097 ->Factors of 81097 = [1, 11, 7372, 81097]
# 85791 ->Factors of 85791 = [1, 3, 9, 27, 3173, 9519, 28597, 85791]
# 29873 ->Factors of 29873 = [1, 13, 2298, 29873]
# 55001 ->Factors of 55001 = [1, 53, 1038, 55001]
# 82504 ->Factors of 82504 = [1, 2, 4, 8, 10251, 20502, 41252, 82504]
# 61681 ->Factors of 61681 = [1, 61, 1011, 61681]
# 73882 ->Factors of 73882 = [1, 2, 36941, 73882]
# 33767 ->Factors of 33767 = [1, 19, 1777, 33767]
# 2657 ->Factors of 2657 = [1, 2657]
# 7681 ->Factors of 7681 = [1, 7, 1097, 7681]
# 68399 ->Factors of 68399 = [1, 13, 5261, 68399]
# 43987 ->Factors of 43987 = [1, 17, 2587, 43987]
# 12301 ->Factors of 12301 = [1, 11, 1119, 12301]
# Received responses for batch 14 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 15 of 400
# # of prompts:  25 # of responses:  25
# 26893 ->Factors of 26893 = [1, 26893]
# 72617 ->Factors of 72617 = [1, 72617]
# 88058 ->Factors of 88058 = [1, 2, 3, 6, 14677, 44029, 88058]
# 6157 ->Factors of 6157 = [1, 6157]
# 49009 ->Factors of 49009 = [1, 49009]
# 64040 ->Factors of 64040 = [1, 2, 4, 5, 8, 10, 16, 20, 40, 80, 1603, 3206, 6412, 8015, 16030, 32060, 64040]
# 16573 ->Factors of 16573 = [1, 16573]
# 63421 ->Factors of 63421 = [1, 63421]
# 61031 ->Factors of 61031 = [1, 61031]
# 2609 ->Factors of 2609 = [1, 2609]
# 63643 ->Factors of 63643 = [1, 63643]
# 44071 ->Factors of 44071 = [1, 44071]
# 74297 ->Factors of 74297 = [1, 74297]
# 32191 ->Factors of 32191 = [1, 32191]
# 95802 ->Factors of 95802 = [1, 2, 3, 6, 15967, 31934, 47901, 95802]
# 58889 ->Factors of 58889 = [1, 58889]
# 17827 ->Factors of 17827 = [1, 17827]
# 14723 ->Factors of 14723 = [1, 14723]
# 16096 ->Factors of 16096 = [1, 2, 4, 8, 16, 32, 503, 1006, 2012, 4024, 8048, 16096]
# 80504 ->Factors of 80504 = [1, 2, 4, 8, 10151, 20302, 40604, 80504]
# 62303 ->Factors of 62303 = [1, 62303]
# 32327 ->Factors of 32327 = [1, 32327]
# 78173 ->Factors of 78173 = [1, 78173]
# 63774 ->Factors of 63774 = [1, 2, 3, 6, 10629, 21258, 31887, 63774]
# 59483 ->Factors of 59483 = [1, 59483]
# Received responses for batch 15 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 16 of 400
# # of prompts:  25 # of responses:  25
# 15599 ->Factors of 15599 = [1, 13, 1199, 15599]
# 23874 ->Factors of 23874 = [1, 2, 3, 6, 3979, 7958, 11937, 23874]
# 26459 ->Factors of 26459 = [1, 23, 1150, 26459]
# 89591 ->Factors of 89591 = [1, 7, 12799, 89591]
# 14313 ->Factors of 14313 = [1, 3, 9, 1613, 4771, 14313]
# 79427 ->Factors of 79427 = [1, 11, 7221, 79427]
# 55364 ->Factors of 55364 = [1, 2, 4, 13841, 27682, 55364]
# 13383 ->Factors of 13383 = [1, 3, 4461, 13383]
# 37409 ->Factors of 37409 = [1, 17, 2201, 37409]
# 9091 ->Factors of 9091 = [1, 7, 13, 699, 1299, 9091]
# 56607 ->Factors of 56607 = [1, 3, 18869, 56607]
# 39107 ->Factors of 39107 = [1, 11, 3555, 39107]
# 8513 ->Factors of 8513 = [1, 29, 294, 8513]
# 52627 ->Factors of 52627 = [1, 19, 2770, 52627]
# 46477 ->Factors of 46477 = [1, 3, 15493, 46477]
# 83663 ->Factors of 83663 = [1, 7, 11952, 83663]
# 82813 ->Factors of 82813 = [1, 13, 6369, 82813]
# 63823 ->Factors of 63823 = [1, 23, 2775, 63823]
# 76609 ->Factors of 76609 = [1, 3, 25537, 76609]
# 46007 ->Factors of 46007 = [1, 43, 1070, 46007]
# 56872 ->Factors of 56872 = [1, 2, 4, 8, 7109, 14218, 28436, 56872]
# 14591 ->Factors of 14591 = [1, 7, 2085, 14591]
# 92329 ->Factors of 92329 = [1, 11, 8394, 92329]
# 4421 ->Factors of 4421 = [1, 41, 108, 4421]
# 64693 ->Factors of 64693 = [1, 3, 21565, 64693]
# Received responses for batch 16 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 17 of 400
# # of prompts:  25 # of responses:  25
# 19991 ->Factors of 19991 = [1, 19991]
# 26361 ->Factors of 26361 = [1, 3, 8787, 26361]
# 68658 ->Factors of 68658 = [1, 2, 3, 6, 11443, 22886, 34329, 68658]
# 84859 ->Factors of 84859 = [1, 84859]
# 48491 ->Factors of 48491 = [1, 48491]
# 51827 ->Factors of 51827 = [1, 51827]
# 70147 ->Factors of 70147 = [1, 70147]
# 9930 ->Factors of 9930 = [1, 2, 3, 5, 6, 10, 15, 30, 330, 990, 1655, 3310, 4965, 9930]
# 86477 ->Factors of 86477 = [1, 86477]
# 81637 ->Factors of 81637 = [1, 81637]
# 46165 ->Factors of 46165 = [1, 5, 9233, 46165]
# 32941 ->Factors of 32941 = [1, 32941]
# 21011 ->Factors of 21011 = [1, 21011]
# 14872 ->Factors of 14872 = [1, 2, 4, 8, 1869, 3738, 7476, 14872]
# 98936 ->Factors of 98936 = [1, 2, 4, 8, 12242, 24484, 49468, 98936]
# 28571 ->Factors of 28571 = [1, 28571]
# 71152 ->Factors of 71152 = [1, 2, 3, 4, 6, 8, 12, 16, 24, 32, 48, 96, 747, 1494, 2241, 2988, 3732, 5976, 8964, 17928, 35856, 71152]
# 85661 ->Factors of 85661 = [1, 85661]
# 63493 ->Factors of 63493 = [1, 63493]
# 69557 ->Factors of 69557 = [1, 69557]
# 2843 ->Factors of 2843 = [1, 2843]
# 89393 ->Factors of 89393 = [1, 89393]
# 27197 ->Factors of 27197 = [1, 27197]
# 9382 ->Factors of 9382 = [1, 2, 47, 199, 4691, 9382]
# 66889 ->Factors of 66889 = [1, 66889]
# Received responses for batch 17 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 18 of 400
# # of prompts:  25 # of responses:  25
# 87517 ->Factors of 87517 = [1, 87517]
# 41626 ->Factors of 41626 = [1, 2, 20813, 41626]
# 48390 ->Factors of 48390 = [1, 2, 3, 5, 7, 10, 14, 15, 35, 42, 1155, 1386, 3465, 48390]
# 31391 ->Factors of 31391 = [1, 31391]
# 23327 ->Factors of 23327 = [1, 23327]
# 94049 ->Factors of 94049 = [1, 94049]
# 44189 ->Factors of 44189 = [1, 44189]
# 11623 ->Factors of 11623 = [1, 11623]
# 25977 ->Factors of 25977 = [1, 3, 8659, 25977]
# 24535 ->Factors of 24535 = [1, 5, 4907, 24535]
# 67589 ->Factors of 67589 = [1, 67589]
# 30047 ->Factors of 30047 = [1, 30047]
# 45757 ->Factors of 45757 = [1, 45757]
# 29016 ->Factors of 29016 = [1, 2, 3, 4, 6, 8, 12, 24, 1207, 2414, 4828, 9656, 14508, 29016]
# 55588 ->Factors of 55588 = [1, 2, 4, 13897, 27794, 55588]
# 92269 ->Factors of 92269 = [1, 92269]
# 52710 ->Factors of 52710 = [1, 2, 3, 5, 6, 10, 15, 30, 1757, 3514, 5271, 10542, 15813, 26355, 52710]
# 18597 ->Factors of 18597 = [1, 3, 6199, 18597]
# 89303 ->Factors of 89303 = [1, 89303]
# 96699 ->Factors of 96699 = [1, 3, 9, 11, 33, 99, 988, 2967, 3297, 96699]
# 98694 ->Factors of 98694 = [1, 2, 3, 6, 16449, 32898, 49347, 98694]
# 13080 ->Factors of 13080 = [1, 2, 3, 4, 5, 6, 8, 10, 12, 15, 20, 24, 30, 40, 60, 80, 120, 160, 216, 320, 432, 640, 864, 1080, 1308, 2616, 3276, 4360, 6540, 13080]
# 40573 ->Factors of 40573 = [1, 40573]
# 3392 ->Factors of 3392 = [1, 2, 4, 8, 16, 32, 106, 212, 424, 848, 1696, 3392]
# 2069 ->Factors of 2069 = [1, 2069]
# Received responses for batch 18 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 19 of 400
# # of prompts:  25 # of responses:  25
# 27345 ->Factors of 27345 = [1, 3, 5, 9, 15, 45, 607, 1823, 3035, 5469, 9115, 27345]
# 15413 ->Factors of 15413 = [1, 11, 1397, 15413]
# 5189 ->Factors of 5189 = [1, 17, 305, 5189]
# 69467 ->Factors of 69467 = [1, 19, 3656, 69467]
# 78742 ->Factors of 78742 = [1, 2, 39371, 78742]
# 28263 ->Factors of 28263 = [1, 3, 9421, 28263]
# 59467 ->Factors of 59467 = [1, 59467]
# 49517 ->Factors of 49517 = [1, 49517]
# 35318 ->Factors of 35318 = [1, 2, 17659, 35318]
# 45263 ->Factors of 45263 = [1, 45263]
# 36739 ->Factors of 36739 = [1, 36739]
# 71047 ->Factors of 71047 = [1, 71047]
# 70425 ->Factors of 70425 = [1, 3, 5, 15, 4695, 14085, 23475, 70425]
# 877 ->Factors of 877 = [1, 877]
# 3541 ->Factors of 3541 = [1, 3541]
# 95881 ->Factors of 95881 = [1, 95881]
# 42705 ->Factors of 42705 = [1, 3, 5, 15, 2847, 8541, 14235, 42705]
# 33492 ->Factors of 33492 = [1, 2, 3, 4, 6, 12, 2793, 5586, 8379, 11172, 16746, 33492]
# 3155 ->Factors of 3155 = [1, 5, 631, 3155]
# 57949 ->Factors of 57949 = [1, 57949]
# 67665 ->Factors of 67665 = [1, 3, 5, 15, 4511, 13533, 22555, 67665]
# 1607 ->Factors of 1607 = [1, 1607]
# 2797 ->Factors of 2797 = [1, 2797]
# 31091 ->Factors of 31091 = [1, 31091]
# 41017 ->Factors of 41017 = [1, 41017]
# Received responses for batch 19 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 20 of 400
# # of prompts:  25 # of responses:  25
# 70833 ->Factors of 70833 = [1, 3, 7, 11, 21, 33, 63, 77, 91, 213, 331, 777, 921, 2163, 3367, 6531, 10123, 20247, 70833]
# 5417 ->Factors of 5417 = [1, 5417]
# 27449 ->Factors of 27449 = [1, 27449]
# 92243 ->Factors of 92243 = [1, 92243]
# 63773 ->Factors of 63773 = [1, 63773]
# 70745 ->Factors of 70745 = [1, 5, 11, 13, 55, 65, 1089, 1287, 5445, 70745]
# 69506 ->Factors of 69506 = [1, 2, 34753, 69506]
# 33493 ->Factors of 33493 = [1, 33493]
# 51899 ->Factors of 51899 = [1, 51899]
# 66616 ->Factors of 66616 = [1, 2, 4, 8, 16, 32, 64, 1039, 2078, 4156, 8312, 16624, 33248, 66616]
# 50389 ->Factors of 50389 = [1, 50389]
# 57637 ->Factors of 57637 = [1, 57637]
# 29221 ->Factors of 29221 = [1, 29221]
# 49613 ->Factors of 49613 = [1, 49613]
# 78593 ->Factors of 78593 = [1, 78593]
# 41387 ->Factors of 41387 = [1, 41387]
# 14563 ->Factors of 14563 = [1, 14563]
# 58058 ->Factors of 58058 = [1, 2, 29029, 58058]
# 65323 ->Factors of 65323 = [1, 65323]
# 10831 ->Factors of 10831 = [1, 10831]
# 20899 ->Factors of 20899 = [1, 20899]
# 33731 ->Factors of 33731 = [1, 33731]
# 56549 ->Factors of 56549 = [1, 56549]
# 86297 ->Factors of 86297 = [1, 86297]
# 80849 ->Factors of 80849 = [1, 80849]
# Received responses for batch 20 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 21 of 400
# # of prompts:  25 # of responses:  25
# 40618 ->Factors of 40618 = [1, 2, 11, 19, 38, 1061, 2122, 40618]
# 47189 ->Factors of 47189 = [1, 13, 3629, 47189]
# 32839 ->Factors of 32839 = [1, 17, 1931, 32839]
# 46232 ->Factors of 46232 = [1, 2, 4, 8, 16, 2309, 4618, 11545, 23090, 46232]
# 15565 ->Factors of 15565 = [1, 5, 3113, 15565]
# 67783 ->Factors of 67783 = [1, 67783]
# 53129 ->Factors of 53129 = [1, 53129]
# 10715 ->Factors of 10715 = [1, 5, 2143, 10715]
# 26111 ->Factors of 26111 = [1, 26111]
# 14009 ->Factors of 14009 = [1, 11, 1273, 14009]
# 37987 ->Factors of 37987 = [1, 37987]
# 32068 ->Factors of 32068 = [1, 2, 4, 8017, 16034, 32068]
# 67499 ->Factors of 67499 = [1, 67499]
# 2663 ->Factors of 2663 = [1, 2663]
# 27832 ->Factors of 27832 = [1, 2, 4, 8, 16, 1733, 3466, 6932, 13864, 27832]
# 97319 ->Factors of 97319 = [1, 97319]
# 44715 ->Factors of 44715 = [1, 5, 8943, 44715]
# 71483 ->Factors of 71483 = [1, 71483]
# 37448 ->Factors of 37448 = [1, 2, 4, 8, 16, 2341, 4682, 9364, 18728, 37448]
# 229 ->Factors of 229 = [1, 229]
# 91092 ->Factors of 91092 = [1, 2, 3, 4, 6, 12, 7583, 15166, 22749, 30332, 45546, 91092]
# 70639 ->Factors of 70639 = [1, 70639]
# 51563 ->Factors of 51563 = [1, 51563]
# 79123 ->Factors of 79123 = [1, 79123]
# 26293 ->Factors of 26293 = [1, 26293]
# Received responses for batch 21 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 22 of 400
# # of prompts:  25 # of responses:  25
# 45587 ->Factors of 45587 = [1, 45587]
# 76733 ->Factors of 76733 = [1, 76733]
# 98216 ->Factors of 98216 = [1, 2, 4, 8, 12152, 24304, 49108, 98216]
# 85743 ->Factors of 85743 = [1, 3, 9, 11, 7831, 28581, 85743]
# 30886 ->Factors of 30886 = [1, 2, 15443, 30886]
# 81591 ->Factors of 81591 = [1, 3, 7, 13, 21, 39, 63, 1291, 2087, 3873, 6241, 12483, 27197, 81591]
# 84967 ->Factors of 84967 = [1, 84967]
# 73823 ->Factors of 73823 = [1, 73823]
# 72148 ->Factors of 72148 = [1, 2, 4, 18037, 36074, 72148]
# 27372 ->Factors of 27372 = [1, 2, 3, 4, 6, 9, 12, 18, 36, 759, 1518, 2277, 3036, 4554, 6813, 9081, 13626, 27372]
# 69143 ->Factors of 69143 = [1, 69143]
# 14887 ->Factors of 14887 = [1, 14887]
# 15073 ->Factors of 15073 = [1, 15073]
# 63127 ->Factors of 63127 = [1, 63127]
# 61751 ->Factors of 61751 = [1, 61751]
# 13049 ->Factors of 13049 = [1, 13049]
# 94603 ->Factors of 94603 = [1, 3, 31531, 94603]
# 26699 ->Factors of 26699 = [1, 26699]
# 51949 ->Factors of 51949 = [1, 51949]
# 99053 ->Factors of 99053 = [1, 99053]
# 80909 ->Factors of 80909 = [1, 80909]
# 25463 ->Factors of 25463 = [1, 25463]
# 57859 ->Factors of 57859 = [1, 57859]
# 89582 ->Factors of 89582 = [1, 2, 44791, 89582]
# 41144 ->Factors of 41144 = [1, 2, 4, 8, 16, 2569, 5138, 10276, 20552, 41144]
# Received responses for batch 22 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 23 of 400
# # of prompts:  25 # of responses:  25
# 95537 ->Factors of 95537 = [1, 95537]
# 60289 ->Factors of 60289 = [1, 60289]
# 16061 ->Factors of 16061 = [1, 16061]
# 55414 ->Factors of 55414 = [1, 2, 7, 14, 3959, 7918, 27707, 55414]
# 57535 ->Factors of 57535 = [1, 5, 11507, 57535]
# 65332 ->Factors of 65332 = [1, 2, 4, 16333, 32666, 65332]
# 51660 ->Factors of 51660 = [1, 2, 3, 4, 5, 6, 10, 12, 15, 20, 30, 60, 861, 1722, 2583, 4308, 8616, 12915, 25830, 51660]
# 60953 ->Factors of 60953 = [1, 60953]
# 74789 ->Factors of 74789 = [1, 74789]
# 80651 ->Factors of 80651 = [1, 80651]
# 33142 ->Factors of 33142 = [1, 2, 16571, 33142]
# 17147 ->Factors of 17147 = [1, 17147]
# 17333 ->Factors of 17333 = [1, 17333]
# 74197 ->Factors of 74197 = [1, 74197]
# 10355 ->Factors of 10355 = [1, 5, 2071, 10355]
# 59688 ->Factors of 59688 = [1, 2, 3, 4, 6, 8, 12, 16, 24, 48, 1243, 2486, 4972, 9944, 14923, 19888, 29846, 59688]
# 39396 ->Factors of 39396 = [1, 2, 3, 4, 6, 12, 3283, 6566, 9858, 13132, 19698, 39396]
# 58231 ->Factors of 58231 = [1, 58231]
# 55404 ->Factors of 55404 = [1, 2, 3, 4, 6, 9, 12, 18, 36, 1543, 3086, 4629, 6172, 9258, 13854, 18516, 27708, 55404]
# 68443 ->Factors of 68443 = [1, 68443]
# 74063 ->Factors of 74063 = [1, 74063]
# 88843 ->Factors of 88843 = [1, 88843]
# 62903 ->Factors of 62903 = [1, 62903]
# 67451 ->Factors of 67451 = [1, 67451]
# 88410 ->Factors of 88410 = [1, 2, 3, 5, 6, 10, 15, 30, 2947, 5894, 8841, 14735, 17682, 29470, 44205, 88410]
# Received responses for batch 23 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 24 of 400
# # of prompts:  25 # of responses:  25
# 1973 ->Factors of 1973 = [1, 1973]
# 11923 ->Factors of 11923 = [1, 11923]
# 8467 ->Factors of 8467 = [1, 8467]
# 20696 ->Factors of 20696 = [1, 2, 4, 8, 16, 32, 649, 1298, 2596, 5192, 10384, 20696]
# 40241 ->Factors of 40241 = [1, 40241]
# 28636 ->Factors of 28636 = [1, 2, 4, 7159, 14318, 28636]
# 57793 ->Factors of 57793 = [1, 57793]
# 4595 ->Factors of 4595 = [1, 5, 919, 4595]
# 27983 ->Factors of 27983 = [1, 27983]
# 56901 ->Factors of 56901 = [1, 3, 19, 18967, 56901]
# 90783 ->Factors of 90783 = [1, 3, 9, 10087, 30261, 90783]
# 98006 ->Factors of 98006 = [1, 2, 7, 14, 49003, 98006]
# 67807 ->Factors of 67807 = [1, 67807]
# 76884 ->Factors of 76884 = [1, 2, 3, 4, 6, 12, 6407, 12814, 19221, 38442, 76884]
# 67010 ->Factors of 67010 = [1, 2, 5, 10, 6701, 13402, 33505, 67010]
# 91143 ->Factors of 91143 = [1, 3, 30381, 91143]
# 50087 ->Factors of 50087 = [1, 50087]
# 32406 ->Factors of 32406 = [1, 2, 3, 6, 9, 18, 1795, 3590, 5385, 10770, 16203, 32406]
# 21831 ->Factors of 21831 = [1, 3, 7277, 21831]
# 32636 ->Factors of 32636 = [1, 2, 4, 8159, 16318, 32636]
# 61657 ->Factors of 61657 = [1, 61657]
# 91504 ->Factors of 91504 = [1, 2, 4, 8, 16, 32, 2863, 5726, 11452, 22904, 45808, 91504]
# 21601 ->Factors of 21601 = [1, 21601]
# 65123 ->Factors of 65123 = [1, 65123]
# 51889 ->Factors of 51889 = [1, 17, 3052, 51889]
# Received responses for batch 24 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 25 of 400
# # of prompts:  25 # of responses:  25
# 55863 ->Factors of 55863 = [1, 3, 17, 19, 51, 102, 543, 1086, 1893, 3279, 55863]
# 40763 ->Factors of 40763 = [1, 11, 13, 31, 37, 111, 363, 1091, 1321, 3103, 40763]
# 62125 ->Factors of 62125 = [1, 5, 25, 125, 497, 2485, 62125]
# 88830 ->Factors of 88830 = [1, 2, 3, 5, 6, 10, 11, 15, 30, 33, 55, 66, 99, 165, 330, 549, 825, 1650, 2970, 5940, 88830]
# 26314 ->Factors of 26314 = [1, 2, 13157, 26314]
# 92861 ->Factors of 92861 = [1, 7, 13265, 92861]
# 62247 ->Factors of 62247 = [1, 3, 7, 9, 21, 27, 63, 81, 778, 2263, 2943, 62247]
# 71399 ->Factors of 71399 = [1, 17, 4206, 71399]
# 68532 ->Factors of 68532 = [1, 2, 3, 4, 6, 9, 12, 18, 36, 1903, 3806, 5709, 11418, 22836, 68532]
# 9743 ->Factors of 9743 = [1, 7, 1391, 9743]
# 63131 ->Factors of 63131 = [1, 11, 5739, 63131]
# 62683 ->Factors of 62683 = [1, 3, 20893, 62683]
# 76145 ->Factors of 76145 = [1, 5, 15229, 76145]
# 5261 ->Factors of 5261 = [1, 7, 751, 5261]
# 95873 ->Factors of 95873 = [1, 11, 8716, 95873]
# 86325 ->Factors of 86325 = [1, 3, 5, 15, 5755, 17265, 28775, 86325]
# 20219 ->Factors of 20219 = [1, 19, 1064, 20219]
# 63825 ->Factors of 63825 = [1, 3, 5, 15, 4255, 12765, 21275, 63825]
# 94716 ->Factors of 94716 = [1, 2, 3, 4, 6, 12, 7893, 15786, 23679, 47358, 94716]
# 86501 ->Factors of 86501 = [1, 7, 12357, 86501]
# 68087 ->Factors of 68087 = [1, 13, 5237, 68087]
# 35027 ->Factors of 35027 = [1, 17, 2060, 35027]
# 48733 ->Factors of 48733 = [1, 11, 4430, 48733]
# 62815 ->Factors of 62815 = [1, 5, 12563, 62815]
# 40433 ->Factors of 40433 = [1, 13, 3109, 40433]
# Received responses for batch 25 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 26 of 400
# # of prompts:  25 # of responses:  25
# 82499 ->Factors of 82499 = [1, 82499]
# 2819 ->Factors of 2819 = [1, 2819]
# 86843 ->Factors of 86843 = [1, 86843]
# 41233 ->Factors of 41233 = [1, 41233]
# 19213 ->Factors of 19213 = [1, 19213]
# 43945 ->Factors of 43945 = [1, 43945]
# 13234 ->Factors of 13234 = [1, 2, 6617, 13234]
# 22643 ->Factors of 22643 = [1, 22643]
# 21739 ->Factors of 21739 = [1, 21739]
# 69031 ->Factors of 69031 = [1, 69031]
# 87330 ->Factors of 87330 = [1, 2, 3, 5, 6, 9, 10, 15, 18, 30, 45, 90, 973, 1946, 2919, 4865, 9730, 14595, 29190, 43770, 87330]
# 71576 ->Factors of 71576 = [1, 2, 4, 8, 16, 32, 64, 1111, 2222, 4444, 8888, 17776, 35552, 71576]
# 92957 ->Factors of 92957 = [1, 92957]
# 96071 ->Factors of 96071 = [1, 96071]
# 26905 ->Factors of 26905 = [1, 5, 5381, 26905]
# 10457 ->Factors of 10457 = [1, 10457]
# 87283 ->Factors of 87283 = [1, 87283]
# 58579 ->Factors of 58579 = [1, 58579]
# 67619 ->Factors of 67619 = [1, 67619]
# 15877 ->Factors of 15877 = [1, 15877]
# 26993 ->Factors of 26993 = [1, 26993]
# 65995 ->Factors of 65995 = [1, 5, 13199, 65995]
# 7451 ->Factors of 7451 = [1, 7, 1064, 7451]
# 92162 ->Factors of 92162 = [1, 2, 7, 14, 46081, 92162]
# 40693 ->Factors of 40693 = [1, 40693]
# Received responses for batch 26 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 27 of 400
# # of prompts:  25 # of responses:  25
# 26687 ->Factors of 26687 = [1, 26687]
# 51477 ->Factors of 51477 = [1, 51477]
# 181 ->Factors of 181 = [1, 181]
# 89431 ->Factors of 89431 = [1, 89431]
# 91918 ->Factors of 91918 = [1, 2, 91918]
# 58943 ->Factors of 58943 = [1, 58943]
# 54876 ->Factors of 54876 = [1, 2, 3, 4, 6, 9, 12, 18, 36, 1523, 3046, 6092, 9123, 18246, 27438, 54876]
# 52727 ->Factors of 52727 = [1, 52727]
# 92051 ->Factors of 92051 = [1, 92051]
# 20089 ->Factors of 20089 = [1, 20089]
# 92352 ->Factors of 92352 = [1, 2, 3, 4, 6, 8, 12, 16, 24, 32, 48, 96, 1919, 3838, 5757, 7676, 11514, 15352, 23028, 30704, 46056, 92352]
# 8188 ->Factors of 8188 = [1, 2, 4, 2047, 4094, 8188]
# 85413 ->Factors of 85413 = [1, 3, 9, 11, 7773, 9491, 28471, 85413]
# 19045 ->Factors of 19045 = [1, 5, 19, 95, 201, 1003, 1905, 9523, 19045]
# 72547 ->Factors of 72547 = [1, 72547]
# 68193 ->Factors of 68193 = [1, 3, 22731, 68193]
# 23741 ->Factors of 23741 = [1, 23741]
# 80153 ->Factors of 80153 = [1, 80153]
# 74716 ->Factors of 74716 = [1, 2, 4, 18679, 37358, 74716]
# 73496 ->Factors of 73496 = [1, 2, 4, 8, 16, 32, 2297, 4594, 9188, 18376, 36752, 73496]
# 77761 ->Factors of 77761 = [1, 77761]
# 21492 ->Factors of 21492 = [1, 2, 3, 4, 6, 12, 1799, 3598, 5397, 10794, 21492]
# 61141 ->Factors of 61141 = [1, 61141]
# 19793 ->Factors of 19793 = [1, 19793]
# 1638 ->Factors of 1638 = [1, 2, 3, 6, 273, 546, 819, 1638]
# Received responses for batch 27 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 28 of 400
# # of prompts:  25 # of responses:  25
# 45181 ->Factors of 45181 = [1, 45181]
# 98009 ->Factors of 98009 = [1, 98009]
# 46567 ->Factors of 46567 = [1, 46567]
# 36512 ->Factors of 36512 = [1, 2, 4, 7, 8, 14, 28, 56, 653, 1306, 2612, 5224, 9128, 18256, 36512]
# 69827 ->Factors of 69827 = [1, 69827]
# 21713 ->Factors of 21713 = [1, 21713]
# 51844 ->Factors of 51844 = [1, 2, 4, 12961, 25922, 51844]
# 65963 ->Factors of 65963 = [1, 65963]
# 21044 ->Factors of 21044 = [1, 2, 4, 5261, 10522, 21044]
# 69594 ->Factors of 69594 = [1, 2, 3, 6, 11665, 23330, 34995, 69594]
# 2113 ->Factors of 2113 = [1, 2113]
# 80306 ->Factors of 80306 = [1, 2, 40153, 80306]
# 42223 ->Factors of 42223 = [1, 42223]
# 55111 ->Factors of 55111 = [1, 55111]
# 97621 ->Factors of 97621 = [1, 97621]
# 48463 ->Factors of 48463 = [1, 48463]
# 78637 ->Factors of 78637 = [1, 78637]
# 7230 ->Factors of 7230 = [1, 2, 3, 5, 6, 10, 15, 30, 241, 482, 723, 1446, 1205, 2410, 3615, 7230]
# 42943 ->Factors of 42943 = [1, 42943]
# 46507 ->Factors of 46507 = [1, 46507]
# 21049 ->Factors of 21049 = [1, 21049]
# 11170 ->Factors of 11170 = [1, 2, 5, 10, 1117, 2234, 5585, 11170]
# 77040 ->Factors of 77040 = [1, 2, 3, 4, 5, 6, 8, 9, 10, 12, 15, 16, 18, 20, 24, 30, 32, 36, 40, 45, 48, 60, 72, 80, 90, 96, 120, 160, 180, 240, 320, 360, 480, 640, 864, 1280, 1728, 2560, 3456, 5120, 7704, 10240, 15408, 20480, 30816, 40960, 77040]
# 13696 ->Factors of 13696 = [1, 2, 4, 8, 1712, 3424, 6848, 13696]
# 20023 ->Factors of 20023 = [1, 20023]
# Received responses for batch 28 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 29 of 400
# # of prompts:  25 # of responses:  25
# 44879 ->Factors of 44879 = [1, 44879]
# 82388 ->Factors of 82388 = [1, 2, 4, 20597, 41194, 82388]
# 83023 ->Factors of 83023 = [1, 83023]
# 51853 ->Factors of 51853 = [1, 51853]
# 39020 ->Factors of 39020 = [1, 2, 4, 5, 7, 10, 14, 20, 28, 35, 70, 140, 280, 560, 1120, 1951, 3902, 9755, 19510, 39020]
# 19157 ->Factors of 19157 = [1, 19157]
# 4484 ->Factors of 4484 = [1, 2, 4, 1121, 2242, 4484]
# 74092 ->Factors of 74092 = [1, 2, 4, 18523, 37046, 74092]
# 95737 ->Factors of 95737 = [1, 95737]
# 1597 ->Factors of 1597 = [1, 1597]
# 25633 ->Factors of 25633 = [1, 25633]
# 19763 ->Factors of 19763 = [1, 19763]
# 75110 ->Factors of 75110 = [1, 2, 5, 10, 7511, 15022, 37555, 75110]
# 85021 ->Factors of 85021 = [1, 85021]
# 89603 ->Factors of 89603 = [1, 89603]
# 51487 ->Factors of 51487 = [1, 51487]
# 68023 ->Factors of 68023 = [1, 68023]
# 78857 ->Factors of 78857 = [1, 78857]
# 20749 ->Factors of 20749 = [1, 20749]
# 92423 ->Factors of 92423 = [1, 92423]
# 41314 ->Factors of 41314 = [1, 2, 20657, 41314]
# 65939 ->Factors of 65939 = [1, 65939]
# 5101 ->Factors of 5101 = [1, 5101]
# 856 ->Factors of 856 = [1, 2, 4, 8, 107, 214, 428, 856]
# 88993 ->Factors of 88993 = [1, 88993]
# Received responses for batch 29 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 30 of 400
# # of prompts:  25 # of responses:  25
# 34261 ->Factors of 34261 = [1, 34261]
# 19972 ->Factors of 19972 = [1, 2, 4, 19972]
# 96001 ->Factors of 96001 = [1, 96001]
# 20483 ->Factors of 20483 = [1, 20483]
# 57221 ->Factors of 57221 = [1, 57221]
# 63337 ->Factors of 63337 = [1, 63337]
# 27903 ->Factors of 27903 = [1, 3, 9301, 27903]
# 22133 ->Factors of 22133 = [1, 22133]
# 14095 ->Factors of 14095 = [1, 5, 2819, 14095]
# 56873 ->Factors of 56873 = [1, 56873]
# 54630 ->Factors of 54630 = [1, 2, 3, 5, 6, 9, 10, 15, 18, 30, 45, 90, 607, 1214, 1821, 3035, 5463, 9105, 18210, 27315, 54630]
# 41051 ->Factors of 41051 = [1, 41051]
# 11801 ->Factors of 11801 = [1, 11801]
# 82487 ->Factors of 82487 = [1, 82487]
# 60259 ->Factors of 60259 = [1, 60259]
# 52049 ->Factors of 52049 = [1, 52049]
# 50450 ->Factors of 50450 = [1, 2, 5, 10, 25, 50, 101, 202, 505, 1010, 2525, 5045, 10090, 25225, 50450]
# 97039 ->Factors of 97039 = [1, 97039]
# 23733 ->Factors of 23733 = [1, 3, 7911, 23733]
# 44809 ->Factors of 44809 = [1, 44809]
# 20387 ->Factors of 20387 = [1, 20387]
# 26959 ->Factors of 26959 = [1, 26959]
# 56299 ->Factors of 56299 = [1, 56299]
# 14827 ->Factors of 14827 = [1, 14827]
# 84629 ->Factors of 84629 = [1, 84629]
# Received responses for batch 30 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 31 of 400
# # of prompts:  25 # of responses:  25
# 32741 ->Factors of 32741 = [1, 32741]
# 52817 ->Factors of 52817 = [1, 52817]
# 92682 ->Factors of 92682 = [1, 2, 3, 6, 15341, 30894, 46341, 92682]
# 72558 ->Factors of 72558 = [1, 2, 36279, 72558]
# 55683 ->Factors of 55683 = [1, 3, 18561, 55683]
# 71237 ->Factors of 71237 = [1, 71237]
# 233 ->Factors of 233 = [1, 233]
# 94403 ->Factors of 94403 = [1, 94403]
# 99907 ->Factors of 99907 = [1, 99907]
# 44258 ->Factors of 44258 = [1, 2, 3, 6, 7376, 14753, 22129, 44258]
# 58785 ->Factors of 58785 = [1, 5, 11757, 58785]
# 77893 ->Factors of 77893 = [1, 77893]
# 88128 ->Factors of 88128 = [1, 2, 4, 8, 11016, 22032, 44064, 88128]
# 30469 ->Factors of 30469 = [1, 30469]
# 78736 ->Factors of 78736 = [1, 2, 4, 8, 9842, 19684, 39368, 78736]
# 66797 ->Factors of 66797 = [1, 66797]
# 47825 ->Factors of 47825 = [1, 5, 9565, 47825]
# 28447 ->Factors of 28447 = [1, 28447]
# 88667 ->Factors of 88667 = [1, 88667]
# 37847 ->Factors of 37847 = [1, 37847]
# 39839 ->Factors of 39839 = [1, 39839]
# 79103 ->Factors of 79103 = [1, 79103]
# 78643 ->Factors of 78643 = [1, 78643]
# 67079 ->Factors of 67079 = [1, 67079]
# 52317 ->Factors of 52317 = [1, 3, 17439, 52317]
# Received responses for batch 31 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 32 of 400
# # of prompts:  25 # of responses:  25
# 44617 ->Factors of 44617 = [1, 44617]
# 96259 ->Factors of 96259 = [1, 96259]
# 47303 ->Factors of 47303 = [1, 47303]
# 59779 ->Factors of 59779 = [1, 59779]
# 24359 ->Factors of 24359 = [1, 24359]
# 91549 ->Factors of 91549 = [1, 91549]
# 98369 ->Factors of 98369 = [1, 98369]
# 49207 ->Factors of 49207 = [1, 49207]
# 50969 ->Factors of 50969 = [1, 50969]
# 7039 ->Factors of 7039 = [1, 7039]
# 6175 ->Factors of 6175 = [1, 5, 1235, 6175]
# 52741 ->Factors of 52741 = [1, 52741]
# 88997 ->Factors of 88997 = [1, 88997]
# 29629 ->Factors of 29629 = [1, 29629]
# 12535 ->Factors of 12535 = [1, 5, 2507, 12535]
# 39196 ->Factors of 39196 = [1, 2, 4, 19598, 39196]
# 4955 ->Factors of 4955 = [1, 5, 991, 4955]
# 66168 ->Factors of 66168 = [1, 2, 3, 4, 6, 8, 12, 16, 24, 32, 48, 96, 689, 1378, 2067, 4134, 8268, 16536, 33072, 66168]
# 15440 ->Factors of 15440 = [1, 2, 4, 5, 8, 10, 16, 20, 40, 80, 193, 386, 772, 965, 1544, 1930, 3088, 3860, 7720, 15440]
# 73483 ->Factors of 73483 = [1, 73483]
# 61112 ->Factors of 61112 = [1, 2, 4, 8, 16, 30556, 61112]
# 12101 ->Factors of 12101 = [1, 12101]
# 79612 ->Factors of 79612 = [1, 2, 4, 19903, 39806, 79612]
# 29196 ->Factors of 29196 = [1, 2, 3, 4, 6, 12, 2433, 4866, 7299, 14598, 29196]
# 9511 ->Factors of 9511 = [1, 9511]
# Received responses for batch 32 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 33 of 400
# # of prompts:  25 # of responses:  25
# 27143 ->Factors of 27143 = [1, 27143]
# 91813 ->Factors of 91813 = [1, 91813]
# 73043 ->Factors of 73043 = [1, 73043]
# 56135 ->Factors of 56135 = [1, 5, 11227, 56135]
# 71810 ->Factors of 71810 = [1, 2, 5, 7, 10, 14, 35, 70, 1015, 2030, 3590, 71810]
# 16561 ->Factors of 16561 = [1, 7, 2366, 16561]
# 25243 ->Factors of 25243 = [1, 25243]
# 22777 ->Factors of 22777 = [1, 22777]
# 36683 ->Factors of 36683 = [1, 36683]
# 96787 ->Factors of 96787 = [1, 96787]
# 8191 ->Factors of 8191 = [1, 7, 1183, 8191]
# 50539 ->Factors of 50539 = [1, 50539]
# 39217 ->Factors of 39217 = [1, 39217]
# 54529 ->Factors of 54529 = [1, 54529]
# 19254 ->Factors of 19254 = [1, 2, 3, 6, 9, 18, 1067, 2134, 3201, 6402, 9627, 19254]
# 18745 ->Factors of 18745 = [1, 3, 5, 15, 1249, 3749, 6245, 18745]
# 82611 ->Factors of 82611 = [1, 3, 9, 27, 3061, 9183, 27537, 82611]
# 50221 ->Factors of 50221 = [1, 50221]
# 50651 ->Factors of 50651 = [1, 50651]
# 7879 ->Factors of 7879 = [1, 7, 1125, 7879]
# 48259 ->Factors of 48259 = [1, 48259]
# 62772 ->Factors of 62772 = [1, 2, 3, 4, 6, 12, 5231, 10462, 15693, 31386, 62772]
# 5198 ->Factors of 5198 = [1, 2, 2599, 5198]
# 4297 ->Factors of 4297 = [1, 4297]
# 55339 ->Factors of 55339 = [1, 55339]
# Received responses for batch 33 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 34 of 400
# # of prompts:  25 # of responses:  25
# 96960 ->Factors of 96960 = [1, 2, 3, 4, 5, 6, 8, 10, 12, 15, 16, 20, 24, 30, 32, 40, 48, 60, 64, 80, 96, 120, 160, 192, 240, 320, 480, 640, 960, 1280, 1920, 2560, 3840, 4800, 6400, 8160, 12800, 16200, 19200, 24000, 32400, 48000, 96960]
# 20329 ->Factors of 20329 = [1, 23, 884, 20329]
# 26267 ->Factors of 26267 = [1, 26267]
# 52529 ->Factors of 52529 = [1, 52529]
# 88661 ->Factors of 88661 = [1, 88661]
# 59006 ->Factors of 59006 = [1, 2, 29503, 59006]
# 50581 ->Factors of 50581 = [1, 50581]
# 33023 ->Factors of 33023 = [1, 33023]
# ...
# Sending batch 390 of 400
# # of prompts:  25 # of responses:  25
# 59611 ->Factors of 59611 = [1, 59611]
# 68334 ->Factors of 68334 = [1, 2, 3, 6, 11389, 22778, 34167, 68334]
# 38547 ->Factors of 38547 = [1, 3, 12849, 38547]
# 86851 ->Factors of 86851 = [1, 86851]
# 32911 ->Factors of 32911 = [1, 32911]
# 71707 ->Factors of 71707 = [1, 71707]
# 90191 ->Factors of 90191 = [1, 90191]
# 26849 ->Factors of 26849 = [1, 26849]
# 73670 ->Factors of 73670 = [1, 2, 5, 7, 10, 14, 35, 70, 105, 210, 350, 693, 1050, 2116, 3465, 5250, 7367, 10580, 14734, 36835, 73670]
# 9535 ->Factors of 9535 = [1, 5, 1907, 9535]
# 39704 ->Factors of 39704 = [1, 2, 4, 8, 4963, 9926, 19852, 39704]
# 53047 ->Factors of 53047 = [1, 53047]
# 7710 ->Factors of 7710 = [1, 2, 3, 5, 6, 10, 13, 15, 30, 39, 65, 78, 99, 117, 198, 258, 330, 516, 771, 1290, 1542, 2570, 3855, 7710]
# 71879 ->Factors of 71879 = [1, 71879]
# 82510 ->Factors of 82510 = [1, 2, 5, 10, 8251, 16502, 41255, 82510]
# 92503 ->Factors of 92503 = [1, 92503]
# 1940 ->Factors of 1940 = [1, 2, 4, 5, 10, 20, 49, 98, 196, 392, 970, 1940]
# 45691 ->Factors of 45691 = [1, 45691]
# 49477 ->Factors of 49477 = [1, 49477]
# 42322 ->Factors of 42322 = [1, 2, 3, 6, 7, 11, 14, 21, 22, 42, 63, 66, 126, 132, 189, 224, 333, 378, 666, 756, 1001, 1926, 2002, 3003, 3852, 6006, 7007, 14014, 21018, 42322]
# 9887 ->Factors of 9887 = [1, 9887]
# 3809 ->Factors of 3809 = [1, 3809]
# 72032 ->Factors of 72032 = [1, 2, 4, 8, 16, 32, 64, 1125, 2250, 4500, 9000, 18000, 36000, 72032]
# 66938 ->Factors of 66938 = [1, 2, 33469, 66938]
# 1279 ->Factors of 1279 = [1, 1279]
# Received responses for batch 390 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 391 of 400
# # of prompts:  25 # of responses:  25
# 70177 ->Factors of 70177 = [1, 7, 10025, 70177]
# 34603 ->Factors of 34603 = [1, 3, 11531, 34603]
# 62827 ->Factors of 62827 = [1, 62827]
# 50665 ->Factors of 50665 = [1, 5, 10133, 50665]
# 95917 ->Factors of 95917 = [1, 95917]
# 25303 ->Factors of 25303 = [1, 25303]
# 69122 ->Factors of 69122 = [1, 2, 34561, 69122]
# 24264 ->Factors of 24264 = [1, 2, 3, 4, 6, 8, 12, 24, 1011, 2022, 3033, 6066, 8082, 12132, 24264]
# 88799 ->Factors of 88799 = [1, 88799]
# 85639 ->Factors of 85639 = [1, 85639]
# 71858 ->Factors of 71858 = [1, 2, 36, 1996, 35929, 71858]
# 29483 ->Factors of 29483 = [1, 29483]
# 41189 ->Factors of 41189 = [1, 41189]
# 16164 ->Factors of 16164 = [1, 2, 3, 4, 6, 12, 1351, 2702, 4054, 8082, 16164]
# 93493 ->Factors of 93493 = [1, 93493]
# 70504 ->Factors of 70504 = [1, 2, 4, 8, 16, 32, 2203, 4406, 8812, 17624, 35248, 70504]
# 71926 ->Factors of 71926 = [1, 2, 35963, 71926]
# 48677 ->Factors of 48677 = [1, 48677]
# 29009 ->Factors of 29009 = [1, 29009]
# 78929 ->Factors of 78929 = [1, 78929]
# 83563 ->Factors of 83563 = [1, 83563]
# 56724 ->Factors of 56724 = [1, 2, 3, 4, 6, 9, 12, 18, 36, 1579, 3158, 4737, 6316, 9474, 12632, 18948, 25264, 56724]
# 1473 ->Factors of 1473 = [1, 3, 491, 1473]
# 33151 ->Factors of 33151 = [1, 33151]
# 24239 ->Factors of 24239 = [1, 24239]
# Received responses for batch 391 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 392 of 400
# # of prompts:  25 # of responses:  25
# 17659 ->Factors of 17659 = [1, 17, 1039, 17659]
# 68609 ->Factors of 68609 = [1, 68609]
# 83035 ->Factors of 83035 = [1, 5, 16607, 83035]
# 22594 ->Factors of 22594 = [1, 2, 11297, 22594]
# 97112 ->Factors of 97112 = [1, 2, 3, 4, 6, 8, 12, 16, 24, 48, 2023, 4046, 8092, 12138, 24276, 48552, 97112]
# 75722 ->Factors of 75722 = [1, 2, 37861, 75722]
# 50329 ->Factors of 50329 = [1, 17, 2960, 50329]
# 58441 ->Factors of 58441 = [1, 58441]
# 54469 ->Factors of 54469 = [1, 54469]
# 49493 ->Factors of 49493 = [1, 49493]
# 25104 ->Factors of 25104 = [1, 2, 3, 4, 6, 8, 12, 24, 1042, 2084, 4168, 8336, 12552, 25104]
# 13693 ->Factors of 13693 = [1, 13693]
# 88425 ->Factors of 88425 = [1, 5, 17685, 88425]
# 13284 ->Factors of 13284 = [1, 2, 3, 4, 6, 12, 1107, 2214, 3321, 4428, 6642, 13284]
# 78226 ->Factors of 78226 = [1, 2, 39113, 78226]
# 68389 ->Factors of 68389 = [1, 68389]
# 30086 ->Factors of 30086 = [1, 2, 15043, 30086]
# 56003 ->Factors of 56003 = [1, 56003]
# 78350 ->Factors of 78350 = [1, 2, 5, 10, 1567, 3134, 7835, 15670, 39175, 78350]
# 89561 ->Factors of 89561 = [1, 89561]
# 24697 ->Factors of 24697 = [1, 24697]
# 95676 ->Factors of 95676 = [1, 2, 3, 4, 6, 12, 7973, 15946, 23922, 47844, 95676]
# 19477 ->Factors of 19477 = [1, 19477]
# 86205 ->Factors of 86205 = [1, 3, 5, 15, 5747, 17241, 28735, 86205]
# 43793 ->Factors of 43793 = [1, 43793]
# Received responses for batch 392 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 393 of 400
# # of prompts:  25 # of responses:  25
# 99823 ->Factors of 99823 = [1, 99823]
# 73277 ->Factors of 73277 = [1, 73277]
# 28837 ->Factors of 28837 = [1, 28837]
# 37181 ->Factors of 37181 = [1, 37181]
# 19753 ->Factors of 19753 = [1, 19753]
# 34031 ->Factors of 34031 = [1, 34031]
# 16205 ->Factors of 16205 = [1, 16205]
# 14533 ->Factors of 14533 = [1, 14533]
# 3096 ->Factors of 3096 = [1, 2, 3, 4, 6, 8, 12, 16, 193, 386, 772, 1544, 3096]
# 76678 ->Factors of 76678 = [1, 2, 38339, 76678]
# 9787 ->Factors of 9787 = [1, 9787]
# 48391 ->Factors of 48391 = [1, 48391]
# 36871 ->Factors of 36871 = [1, 36871]
# 33427 ->Factors of 33427 = [1, 33427]
# 79687 ->Factors of 79687 = [1, 79687]
# 84181 ->Factors of 84181 = [1, 84181]
# 58844 ->Factors of 58844 = [1, 2, 3, 4, 6, 9, 12, 18, 36, 1633, 3267, 6534, 9811, 19622, 29422, 58844]
# 85196 ->Factors of 85196 = [1, 2, 4, 21299, 42598, 85196]
# 26632 ->Factors of 26632 = [1, 2, 4, 8, 16, 3329, 6658, 13316, 26632]
# 14678 ->Factors of 14678 = [1, 2, 7339, 14678]
# 22132 ->Factors of 22132 = [1, 2, 4, 5533, 11066, 22132]
# 13174 ->Factors of 13174 = [1, 2, 6587, 13174]
# 85517 ->Factors of 85517 = [1, 85517]
# 74448 ->Factors of 74448 = [1, 2, 4, 8, 16, 32, 2323, 4646, 9292, 18584, 37168, 74448]
# 54377 ->Factors of 54377 = [1, 54377]
# Received responses for batch 393 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 394 of 400
# # of prompts:  25 # of responses:  25
# 31927 ->Factors of 31927 = [1, 31927]
# 92342 ->Factors of 92342 = [1, 2, 43, 86, 1073, 2146, 4617, 92342]
# 59357 ->Factors of 59357 = [1, 59357]
# 22039 ->Factors of 22039 = [1, 22039]
# 78227 ->Factors of 78227 = [1, 78227]
# 70273 ->Factors of 70273 = [1, 70273]
# 91387 ->Factors of 91387 = [1, 91387]
# 32633 ->Factors of 32633 = [1, 32633]
# 58472 ->Factors of 58472 = [1, 2, 3, 4, 6, 8, 12, 16, 24, 32, 48, 96, 609, 1218, 1827, 2436, 3654, 4872, 7308, 9744, 14616, 19488, 29232, 58472]
# 49411 ->Factors of 49411 = [1, 49411]
# 74250 ->Factors of 74250 = [1, 2, 3, 5, 6, 10, 12, 15, 25, 30, 60, 75, 988, 1235, 1976, 2470, 3713, 4940, 6175, 9880, 12350, 18565, 24700, 37125, 74250]
# 68437 ->Factors of 68437 = [1, 68437]
# 86857 ->Factors of 86857 = [1, 86857]
# 51323 ->Factors of 51323 = [1, 51323]
# 97367 ->Factors of 97367 = [1, 97367]
# 89839 ->Factors of 89839 = [1, 89839]
# 7243 ->Factors of 7243 = [1, 7, 1031, 7243]
# 95825 ->Factors of 95825 = [1, 5, 19165, 95825]
# 43540 ->Factors of 43540 = [1, 2, 4, 5, 10, 20, 4354, 8708, 10885, 21770, 43540]
# 53639 ->Factors of 53639 = [1, 53639]
# 22807 ->Factors of 22807 = [1, 22807]
# 39849 ->Factors of 39849 = [1, 3, 13283, 39849]
# 57322 ->Factors of 57322 = [1, 2, 28661, 57322]
# 94066 ->Factors of 94066 = [1, 2, 3, 6, 15644, 31288, 47033, 94066]
# 61001 ->Factors of 61001 = [1, 61001]
# Received responses for batch 394 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 395 of 400
# # of prompts:  25 # of responses:  25
# 86521 ->Factors of 86521 = [1, 3, 7, 11, 13, 21, 33, 39, 63, 91, 137, 221, 399, 663, 1237, 2473, 3541, 6103, 12207, 24414, 40464, 86521]
# 25278 ->Factors of 25278 = [1, 2, 3, 6, 4213, 8426, 12639, 25278]
# 44491 ->Factors of 44491 = [1, 44491]
# 42729 ->Factors of 42729 = [1, 3, 9, 11, 27, 33, 129, 323, 1281, 3843, 4729, 14187, 42729]
# 259 ->Factors of 259 = [1, 259]
# 85243 ->Factors of 85243 = [1, 85243]
# 15342 ->Factors of 15342 = [1, 2, 3, 6, 7, 14, 21, 42, 363, 726, 1093, 2186, 5113, 15342]
# 29453 ->Factors of 29453 = [1, 29453]
# 12011 ->Factors of 12011 = [1, 12011]
# 99455 ->Factors of 99455 = [1, 5, 19891, 99455]
# 75989 ->Factors of 75989 = [1, 75989]
# 25222 ->Factors of 25222 = [1, 2, 12611, 25222]
# 76697 ->Factors of 76697 = [1, 76697]
# 21859 ->Factors of 21859 = [1, 21859]
# 50454 ->Factors of 50454 = [1, 2, 3, 6, 8409, 16818, 25227, 50454]
# 68543 ->Factors of 68543 = [1, 68543]
# 29250 ->Factors of 29250 = [1, 2, 3, 5, 6, 9, 10, 15, 18, 30, 45, 50, 90, 150, 195, 325, 585, 975, 1625, 2925, 4875, 9750, 14625, 29250]
# 23753 ->Factors of 23753 = [1, 23753]
# 13721 ->Factors of 13721 = [1, 13721]
# 50045 ->Factors of 50045 = [1, 5, 10009, 50045]
# 80221 ->Factors of 80221 = [1, 80221]
# 76160 ->Factors of 76160 = [1, 2, 4, 5, 8, 10, 16, 20, 32, 40, 64, 80, 960, 1280, 1920, 3840, 7680, 15360, 19200, 38400, 76160]
# 75029 ->Factors of 75029 = [1, 75029]
# 77477 ->Factors of 77477 = [1, 77477]
# 40464 ->Factors of 40464 = [1, 2, 3, 4, 6, 8, 12, 16, 24, 32, 48, 64, 96, 128, 192, 256, 384, 512, 768, 1024, 1280, 1536, 2048, 2560, 3072, 4096, 5120, 6144, 8192, 10240, 12288, 16384, 20480, 40464]
# Received responses for batch 395 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 396 of 400
# # of prompts:  25 # of responses:  25
# 66301 ->Factors of 66301 = [1, 66301]
# 61874 ->Factors of 61874 = [1, 2, 30937, 61874]
# 99567 ->Factors of 99567 = [1, 3, 9, 11063, 33189, 99567]
# 66881 ->Factors of 66881 = [1, 66881]
# 27261 ->Factors of 27261 = [1, 3, 9087, 27261]
# 69222 ->Factors of 69222 = [1, 2, 3, 6, 11537, 23074, 34611, 69222]
# 6829 ->Factors of 6829 = [1, 13, 525, 6829]
# 75188 ->Factors of 75188 = [1, 2, 23, 46, 1633, 3266, 37594, 75188]
# 77905 ->Factors of 77905 = [1, 5, 15581, 77905]
# 91969 ->Factors of 91969 = [1, 17, 5410, 91969]
# 72103 ->Factors of 72103 = [1, 7, 10315, 72103]
# 66533 ->Factors of 66533 = [1, 66533]
# 45763 ->Factors of 45763 = [1, 11, 4160, 45763]
# 93809 ->Factors of 93809 = [1, 7, 13401, 93809]
# 6954 ->Factors of 6954 = [1, 2, 3, 6, 1159, 2318, 3477, 6954]
# 98135 ->Factors of 98135 = [1, 5, 19627, 98135]
# 64013 ->Factors of 64013 = [1, 64013]
# 96323 ->Factors of 96323 = [1, 7, 13761, 96323]
# 12388 ->Factors of 12388 = [1, 2, 29, 61, 203, 427, 6194, 12388]
# 58767 ->Factors of 58767 = [1, 3, 19589, 58767]
# 44787 ->Factors of 44787 = [1, 44787]
# 92031 ->Factors of 92031 = [1, 3, 30677, 92031]
# 36278 ->Factors of 36278 = [1, 2, 18139, 36278]
# 21803 ->Factors of 21803 = [1, 23, 948, 21803]
# 22396 ->Factors of 22396 = [1, 2, 4, 5649, 11198, 22396]
# Received responses for batch 396 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 397 of 400
# # of prompts:  25 # of responses:  25
# 49091 ->Factors of 49091 = [1, 49091]
# 82141 ->Factors of 82141 = [1, 82141]
# 26203 ->Factors of 26203 = [1, 26203]
# 70019 ->Factors of 70019 = [1, 70019]
# 6803 ->Factors of 6803 = [1, 6803]
# 25251 ->Factors of 25251 = [1, 25251]
# 84598 ->Factors of 84598 = [1, 2, 42299, 84598]
# 80862 ->Factors of 80862 = [1, 2, 3, 6, 13477, 26954, 40431, 80862]
# 55829 ->Factors of 55829 = [1, 55829]
# 51834 ->Factors of 51834 = [1, 2, 3, 6, 8639, 17278, 25917, 51834]
# 54891 ->Factors of 54891 = [1, 3, 18297, 54891]
# 43591 ->Factors of 43591 = [1, 43591]
# 11093 ->Factors of 11093 = [1, 11093]
# 22481 ->Factors of 22481 = [1, 22481]
# 24326 ->Factors of 24326 = [1, 2, 12163, 24326]
# 59647 ->Factors of 59647 = [1, 59647]
# 63703 ->Factors of 63703 = [1, 63703]
# 49331 ->Factors of 49331 = [1, 49331]
# 77983 ->Factors of 77983 = [1, 77983]
# 3482 ->Factors of 3482 = [1, 2, 1741, 3482]
# 49739 ->Factors of 49739 = [1, 49739]
# 56768 ->Factors of 56768 = [1, 2, 4, 8, 7096, 14192, 28384, 56768]
# 1091 ->Factors of 1091 = [1, 1091]
# 21080 ->Factors of 21080 = [1, 2, 4, 5, 8, 10, 16, 20, 40, 80, 2635, 5270, 10540, 21080]
# 62594 ->Factors of 62594 = [1, 2, 31297, 62594]
# Received responses for batch 397 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 398 of 400
# # of prompts:  25 # of responses:  25
# 69029 ->Factors of 69029 = [1, 69029]
# 59197 ->Factors of 59197 = [1, 59197]
# 30178 ->Factors of 30178 = [1, 2, 15089, 30178]
# 95009 ->Factors of 95009 = [1, 95009]
# 31249 ->Factors of 31249 = [1, 31249]
# 95327 ->Factors of 95327 = [1, 95327]
# 48353 ->Factors of 48353 = [1, 48353]
# 91892 ->Factors of 91892 = [1, 2, 45946, 91892]
# 63004 ->Factors of 63004 = [1, 2, 4, 15751, 31502, 63004]
# 24443 ->Factors of 24443 = [1, 23, 1063, 24443]
# 64491 ->Factors of 64491 = [1, 3, 7, 9, 21, 63, 1023, 3069, 7213, 21431, 64491]
# 26095 ->Factors of 26095 = [1, 5, 5219, 26095]
# 66041 ->Factors of 66041 = [1, 66041]
# 33921 ->Factors of 33921 = [1, 3, 11307, 33921]
# 46327 ->Factors of 46327 = [1, 46327]
# 269 ->Factors of 269 = [1, 269]
# 87251 ->Factors of 87251 = [1, 87251]
# 3361 ->Factors of 3361 = [1, 3361]
# 36929 ->Factors of 36929 = [1, 36929]
# 79333 ->Factors of 79333 = [1, 79333]
# 2393 ->Factors of 2393 = [1, 2393]
# 51481 ->Factors of 51481 = [1, 51481]
# 56521 ->Factors of 56521 = [1, 56521]
# 3545 ->Factors of 3545 = [1, 5, 709, 3545]
# 83477 ->Factors of 83477 = [1, 83477]
# Received responses for batch 398 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 399 of 400
# # of prompts:  25 # of responses:  25
# 67561 ->Factors of 67561 = [1, 67561]
# 82457 ->Factors of 82457 = [1, 82457]
# 49435 ->Factors of 49435 = [1, 5, 9887, 49435]
# 93253 ->Factors of 93253 = [1, 93253]
# 79581 ->Factors of 79581 = [1, 3, 26527, 79581]
# 12153 ->Factors of 12153 = [1, 3, 9, 1341, 4051, 12153]
# 43991 ->Factors of 43991 = [1, 43991]
# 71257 ->Factors of 71257 = [1, 71257]
# 59670 ->Factors of 59670 = [1, 2, 3, 5, 6, 7, 10, 14, 15, 21, 30, 35, 42, 70, 84, 105, 140, 210, 280, 420, 560, 840, 1120, 1680, 2240, 29835, 59670]
# 94641 ->Factors of 94641 = [1, 3, 31547, 94641]
# 18621 ->Factors of 18621 = [1, 3, 6173, 18621]
# 94583 ->Factors of 94583 = [1, 94583]
# 90546 ->Factors of 90546 = [1, 2, 3, 6, 9, 18, 5031, 10062, 15093, 30186, 90546]
# 22637 ->Factors of 22637 = [1, 22637]
# 7213 ->Factors of 7213 = [1, 7, 1031, 7213]
# 71401 ->Factors of 71401 = [1, 71401]
# 98773 ->Factors of 98773 = [1, 98773]
# 52837 ->Factors of 52837 = [1, 52837]
# 24197 ->Factors of 24197 = [1, 24197]
# 51015 ->Factors of 51015 = [1, 3, 5, 15, 3401, 17005, 51015]
# 66591 ->Factors of 66591 = [1, 3, 22197, 66591]
# 4957 ->Factors of 4957 = [1, 4957]
# 26251 ->Factors of 26251 = [1, 26251]
# 56813 ->Factors of 56813 = [1, 56813]
# 47984 ->Factors of 47984 = [1, 2, 4, 8, 5998, 11996, 23992, 47984]
# Received responses for batch 399 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sending batch 400 of 400
# # of prompts:  25 # of responses:  25
# 88746 ->Factors of 88746 = [1, 2, 3, 6, 14791, 29582, 44373, 88746]
# 81929 ->Factors of 81929 = [1, 81929]
# 31943 ->Factors of 31943 = [1, 31943]
# 52665 ->Factors of 52665 = [1, 3, 5, 17555, 52665]
# 86117 ->Factors of 86117 = [1, 86117]
# 45984 ->Factors of 45984 = [1, 2, 3, 4, 6, 8, 12, 16, 24, 32, 48, 96, 1919, 3838, 5757, 11514, 23028, 45984]
# 80363 ->Factors of 80363 = [1, 80363]
# 17185 ->Factors of 17185 = [1, 5, 17, 1011, 3437, 17185]
# 53420 ->Factors of 53420 = [1, 2, 4, 5, 10, 20, 2671, 5342, 10684, 26710, 53420]
# 44449 ->Factors of 44449 = [1, 7, 6349, 44449]
# 89527 ->Factors of 89527 = [1, 89527]
# 49871 ->Factors of 49871 = [1, 49871]
# 44029 ->Factors of 44029 = [1, 44029]
# 1567 ->Factors of 1567 = [1, 1567]
# 79429 ->Factors of 79429 = [1, 79429]
# 41250 ->Factors of 41250 = [1, 2, 3, 5, 6, 10, 15, 30, 1375, 2750, 4125, 8250, 12375, 20625, 41250]
# 28933 ->Factors of 28933 = [1, 28933]
# 78113 ->Factors of 78113 = [1, 78113]
# 12239 ->Factors of 12239 = [1, 12239]
# 87547 ->Factors of 87547 = [1, 87547]
# 26339 ->Factors of 26339 = [1, 26339]
# 33533 ->Factors of 33533 = [1, 33533]
# 7321 ->Factors of 7321 = [1, 7, 1046, 7321]
# 28349 ->Factors of 28349 = [1, 28349]
# 87629 ->Factors of 87629 = [1, 87629]
# Received responses for batch 400 of 400
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Responses saved to gemini_response/factors_response.txt
